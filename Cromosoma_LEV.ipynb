# %%
import pandas as pd
docentes = pd.read_csv("docentes.csv")

# %% [markdown]
# ### 🧹 1. Unificación de docentes de Inglés
#
# Este bloque estandariza los docentes que dictan Inglés a partir de 7mo EGB. Se eliminan los registros de las docentes "ELIZABETH PUGA" y "SIMONE AYALA", y se reemplaza a "DAISY HERRERA" por el identificador genérico `"INGLES ESPECIAL"`.
#
# Este paso facilita la asignación conjunta de horarios en niveles superiores donde el docente de inglés es compartido entre paralelos.

# %%
#Unificar docentes de inglés a partir de 7mo EGB
docentes=docentes.drop(docentes[docentes['Nombres']=='ELIZABETH PUGA'].index)
docentes=docentes.drop(docentes[docentes['Nombres']=='SIMONE AYALA'].index)
docentes["Nombres"] = docentes["Nombres"].replace("DAISY HERRERA", "INGLES ESPECIAL")

# %% [markdown]
# ### 🏃 2. Unificación de docentes de Educación Física
#
# De forma similar, se agrupan los docentes de Educación Física a partir de 3ro EGB. Se eliminan "CARLOS MORALES" e "IVÁN MALDONADO" y se reemplaza a "NANCY LINCANGO" por `"EF ESPECIAL"`.
#
# Esto permite manejar la materia como una asignación especial compartida, lo cual es fundamental para las restricciones del modelo de horarios.

# %%
#Unificar docentes de Educación Física a partir de 3ro EGB
docentes=docentes.drop(docentes[docentes['Nombres']=='CARLOS MORALES'].index)
docentes=docentes.drop(docentes[docentes['Nombres']=='IVÁN MALDONADO'].index)
docentes["Nombres"] = docentes["Nombres"].replace("NANCY LINCANGO", "EF ESPECIAL")

docentes.reset_index()

# %% [markdown]
# ### 🧹 3. Normalización y expansión de códigos de asignación docente
#
# En este bloque se transforma la columna `Codigo` del DataFrame `docentes`, que originalmente contiene múltiples códigos por celda, en un formato estructurado con una fila por cada asignación.
#
# #### 🔄 Proceso aplicado:
# 1. **Copia del DataFrame:** Se trabaja sobre una copia (`df`) para mantener intacto el original.
# 2. **Limpieza de caracteres:** Se eliminan `{}`, `'` y otros símbolos innecesarios con una expresión regular.
# 3. **Separación y expansión:**
#    - Se usa `.str.split(", ")` para dividir los códigos.
#    - Se aplica `.explode()` para expandir los valores en filas separadas.
#
# #### 📊 Resultado:
# Cada fila del nuevo DataFrame `docentes` contiene una única asignación `{docente ↔ código}`.
#
# Esto facilita la construcción de diccionarios rápidos y consultas eficientes para el algoritmo de generación de horarios.

# %%
df=docentes.copy()
# Limpiar la columna 'Codigo': eliminar llaves y comillas simples
df["Codigo"] = df["Codigo"].str.replace(r"[{}']", "", regex=True)

# Separar los códigos por coma y expandir en filas individuales
docentes = df.assign(Codigo=df["Codigo"].str.split(", ")).explode("Codigo")

docentes.head(20)
# Out:
#    index             Nombres            Cargo      Materia     Codigo
# 0      0          MALENA OÑA  Tiempo completo     LENGUAJE   LEN_1EGB
# 1      1        ALISON PLAZA  Tiempo completo     LECTORES   LEC_1EGB
# 1      1        ALISON PLAZA  Tiempo completo     LECTORES   LEC_2EGB
# 1      1        ALISON PLAZA  Tiempo completo     LECTORES   LEC_3EGB
# 2      2         SOFÍA YÉPEZ  Tiempo completo     LENGUAJE   LEN_3EGB
# 2      2         SOFÍA YÉPEZ  Tiempo completo     LENGUAJE   LEN_2EGB
# 3      3       ROSITA ALBUJA  Tiempo completo     LENGUAJE   LEN_5EGB
# 3      3       ROSITA ALBUJA  Tiempo completo     LENGUAJE   LEN_4EGB
# 4      4       NARCISA MUÑOZ  Tiempo completo     LENGUAJE   LEN_6EGB
# 4      4       NARCISA MUÑOZ  Tiempo completo     LENGUAJE   LEN_7EGB
# 5      5       ANDRÉS OLMEDO  Tiempo completo     LENGUAJE  LEN_10EGB
# 5      5       ANDRÉS OLMEDO  Tiempo completo     LENGUAJE   LEN_1BGU
# 5      5       ANDRÉS OLMEDO  Tiempo completo     LENGUAJE   LEN_3BGU
# 5      5       ANDRÉS OLMEDO  Tiempo completo     LENGUAJE   LEN_8EGB
# 5      5       ANDRÉS OLMEDO  Tiempo completo     LENGUAJE   LEN_9EGB
# 5      5       ANDRÉS OLMEDO  Tiempo completo     LENGUAJE   LEN_2BGU
# 6      6  FERNANDA CAÑIZARES  Tiempo completo  PENSAMIENTO   PEN_1EGB
# 7      7      XIMENA AGUIRRE    Subdirector/a  PENSAMIENTO   PEN_3EGB
# 7      7      XIMENA AGUIRRE    Subdirector/a  PENSAMIENTO   PEN_4EGB
# 8      8        RUTH PORTERO    Subdirector/a  PENSAMIENTO   PEN_5EGB

# %% [markdown]
# ### 🧠 4. Construcción del diccionario de asignación docente (`dic_profesores`)
#
# Este bloque itera sobre cada fila del DataFrame `docentes` y construye un diccionario llamado `dic_profesores` con el siguiente mapeo:
#
# ```python
# { código_materia → nombre_docente }

# %%
df=docentes.copy()
# Carga del archivo CSV
df = docentes

# Identifica las columnas
col_codigo = 'Codigo'
col_profesor = 'Nombres'

# Diccionario resultado
dic_profesores = {}

for _, row in df.iterrows():
    raw = row[col_codigo]
    if pd.isna(raw):
        continue

    # Convertimos a cadena y eliminamos espacios exteriores
    s = str(raw).strip()

    # Si empieza por '{' o '[' acabamos quitando delimitadores
    if s.startswith('{') and s.endswith('}'):
        # Quitamos las llaves
        s = s[1:-1]
    elif s.startswith('[') and s.endswith(']'):
        # Quitamos los corchetes
        s = s[1:-1]

    # Ahora s es algo como "'LEC_1EGB', 'LEC_3EGB', 'LEC_2EGB'"
    # Partimos por comas y limpiamos comillas
    codes = []
    for part in s.split(','):
        part = part.strip().strip("'\"")  # quita comillas simples o dobles
        if part:
            codes.append(part)

    # Asociamos cada código con el profesor
    for code in codes:
        dic_profesores[code] = row[col_profesor]

# Ejemplo de uso:
for ejemplo in ['LEN_3EGB', 'PEN_10EGB', 'EST_10EGB']:
    prof = dic_profesores.get(ejemplo, 'No encontrado')
    print(f"Profesor de {ejemplo}: {prof}")
# Out:
# Profesor de LEN_3EGB: SOFÍA YÉPEZ
# Profesor de PEN_10EGB: MIREYA BRITO
# Profesor de EST_10EGB: JONATHAN CASTRO

# %% [markdown]
# ### 🧑‍🏫 5. Función para obtener el docente a partir del código de materia
#
# La función `obtener_docente_por_materia_codigo(...)` permite consultar qué docente imparte una determinada materia, usando el diccionario previamente construido `dic_profesores`.
#
# #### 📌 Lógica:
# - Recibe como parámetro el código completo de la materia, por ejemplo: `"MAT_3BGU"`, `"LEN_1EGB"`, `"EF_6EGB"`.
# - Busca en `dic_profesores` y retorna el nombre del docente correspondiente.
# - Si el código no existe en el diccionario, retorna `None`.
#
# #### ✅ Aplicaciones:
# Esta función es útil para:
# - Asignar automáticamente docentes durante la generación de cromosomas.
# - Validar asignaciones en un horario generado.
# - Construir bloques LaTeX completos a partir de información parcial.

# %%
# Obtener docente que imparte la materia
def obtener_docente_por_materia_codigo(codigo_materia):
    return dic_profesores.get(codigo_materia, None)

# %% [markdown]
# ### 🧬 6. Reconstrucción de cromosoma global a partir de archivos `.txt`
#
# Este bloque permite combinar múltiples horarios individuales (guardados como archivos `.txt`) en un solo cromosoma completo que sigue la estructura esperada por el algoritmo genético.
#
# #### 📌 Componentes clave:
#
# 1. **Orden de niveles y días:**
#    Se define el orden deseado para garantizar una estructura coherente al ordenar el cromosoma.
#
# 2. **`leer_txt_como_tuplas(...)`:**
#    Función que lee un archivo `.txt` y retorna su contenido como lista de tuplas `(nivel, aula, día, hora, código_materia)`.
#
# 3. **`ordenar_cromosoma(...)`:**
#    Ordena el cromosoma combinando criterios jerárquicos: nivel → aula → día → hora.
#
# 4. **Listado de archivos:**
#    Se especifican los archivos `.txt` que contienen los horarios individuales por paralelo.
#
# 5. **`reconstruir_cromosoma_desde_txt(...)`:**
#    Carga todos los archivos, asigna automáticamente el docente a partir del código de materia usando `obtener_docente_por_materia_codigo`, y genera el cromosoma completo listo para ser evaluado o graficado.
#
# #### ✅ Resultado:
# Una lista estructurada de genes de la forma:

# %%
import os

# === 1. ORDEN DE NIVELES Y DÍAS PARA POSTERIOR ORDENAMIENTO ===
orden_niveles = ['1EGB', '2EGB', '3EGB', '4EGB', '5EGB', '6EGB', '7EGB', '8EGB', '9EGB', '10EGB', '1BGU', '2BGU', '3BGU']
orden_dias = ['Lunes', 'Martes', 'Miércoles', 'Jueves', 'Viernes']

# === 2. FUNCIÓN PARA LEER TXT COMO LISTA DE TUPLAS ===
def leer_txt_como_tuplas(filepath):
    with open(filepath, "r", encoding="utf-8") as f:
        lines = f.readlines()
    return [eval(line.strip()) for line in lines if line.strip()]

# === 3. FUNCIÓN PARA ORDENAR CROMOSOMA (IGUAL A LA TUYA) ===
def ordenar_cromosoma(cromosoma):
    return sorted(
        cromosoma,
        key=lambda g: (
            orden_niveles.index(g[0]),
            g[1],
            orden_dias.index(g[2]),
            g[3]
        )
    )
# === 5. NOMBRES DE ARCHIVOS A INCLUIR ===
archivos_txt = [
    '1EGB_Ejemplares.txt', '1EGB_Entusiastas.txt', '1EGB_Estudiosos.txt', '1EGB_Exitosos.txt',
    '2BGU_Honestos.txt', '2BGU_Justos.txt', '2BGU_Proactivos.txt', '2EGB_Afectuosos.txt',
    '2EGB_Amables.txt', '2EGB_Amigables.txt', '2EGB_Amistosos.txt', '3BGU_Empáticos.txt',
    '3BGU_Solidarios.txt', '3BGU_Vanguardistas.txt', '3EGB_Colaboradores.txt', '3EGB_Conciliadores.txt',
    '3EGB_Cordiales.txt', '3EGB_Creativos.txt', '4EGB_Optimistas.txt', '4EGB_Ordenados.txt',
    '4EGB_Organizados.txt', '4EGB_Originales.txt', '5EGB_Admirables.txt', '5EGB_Afectivos.txt',
    '5EGB_Aplicados.txt', '5EGB_Atentos.txt', '6EGB_Ecuanimes.txt', '6EGB_Emprendedores.txt',
    '6EGB_Excelentes.txt', '6EGB_Expresivos.txt', '7EGB_Reflexivos.txt', '7EGB_Resilientes.txt',
    '7EGB_Respetuosos.txt', '7EGB_Responsables.txt', '8EGB_Decididos.txt', '8EGB_Diligentes.txt',
    '8EGB_Dinámicos.txt', '8EGB_Disciplinados.txt', '9EGB_Altruistas.txt', '9EGB_Asertivos.txt',
    '9EGB_Audaces.txt', '9EGB_Auténticos.txt', '10EGB_Pacifistas.txt', '10EGB_Perspicaces.txt',
    '10EGB_Positivos.txt', '1BGU_Confiables.txt', '1BGU_Íntegros.txt', '1BGU_Leales.txt'
]

# === 6. FUNCIÓN PARA GENERAR CROMOSOMA DESDE LOS TXT ===
def reconstruir_cromosoma_desde_txt():
    cromosoma = []

    for nombre_archivo in archivos_txt:
        if not os.path.exists(nombre_archivo):
            print(f"[!] Archivo no encontrado: {nombre_archivo}")
            continue

        datos = leer_txt_como_tuplas(nombre_archivo)
        for fila in datos:
            nivel, aula, dia, hora, codigo_materia = fila
            docente = obtener_docente_por_materia_codigo(codigo_materia)
            cromosoma.append((nivel, aula, dia, hora, codigo_materia, docente))

    return ordenar_cromosoma(cromosoma)

cromosoma = reconstruir_cromosoma_desde_txt()

# %% [markdown]
# ### 🔍 7. Visualización y verificación del cromosoma reconstruido
#
# Este bloque imprime información básica del cromosoma generado en el paso anterior.
#
# #### 📌 Acciones realizadas:
# - Se muestra el número total de genes generados, lo que equivale al total de bloques horarios asignados.
# - Se imprimen todos los genes del cromosoma para inspeccionar manualmente su contenido.
#
# Cada gen tiene la estructura:
# ```python
# (nivel, aula, día, hora, código_materia, docente)

# %%
print(f"Total de genes generados: {len(cromosoma)}")
# Mostrar los primeros 5 genes
for gen in cromosoma[:]:
    print(gen)
# Out:
# Total de genes generados: 2832
# ('1EGB', 'Ejemplares', 'Lunes', 1, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Ejemplares', 'Lunes', 2, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Ejemplares', 'Lunes', 3, 'PEN_1EGB', 'FERNANDA CAÑIZARES')
# ('1EGB', 'Ejemplares', 'Lunes', 4, 'PEN_1EGB', 'FERNANDA CAÑIZARES')
# ('1EGB', 'Ejemplares', 'Lunes', 6, 'DES_1EGB', 'ANDREA MACIAS')
# ('1EGB', 'Ejemplares', 'Lunes', 7, 'EDU_1EGB', 'EF ESPECIAL')
# ('1EGB', 'Ejemplares', 'Lunes', 8, 'EDU_1EGB', 'EF ESPECIAL')
# ('1EGB', 'Ejemplares', 'Lunes', 9, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Ejemplares', 'Lunes', 10, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Ejemplares', 'Lunes', 13, 'DAN_1EGB', 'PAOLA LÓPEZ')
# ('1EGB', 'Ejemplares', 'Lunes', 14, 'MUS_1EGB', 'LUIS JÁCOME')
# ('1EGB', 'Ejemplares', 'Martes', 1, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Ejemplares', 'Martes', 2, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Ejemplares', 'Martes', 3, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Ejemplares', 'Martes', 4, 'EST_1EGB', 'SANTIAGO CALLE')
# ('1EGB', 'Ejemplares', 'Martes', 6, 'EXT_1EGB', 'MARIEL RODRIGUEZ')
# ('1EGB', 'Ejemplares', 'Martes', 7, 'COM_1EGB', 'ERIKA CAIZATOA')
# ('1EGB', 'Ejemplares', 'Martes', 8, 'DER_1EGB', 'CORALÍA CÓRDOVA')
# ('1EGB', 'Ejemplares', 'Martes', 9, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Ejemplares', 'Martes', 10, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Ejemplares', 'Martes', 13, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Ejemplares', 'Martes', 14, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Ejemplares', 'Martes', 15, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Ejemplares', 'Martes', 16, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Ejemplares', 'Miércoles', 3, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Ejemplares', 'Miércoles', 4, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Ejemplares', 'Miércoles', 6, 'LEC_1EGB', 'ALISON PLAZA')
# ('1EGB', 'Ejemplares', 'Miércoles', 7, 'EST_1EGB', 'SANTIAGO CALLE')
# ('1EGB', 'Ejemplares', 'Miércoles', 8, 'EST_1EGB', 'SANTIAGO CALLE')
# ('1EGB', 'Ejemplares', 'Miércoles', 9, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Ejemplares', 'Miércoles', 10, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Ejemplares', 'Miércoles', 13, 'ROB_1EGB', 'JENNY CHICAIZA')
# ('1EGB', 'Ejemplares', 'Miércoles', 14, 'ROB_1EGB', 'JENNY CHICAIZA')
# ('1EGB', 'Ejemplares', 'Miércoles', 15, 'ESP_1EGB', 'MERY VENEGAS')
# ('1EGB', 'Ejemplares', 'Miércoles', 16, 'ESP_1EGB', 'MERY VENEGAS')
# ('1EGB', 'Ejemplares', 'Jueves', 1, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Ejemplares', 'Jueves', 2, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Ejemplares', 'Jueves', 3, 'DES_1EGB', 'ANDREA MACIAS')
# ('1EGB', 'Ejemplares', 'Jueves', 4, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Ejemplares', 'Jueves', 6, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Ejemplares', 'Jueves', 7, 'LEC_1EGB', 'ALISON PLAZA')
# ('1EGB', 'Ejemplares', 'Jueves', 8, 'LEC_1EGB', 'ALISON PLAZA')
# ('1EGB', 'Ejemplares', 'Jueves', 9, 'SPE_1EGB', 'CHRISTIAN SOLANO')
# ('1EGB', 'Ejemplares', 'Jueves', 10, 'INV_1EGB', 'KARLA LAZCANO')
# ('1EGB', 'Ejemplares', 'Jueves', 15, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Ejemplares', 'Jueves', 16, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Ejemplares', 'Viernes', 1, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Ejemplares', 'Viernes', 2, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Ejemplares', 'Viernes', 3, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Ejemplares', 'Viernes', 4, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Ejemplares', 'Viernes', 6, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Ejemplares', 'Viernes', 7, 'ECO_1EGB', 'MARJURIE JÁCOME')
# ('1EGB', 'Ejemplares', 'Viernes', 8, 'SAL_1EGB', 'VANESSA ESPÍN')
# ('1EGB', 'Ejemplares', 'Viernes', 9, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Ejemplares', 'Viernes', 10, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Ejemplares', 'Viernes', 13, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Ejemplares', 'Viernes', 14, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Ejemplares', 'Viernes', 15, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Ejemplares', 'Viernes', 16, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Entusiastas', 'Lunes', 1, 'EXT_1EGB', 'MARIEL RODRIGUEZ')
# ('1EGB', 'Entusiastas', 'Lunes', 2, 'EDU_1EGB', 'EF ESPECIAL')
# ('1EGB', 'Entusiastas', 'Lunes', 3, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Entusiastas', 'Lunes', 4, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Entusiastas', 'Lunes', 6, 'ROB_1EGB', 'JENNY CHICAIZA')
# ('1EGB', 'Entusiastas', 'Lunes', 7, 'ROB_1EGB', 'JENNY CHICAIZA')
# ('1EGB', 'Entusiastas', 'Lunes', 8, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Entusiastas', 'Lunes', 9, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Entusiastas', 'Lunes', 10, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Entusiastas', 'Lunes', 13, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Entusiastas', 'Lunes', 14, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Entusiastas', 'Martes', 1, 'SAL_1EGB', 'VANESSA ESPÍN')
# ('1EGB', 'Entusiastas', 'Martes', 2, 'ECO_1EGB', 'MARJURIE JÁCOME')
# ('1EGB', 'Entusiastas', 'Martes', 3, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Entusiastas', 'Martes', 4, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Entusiastas', 'Martes', 6, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Entusiastas', 'Martes', 7, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Entusiastas', 'Martes', 8, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Entusiastas', 'Martes', 9, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Entusiastas', 'Martes', 10, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Entusiastas', 'Martes', 13, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Entusiastas', 'Martes', 14, 'DES_1EGB', 'ANDREA MACIAS')
# ('1EGB', 'Entusiastas', 'Martes', 15, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Entusiastas', 'Martes', 16, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Entusiastas', 'Miércoles', 3, 'EST_1EGB', 'SANTIAGO CALLE')
# ('1EGB', 'Entusiastas', 'Miércoles', 4, 'EST_1EGB', 'SANTIAGO CALLE')
# ('1EGB', 'Entusiastas', 'Miércoles', 6, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Entusiastas', 'Miércoles', 7, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Entusiastas', 'Miércoles', 8, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Entusiastas', 'Miércoles', 9, 'COM_1EGB', 'ERIKA CAIZATOA')
# ('1EGB', 'Entusiastas', 'Miércoles', 10, 'DER_1EGB', 'CORALÍA CÓRDOVA')
# ('1EGB', 'Entusiastas', 'Miércoles', 13, 'LEC_1EGB', 'ALISON PLAZA')
# ('1EGB', 'Entusiastas', 'Miércoles', 14, 'LEC_1EGB', 'ALISON PLAZA')
# ('1EGB', 'Entusiastas', 'Miércoles', 15, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Entusiastas', 'Miércoles', 16, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Entusiastas', 'Jueves', 1, 'LEC_1EGB', 'ALISON PLAZA')
# ('1EGB', 'Entusiastas', 'Jueves', 2, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Entusiastas', 'Jueves', 3, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Entusiastas', 'Jueves', 4, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Entusiastas', 'Jueves', 6, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Entusiastas', 'Jueves', 7, 'DAN_1EGB', 'PAOLA LÓPEZ')
# ('1EGB', 'Entusiastas', 'Jueves', 8, 'MUS_1EGB', 'LUIS JÁCOME')
# ('1EGB', 'Entusiastas', 'Jueves', 9, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Entusiastas', 'Jueves', 10, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Entusiastas', 'Jueves', 15, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Entusiastas', 'Jueves', 16, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Entusiastas', 'Viernes', 1, 'EDU_1EGB', 'EF ESPECIAL')
# ('1EGB', 'Entusiastas', 'Viernes', 2, 'EDU_1EGB', 'EF ESPECIAL')
# ('1EGB', 'Entusiastas', 'Viernes', 3, 'PEN_1EGB', 'FERNANDA CAÑIZARES')
# ('1EGB', 'Entusiastas', 'Viernes', 4, 'PEN_1EGB', 'FERNANDA CAÑIZARES')
# ('1EGB', 'Entusiastas', 'Viernes', 6, 'DES_1EGB', 'ANDREA MACIAS')
# ('1EGB', 'Entusiastas', 'Viernes', 7, 'INV_1EGB', 'KARLA LAZCANO')
# ('1EGB', 'Entusiastas', 'Viernes', 8, 'SPE_1EGB', 'CHRISTIAN SOLANO')
# ('1EGB', 'Entusiastas', 'Viernes', 9, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Entusiastas', 'Viernes', 10, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Entusiastas', 'Viernes', 13, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Entusiastas', 'Viernes', 14, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Entusiastas', 'Viernes', 15, 'ESP_1EGB', 'MERY VENEGAS')
# ('1EGB', 'Entusiastas', 'Viernes', 16, 'ESP_1EGB', 'MERY VENEGAS')
# ('1EGB', 'Estudiosos', 'Lunes', 1, 'PEN_1EGB', 'FERNANDA CAÑIZARES')
# ('1EGB', 'Estudiosos', 'Lunes', 2, 'PEN_1EGB', 'FERNANDA CAÑIZARES')
# ('1EGB', 'Estudiosos', 'Lunes', 3, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Estudiosos', 'Lunes', 4, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Estudiosos', 'Lunes', 6, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Estudiosos', 'Lunes', 7, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Estudiosos', 'Lunes', 8, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Estudiosos', 'Lunes', 9, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Estudiosos', 'Lunes', 10, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Estudiosos', 'Lunes', 13, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Estudiosos', 'Lunes', 14, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Estudiosos', 'Martes', 1, 'ECO_1EGB', 'MARJURIE JÁCOME')
# ('1EGB', 'Estudiosos', 'Martes', 2, 'SAL_1EGB', 'VANESSA ESPÍN')
# ('1EGB', 'Estudiosos', 'Martes', 3, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Estudiosos', 'Martes', 4, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Estudiosos', 'Martes', 6, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Estudiosos', 'Martes', 7, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Estudiosos', 'Martes', 8, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Estudiosos', 'Martes', 9, 'EDU_1EGB', 'EF ESPECIAL')
# ('1EGB', 'Estudiosos', 'Martes', 10, 'EDU_1EGB', 'EF ESPECIAL')
# ('1EGB', 'Estudiosos', 'Martes', 13, 'ROB_1EGB', 'JENNY CHICAIZA')
# ('1EGB', 'Estudiosos', 'Martes', 14, 'LEC_1EGB', 'ALISON PLAZA')
# ('1EGB', 'Estudiosos', 'Martes', 15, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Estudiosos', 'Martes', 16, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Estudiosos', 'Miércoles', 3, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Estudiosos', 'Miércoles', 4, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Estudiosos', 'Miércoles', 6, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Estudiosos', 'Miércoles', 7, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Estudiosos', 'Miércoles', 8, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Estudiosos', 'Miércoles', 9, 'DER_1EGB', 'CORALÍA CÓRDOVA')
# ('1EGB', 'Estudiosos', 'Miércoles', 10, 'COM_1EGB', 'ERIKA CAIZATOA')
# ('1EGB', 'Estudiosos', 'Miércoles', 13, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Estudiosos', 'Miércoles', 14, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Estudiosos', 'Miércoles', 15, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Estudiosos', 'Miércoles', 16, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Estudiosos', 'Jueves', 1, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Estudiosos', 'Jueves', 2, 'EXT_1EGB', 'MARIEL RODRIGUEZ')
# ('1EGB', 'Estudiosos', 'Jueves', 3, 'EDU_1EGB', 'EF ESPECIAL')
# ('1EGB', 'Estudiosos', 'Jueves', 4, 'ESP_1EGB', 'MERY VENEGAS')
# ('1EGB', 'Estudiosos', 'Jueves', 6, 'ESP_1EGB', 'MERY VENEGAS')
# ('1EGB', 'Estudiosos', 'Jueves', 7, 'MUS_1EGB', 'LUIS JÁCOME')
# ('1EGB', 'Estudiosos', 'Jueves', 8, 'DAN_1EGB', 'PAOLA LÓPEZ')
# ('1EGB', 'Estudiosos', 'Jueves', 9, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Estudiosos', 'Jueves', 10, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Estudiosos', 'Jueves', 15, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Estudiosos', 'Jueves', 16, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Estudiosos', 'Viernes', 1, 'DES_1EGB', 'ANDREA MACIAS')
# ('1EGB', 'Estudiosos', 'Viernes', 2, 'DES_1EGB', 'ANDREA MACIAS')
# ('1EGB', 'Estudiosos', 'Viernes', 3, 'LEC_1EGB', 'ALISON PLAZA')
# ('1EGB', 'Estudiosos', 'Viernes', 4, 'LEC_1EGB', 'ALISON PLAZA')
# ('1EGB', 'Estudiosos', 'Viernes', 6, 'ROB_1EGB', 'JENNY CHICAIZA')
# ('1EGB', 'Estudiosos', 'Viernes', 7, 'SPE_1EGB', 'CHRISTIAN SOLANO')
# ('1EGB', 'Estudiosos', 'Viernes', 8, 'INV_1EGB', 'KARLA LAZCANO')
# ('1EGB', 'Estudiosos', 'Viernes', 9, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Estudiosos', 'Viernes', 10, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Estudiosos', 'Viernes', 13, 'EST_1EGB', 'SANTIAGO CALLE')
# ('1EGB', 'Estudiosos', 'Viernes', 14, 'EST_1EGB', 'SANTIAGO CALLE')
# ('1EGB', 'Estudiosos', 'Viernes', 15, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Estudiosos', 'Viernes', 16, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Exitosos', 'Lunes', 1, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Exitosos', 'Lunes', 2, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Exitosos', 'Lunes', 3, 'ESP_1EGB', 'MERY VENEGAS')
# ('1EGB', 'Exitosos', 'Lunes', 4, 'ESP_1EGB', 'MERY VENEGAS')
# ('1EGB', 'Exitosos', 'Lunes', 6, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Exitosos', 'Lunes', 7, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Exitosos', 'Lunes', 8, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Exitosos', 'Lunes', 9, 'EST_1EGB', 'SANTIAGO CALLE')
# ('1EGB', 'Exitosos', 'Lunes', 10, 'EXT_1EGB', 'MARIEL RODRIGUEZ')
# ('1EGB', 'Exitosos', 'Lunes', 13, 'MUS_1EGB', 'LUIS JÁCOME')
# ('1EGB', 'Exitosos', 'Lunes', 14, 'DAN_1EGB', 'PAOLA LÓPEZ')
# ('1EGB', 'Exitosos', 'Martes', 1, 'LEC_1EGB', 'ALISON PLAZA')
# ('1EGB', 'Exitosos', 'Martes', 2, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Exitosos', 'Martes', 3, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Exitosos', 'Martes', 4, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Exitosos', 'Martes', 6, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Exitosos', 'Martes', 7, 'DER_1EGB', 'CORALÍA CÓRDOVA')
# ('1EGB', 'Exitosos', 'Martes', 8, 'COM_1EGB', 'ERIKA CAIZATOA')
# ('1EGB', 'Exitosos', 'Martes', 9, 'ROB_1EGB', 'JENNY CHICAIZA')
# ('1EGB', 'Exitosos', 'Martes', 10, 'ROB_1EGB', 'JENNY CHICAIZA')
# ('1EGB', 'Exitosos', 'Martes', 13, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Exitosos', 'Martes', 14, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Exitosos', 'Martes', 15, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Exitosos', 'Martes', 16, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Exitosos', 'Miércoles', 3, 'LEC_1EGB', 'ALISON PLAZA')
# ('1EGB', 'Exitosos', 'Miércoles', 4, 'LEC_1EGB', 'ALISON PLAZA')
# ('1EGB', 'Exitosos', 'Miércoles', 6, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Exitosos', 'Miércoles', 7, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Exitosos', 'Miércoles', 8, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Exitosos', 'Miércoles', 9, 'EDU_1EGB', 'EF ESPECIAL')
# ('1EGB', 'Exitosos', 'Miércoles', 10, 'EDU_1EGB', 'EF ESPECIAL')
# ('1EGB', 'Exitosos', 'Miércoles', 13, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Exitosos', 'Miércoles', 14, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Exitosos', 'Miércoles', 15, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Exitosos', 'Miércoles', 16, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Exitosos', 'Jueves', 1, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Exitosos', 'Jueves', 2, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Exitosos', 'Jueves', 3, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Exitosos', 'Jueves', 4, 'PEN_1EGB', 'FERNANDA CAÑIZARES')
# ('1EGB', 'Exitosos', 'Jueves', 6, 'PEN_1EGB', 'FERNANDA CAÑIZARES')
# ('1EGB', 'Exitosos', 'Jueves', 7, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Exitosos', 'Jueves', 8, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Exitosos', 'Jueves', 9, 'INV_1EGB', 'KARLA LAZCANO')
# ('1EGB', 'Exitosos', 'Jueves', 10, 'SPE_1EGB', 'CHRISTIAN SOLANO')
# ('1EGB', 'Exitosos', 'Jueves', 15, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Exitosos', 'Jueves', 16, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Exitosos', 'Viernes', 1, 'EST_1EGB', 'SANTIAGO CALLE')
# ('1EGB', 'Exitosos', 'Viernes', 2, 'EST_1EGB', 'SANTIAGO CALLE')
# ('1EGB', 'Exitosos', 'Viernes', 3, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Exitosos', 'Viernes', 4, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Exitosos', 'Viernes', 6, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Exitosos', 'Viernes', 7, 'SAL_1EGB', 'VANESSA ESPÍN')
# ('1EGB', 'Exitosos', 'Viernes', 8, 'ECO_1EGB', 'MARJURIE JÁCOME')
# ('1EGB', 'Exitosos', 'Viernes', 9, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Exitosos', 'Viernes', 10, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Exitosos', 'Viernes', 13, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Exitosos', 'Viernes', 14, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Exitosos', 'Viernes', 15, 'DES_1EGB', 'ANDREA MACIAS')
# ('1EGB', 'Exitosos', 'Viernes', 16, 'DES_1EGB', 'ANDREA MACIAS')
# ('2EGB', 'Afectuosos', 'Lunes', 1, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Afectuosos', 'Lunes', 2, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Afectuosos', 'Lunes', 3, 'PRO_2EGB', 'LUDWIN GUALOTUÑA')
# ('2EGB', 'Afectuosos', 'Lunes', 4, 'PRO_2EGB', 'LUDWIN GUALOTUÑA')
# ('2EGB', 'Afectuosos', 'Lunes', 6, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Afectuosos', 'Lunes', 7, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Afectuosos', 'Lunes', 8, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Afectuosos', 'Lunes', 9, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Afectuosos', 'Lunes', 10, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Afectuosos', 'Lunes', 13, 'DES_2EGB', 'MISHEL SALTOS')
# ('2EGB', 'Afectuosos', 'Lunes', 14, 'DES_2EGB', 'MISHEL SALTOS')
# ('2EGB', 'Afectuosos', 'Lunes', 15, 'CAL_2EGB', 'JAIR CRIOLLO')
# ('2EGB', 'Afectuosos', 'Lunes', 16, 'EXP_2EGB', 'JOSÉ LUIS HERNÁNDEZ')
# ('2EGB', 'Afectuosos', 'Martes', 1, 'ROB_2EGB', 'DAVID CASTRO')
# ('2EGB', 'Afectuosos', 'Martes', 2, 'ROB_2EGB', 'DAVID CASTRO')
# ('2EGB', 'Afectuosos', 'Martes', 3, 'COM_2EGB', 'ERIKA CAIZATOA')
# ('2EGB', 'Afectuosos', 'Martes', 4, 'DER_2EGB', 'CORALÍA CÓRDOVA')
# ('2EGB', 'Afectuosos', 'Martes', 6, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Afectuosos', 'Martes', 7, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Afectuosos', 'Martes', 8, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Afectuosos', 'Martes', 9, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Afectuosos', 'Martes', 10, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Afectuosos', 'Martes', 13, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Afectuosos', 'Martes', 14, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Afectuosos', 'Miércoles', 3, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Afectuosos', 'Miércoles', 4, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Afectuosos', 'Miércoles', 6, 'ECO_2EGB', 'MARJURIE JÁCOME')
# ('2EGB', 'Afectuosos', 'Miércoles', 7, 'SAL_2EGB', 'VANESSA ESPÍN')
# ('2EGB', 'Afectuosos', 'Miércoles', 8, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Afectuosos', 'Miércoles', 9, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Afectuosos', 'Miércoles', 10, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Afectuosos', 'Miércoles', 13, 'SOC_2EGB', 'ALBITA QUILLUPANGUI')
# ('2EGB', 'Afectuosos', 'Miércoles', 14, 'SOC_2EGB', 'ALBITA QUILLUPANGUI')
# ('2EGB', 'Afectuosos', 'Miércoles', 15, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Afectuosos', 'Miércoles', 16, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Afectuosos', 'Jueves', 1, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Afectuosos', 'Jueves', 2, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Afectuosos', 'Jueves', 3, 'SPE_2EGB', 'CHRISTIAN SOLANO')
# ('2EGB', 'Afectuosos', 'Jueves', 4, 'INV_2EGB', 'KARLA LAZCANO')
# ('2EGB', 'Afectuosos', 'Jueves', 6, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Afectuosos', 'Jueves', 7, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Afectuosos', 'Jueves', 8, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Afectuosos', 'Jueves', 9, 'EDU_2EGB', 'EF ESPECIAL')
# ('2EGB', 'Afectuosos', 'Jueves', 10, 'EDU_2EGB', 'EF ESPECIAL')
# ('2EGB', 'Afectuosos', 'Jueves', 13, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Afectuosos', 'Jueves', 14, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Afectuosos', 'Viernes', 1, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Afectuosos', 'Viernes', 2, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Afectuosos', 'Viernes', 3, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Afectuosos', 'Viernes', 4, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Afectuosos', 'Viernes', 6, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Afectuosos', 'Viernes', 7, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Afectuosos', 'Viernes', 8, 'PLA_2EGB', 'LIZ DÍAZ')
# ('2EGB', 'Afectuosos', 'Viernes', 9, 'PLA_2EGB', 'LIZ DÍAZ')
# ('2EGB', 'Afectuosos', 'Viernes', 10, 'SOC_2EGB', 'ALBITA QUILLUPANGUI')
# ('2EGB', 'Afectuosos', 'Viernes', 13, 'MUS_2EGB', 'LUIS JÁCOME')
# ('2EGB', 'Afectuosos', 'Viernes', 14, 'DAN_2EGB', 'PAOLA LÓPEZ')
# ('2EGB', 'Afectuosos', 'Viernes', 15, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Afectuosos', 'Viernes', 16, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amables', 'Lunes', 1, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amables', 'Lunes', 2, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amables', 'Lunes', 3, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Amables', 'Lunes', 4, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Amables', 'Lunes', 6, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Amables', 'Lunes', 7, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amables', 'Lunes', 8, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amables', 'Lunes', 9, 'PRO_2EGB', 'LUDWIN GUALOTUÑA')
# ('2EGB', 'Amables', 'Lunes', 10, 'PRO_2EGB', 'LUDWIN GUALOTUÑA')
# ('2EGB', 'Amables', 'Lunes', 13, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Amables', 'Lunes', 14, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Amables', 'Lunes', 15, 'EXP_2EGB', 'JOSÉ LUIS HERNÁNDEZ')
# ('2EGB', 'Amables', 'Lunes', 16, 'CAL_2EGB', 'JAIR CRIOLLO')
# ('2EGB', 'Amables', 'Martes', 1, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amables', 'Martes', 2, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amables', 'Martes', 3, 'DER_2EGB', 'CORALÍA CÓRDOVA')
# ('2EGB', 'Amables', 'Martes', 4, 'COM_2EGB', 'ERIKA CAIZATOA')
# ('2EGB', 'Amables', 'Martes', 6, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amables', 'Martes', 7, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amables', 'Martes', 8, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amables', 'Martes', 9, 'SOC_2EGB', 'ALBITA QUILLUPANGUI')
# ('2EGB', 'Amables', 'Martes', 10, 'SOC_2EGB', 'ALBITA QUILLUPANGUI')
# ('2EGB', 'Amables', 'Martes', 13, 'DES_2EGB', 'MISHEL SALTOS')
# ('2EGB', 'Amables', 'Martes', 14, 'DES_2EGB', 'MISHEL SALTOS')
# ('2EGB', 'Amables', 'Miércoles', 3, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amables', 'Miércoles', 4, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amables', 'Miércoles', 6, 'SAL_2EGB', 'VANESSA ESPÍN')
# ('2EGB', 'Amables', 'Miércoles', 7, 'ECO_2EGB', 'MARJURIE JÁCOME')
# ('2EGB', 'Amables', 'Miércoles', 8, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amables', 'Miércoles', 9, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amables', 'Miércoles', 10, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amables', 'Miércoles', 13, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Amables', 'Miércoles', 14, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Amables', 'Miércoles', 15, 'ROB_2EGB', 'DAVID CASTRO')
# ('2EGB', 'Amables', 'Miércoles', 16, 'ROB_2EGB', 'DAVID CASTRO')
# ('2EGB', 'Amables', 'Jueves', 1, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amables', 'Jueves', 2, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amables', 'Jueves', 3, 'INV_2EGB', 'KARLA LAZCANO')
# ('2EGB', 'Amables', 'Jueves', 4, 'SPE_2EGB', 'CHRISTIAN SOLANO')
# ('2EGB', 'Amables', 'Jueves', 6, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amables', 'Jueves', 7, 'PLA_2EGB', 'LIZ DÍAZ')
# ('2EGB', 'Amables', 'Jueves', 8, 'PLA_2EGB', 'LIZ DÍAZ')
# ('2EGB', 'Amables', 'Jueves', 9, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Amables', 'Jueves', 10, 'SOC_2EGB', 'ALBITA QUILLUPANGUI')
# ('2EGB', 'Amables', 'Jueves', 13, 'EDU_2EGB', 'EF ESPECIAL')
# ('2EGB', 'Amables', 'Jueves', 14, 'EDU_2EGB', 'EF ESPECIAL')
# ('2EGB', 'Amables', 'Viernes', 1, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amables', 'Viernes', 2, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amables', 'Viernes', 3, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Amables', 'Viernes', 4, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Amables', 'Viernes', 6, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amables', 'Viernes', 7, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amables', 'Viernes', 8, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amables', 'Viernes', 9, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Amables', 'Viernes', 10, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Amables', 'Viernes', 13, 'DAN_2EGB', 'PAOLA LÓPEZ')
# ('2EGB', 'Amables', 'Viernes', 14, 'MUS_2EGB', 'LUIS JÁCOME')
# ('2EGB', 'Amables', 'Viernes', 15, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amables', 'Viernes', 16, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amigables', 'Lunes', 1, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Amigables', 'Lunes', 2, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Amigables', 'Lunes', 3, 'ROB_2EGB', 'DAVID CASTRO')
# ('2EGB', 'Amigables', 'Lunes', 4, 'ROB_2EGB', 'DAVID CASTRO')
# ('2EGB', 'Amigables', 'Lunes', 6, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amigables', 'Lunes', 7, 'DAN_2EGB', 'PAOLA LÓPEZ')
# ('2EGB', 'Amigables', 'Lunes', 8, 'MUS_2EGB', 'LUIS JÁCOME')
# ('2EGB', 'Amigables', 'Lunes', 9, 'PLA_2EGB', 'LIZ DÍAZ')
# ('2EGB', 'Amigables', 'Lunes', 10, 'PLA_2EGB', 'LIZ DÍAZ')
# ('2EGB', 'Amigables', 'Lunes', 13, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amigables', 'Lunes', 14, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amigables', 'Lunes', 15, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Amigables', 'Lunes', 16, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Amigables', 'Martes', 1, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amigables', 'Martes', 2, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amigables', 'Martes', 3, 'ECO_2EGB', 'MARJURIE JÁCOME')
# ('2EGB', 'Amigables', 'Martes', 4, 'SAL_2EGB', 'VANESSA ESPÍN')
# ('2EGB', 'Amigables', 'Martes', 6, 'SOC_2EGB', 'ALBITA QUILLUPANGUI')
# ('2EGB', 'Amigables', 'Martes', 7, 'PRO_2EGB', 'LUDWIN GUALOTUÑA')
# ('2EGB', 'Amigables', 'Martes', 8, 'PRO_2EGB', 'LUDWIN GUALOTUÑA')
# ('2EGB', 'Amigables', 'Martes', 9, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Amigables', 'Martes', 10, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Amigables', 'Martes', 13, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amigables', 'Martes', 14, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amigables', 'Miércoles', 3, 'COM_2EGB', 'ERIKA CAIZATOA')
# ('2EGB', 'Amigables', 'Miércoles', 4, 'DER_2EGB', 'CORALÍA CÓRDOVA')
# ('2EGB', 'Amigables', 'Miércoles', 6, 'DES_2EGB', 'MISHEL SALTOS')
# ('2EGB', 'Amigables', 'Miércoles', 7, 'DES_2EGB', 'MISHEL SALTOS')
# ('2EGB', 'Amigables', 'Miércoles', 8, 'CAL_2EGB', 'JAIR CRIOLLO')
# ('2EGB', 'Amigables', 'Miércoles', 9, 'EXP_2EGB', 'JOSÉ LUIS HERNÁNDEZ')
# ('2EGB', 'Amigables', 'Miércoles', 10, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amigables', 'Miércoles', 13, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amigables', 'Miércoles', 14, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amigables', 'Miércoles', 15, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Amigables', 'Miércoles', 16, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Amigables', 'Jueves', 1, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amigables', 'Jueves', 2, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amigables', 'Jueves', 3, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amigables', 'Jueves', 4, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amigables', 'Jueves', 6, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Amigables', 'Jueves', 7, 'EDU_2EGB', 'EF ESPECIAL')
# ('2EGB', 'Amigables', 'Jueves', 8, 'EDU_2EGB', 'EF ESPECIAL')
# ('2EGB', 'Amigables', 'Jueves', 9, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amigables', 'Jueves', 10, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amigables', 'Jueves', 13, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amigables', 'Jueves', 14, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amigables', 'Viernes', 1, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amigables', 'Viernes', 2, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amigables', 'Viernes', 3, 'SPE_2EGB', 'CHRISTIAN SOLANO')
# ('2EGB', 'Amigables', 'Viernes', 4, 'INV_2EGB', 'KARLA LAZCANO')
# ('2EGB', 'Amigables', 'Viernes', 6, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amigables', 'Viernes', 7, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amigables', 'Viernes', 8, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Amigables', 'Viernes', 9, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amigables', 'Viernes', 10, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amigables', 'Viernes', 13, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Amigables', 'Viernes', 14, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Amigables', 'Viernes', 15, 'SOC_2EGB', 'ALBITA QUILLUPANGUI')
# ('2EGB', 'Amigables', 'Viernes', 16, 'SOC_2EGB', 'ALBITA QUILLUPANGUI')
# ('2EGB', 'Amistosos', 'Lunes', 1, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amistosos', 'Lunes', 2, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amistosos', 'Lunes', 3, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amistosos', 'Lunes', 4, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amistosos', 'Lunes', 6, 'SOC_2EGB', 'ALBITA QUILLUPANGUI')
# ('2EGB', 'Amistosos', 'Lunes', 7, 'MUS_2EGB', 'LUIS JÁCOME')
# ('2EGB', 'Amistosos', 'Lunes', 8, 'DAN_2EGB', 'PAOLA LÓPEZ')
# ('2EGB', 'Amistosos', 'Lunes', 9, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amistosos', 'Lunes', 10, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amistosos', 'Lunes', 13, 'EDU_2EGB', 'EF ESPECIAL')
# ('2EGB', 'Amistosos', 'Lunes', 14, 'EDU_2EGB', 'EF ESPECIAL')
# ('2EGB', 'Amistosos', 'Lunes', 15, 'PRO_2EGB', 'LUDWIN GUALOTUÑA')
# ('2EGB', 'Amistosos', 'Lunes', 16, 'PRO_2EGB', 'LUDWIN GUALOTUÑA')
# ('2EGB', 'Amistosos', 'Martes', 1, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Amistosos', 'Martes', 2, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Amistosos', 'Martes', 3, 'SAL_2EGB', 'VANESSA ESPÍN')
# ('2EGB', 'Amistosos', 'Martes', 4, 'ECO_2EGB', 'MARJURIE JÁCOME')
# ('2EGB', 'Amistosos', 'Martes', 6, 'PLA_2EGB', 'LIZ DÍAZ')
# ('2EGB', 'Amistosos', 'Martes', 7, 'PLA_2EGB', 'LIZ DÍAZ')
# ('2EGB', 'Amistosos', 'Martes', 8, 'DES_2EGB', 'MISHEL SALTOS')
# ('2EGB', 'Amistosos', 'Martes', 9, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amistosos', 'Martes', 10, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amistosos', 'Martes', 13, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Amistosos', 'Martes', 14, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Amistosos', 'Miércoles', 3, 'DER_2EGB', 'CORALÍA CÓRDOVA')
# ('2EGB', 'Amistosos', 'Miércoles', 4, 'COM_2EGB', 'ERIKA CAIZATOA')
# ('2EGB', 'Amistosos', 'Miércoles', 6, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amistosos', 'Miércoles', 7, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amistosos', 'Miércoles', 8, 'EXP_2EGB', 'JOSÉ LUIS HERNÁNDEZ')
# ('2EGB', 'Amistosos', 'Miércoles', 9, 'CAL_2EGB', 'JAIR CRIOLLO')
# ('2EGB', 'Amistosos', 'Miércoles', 10, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Amistosos', 'Miércoles', 13, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Amistosos', 'Miércoles', 14, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amistosos', 'Miércoles', 15, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amistosos', 'Miércoles', 16, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amistosos', 'Jueves', 1, 'ROB_2EGB', 'DAVID CASTRO')
# ('2EGB', 'Amistosos', 'Jueves', 2, 'ROB_2EGB', 'DAVID CASTRO')
# ('2EGB', 'Amistosos', 'Jueves', 3, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amistosos', 'Jueves', 4, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amistosos', 'Jueves', 6, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amistosos', 'Jueves', 7, 'SOC_2EGB', 'ALBITA QUILLUPANGUI')
# ('2EGB', 'Amistosos', 'Jueves', 8, 'SOC_2EGB', 'ALBITA QUILLUPANGUI')
# ('2EGB', 'Amistosos', 'Jueves', 9, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amistosos', 'Jueves', 10, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amistosos', 'Jueves', 13, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Amistosos', 'Jueves', 14, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Amistosos', 'Viernes', 1, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Amistosos', 'Viernes', 2, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Amistosos', 'Viernes', 3, 'INV_2EGB', 'KARLA LAZCANO')
# ('2EGB', 'Amistosos', 'Viernes', 4, 'SPE_2EGB', 'CHRISTIAN SOLANO')
# ('2EGB', 'Amistosos', 'Viernes', 6, 'DES_2EGB', 'MISHEL SALTOS')
# ('2EGB', 'Amistosos', 'Viernes', 7, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amistosos', 'Viernes', 8, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amistosos', 'Viernes', 9, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Amistosos', 'Viernes', 10, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Amistosos', 'Viernes', 13, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amistosos', 'Viernes', 14, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amistosos', 'Viernes', 15, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amistosos', 'Viernes', 16, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('3EGB', 'Colaboradores', 'Lunes', 1, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Colaboradores', 'Lunes', 2, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Colaboradores', 'Lunes', 3, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Colaboradores', 'Lunes', 4, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Colaboradores', 'Lunes', 6, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Colaboradores', 'Lunes', 7, 'PRO_3EGB', 'LUDWIN GUALOTUÑA')
# ('3EGB', 'Colaboradores', 'Lunes', 8, 'PRO_3EGB', 'LUDWIN GUALOTUÑA')
# ('3EGB', 'Colaboradores', 'Lunes', 9, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Colaboradores', 'Lunes', 10, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Colaboradores', 'Lunes', 13, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Colaboradores', 'Lunes', 14, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Colaboradores', 'Lunes', 15, 'DES_3EGB', 'MISHEL SALTOS')
# ('3EGB', 'Colaboradores', 'Lunes', 16, 'DES_3EGB', 'MISHEL SALTOS')
# ('3EGB', 'Colaboradores', 'Martes', 1, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Colaboradores', 'Martes', 2, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Colaboradores', 'Martes', 3, 'SPE_3EGB', 'CHRISTIAN SOLANO')
# ('3EGB', 'Colaboradores', 'Martes', 4, 'INV_3EGB', 'KARLA LAZCANO')
# ('3EGB', 'Colaboradores', 'Martes', 6, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Colaboradores', 'Martes', 7, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Colaboradores', 'Martes', 8, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Colaboradores', 'Martes', 9, 'ROB_3EGB', 'DAVID CASTRO')
# ('3EGB', 'Colaboradores', 'Martes', 10, 'ROB_3EGB', 'DAVID CASTRO')
# ('3EGB', 'Colaboradores', 'Martes', 13, 'SOC_3EGB', 'ALBITA QUILLUPANGUI')
# ('3EGB', 'Colaboradores', 'Martes', 14, 'SOC_3EGB', 'ALBITA QUILLUPANGUI')
# ('3EGB', 'Colaboradores', 'Miércoles', 3, 'EDU_3EGB', 'EF ESPECIAL')
# ('3EGB', 'Colaboradores', 'Miércoles', 4, 'EDU_3EGB', 'EF ESPECIAL')
# ('3EGB', 'Colaboradores', 'Miércoles', 6, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Colaboradores', 'Miércoles', 7, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Colaboradores', 'Miércoles', 8, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Colaboradores', 'Miércoles', 9, 'PLA_3EGB', 'LIZ DÍAZ')
# ('3EGB', 'Colaboradores', 'Miércoles', 10, 'PLA_3EGB', 'LIZ DÍAZ')
# ('3EGB', 'Colaboradores', 'Miércoles', 13, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Colaboradores', 'Miércoles', 14, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Colaboradores', 'Miércoles', 15, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Colaboradores', 'Miércoles', 16, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Colaboradores', 'Jueves', 1, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Colaboradores', 'Jueves', 2, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Colaboradores', 'Jueves', 3, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Colaboradores', 'Jueves', 4, 'SOC_3EGB', 'ALBITA QUILLUPANGUI')
# ('3EGB', 'Colaboradores', 'Jueves', 6, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Colaboradores', 'Jueves', 7, 'ECO_3EGB', 'MARJURIE JÁCOME')
# ('3EGB', 'Colaboradores', 'Jueves', 8, 'SAL_3EGB', 'VANESSA ESPÍN')
# ('3EGB', 'Colaboradores', 'Jueves', 9, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Colaboradores', 'Jueves', 10, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Colaboradores', 'Jueves', 13, 'COM_3EGB', 'ERIKA CAIZATOA')
# ('3EGB', 'Colaboradores', 'Jueves', 14, 'DER_3EGB', 'CORALÍA CÓRDOVA')
# ('3EGB', 'Colaboradores', 'Viernes', 1, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Colaboradores', 'Viernes', 2, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Colaboradores', 'Viernes', 3, 'EXP_3EGB', 'JOSÉ LUIS HERNÁNDEZ')
# ('3EGB', 'Colaboradores', 'Viernes', 4, 'CAL_3EGB', 'JAIR CRIOLLO')
# ('3EGB', 'Colaboradores', 'Viernes', 6, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Colaboradores', 'Viernes', 7, 'MUS_3EGB', 'LUIS JÁCOME')
# ('3EGB', 'Colaboradores', 'Viernes', 8, 'DAN_3EGB', 'PAOLA LÓPEZ')
# ('3EGB', 'Colaboradores', 'Viernes', 9, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Colaboradores', 'Viernes', 10, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Colaboradores', 'Viernes', 13, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Colaboradores', 'Viernes', 14, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Colaboradores', 'Viernes', 15, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Colaboradores', 'Viernes', 16, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Conciliadores', 'Lunes', 1, 'PRO_3EGB', 'LUDWIN GUALOTUÑA')
# ('3EGB', 'Conciliadores', 'Lunes', 2, 'PRO_3EGB', 'LUDWIN GUALOTUÑA')
# ('3EGB', 'Conciliadores', 'Lunes', 3, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Conciliadores', 'Lunes', 4, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Conciliadores', 'Lunes', 6, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Conciliadores', 'Lunes', 7, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Conciliadores', 'Lunes', 8, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Conciliadores', 'Lunes', 9, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Conciliadores', 'Lunes', 10, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Conciliadores', 'Lunes', 13, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Conciliadores', 'Lunes', 14, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Conciliadores', 'Lunes', 15, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Conciliadores', 'Lunes', 16, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Conciliadores', 'Martes', 1, 'SOC_3EGB', 'ALBITA QUILLUPANGUI')
# ('3EGB', 'Conciliadores', 'Martes', 2, 'SOC_3EGB', 'ALBITA QUILLUPANGUI')
# ('3EGB', 'Conciliadores', 'Martes', 3, 'INV_3EGB', 'KARLA LAZCANO')
# ('3EGB', 'Conciliadores', 'Martes', 4, 'SPE_3EGB', 'CHRISTIAN SOLANO')
# ('3EGB', 'Conciliadores', 'Martes', 6, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Conciliadores', 'Martes', 7, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Conciliadores', 'Martes', 8, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Conciliadores', 'Martes', 9, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Conciliadores', 'Martes', 10, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Conciliadores', 'Martes', 13, 'ROB_3EGB', 'DAVID CASTRO')
# ('3EGB', 'Conciliadores', 'Martes', 14, 'ROB_3EGB', 'DAVID CASTRO')
# ('3EGB', 'Conciliadores', 'Miércoles', 3, 'DES_3EGB', 'MISHEL SALTOS')
# ('3EGB', 'Conciliadores', 'Miércoles', 4, 'DES_3EGB', 'MISHEL SALTOS')
# ('3EGB', 'Conciliadores', 'Miércoles', 6, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Conciliadores', 'Miércoles', 7, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Conciliadores', 'Miércoles', 8, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Conciliadores', 'Miércoles', 9, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Conciliadores', 'Miércoles', 10, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Conciliadores', 'Miércoles', 13, 'EDU_3EGB', 'EF ESPECIAL')
# ('3EGB', 'Conciliadores', 'Miércoles', 14, 'EDU_3EGB', 'EF ESPECIAL')
# ('3EGB', 'Conciliadores', 'Miércoles', 15, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Conciliadores', 'Miércoles', 16, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Conciliadores', 'Jueves', 1, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Conciliadores', 'Jueves', 2, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Conciliadores', 'Jueves', 3, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Conciliadores', 'Jueves', 4, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Conciliadores', 'Jueves', 6, 'SOC_3EGB', 'ALBITA QUILLUPANGUI')
# ('3EGB', 'Conciliadores', 'Jueves', 7, 'SAL_3EGB', 'VANESSA ESPÍN')
# ('3EGB', 'Conciliadores', 'Jueves', 8, 'ECO_3EGB', 'MARJURIE JÁCOME')
# ('3EGB', 'Conciliadores', 'Jueves', 9, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Conciliadores', 'Jueves', 10, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Conciliadores', 'Jueves', 13, 'DER_3EGB', 'CORALÍA CÓRDOVA')
# ('3EGB', 'Conciliadores', 'Jueves', 14, 'COM_3EGB', 'ERIKA CAIZATOA')
# ('3EGB', 'Conciliadores', 'Viernes', 1, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Conciliadores', 'Viernes', 2, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Conciliadores', 'Viernes', 3, 'CAL_3EGB', 'JAIR CRIOLLO')
# ('3EGB', 'Conciliadores', 'Viernes', 4, 'EXP_3EGB', 'JOSÉ LUIS HERNÁNDEZ')
# ('3EGB', 'Conciliadores', 'Viernes', 6, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Conciliadores', 'Viernes', 7, 'DAN_3EGB', 'PAOLA LÓPEZ')
# ('3EGB', 'Conciliadores', 'Viernes', 8, 'MUS_3EGB', 'LUIS JÁCOME')
# ('3EGB', 'Conciliadores', 'Viernes', 9, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Conciliadores', 'Viernes', 10, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Conciliadores', 'Viernes', 13, 'PLA_3EGB', 'LIZ DÍAZ')
# ('3EGB', 'Conciliadores', 'Viernes', 14, 'PLA_3EGB', 'LIZ DÍAZ')
# ('3EGB', 'Conciliadores', 'Viernes', 15, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Conciliadores', 'Viernes', 16, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Cordiales', 'Lunes', 1, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Cordiales', 'Lunes', 2, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Cordiales', 'Lunes', 3, 'SAL_3EGB', 'VANESSA ESPÍN')
# ('3EGB', 'Cordiales', 'Lunes', 4, 'ECO_3EGB', 'MARJURIE JÁCOME')
# ('3EGB', 'Cordiales', 'Lunes', 6, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Cordiales', 'Lunes', 7, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Cordiales', 'Lunes', 8, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Cordiales', 'Lunes', 9, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Cordiales', 'Lunes', 10, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Cordiales', 'Lunes', 13, 'PRO_3EGB', 'LUDWIN GUALOTUÑA')
# ('3EGB', 'Cordiales', 'Lunes', 14, 'PRO_3EGB', 'LUDWIN GUALOTUÑA')
# ('3EGB', 'Cordiales', 'Lunes', 15, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Cordiales', 'Lunes', 16, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Cordiales', 'Martes', 1, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Cordiales', 'Martes', 2, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Cordiales', 'Martes', 3, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Cordiales', 'Martes', 4, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Cordiales', 'Martes', 6, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Cordiales', 'Martes', 7, 'SOC_3EGB', 'ALBITA QUILLUPANGUI')
# ('3EGB', 'Cordiales', 'Martes', 8, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Cordiales', 'Martes', 9, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Cordiales', 'Martes', 10, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Cordiales', 'Martes', 13, 'EDU_3EGB', 'EF ESPECIAL')
# ('3EGB', 'Cordiales', 'Martes', 14, 'EDU_3EGB', 'EF ESPECIAL')
# ('3EGB', 'Cordiales', 'Miércoles', 3, 'INV_3EGB', 'KARLA LAZCANO')
# ('3EGB', 'Cordiales', 'Miércoles', 4, 'SPE_3EGB', 'CHRISTIAN SOLANO')
# ('3EGB', 'Cordiales', 'Miércoles', 6, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Cordiales', 'Miércoles', 7, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Cordiales', 'Miércoles', 8, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Cordiales', 'Miércoles', 9, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Cordiales', 'Miércoles', 10, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Cordiales', 'Miércoles', 13, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Cordiales', 'Miércoles', 14, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Cordiales', 'Miércoles', 15, 'DES_3EGB', 'MISHEL SALTOS')
# ('3EGB', 'Cordiales', 'Miércoles', 16, 'DES_3EGB', 'MISHEL SALTOS')
# ('3EGB', 'Cordiales', 'Jueves', 1, 'DAN_3EGB', 'PAOLA LÓPEZ')
# ('3EGB', 'Cordiales', 'Jueves', 2, 'MUS_3EGB', 'LUIS JÁCOME')
# ('3EGB', 'Cordiales', 'Jueves', 3, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Cordiales', 'Jueves', 4, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Cordiales', 'Jueves', 6, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Cordiales', 'Jueves', 7, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Cordiales', 'Jueves', 8, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Cordiales', 'Jueves', 9, 'PLA_3EGB', 'LIZ DÍAZ')
# ('3EGB', 'Cordiales', 'Jueves', 10, 'PLA_3EGB', 'LIZ DÍAZ')
# ('3EGB', 'Cordiales', 'Jueves', 13, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Cordiales', 'Jueves', 14, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Cordiales', 'Viernes', 1, 'ROB_3EGB', 'DAVID CASTRO')
# ('3EGB', 'Cordiales', 'Viernes', 2, 'ROB_3EGB', 'DAVID CASTRO')
# ('3EGB', 'Cordiales', 'Viernes', 3, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Cordiales', 'Viernes', 4, 'SOC_3EGB', 'ALBITA QUILLUPANGUI')
# ('3EGB', 'Cordiales', 'Viernes', 6, 'SOC_3EGB', 'ALBITA QUILLUPANGUI')
# ('3EGB', 'Cordiales', 'Viernes', 7, 'COM_3EGB', 'ERIKA CAIZATOA')
# ('3EGB', 'Cordiales', 'Viernes', 8, 'DER_3EGB', 'CORALÍA CÓRDOVA')
# ('3EGB', 'Cordiales', 'Viernes', 9, 'CAL_3EGB', 'JAIR CRIOLLO')
# ('3EGB', 'Cordiales', 'Viernes', 10, 'EXP_3EGB', 'JOSÉ LUIS HERNÁNDEZ')
# ('3EGB', 'Cordiales', 'Viernes', 13, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Cordiales', 'Viernes', 14, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Cordiales', 'Viernes', 15, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Cordiales', 'Viernes', 16, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Creativos', 'Lunes', 1, 'ROB_3EGB', 'DAVID CASTRO')
# ('3EGB', 'Creativos', 'Lunes', 2, 'ROB_3EGB', 'DAVID CASTRO')
# ('3EGB', 'Creativos', 'Lunes', 3, 'ECO_3EGB', 'MARJURIE JÁCOME')
# ('3EGB', 'Creativos', 'Lunes', 4, 'SAL_3EGB', 'VANESSA ESPÍN')
# ('3EGB', 'Creativos', 'Lunes', 5, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Creativos', 'Lunes', 7, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Creativos', 'Lunes', 8, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Creativos', 'Lunes', 9, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Creativos', 'Lunes', 10, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Creativos', 'Lunes', 13, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Creativos', 'Lunes', 14, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Creativos', 'Lunes', 15, 'EDU_3EGB', 'EF ESPECIAL')
# ('3EGB', 'Creativos', 'Lunes', 16, 'EDU_3EGB', 'EF ESPECIAL')
# ('3EGB', 'Creativos', 'Martes', 1, 'PLA_3EGB', 'LIZ DÍAZ')
# ('3EGB', 'Creativos', 'Martes', 2, 'PLA_3EGB', 'LIZ DÍAZ')
# ('3EGB', 'Creativos', 'Martes', 3, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Creativos', 'Martes', 4, 'SOC_3EGB', 'ALBITA QUILLUPANGUI')
# ('3EGB', 'Creativos', 'Martes', 6, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Creativos', 'Martes', 7, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Creativos', 'Martes', 8, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Creativos', 'Martes', 9, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Creativos', 'Martes', 10, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Creativos', 'Martes', 13, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Creativos', 'Martes', 14, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Creativos', 'Miércoles', 3, 'SPE_3EGB', 'CHRISTIAN SOLANO')
# ('3EGB', 'Creativos', 'Miércoles', 4, 'INV_3EGB', 'KARLA LAZCANO')
# ('3EGB', 'Creativos', 'Miércoles', 6, 'SOC_3EGB', 'ALBITA QUILLUPANGUI')
# ('3EGB', 'Creativos', 'Miércoles', 7, 'SOC_3EGB', 'ALBITA QUILLUPANGUI')
# ('3EGB', 'Creativos', 'Miércoles', 8, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Creativos', 'Miércoles', 9, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Creativos', 'Miércoles', 10, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Creativos', 'Miércoles', 13, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Creativos', 'Miércoles', 14, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Creativos', 'Miércoles', 15, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Creativos', 'Miércoles', 16, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Creativos', 'Jueves', 1, 'MUS_3EGB', 'LUIS JÁCOME')
# ('3EGB', 'Creativos', 'Jueves', 2, 'DAN_3EGB', 'PAOLA LÓPEZ')
# ('3EGB', 'Creativos', 'Jueves', 3, 'PRO_3EGB', 'LUDWIN GUALOTUÑA')
# ('3EGB', 'Creativos', 'Jueves', 4, 'PRO_3EGB', 'LUDWIN GUALOTUÑA')
# ('3EGB', 'Creativos', 'Jueves', 6, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Creativos', 'Jueves', 7, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Creativos', 'Jueves', 8, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Creativos', 'Jueves', 9, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Creativos', 'Jueves', 10, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Creativos', 'Jueves', 13, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Creativos', 'Jueves', 14, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Creativos', 'Viernes', 1, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Creativos', 'Viernes', 2, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Creativos', 'Viernes', 3, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Creativos', 'Viernes', 4, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Creativos', 'Viernes', 6, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Creativos', 'Viernes', 7, 'DER_3EGB', 'CORALÍA CÓRDOVA')
# ('3EGB', 'Creativos', 'Viernes', 8, 'COM_3EGB', 'ERIKA CAIZATOA')
# ('3EGB', 'Creativos', 'Viernes', 9, 'EXP_3EGB', 'JOSÉ LUIS HERNÁNDEZ')
# ('3EGB', 'Creativos', 'Viernes', 10, 'CAL_3EGB', 'JAIR CRIOLLO')
# ('3EGB', 'Creativos', 'Viernes', 13, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Creativos', 'Viernes', 14, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Creativos', 'Viernes', 15, 'DES_3EGB', 'MISHEL SALTOS')
# ('3EGB', 'Creativos', 'Viernes', 16, 'DES_3EGB', 'MISHEL SALTOS')
# ('4EGB', 'Optimistas', 'Lunes', 1, 'MAT_4EGB', 'PATY ARIAS')
# ('4EGB', 'Optimistas', 'Lunes', 2, 'MAT_4EGB', 'PATY ARIAS')
# ('4EGB', 'Optimistas', 'Lunes', 3, 'PEN_4EGB', 'XIMENA AGUIRRE')
# ('4EGB', 'Optimistas', 'Lunes', 4, 'PEN_4EGB', 'XIMENA AGUIRRE')
# ('4EGB', 'Optimistas', 'Lunes', 5, 'PLA_4EGB', 'LIZ DÍAZ')
# ('4EGB', 'Optimistas', 'Lunes', 7, 'PLA_4EGB', 'LIZ DÍAZ')
# ('4EGB', 'Optimistas', 'Lunes', 8, 'NAT_4EGB', 'DIANA SÁNCHEZ')
# ('4EGB', 'Optimistas', 'Lunes', 9, 'LEC_4EGB', 'ANITA ARROBA')
# ('4EGB', 'Optimistas', 'Lunes', 10, 'LEC_4EGB', 'ANITA ARROBA')
# ('4EGB', 'Optimistas', 'Lunes', 13, 'ING_4EGB', 'SOLEDAD REVELO')
# ('4EGB', 'Optimistas', 'Lunes', 14, 'ING_4EGB', 'SOLEDAD REVELO')
# ('4EGB', 'Optimistas', 'Lunes', 15, 'MAT_4EGB', 'PATY ARIAS')
# ('4EGB', 'Optimistas', 'Lunes', 16, 'MAT_4EGB', 'PATY ARIAS')
# ('4EGB', 'Optimistas', 'Martes', 1, 'INV_4EGB', 'KARLA LAZCANO')
# ('4EGB', 'Optimistas', 'Martes', 2, 'SPE_4EGB', 'CHRISTIAN SOLANO')
# ...
# ('2BGU', 'Justos', 'Viernes', 12, 'GEO_2BGU', 'LEONARDO ESPINOSA')
# ('2BGU', 'Proactivos', 'Lunes', 1, 'CIU_2BGU', 'ISABEL GARCÍA')
# ('2BGU', 'Proactivos', 'Lunes', 2, 'MAT_2BGU', 'ISAAC NÚÑEZ')
# ('2BGU', 'Proactivos', 'Lunes', 3, 'MAT_2BGU', 'ISAAC NÚÑEZ')
# ('2BGU', 'Proactivos', 'Lunes', 4, 'ING_2BGU', 'INGLES ESPECIAL')
# ('2BGU', 'Proactivos', 'Lunes', 5, 'ING_2BGU', 'INGLES ESPECIAL')
# ('2BGU', 'Proactivos', 'Lunes', 7, 'QUI_2BGU', 'MAYRA QUISHPE')
# ('2BGU', 'Proactivos', 'Lunes', 8, 'QUI_2BGU', 'MAYRA QUISHPE')
# ('2BGU', 'Proactivos', 'Lunes', 9, 'GEO_2BGU', 'LEONARDO ESPINOSA')
# ('2BGU', 'Proactivos', 'Lunes', 10, 'GEO_2BGU', 'LEONARDO ESPINOSA')
# ('2BGU', 'Proactivos', 'Lunes', 11, 'LEC_2BGU', 'PATY FLORES')
# ('2BGU', 'Proactivos', 'Lunes', 12, 'LEC_2BGU', 'PATY FLORES')
# ('2BGU', 'Proactivos', 'Lunes', 15, 'SPE_2BGU', 'CHRISTIAN SOLANO')
# ('2BGU', 'Proactivos', 'Lunes', 16, 'INV_2BGU', 'KARLA LAZCANO')
# ('2BGU', 'Proactivos', 'Martes', 1, 'EMP_2BGU', 'MARÍA BELÉN MALDONADO')
# ('2BGU', 'Proactivos', 'Martes', 2, 'EMP_2BGU', 'MARÍA BELÉN MALDONADO')
# ('2BGU', 'Proactivos', 'Martes', 3, 'NAT_2BGU', 'CARLOS BENALCÁZAR')
# ('2BGU', 'Proactivos', 'Martes', 4, 'NAT_2BGU', 'CARLOS BENALCÁZAR')
# ('2BGU', 'Proactivos', 'Martes', 5, 'PEN_2BGU', 'ANITA BARRENO')
# ('2BGU', 'Proactivos', 'Martes', 7, 'SOC_2BGU', 'ISABEL GARCÍA')
# ('2BGU', 'Proactivos', 'Martes', 8, 'SOC_2BGU', 'ISABEL GARCÍA')
# ('2BGU', 'Proactivos', 'Martes', 9, 'ROB_2BGU', 'DAVID RÓGEL')
# ('2BGU', 'Proactivos', 'Martes', 10, 'ROB_2BGU', 'DAVID RÓGEL')
# ('2BGU', 'Proactivos', 'Martes', 11, 'MAT_2BGU', 'ISAAC NÚÑEZ')
# ('2BGU', 'Proactivos', 'Martes', 12, 'MAT_2BGU', 'ISAAC NÚÑEZ')
# ('2BGU', 'Proactivos', 'Martes', 15, 'SAL_2BGU', 'VANESSA ESPÍN')
# ('2BGU', 'Proactivos', 'Martes', 16, 'ECO_2BGU', 'MARJURIE JÁCOME')
# ('2BGU', 'Proactivos', 'Miércoles', 3, 'PLA_2BGU', 'KEVIN VICENTE')
# ('2BGU', 'Proactivos', 'Miércoles', 4, 'PLA_2BGU', 'KEVIN VICENTE')
# ('2BGU', 'Proactivos', 'Miércoles', 5, 'GEO_2BGU', 'LEONARDO ESPINOSA')
# ('2BGU', 'Proactivos', 'Miércoles', 7, 'ING_2BGU', 'INGLES ESPECIAL')
# ('2BGU', 'Proactivos', 'Miércoles', 8, 'ING_2BGU', 'INGLES ESPECIAL')
# ('2BGU', 'Proactivos', 'Miércoles', 9, 'QUI_2BGU', 'MAYRA QUISHPE')
# ('2BGU', 'Proactivos', 'Miércoles', 10, 'QUI_2BGU', 'MAYRA QUISHPE')
# ('2BGU', 'Proactivos', 'Miércoles', 11, 'LEN_2BGU', 'ANDRÉS OLMEDO')
# ('2BGU', 'Proactivos', 'Miércoles', 12, 'LEN_2BGU', 'ANDRÉS OLMEDO')
# ('2BGU', 'Proactivos', 'Jueves', 1, 'COM_2BGU', 'ERIKA CAIZATOA')
# ('2BGU', 'Proactivos', 'Jueves', 2, 'DER_2BGU', 'CORALÍA CÓRDOVA')
# ('2BGU', 'Proactivos', 'Jueves', 3, 'MAT_2BGU', 'ISAAC NÚÑEZ')
# ('2BGU', 'Proactivos', 'Jueves', 4, 'MAT_2BGU', 'ISAAC NÚÑEZ')
# ('2BGU', 'Proactivos', 'Jueves', 5, 'LEC_2BGU', 'PATY FLORES')
# ('2BGU', 'Proactivos', 'Jueves', 7, 'PRO_2BGU', 'MARCO SAFADI')
# ('2BGU', 'Proactivos', 'Jueves', 8, 'PRO_2BGU', 'MARCO SAFADI')
# ('2BGU', 'Proactivos', 'Jueves', 9, 'FIS_2BGU', 'JOSÉ NICOLALDE')
# ('2BGU', 'Proactivos', 'Jueves', 10, 'FIS_2BGU', 'JOSÉ NICOLALDE')
# ('2BGU', 'Proactivos', 'Jueves', 11, 'SOC_2BGU', 'ISABEL GARCÍA')
# ('2BGU', 'Proactivos', 'Jueves', 12, 'SOC_2BGU', 'ISABEL GARCÍA')
# ('2BGU', 'Proactivos', 'Jueves', 15, 'ING_2BGU', 'INGLES ESPECIAL')
# ('2BGU', 'Proactivos', 'Jueves', 16, 'ING_2BGU', 'INGLES ESPECIAL')
# ('2BGU', 'Proactivos', 'Viernes', 1, 'EST_2BGU', 'JONATHAN CASTRO')
# ('2BGU', 'Proactivos', 'Viernes', 2, 'EST_2BGU', 'JONATHAN CASTRO')
# ('2BGU', 'Proactivos', 'Viernes', 3, 'NAT_2BGU', 'CARLOS BENALCÁZAR')
# ('2BGU', 'Proactivos', 'Viernes', 4, 'PEN_2BGU', 'ANITA BARRENO')
# ('2BGU', 'Proactivos', 'Viernes', 5, 'PEN_2BGU', 'ANITA BARRENO')
# ('2BGU', 'Proactivos', 'Viernes', 7, 'EDU_2BGU', 'EF ESPECIAL')
# ('2BGU', 'Proactivos', 'Viernes', 8, 'EDU_2BGU', 'EF ESPECIAL')
# ('2BGU', 'Proactivos', 'Viernes', 9, 'DES_2BGU', 'JANETH MELO')
# ('2BGU', 'Proactivos', 'Viernes', 10, 'DES_2BGU', 'JANETH MELO')
# ('2BGU', 'Proactivos', 'Viernes', 11, 'FIS_2BGU', 'JOSÉ NICOLALDE')
# ('2BGU', 'Proactivos', 'Viernes', 12, 'FIS_2BGU', 'JOSÉ NICOLALDE')
# ('3BGU', 'Empáticos', 'Lunes', 1, 'NAT_3BGU', 'CARLOS BENALCÁZAR')
# ('3BGU', 'Empáticos', 'Lunes', 2, 'NAT_3BGU', 'CARLOS BENALCÁZAR')
# ('3BGU', 'Empáticos', 'Lunes', 3, 'GEO_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Empáticos', 'Lunes', 4, 'GEO_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Empáticos', 'Lunes', 5, 'GEO_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Empáticos', 'Lunes', 7, 'LEN_3BGU', 'ANDRÉS OLMEDO')
# ('3BGU', 'Empáticos', 'Lunes', 8, 'LEN_3BGU', 'ANDRÉS OLMEDO')
# ('3BGU', 'Empáticos', 'Lunes', 9, 'FIS_3BGU', 'JOSÉ NICOLALDE')
# ('3BGU', 'Empáticos', 'Lunes', 10, 'FIS_3BGU', 'JOSÉ NICOLALDE')
# ('3BGU', 'Empáticos', 'Lunes', 11, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Empáticos', 'Lunes', 12, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Empáticos', 'Lunes', 15, 'EST_3BGU', 'JONATHAN CASTRO')
# ('3BGU', 'Empáticos', 'Lunes', 16, 'EST_3BGU', 'JONATHAN CASTRO')
# ('3BGU', 'Empáticos', 'Martes', 1, 'QUI_3BGU', 'MAYRA QUISHPE')
# ('3BGU', 'Empáticos', 'Martes', 2, 'QUI_3BGU', 'MAYRA QUISHPE')
# ('3BGU', 'Empáticos', 'Martes', 3, 'SOC_3BGU', 'ISABEL GARCÍA')
# ('3BGU', 'Empáticos', 'Martes', 4, 'SOC_3BGU', 'ISABEL GARCÍA')
# ('3BGU', 'Empáticos', 'Martes', 5, 'NAT_3BGU', 'CARLOS BENALCÁZAR')
# ('3BGU', 'Empáticos', 'Martes', 7, 'PEN_3BGU', 'ANITA BARRENO')
# ('3BGU', 'Empáticos', 'Martes', 8, 'PEN_3BGU', 'ANITA BARRENO')
# ('3BGU', 'Empáticos', 'Martes', 9, 'PLA_3BGU', 'KEVIN VICENTE')
# ('3BGU', 'Empáticos', 'Martes', 10, 'PLA_3BGU', 'KEVIN VICENTE')
# ('3BGU', 'Empáticos', 'Martes', 11, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Empáticos', 'Martes', 12, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Empáticos', 'Martes', 15, 'SPE_3BGU', 'CHRISTIAN SOLANO')
# ('3BGU', 'Empáticos', 'Martes', 16, 'INV_3BGU', 'KARLA LAZCANO')
# ('3BGU', 'Empáticos', 'Miércoles', 3, 'LEN_3BGU', 'ANDRÉS OLMEDO')
# ('3BGU', 'Empáticos', 'Miércoles', 4, 'EDU_3BGU', 'EF ESPECIAL')
# ('3BGU', 'Empáticos', 'Miércoles', 5, 'LEC_3BGU', 'PATY FLORES')
# ('3BGU', 'Empáticos', 'Miércoles', 7, 'DER_3BGU', 'CORALÍA CÓRDOVA')
# ('3BGU', 'Empáticos', 'Miércoles', 8, 'COM_3BGU', 'ERIKA CAIZATOA')
# ('3BGU', 'Empáticos', 'Miércoles', 9, 'FIS_3BGU', 'JOSÉ NICOLALDE')
# ('3BGU', 'Empáticos', 'Miércoles', 10, 'FIS_3BGU', 'JOSÉ NICOLALDE')
# ('3BGU', 'Empáticos', 'Miércoles', 11, 'ECO_3BGU', 'MARJURIE JÁCOME')
# ('3BGU', 'Empáticos', 'Miércoles', 12, 'SAL_3BGU', 'VANESSA ESPÍN')
# ('3BGU', 'Empáticos', 'Jueves', 1, 'ROB_3BGU', 'DAVID RÓGEL')
# ('3BGU', 'Empáticos', 'Jueves', 2, 'ROB_3BGU', 'DAVID RÓGEL')
# ('3BGU', 'Empáticos', 'Jueves', 3, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Empáticos', 'Jueves', 4, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Empáticos', 'Jueves', 5, 'PEN_3BGU', 'ANITA BARRENO')
# ('3BGU', 'Empáticos', 'Jueves', 7, 'EMP_3BGU', 'MARÍA BELÉN MALDONADO')
# ('3BGU', 'Empáticos', 'Jueves', 8, 'EMP_3BGU', 'MARÍA BELÉN MALDONADO')
# ('3BGU', 'Empáticos', 'Jueves', 9, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Empáticos', 'Jueves', 10, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Empáticos', 'Jueves', 11, 'QUI_3BGU', 'MAYRA QUISHPE')
# ('3BGU', 'Empáticos', 'Jueves', 12, 'QUI_3BGU', 'MAYRA QUISHPE')
# ('3BGU', 'Empáticos', 'Jueves', 15, 'DES_3BGU', 'JANETH MELO')
# ('3BGU', 'Empáticos', 'Jueves', 16, 'DES_3BGU', 'JANETH MELO')
# ('3BGU', 'Empáticos', 'Viernes', 1, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Empáticos', 'Viernes', 2, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Empáticos', 'Viernes', 3, 'EDU_3BGU', 'EF ESPECIAL')
# ('3BGU', 'Empáticos', 'Viernes', 4, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Empáticos', 'Viernes', 5, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Empáticos', 'Viernes', 7, 'SOC_3BGU', 'ISABEL GARCÍA')
# ('3BGU', 'Empáticos', 'Viernes', 8, 'SOC_3BGU', 'ISABEL GARCÍA')
# ('3BGU', 'Empáticos', 'Viernes', 9, 'PRO_3BGU', 'MARCO SAFADI')
# ('3BGU', 'Empáticos', 'Viernes', 10, 'PRO_3BGU', 'MARCO SAFADI')
# ('3BGU', 'Empáticos', 'Viernes', 11, 'LEC_3BGU', 'PATY FLORES')
# ('3BGU', 'Empáticos', 'Viernes', 12, 'LEC_3BGU', 'PATY FLORES')
# ('3BGU', 'Solidarios', 'Lunes', 1, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Solidarios', 'Lunes', 2, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Solidarios', 'Lunes', 3, 'PEN_3BGU', 'ANITA BARRENO')
# ('3BGU', 'Solidarios', 'Lunes', 4, 'NAT_3BGU', 'CARLOS BENALCÁZAR')
# ('3BGU', 'Solidarios', 'Lunes', 5, 'NAT_3BGU', 'CARLOS BENALCÁZAR')
# ('3BGU', 'Solidarios', 'Lunes', 7, 'SOC_3BGU', 'ISABEL GARCÍA')
# ('3BGU', 'Solidarios', 'Lunes', 8, 'SOC_3BGU', 'ISABEL GARCÍA')
# ('3BGU', 'Solidarios', 'Lunes', 9, 'LEN_3BGU', 'ANDRÉS OLMEDO')
# ('3BGU', 'Solidarios', 'Lunes', 10, 'LEN_3BGU', 'ANDRÉS OLMEDO')
# ('3BGU', 'Solidarios', 'Lunes', 11, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Solidarios', 'Lunes', 12, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Solidarios', 'Lunes', 15, 'EST_3BGU', 'JONATHAN CASTRO')
# ('3BGU', 'Solidarios', 'Lunes', 16, 'EST_3BGU', 'JONATHAN CASTRO')
# ('3BGU', 'Solidarios', 'Martes', 1, 'FIS_3BGU', 'JOSÉ NICOLALDE')
# ('3BGU', 'Solidarios', 'Martes', 2, 'FIS_3BGU', 'JOSÉ NICOLALDE')
# ('3BGU', 'Solidarios', 'Martes', 3, 'QUI_3BGU', 'MAYRA QUISHPE')
# ('3BGU', 'Solidarios', 'Martes', 4, 'QUI_3BGU', 'MAYRA QUISHPE')
# ('3BGU', 'Solidarios', 'Martes', 5, 'LEC_3BGU', 'PATY FLORES')
# ('3BGU', 'Solidarios', 'Martes', 7, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Solidarios', 'Martes', 8, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Solidarios', 'Martes', 9, 'SOC_3BGU', 'ISABEL GARCÍA')
# ('3BGU', 'Solidarios', 'Martes', 10, 'SOC_3BGU', 'ISABEL GARCÍA')
# ('3BGU', 'Solidarios', 'Martes', 11, 'PLA_3BGU', 'KEVIN VICENTE')
# ('3BGU', 'Solidarios', 'Martes', 12, 'PLA_3BGU', 'KEVIN VICENTE')
# ('3BGU', 'Solidarios', 'Martes', 15, 'INV_3BGU', 'KARLA LAZCANO')
# ('3BGU', 'Solidarios', 'Martes', 16, 'SPE_3BGU', 'CHRISTIAN SOLANO')
# ('3BGU', 'Solidarios', 'Miércoles', 3, 'QUI_3BGU', 'MAYRA QUISHPE')
# ('3BGU', 'Solidarios', 'Miércoles', 4, 'QUI_3BGU', 'MAYRA QUISHPE')
# ('3BGU', 'Solidarios', 'Miércoles', 5, 'NAT_3BGU', 'CARLOS BENALCÁZAR')
# ('3BGU', 'Solidarios', 'Miércoles', 7, 'COM_3BGU', 'ERIKA CAIZATOA')
# ('3BGU', 'Solidarios', 'Miércoles', 8, 'DER_3BGU', 'CORALÍA CÓRDOVA')
# ('3BGU', 'Solidarios', 'Miércoles', 9, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Solidarios', 'Miércoles', 10, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Solidarios', 'Miércoles', 11, 'SAL_3BGU', 'VANESSA ESPÍN')
# ('3BGU', 'Solidarios', 'Miércoles', 12, 'ECO_3BGU', 'MARJURIE JÁCOME')
# ('3BGU', 'Solidarios', 'Jueves', 1, 'FIS_3BGU', 'JOSÉ NICOLALDE')
# ('3BGU', 'Solidarios', 'Jueves', 2, 'FIS_3BGU', 'JOSÉ NICOLALDE')
# ('3BGU', 'Solidarios', 'Jueves', 3, 'ROB_3BGU', 'DAVID RÓGEL')
# ('3BGU', 'Solidarios', 'Jueves', 4, 'ROB_3BGU', 'DAVID RÓGEL')
# ('3BGU', 'Solidarios', 'Jueves', 5, 'GEO_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Solidarios', 'Jueves', 7, 'PEN_3BGU', 'ANITA BARRENO')
# ('3BGU', 'Solidarios', 'Jueves', 8, 'PEN_3BGU', 'ANITA BARRENO')
# ('3BGU', 'Solidarios', 'Jueves', 9, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Solidarios', 'Jueves', 10, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Solidarios', 'Jueves', 11, 'LEC_3BGU', 'PATY FLORES')
# ('3BGU', 'Solidarios', 'Jueves', 12, 'LEC_3BGU', 'PATY FLORES')
# ('3BGU', 'Solidarios', 'Jueves', 15, 'DES_3BGU', 'JANETH MELO')
# ('3BGU', 'Solidarios', 'Jueves', 16, 'DES_3BGU', 'JANETH MELO')
# ('3BGU', 'Solidarios', 'Viernes', 1, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Solidarios', 'Viernes', 2, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Solidarios', 'Viernes', 3, 'LEN_3BGU', 'ANDRÉS OLMEDO')
# ('3BGU', 'Solidarios', 'Viernes', 4, 'PRO_3BGU', 'MARCO SAFADI')
# ('3BGU', 'Solidarios', 'Viernes', 5, 'PRO_3BGU', 'MARCO SAFADI')
# ('3BGU', 'Solidarios', 'Viernes', 7, 'GEO_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Solidarios', 'Viernes', 8, 'GEO_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Solidarios', 'Viernes', 9, 'EDU_3BGU', 'EF ESPECIAL')
# ('3BGU', 'Solidarios', 'Viernes', 10, 'EDU_3BGU', 'EF ESPECIAL')
# ('3BGU', 'Solidarios', 'Viernes', 11, 'EMP_3BGU', 'MARÍA BELÉN MALDONADO')
# ('3BGU', 'Solidarios', 'Viernes', 12, 'EMP_3BGU', 'MARÍA BELÉN MALDONADO')
# ('3BGU', 'Vanguardistas', 'Lunes', 1, 'FIS_3BGU', 'JOSÉ NICOLALDE')
# ('3BGU', 'Vanguardistas', 'Lunes', 2, 'FIS_3BGU', 'JOSÉ NICOLALDE')
# ('3BGU', 'Vanguardistas', 'Lunes', 3, 'QUI_3BGU', 'MAYRA QUISHPE')
# ('3BGU', 'Vanguardistas', 'Lunes', 4, 'QUI_3BGU', 'MAYRA QUISHPE')
# ('3BGU', 'Vanguardistas', 'Lunes', 5, 'PEN_3BGU', 'ANITA BARRENO')
# ('3BGU', 'Vanguardistas', 'Lunes', 7, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Vanguardistas', 'Lunes', 8, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Vanguardistas', 'Lunes', 9, 'LEC_3BGU', 'PATY FLORES')
# ('3BGU', 'Vanguardistas', 'Lunes', 10, 'LEC_3BGU', 'PATY FLORES')
# ('3BGU', 'Vanguardistas', 'Lunes', 11, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Vanguardistas', 'Lunes', 12, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Vanguardistas', 'Lunes', 15, 'EST_3BGU', 'JONATHAN CASTRO')
# ('3BGU', 'Vanguardistas', 'Lunes', 16, 'EST_3BGU', 'JONATHAN CASTRO')
# ('3BGU', 'Vanguardistas', 'Martes', 1, 'NAT_3BGU', 'CARLOS BENALCÁZAR')
# ('3BGU', 'Vanguardistas', 'Martes', 2, 'NAT_3BGU', 'CARLOS BENALCÁZAR')
# ('3BGU', 'Vanguardistas', 'Martes', 3, 'PEN_3BGU', 'ANITA BARRENO')
# ('3BGU', 'Vanguardistas', 'Martes', 4, 'PEN_3BGU', 'ANITA BARRENO')
# ('3BGU', 'Vanguardistas', 'Martes', 5, 'LEN_3BGU', 'ANDRÉS OLMEDO')
# ('3BGU', 'Vanguardistas', 'Martes', 7, 'PLA_3BGU', 'KEVIN VICENTE')
# ('3BGU', 'Vanguardistas', 'Martes', 8, 'PLA_3BGU', 'KEVIN VICENTE')
# ('3BGU', 'Vanguardistas', 'Martes', 9, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Vanguardistas', 'Martes', 10, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Vanguardistas', 'Martes', 11, 'SOC_3BGU', 'ISABEL GARCÍA')
# ('3BGU', 'Vanguardistas', 'Martes', 12, 'SOC_3BGU', 'ISABEL GARCÍA')
# ('3BGU', 'Vanguardistas', 'Martes', 15, 'ECO_3BGU', 'MARJURIE JÁCOME')
# ('3BGU', 'Vanguardistas', 'Martes', 16, 'SAL_3BGU', 'VANESSA ESPÍN')
# ('3BGU', 'Vanguardistas', 'Miércoles', 3, 'LEC_3BGU', 'PATY FLORES')
# ('3BGU', 'Vanguardistas', 'Miércoles', 4, 'FIS_3BGU', 'JOSÉ NICOLALDE')
# ('3BGU', 'Vanguardistas', 'Miércoles', 5, 'FIS_3BGU', 'JOSÉ NICOLALDE')
# ('3BGU', 'Vanguardistas', 'Miércoles', 7, 'ROB_3BGU', 'DAVID RÓGEL')
# ('3BGU', 'Vanguardistas', 'Miércoles', 8, 'ROB_3BGU', 'DAVID RÓGEL')
# ('3BGU', 'Vanguardistas', 'Miércoles', 9, 'SOC_3BGU', 'ISABEL GARCÍA')
# ('3BGU', 'Vanguardistas', 'Miércoles', 10, 'SOC_3BGU', 'ISABEL GARCÍA')
# ('3BGU', 'Vanguardistas', 'Miércoles', 11, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Vanguardistas', 'Miércoles', 12, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Vanguardistas', 'Jueves', 1, 'DER_3BGU', 'CORALÍA CÓRDOVA')
# ('3BGU', 'Vanguardistas', 'Jueves', 2, 'COM_3BGU', 'ERIKA CAIZATOA')
# ('3BGU', 'Vanguardistas', 'Jueves', 3, 'EDU_3BGU', 'EF ESPECIAL')
# ('3BGU', 'Vanguardistas', 'Jueves', 4, 'EDU_3BGU', 'EF ESPECIAL')
# ('3BGU', 'Vanguardistas', 'Jueves', 5, 'NAT_3BGU', 'CARLOS BENALCÁZAR')
# ('3BGU', 'Vanguardistas', 'Jueves', 7, 'GEO_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Vanguardistas', 'Jueves', 8, 'GEO_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Vanguardistas', 'Jueves', 9, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Vanguardistas', 'Jueves', 10, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Vanguardistas', 'Jueves', 11, 'SPE_3BGU', 'CHRISTIAN SOLANO')
# ('3BGU', 'Vanguardistas', 'Jueves', 12, 'INV_3BGU', 'KARLA LAZCANO')
# ('3BGU', 'Vanguardistas', 'Jueves', 15, 'DES_3BGU', 'JANETH MELO')
# ('3BGU', 'Vanguardistas', 'Jueves', 16, 'DES_3BGU', 'JANETH MELO')
# ('3BGU', 'Vanguardistas', 'Viernes', 1, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Vanguardistas', 'Viernes', 2, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Vanguardistas', 'Viernes', 3, 'GEO_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Vanguardistas', 'Viernes', 4, 'EMP_3BGU', 'MARÍA BELÉN MALDONADO')
# ('3BGU', 'Vanguardistas', 'Viernes', 5, 'EMP_3BGU', 'MARÍA BELÉN MALDONADO')
# ('3BGU', 'Vanguardistas', 'Viernes', 7, 'PRO_3BGU', 'MARCO SAFADI')
# ('3BGU', 'Vanguardistas', 'Viernes', 8, 'PRO_3BGU', 'MARCO SAFADI')
# ('3BGU', 'Vanguardistas', 'Viernes', 9, 'LEN_3BGU', 'ANDRÉS OLMEDO')
# ('3BGU', 'Vanguardistas', 'Viernes', 10, 'LEN_3BGU', 'ANDRÉS OLMEDO')
# ('3BGU', 'Vanguardistas', 'Viernes', 11, 'QUI_3BGU', 'MAYRA QUISHPE')
# ('3BGU', 'Vanguardistas', 'Viernes', 12, 'QUI_3BGU', 'MAYRA QUISHPE')

# %% [markdown]
# ### 🧪 8. Verificación de docentes asignados en el cromosoma
#
# La función `verificar_docentes_asignados(cromosoma)` permite identificar genes que no tienen un docente asignado (es decir, aquellos donde `docente is None`).
#
# #### 📌 Funcionalidad:
# - Recorre cada gen del cromosoma.
# - Detecta aquellos cuya posición de docente (`gene[5]`) está vacía (`None`).
# - Imprime un resumen indicando cuántas asignaciones no tienen docente y detalla cada una.
#
# #### ✅ Uso:
# Permite validar que el diccionario `dic_profesores` esté completo y correctamente sincronizado con los códigos de materia usados en los archivos `.txt`.
#
# #### 🔁 Retorno:
# Devuelve una lista con los genes problemáticos, útil para análisis o correcciones posteriores.

# %%
def verificar_docentes_asignados(cromosoma):
    errores = [gene for gene in cromosoma if gene[5] is None]

    if not errores:
        print("✅ Todos los docentes están correctamente asignados.")
    else:
        print(f"❌ Se encontraron {len(errores)} asignaciones sin docente.")
        for gene in errores:
            nivel, aula, dia, hora, codigo_materia, _ = gene
            print(f"- Sin docente → Nivel: {nivel}, Aula: {aula}, Día: {dia}, Hora: {hora}, Materia: {codigo_materia}")

    return errores  # retorna la lista por si necesitas trabajar con ella

# %%
errores = verificar_docentes_asignados(cromosoma)
# Out:
# ✅ Todos los docentes están correctamente asignados.

# %% [markdown]
# ### 💾 9. Guardado del cromosoma en archivo `.txt`
#
# La función `guardar_cromosoma_en_txt(cromosoma, nombre_archivo)` permite almacenar un cromosoma completo en un archivo plano para usos posteriores, como:
#
# - Carga en notebooks de evaluación.
# - Visualización en LaTeX.
# - Backup de soluciones elite.
#
# #### 📌 Detalles de funcionamiento:
# - Recorre todos los genes del cromosoma.
# - Escribe cada gen como una línea de texto en formato de tupla.
# - El archivo resultante es fácilmente reutilizable con la función `cargar_cromosoma_desde_txt`.
#
# #### ✅ Ejemplo de uso:
# ```python
# guardar_cromosoma_en_txt(cromosoma, "Horario_LEV.txt")

# %%
def guardar_cromosoma_en_txt(cromosoma, nombre_archivo):
    with open(nombre_archivo, "w", encoding="utf-8") as f:
        for gene in cromosoma:
            f.write(f"{gene}\n")
    print(f"📁 Cromosoma guardado correctamente en: {nombre_archivo}")

# %%
guardar_cromosoma_en_txt(cromosoma, "Horario_LEV.txt")
# Out:
# 📁 Cromosoma guardado correctamente en: Horario_LEV.txt
