# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
ruta = '/content/drive/MyDrive/Tesis_MSDS/Horario_LEV.txt'

# Cargar el archivo
# horario = pd.read_csv(ruta+"/Horario_LEV.txt")

# %% [markdown]
# ### 📥 1. Cargar cromosoma desde archivo `.txt`
#
# En este bloque se carga el cromosoma almacenado en un archivo `.txt`, transformándolo en un DataFrame de Pandas con columnas organizadas por nivel, aula, día, hora, materia y docente. Se normalizan los tipos de datos y se eliminan espacios innecesarios.

# %%
import pandas as pd

# --- 1. Cargar cromosoma ---
cromosoma = []
with open(ruta, "r", encoding="utf-8") as f:
    for linea in f:
        if linea.strip():
            cromosoma.append(eval(linea.strip()))

df = pd.DataFrame(cromosoma, columns=["Nivel", "Aula", "Día", "Hora", "Materia", "Docente"])
df["Hora"] = df["Hora"].astype(int)
for col in ["Nivel", "Aula", "Día", "Materia", "Docente"]:
    df[col] = df[col].astype(str).str.strip()

# %% [markdown]
# ### 🧩 2. Definición de bloques especiales
#
# Función `tipo_bloque_especial` que determina si un bloque de horario debe ser marcado como `RECESO`, `ALMUERZO`, `EVALEV` o `CLUBS`, en función del nivel, día y franja horaria. Esta lógica se utiliza para agregar automáticamente estas actividades en el horario generado.

# %%
# --- 2. Bloques especiales ---
def tipo_bloque_especial(nivel, dia, hora):
    if nivel in ["1EGB", "2EGB", "3EGB"] and hora == 5:
        return "RECESO"
    if nivel not in ["1EGB", "2EGB", "3EGB"] and hora == 6:
        return "RECESO"
    if nivel in ["1EGB", "2EGB", "3EGB", "4EGB", "5EGB", "6EGB", "7EGB"] and hora in [11, 12]:
        return "ALMUERZO"
    if nivel in ["8EGB", "9EGB", "10EGB", "1BGU", "2BGU", "3BGU"] and hora in [13, 14]:
        return "ALMUERZO"
    if dia == "Miércoles" and hora in [1, 2]:
        return "EVALEV"
    if nivel == "1EGB" and ((dia == "Lunes" and hora in [15, 16]) or (dia == "Jueves" and hora in [13, 14])):
        return "CLUBS"
    if nivel in ["2EGB", "3EGB", "4EGB", "5EGB", "6EGB", "7EGB"] and dia in ["Martes", "Jueves"] and hora in [15, 16]:
        return "CLUBS"
    if nivel in ["8EGB", "9EGB", "10EGB", "1BGU", "2BGU", "3BGU"] and dia in ["Miércoles", "Viernes"] and hora in [15, 16]:
        return "CLUBS"
    return None

# %% [markdown]
# ### 🔤 3. Función de escape para caracteres especiales de LaTeX
#
# La función `latex_escape` reemplaza los caracteres conflictivos como `\`, `_`, `%`, etc., por versiones seguras compatibles con LaTeX. Esto asegura que los nombres de materias y docentes no causen errores de compilación.

# %%
# --- 3. Escapar caracteres especiales LaTeX ---
def latex_escape(texto):
    return (
        texto.replace("\\", "\\textbackslash{}")
             .replace("&", "\\&")
             .replace("%", "\\%")
             .replace("$", "\\$")
             .replace("#", "\\#")
             .replace("_", "\\_")
             .replace("{", "\\{")
             .replace("}", "\\}")
             .replace("~", "\\textasciitilde{}")
             .replace("^", "\\^{}")
    )

# %% [markdown]
# ### 🧾 4. Función `generar_tabla_latex`: construcción del horario en formato LaTeX
#
# Esta función toma como entrada un nivel, un aula y el DataFrame con asignaciones, y genera automáticamente una tabla en código LaTeX:
#
# - Define la estructura de días y horas.
# - Rellena los bloques especiales y las horas de tutoría.
# - Inserta las asignaciones de materias con nombre de docente.
# - Aplica coloreado condicional con `\cellcolor`.
# - Devuelve un bloque completo de tabla listo para insertar en documentos LaTeX usando `landscape`, `makecell` y `tabular`.
#
# Incluye etiquetas (`\label`) y estilos gráficos como `arrayrulewidth`, `rowcolor` y `caption`.

# %%
# --- 4. Función para generar tabla con formato final ---
def generar_tabla_latex(nivel, aula, df):
    dias = ["Lunes", "Martes", "Miércoles", "Jueves", "Viernes"]
    franjas = {
        "Act. Inicial": "7h30 a 7h45", 1: "7h45 a 8h15", 2: "8h15 a 8h45", 3: "8h45 a 9h15",
        4: "9h15 a 9h45", 5: "9h45 a 10h15", 6: "10h15 a 10h45", 7: "10h45 a 11h15",
        8: "11h15 a 11h45", 9: "11h45 a 12h15", 10: "12h15 a 12h45", 11: "12h45 a 13h15",
        12: "13h15 a 13h45", 13: "13h45 a 14h15", 14: "14h15 a 14h45", 15: "14h45 a 15h15",
        16: "15h15 a 15h45", "Act. Final": "15h45 a 16h00"
    }
    colores = {
        "TUTORIA": "purple!20",
        "RECESO": "cyan!20",
        "ALMUERZO": "teal!20",
        "CLUBS": "orange!20",
        "EVALEV": "yellow!30"
    }

    horas = ["Act. Inicial"] + list(range(1, 17)) + ["Act. Final"]
    tabla = pd.DataFrame(index=horas, columns=dias)

    # Rellenar tabla con bloques especiales y TUTORIA
    for h in horas:
        for d in dias:
            if isinstance(h, int):
                bloque = tipo_bloque_especial(nivel, d, h)
                if bloque:
                    tabla.at[h, d] = bloque
            else:
                tabla.at[h, d] = "TUTORIA"

    # Insertar materias reales
    datos = df[(df["Nivel"] == nivel) & (df["Aula"] == aula)]
    datos_unicos = datos.groupby(["Hora", "Día"], as_index=False).first()
    for _, fila in datos_unicos.iterrows():
        hora = int(fila["Hora"])
        dia = fila["Día"]
        materia = latex_escape(fila["Materia"])
        docente = latex_escape(fila["Docente"])
        tabla.at[hora, dia] = f"\\makecell{{{materia}\\\\({docente})}}"

    # Construcción del bloque LaTeX
    latex = []
    latex.append("\\begin{landscape}")
    latex.append("\\begin{table}[H]")
    latex.append("\\centering")
    latex.append("\\scriptsize")
    latex.append(f"\\caption{{Horario para {latex_escape(nivel)} {latex_escape(aula)}}}")
    latex.append("\\setlength{\\arrayrulewidth}{1pt}")
    latex.append("\\arrayrulecolor{black}")
    latex.append("\\begin{tabular}{|c|c|" + "c|" * len(dias) + "}")
    latex.append("\\specialrule{1pt}{0pt}{0pt}")
    latex.append("\\rowcolor{white}")
    latex.append("\\textbf{Hora} & \\textbf{Horario} & " + " & ".join([f"\\textbf{{{d}}}" for d in dias]) + " \\\\ \\specialrule{1pt}{0pt}{0pt}")

    for h in horas:
        fila = [str(h), franjas[h]]
        for d in dias:
            celda = tabla.at[h, d]
            if isinstance(celda, str) and celda in colores:
                fila.append(f"\\cellcolor{{{colores[celda]}}}\\textbf{{{celda}}}")
            else:
                fila.append(celda if pd.notna(celda) else "")
        latex.append(" & ".join(fila) + " \\\\ \\hline")

    latex.append("\\end{tabular}")
    latex.append(f"\\label{{tab:{nivel}_{aula}}}")
    latex.append("\\end{table}")
    latex.append("\\end{landscape}")
    return "\n".join(latex)

# %% [markdown]
# ### ▶️ 5. Ejemplo de ejecución para "1EGB - Exitosos"
#
# Se genera e imprime la tabla LaTeX del horario correspondiente al aula "Exitosos" del nivel "1EGB".

# %%
# --- 5. Ejecutar para ejemplo: 1EGB Ejemplares ---
latex_code = generar_tabla_latex("1EGB", "Exitosos", df)
print(latex_code)
# Out:
# \begin{landscape}
# \begin{table}[H]
# \centering
# \scriptsize
# \caption{Horario para 1EGB Exitosos}
# \setlength{\arrayrulewidth}{1pt}
# \arrayrulecolor{black}
# \begin{tabular}{|c|c|c|c|c|c|c|}
# \specialrule{1pt}{0pt}{0pt}
# \rowcolor{white}
# \textbf{Hora} & \textbf{Horario} & \textbf{Lunes} & \textbf{Martes} & \textbf{Miércoles} & \textbf{Jueves} & \textbf{Viernes} \\ \specialrule{1pt}{0pt}{0pt}
# Act. Inicial & 7h30 a 7h45 & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} \\ \hline
# 1 & 7h45 a 8h15 & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{LEC\_1EGB\\(ALISON PLAZA)} & \cellcolor{yellow!30}\textbf{EVALEV} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{EST\_1EGB\\(SANTIAGO CALLE)} \\ \hline
# 2 & 8h15 a 8h45 & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{ING\_1EGB\\(MARCIA HERRERA VÁSQUEZ)} & \cellcolor{yellow!30}\textbf{EVALEV} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{EST\_1EGB\\(SANTIAGO CALLE)} \\ \hline
# 3 & 8h45 a 9h15 & \makecell{ESP\_1EGB\\(MERY VENEGAS)} & \makecell{ING\_1EGB\\(MARCIA HERRERA VÁSQUEZ)} & \makecell{LEC\_1EGB\\(ALISON PLAZA)} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} \\ \hline
# 4 & 9h15 a 9h45 & \makecell{ESP\_1EGB\\(MERY VENEGAS)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{LEC\_1EGB\\(ALISON PLAZA)} & \makecell{PEN\_1EGB\\(FERNANDA CAÑIZARES)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} \\ \hline
# 5 & 9h45 a 10h15 & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} \\ \hline
# 6 & 10h15 a 10h45 & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{PEN\_1EGB\\(FERNANDA CAÑIZARES)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} \\ \hline
# 7 & 10h45 a 11h15 & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{DER\_1EGB\\(CORALÍA CÓRDOVA)} & \makecell{NAT\_1EGB\\(MARIANA HIDALGO)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{SAL\_1EGB\\(VANESSA ESPÍN)} \\ \hline
# 8 & 11h15 a 11h45 & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{COM\_1EGB\\(ERIKA CAIZATOA)} & \makecell{NAT\_1EGB\\(MARIANA HIDALGO)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{ECO\_1EGB\\(MARJURIE JÁCOME)} \\ \hline
# 9 & 11h45 a 12h15 & \makecell{EST\_1EGB\\(SANTIAGO CALLE)} & \makecell{ROB\_1EGB\\(JENNY CHICAIZA)} & \makecell{EDU\_1EGB\\(EF ESPECIAL)} & \makecell{INV\_1EGB\\(KARLA LAZCANO)} & \makecell{ING\_1EGB\\(MARCIA HERRERA VÁSQUEZ)} \\ \hline
# 10 & 12h15 a 12h45 & \makecell{EXT\_1EGB\\(MARIEL RODRIGUEZ)} & \makecell{ROB\_1EGB\\(JENNY CHICAIZA)} & \makecell{EDU\_1EGB\\(EF ESPECIAL)} & \makecell{SPE\_1EGB\\(CHRISTIAN SOLANO)} & \makecell{ING\_1EGB\\(MARCIA HERRERA VÁSQUEZ)} \\ \hline
# 11 & 12h45 a 13h15 & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} \\ \hline
# 12 & 13h15 a 13h45 & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} \\ \hline
# 13 & 13h45 a 14h15 & \makecell{MUS\_1EGB\\(LUIS JÁCOME)} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} \\ \hline
# 14 & 14h15 a 14h45 & \makecell{DAN\_1EGB\\(PAOLA LÓPEZ)} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} \\ \hline
# 15 & 14h45 a 15h15 & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{ING\_1EGB\\(MARCIA HERRERA VÁSQUEZ)} & \makecell{NAT\_1EGB\\(MARIANA HIDALGO)} & \makecell{DES\_1EGB\\(ANDREA MACIAS)} \\ \hline
# 16 & 15h15 a 15h45 & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{ING\_1EGB\\(MARCIA HERRERA VÁSQUEZ)} & \makecell{NAT\_1EGB\\(MARIANA HIDALGO)} & \makecell{DES\_1EGB\\(ANDREA MACIAS)} \\ \hline
# Act. Final & 15h45 a 16h00 & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} \\ \hline
# \end{tabular}
# \label{tab:1EGB_Exitosos}
# \end{table}
# \end{landscape}

# %% [markdown]
# ### 📑 6. Impresión de todos los horarios ordenados
#
# La función `imprimir_todos_los_horarios_ordenados(df)` genera las tablas LaTeX para todos los niveles y aulas presentes en el DataFrame `df`.
#
# - Se define un orden lógico para los niveles educativos (de 1EGB a 3BGU).
# - Se eliminan duplicados y se ordenan los pares (Nivel, Aula).
# - Se recorre cada combinación ordenada y se imprime la tabla LaTeX generada con la función `generar_tabla_latex`.
#
# Este bloque permite generar automáticamente todos los horarios del sistema en un solo paso, siguiendo una estructura ordenada y lista para ser copiada o insertada en un documento de LaTeX.

# %%
def imprimir_todos_los_horarios_ordenados(df):
    orden_niveles = ['1EGB', '2EGB', '3EGB', '4EGB', '5EGB', '6EGB',
                     '7EGB', '8EGB', '9EGB', '10EGB', '1BGU', '2BGU', '3BGU']

    niveles_aulas = df[["Nivel", "Aula"]].drop_duplicates()

    # Asignar un valor de orden a cada nivel
    niveles_aulas["Orden"] = niveles_aulas["Nivel"].apply(lambda x: orden_niveles.index(x) if x in orden_niveles else -1)

    # Ordenar por el índice definido
    niveles_aulas = niveles_aulas.sort_values(by=["Orden", "Aula"])

    for _, fila in niveles_aulas.iterrows():
        nivel = fila["Nivel"]
        aula = fila["Aula"]
        print(f"% === HORARIO: {nivel} {aula} ===")
        print(generar_tabla_latex(nivel, aula, df))
        print("\n\n")

imprimir_todos_los_horarios_ordenados(df)
# Out:
# % === HORARIO: 1EGB Ejemplares ===
# \begin{landscape}
# \begin{table}[H]
# \centering
# \scriptsize
# \caption{Horario para 1EGB Ejemplares}
# \setlength{\arrayrulewidth}{1pt}
# \arrayrulecolor{black}
# \begin{tabular}{|c|c|c|c|c|c|c|}
# \specialrule{1pt}{0pt}{0pt}
# \rowcolor{white}
# \textbf{Hora} & \textbf{Horario} & \textbf{Lunes} & \textbf{Martes} & \textbf{Miércoles} & \textbf{Jueves} & \textbf{Viernes} \\ \specialrule{1pt}{0pt}{0pt}
# Act. Inicial & 7h30 a 7h45 & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} \\ \hline
# 1 & 7h45 a 8h15 & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \cellcolor{yellow!30}\textbf{EVALEV} & \makecell{ING\_1EGB\\(MARCIA HERRERA VÁSQUEZ)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} \\ \hline
# 2 & 8h15 a 8h45 & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \cellcolor{yellow!30}\textbf{EVALEV} & \makecell{ING\_1EGB\\(MARCIA HERRERA VÁSQUEZ)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} \\ \hline
# 3 & 8h45 a 9h15 & \makecell{PEN\_1EGB\\(FERNANDA CAÑIZARES)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{DES\_1EGB\\(ANDREA MACIAS)} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} \\ \hline
# 4 & 9h15 a 9h45 & \makecell{PEN\_1EGB\\(FERNANDA CAÑIZARES)} & \makecell{EST\_1EGB\\(SANTIAGO CALLE)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} \\ \hline
# 5 & 9h45 a 10h15 & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} \\ \hline
# 6 & 10h15 a 10h45 & \makecell{DES\_1EGB\\(ANDREA MACIAS)} & \makecell{EXT\_1EGB\\(MARIEL RODRIGUEZ)} & \makecell{LEC\_1EGB\\(ALISON PLAZA)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} \\ \hline
# 7 & 10h45 a 11h15 & \makecell{EDU\_1EGB\\(EF ESPECIAL)} & \makecell{COM\_1EGB\\(ERIKA CAIZATOA)} & \makecell{EST\_1EGB\\(SANTIAGO CALLE)} & \makecell{LEC\_1EGB\\(ALISON PLAZA)} & \makecell{ECO\_1EGB\\(MARJURIE JÁCOME)} \\ \hline
# 8 & 11h15 a 11h45 & \makecell{EDU\_1EGB\\(EF ESPECIAL)} & \makecell{DER\_1EGB\\(CORALÍA CÓRDOVA)} & \makecell{EST\_1EGB\\(SANTIAGO CALLE)} & \makecell{LEC\_1EGB\\(ALISON PLAZA)} & \makecell{SAL\_1EGB\\(VANESSA ESPÍN)} \\ \hline
# 9 & 11h45 a 12h15 & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{SPE\_1EGB\\(CHRISTIAN SOLANO)} & \makecell{NAT\_1EGB\\(MARIANA HIDALGO)} \\ \hline
# 10 & 12h15 a 12h45 & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{INV\_1EGB\\(KARLA LAZCANO)} & \makecell{NAT\_1EGB\\(MARIANA HIDALGO)} \\ \hline
# 11 & 12h45 a 13h15 & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} \\ \hline
# 12 & 13h15 a 13h45 & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} \\ \hline
# 13 & 13h45 a 14h15 & \makecell{DAN\_1EGB\\(PAOLA LÓPEZ)} & \makecell{ING\_1EGB\\(MARCIA HERRERA VÁSQUEZ)} & \makecell{ROB\_1EGB\\(JENNY CHICAIZA)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{ING\_1EGB\\(MARCIA HERRERA VÁSQUEZ)} \\ \hline
# 14 & 14h15 a 14h45 & \makecell{MUS\_1EGB\\(LUIS JÁCOME)} & \makecell{ING\_1EGB\\(MARCIA HERRERA VÁSQUEZ)} & \makecell{ROB\_1EGB\\(JENNY CHICAIZA)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{ING\_1EGB\\(MARCIA HERRERA VÁSQUEZ)} \\ \hline
# 15 & 14h45 a 15h15 & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{NAT\_1EGB\\(MARIANA HIDALGO)} & \makecell{ESP\_1EGB\\(MERY VENEGAS)} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} \\ \hline
# 16 & 15h15 a 15h45 & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{NAT\_1EGB\\(MARIANA HIDALGO)} & \makecell{ESP\_1EGB\\(MERY VENEGAS)} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} \\ \hline
# Act. Final & 15h45 a 16h00 & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} \\ \hline
# \end{tabular}
# \label{tab:1EGB_Ejemplares}
# \end{table}
# \end{landscape}
#
#
#
# % === HORARIO: 1EGB Entusiastas ===
# \begin{landscape}
# \begin{table}[H]
# \centering
# \scriptsize
# \caption{Horario para 1EGB Entusiastas}
# \setlength{\arrayrulewidth}{1pt}
# \arrayrulecolor{black}
# \begin{tabular}{|c|c|c|c|c|c|c|}
# \specialrule{1pt}{0pt}{0pt}
# \rowcolor{white}
# \textbf{Hora} & \textbf{Horario} & \textbf{Lunes} & \textbf{Martes} & \textbf{Miércoles} & \textbf{Jueves} & \textbf{Viernes} \\ \specialrule{1pt}{0pt}{0pt}
# Act. Inicial & 7h30 a 7h45 & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} \\ \hline
# 1 & 7h45 a 8h15 & \makecell{EXT\_1EGB\\(MARIEL RODRIGUEZ)} & \makecell{SAL\_1EGB\\(VANESSA ESPÍN)} & \cellcolor{yellow!30}\textbf{EVALEV} & \makecell{LEC\_1EGB\\(ALISON PLAZA)} & \makecell{EDU\_1EGB\\(EF ESPECIAL)} \\ \hline
# 2 & 8h15 a 8h45 & \makecell{EDU\_1EGB\\(EF ESPECIAL)} & \makecell{ECO\_1EGB\\(MARJURIE JÁCOME)} & \cellcolor{yellow!30}\textbf{EVALEV} & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{EDU\_1EGB\\(EF ESPECIAL)} \\ \hline
# 3 & 8h45 a 9h15 & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{NAT\_1EGB\\(MARIANA HIDALGO)} & \makecell{EST\_1EGB\\(SANTIAGO CALLE)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{PEN\_1EGB\\(FERNANDA CAÑIZARES)} \\ \hline
# 4 & 9h15 a 9h45 & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{NAT\_1EGB\\(MARIANA HIDALGO)} & \makecell{EST\_1EGB\\(SANTIAGO CALLE)} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{PEN\_1EGB\\(FERNANDA CAÑIZARES)} \\ \hline
# 5 & 9h45 a 10h15 & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} \\ \hline
# 6 & 10h15 a 10h45 & \makecell{ROB\_1EGB\\(JENNY CHICAIZA)} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{DES\_1EGB\\(ANDREA MACIAS)} \\ \hline
# 7 & 10h45 a 11h15 & \makecell{ROB\_1EGB\\(JENNY CHICAIZA)} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{DAN\_1EGB\\(PAOLA LÓPEZ)} & \makecell{INV\_1EGB\\(KARLA LAZCANO)} \\ \hline
# 8 & 11h15 a 11h45 & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{MUS\_1EGB\\(LUIS JÁCOME)} & \makecell{SPE\_1EGB\\(CHRISTIAN SOLANO)} \\ \hline
# 9 & 11h45 a 12h15 & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{COM\_1EGB\\(ERIKA CAIZATOA)} & \makecell{NAT\_1EGB\\(MARIANA HIDALGO)} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} \\ \hline
# 10 & 12h15 a 12h45 & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{DER\_1EGB\\(CORALÍA CÓRDOVA)} & \makecell{NAT\_1EGB\\(MARIANA HIDALGO)} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} \\ \hline
# 11 & 12h45 a 13h15 & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} \\ \hline
# 12 & 13h15 a 13h45 & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} \\ \hline
# 13 & 13h45 a 14h15 & \makecell{ING\_1EGB\\(MARCIA HERRERA VÁSQUEZ)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{LEC\_1EGB\\(ALISON PLAZA)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{LEN\_1EGB\\(MALENA OÑA)} \\ \hline
# 14 & 14h15 a 14h45 & \makecell{ING\_1EGB\\(MARCIA HERRERA VÁSQUEZ)} & \makecell{DES\_1EGB\\(ANDREA MACIAS)} & \makecell{LEC\_1EGB\\(ALISON PLAZA)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{LEN\_1EGB\\(MALENA OÑA)} \\ \hline
# 15 & 14h45 a 15h15 & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{ING\_1EGB\\(MARCIA HERRERA VÁSQUEZ)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{ING\_1EGB\\(MARCIA HERRERA VÁSQUEZ)} & \makecell{ESP\_1EGB\\(MERY VENEGAS)} \\ \hline
# 16 & 15h15 a 15h45 & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{ING\_1EGB\\(MARCIA HERRERA VÁSQUEZ)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{ING\_1EGB\\(MARCIA HERRERA VÁSQUEZ)} & \makecell{ESP\_1EGB\\(MERY VENEGAS)} \\ \hline
# Act. Final & 15h45 a 16h00 & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} \\ \hline
# \end{tabular}
# \label{tab:1EGB_Entusiastas}
# \end{table}
# \end{landscape}
#
#
#
# % === HORARIO: 1EGB Estudiosos ===
# \begin{landscape}
# \begin{table}[H]
# \centering
# \scriptsize
# \caption{Horario para 1EGB Estudiosos}
# \setlength{\arrayrulewidth}{1pt}
# \arrayrulecolor{black}
# \begin{tabular}{|c|c|c|c|c|c|c|}
# \specialrule{1pt}{0pt}{0pt}
# \rowcolor{white}
# \textbf{Hora} & \textbf{Horario} & \textbf{Lunes} & \textbf{Martes} & \textbf{Miércoles} & \textbf{Jueves} & \textbf{Viernes} \\ \specialrule{1pt}{0pt}{0pt}
# Act. Inicial & 7h30 a 7h45 & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} \\ \hline
# 1 & 7h45 a 8h15 & \makecell{PEN\_1EGB\\(FERNANDA CAÑIZARES)} & \makecell{ECO\_1EGB\\(MARJURIE JÁCOME)} & \cellcolor{yellow!30}\textbf{EVALEV} & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{DES\_1EGB\\(ANDREA MACIAS)} \\ \hline
# 2 & 8h15 a 8h45 & \makecell{PEN\_1EGB\\(FERNANDA CAÑIZARES)} & \makecell{SAL\_1EGB\\(VANESSA ESPÍN)} & \cellcolor{yellow!30}\textbf{EVALEV} & \makecell{EXT\_1EGB\\(MARIEL RODRIGUEZ)} & \makecell{DES\_1EGB\\(ANDREA MACIAS)} \\ \hline
# 3 & 8h45 a 9h15 & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{NAT\_1EGB\\(MARIANA HIDALGO)} & \makecell{EDU\_1EGB\\(EF ESPECIAL)} & \makecell{LEC\_1EGB\\(ALISON PLAZA)} \\ \hline
# 4 & 9h15 a 9h45 & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{NAT\_1EGB\\(MARIANA HIDALGO)} & \makecell{ESP\_1EGB\\(MERY VENEGAS)} & \makecell{LEC\_1EGB\\(ALISON PLAZA)} \\ \hline
# 5 & 9h45 a 10h15 & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} \\ \hline
# 6 & 10h15 a 10h45 & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{ING\_1EGB\\(MARCIA HERRERA VÁSQUEZ)} & \makecell{ING\_1EGB\\(MARCIA HERRERA VÁSQUEZ)} & \makecell{ESP\_1EGB\\(MERY VENEGAS)} & \makecell{ROB\_1EGB\\(JENNY CHICAIZA)} \\ \hline
# 7 & 10h45 a 11h15 & \makecell{NAT\_1EGB\\(MARIANA HIDALGO)} & \makecell{ING\_1EGB\\(MARCIA HERRERA VÁSQUEZ)} & \makecell{ING\_1EGB\\(MARCIA HERRERA VÁSQUEZ)} & \makecell{MUS\_1EGB\\(LUIS JÁCOME)} & \makecell{SPE\_1EGB\\(CHRISTIAN SOLANO)} \\ \hline
# 8 & 11h15 a 11h45 & \makecell{NAT\_1EGB\\(MARIANA HIDALGO)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{DAN\_1EGB\\(PAOLA LÓPEZ)} & \makecell{INV\_1EGB\\(KARLA LAZCANO)} \\ \hline
# 9 & 11h45 a 12h15 & \makecell{ING\_1EGB\\(MARCIA HERRERA VÁSQUEZ)} & \makecell{EDU\_1EGB\\(EF ESPECIAL)} & \makecell{DER\_1EGB\\(CORALÍA CÓRDOVA)} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} \\ \hline
# 10 & 12h15 a 12h45 & \makecell{ING\_1EGB\\(MARCIA HERRERA VÁSQUEZ)} & \makecell{EDU\_1EGB\\(EF ESPECIAL)} & \makecell{COM\_1EGB\\(ERIKA CAIZATOA)} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} \\ \hline
# 11 & 12h45 a 13h15 & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} \\ \hline
# 12 & 13h15 a 13h45 & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} \\ \hline
# 13 & 13h45 a 14h15 & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{ROB\_1EGB\\(JENNY CHICAIZA)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{EST\_1EGB\\(SANTIAGO CALLE)} \\ \hline
# 14 & 14h15 a 14h45 & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{LEC\_1EGB\\(ALISON PLAZA)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{EST\_1EGB\\(SANTIAGO CALLE)} \\ \hline
# 15 & 14h45 a 15h15 & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} \\ \hline
# 16 & 15h15 a 15h45 & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} \\ \hline
# Act. Final & 15h45 a 16h00 & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} \\ \hline
# \end{tabular}
# \label{tab:1EGB_Estudiosos}
# \end{table}
# \end{landscape}
#
#
#
# % === HORARIO: 1EGB Exitosos ===
# \begin{landscape}
# \begin{table}[H]
# \centering
# \scriptsize
# \caption{Horario para 1EGB Exitosos}
# \setlength{\arrayrulewidth}{1pt}
# \arrayrulecolor{black}
# \begin{tabular}{|c|c|c|c|c|c|c|}
# \specialrule{1pt}{0pt}{0pt}
# \rowcolor{white}
# \textbf{Hora} & \textbf{Horario} & \textbf{Lunes} & \textbf{Martes} & \textbf{Miércoles} & \textbf{Jueves} & \textbf{Viernes} \\ \specialrule{1pt}{0pt}{0pt}
# Act. Inicial & 7h30 a 7h45 & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} \\ \hline
# 1 & 7h45 a 8h15 & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{LEC\_1EGB\\(ALISON PLAZA)} & \cellcolor{yellow!30}\textbf{EVALEV} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{EST\_1EGB\\(SANTIAGO CALLE)} \\ \hline
# 2 & 8h15 a 8h45 & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{ING\_1EGB\\(MARCIA HERRERA VÁSQUEZ)} & \cellcolor{yellow!30}\textbf{EVALEV} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{EST\_1EGB\\(SANTIAGO CALLE)} \\ \hline
# 3 & 8h45 a 9h15 & \makecell{ESP\_1EGB\\(MERY VENEGAS)} & \makecell{ING\_1EGB\\(MARCIA HERRERA VÁSQUEZ)} & \makecell{LEC\_1EGB\\(ALISON PLAZA)} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} \\ \hline
# 4 & 9h15 a 9h45 & \makecell{ESP\_1EGB\\(MERY VENEGAS)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{LEC\_1EGB\\(ALISON PLAZA)} & \makecell{PEN\_1EGB\\(FERNANDA CAÑIZARES)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} \\ \hline
# 5 & 9h45 a 10h15 & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} \\ \hline
# 6 & 10h15 a 10h45 & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{PEN\_1EGB\\(FERNANDA CAÑIZARES)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} \\ \hline
# 7 & 10h45 a 11h15 & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{DER\_1EGB\\(CORALÍA CÓRDOVA)} & \makecell{NAT\_1EGB\\(MARIANA HIDALGO)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{SAL\_1EGB\\(VANESSA ESPÍN)} \\ \hline
# 8 & 11h15 a 11h45 & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{COM\_1EGB\\(ERIKA CAIZATOA)} & \makecell{NAT\_1EGB\\(MARIANA HIDALGO)} & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{ECO\_1EGB\\(MARJURIE JÁCOME)} \\ \hline
# 9 & 11h45 a 12h15 & \makecell{EST\_1EGB\\(SANTIAGO CALLE)} & \makecell{ROB\_1EGB\\(JENNY CHICAIZA)} & \makecell{EDU\_1EGB\\(EF ESPECIAL)} & \makecell{INV\_1EGB\\(KARLA LAZCANO)} & \makecell{ING\_1EGB\\(MARCIA HERRERA VÁSQUEZ)} \\ \hline
# 10 & 12h15 a 12h45 & \makecell{EXT\_1EGB\\(MARIEL RODRIGUEZ)} & \makecell{ROB\_1EGB\\(JENNY CHICAIZA)} & \makecell{EDU\_1EGB\\(EF ESPECIAL)} & \makecell{SPE\_1EGB\\(CHRISTIAN SOLANO)} & \makecell{ING\_1EGB\\(MARCIA HERRERA VÁSQUEZ)} \\ \hline
# 11 & 12h45 a 13h15 & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} \\ \hline
# 12 & 13h15 a 13h45 & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} \\ \hline
# 13 & 13h45 a 14h15 & \makecell{MUS\_1EGB\\(LUIS JÁCOME)} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} \\ \hline
# 14 & 14h15 a 14h45 & \makecell{DAN\_1EGB\\(PAOLA LÓPEZ)} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{MAT\_1EGB\\(PAULINA ÑACATO)} \\ \hline
# 15 & 14h45 a 15h15 & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{ING\_1EGB\\(MARCIA HERRERA VÁSQUEZ)} & \makecell{NAT\_1EGB\\(MARIANA HIDALGO)} & \makecell{DES\_1EGB\\(ANDREA MACIAS)} \\ \hline
# 16 & 15h15 a 15h45 & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{LEN\_1EGB\\(MALENA OÑA)} & \makecell{ING\_1EGB\\(MARCIA HERRERA VÁSQUEZ)} & \makecell{NAT\_1EGB\\(MARIANA HIDALGO)} & \makecell{DES\_1EGB\\(ANDREA MACIAS)} \\ \hline
# Act. Final & 15h45 a 16h00 & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} \\ \hline
# \end{tabular}
# \label{tab:1EGB_Exitosos}
# \end{table}
# \end{landscape}
#
#
#
# % === HORARIO: 2EGB Afectuosos ===
# \begin{landscape}
# \begin{table}[H]
# \centering
# \scriptsize
# \caption{Horario para 2EGB Afectuosos}
# \setlength{\arrayrulewidth}{1pt}
# \arrayrulecolor{black}
# \begin{tabular}{|c|c|c|c|c|c|c|}
# \specialrule{1pt}{0pt}{0pt}
# \rowcolor{white}
# \textbf{Hora} & \textbf{Horario} & \textbf{Lunes} & \textbf{Martes} & \textbf{Miércoles} & \textbf{Jueves} & \textbf{Viernes} \\ \specialrule{1pt}{0pt}{0pt}
# Act. Inicial & 7h30 a 7h45 & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} \\ \hline
# 1 & 7h45 a 8h15 & \makecell{NAT\_2EGB\\(MARIANA HIDALGO)} & \makecell{ROB\_2EGB\\(DAVID CASTRO)} & \cellcolor{yellow!30}\textbf{EVALEV} & \makecell{CIE\_2EGB\\(DIANA SÁNCHEZ)} & \makecell{MAT\_2EGB\\(DINA TOPÓN)} \\ \hline
# 2 & 8h15 a 8h45 & \makecell{NAT\_2EGB\\(MARIANA HIDALGO)} & \makecell{ROB\_2EGB\\(DAVID CASTRO)} & \cellcolor{yellow!30}\textbf{EVALEV} & \makecell{CIE\_2EGB\\(DIANA SÁNCHEZ)} & \makecell{MAT\_2EGB\\(DINA TOPÓN)} \\ \hline
# 3 & 8h45 a 9h15 & \makecell{PRO\_2EGB\\(LUDWIN GUALOTUÑA)} & \makecell{COM\_2EGB\\(ERIKA CAIZATOA)} & \makecell{MAT\_2EGB\\(DINA TOPÓN)} & \makecell{SPE\_2EGB\\(CHRISTIAN SOLANO)} & \makecell{ING\_2EGB\\(MARCIA HERRERA VÁSQUEZ)} \\ \hline
# 4 & 9h15 a 9h45 & \makecell{PRO\_2EGB\\(LUDWIN GUALOTUÑA)} & \makecell{DER\_2EGB\\(CORALÍA CÓRDOVA)} & \makecell{MAT\_2EGB\\(DINA TOPÓN)} & \makecell{INV\_2EGB\\(KARLA LAZCANO)} & \makecell{ING\_2EGB\\(MARCIA HERRERA VÁSQUEZ)} \\ \hline
# 5 & 9h45 a 10h15 & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} \\ \hline
# 6 & 10h15 a 10h45 & \makecell{MAT\_2EGB\\(DINA TOPÓN)} & \makecell{NAT\_2EGB\\(MARIANA HIDALGO)} & \makecell{ECO\_2EGB\\(MARJURIE JÁCOME)} & \makecell{MAT\_2EGB\\(DINA TOPÓN)} & \makecell{LEC\_2EGB\\(ALISON PLAZA)} \\ \hline
# 7 & 10h45 a 11h15 & \makecell{MAT\_2EGB\\(DINA TOPÓN)} & \makecell{NAT\_2EGB\\(MARIANA HIDALGO)} & \makecell{SAL\_2EGB\\(VANESSA ESPÍN)} & \makecell{MAT\_2EGB\\(DINA TOPÓN)} & \makecell{LEC\_2EGB\\(ALISON PLAZA)} \\ \hline
# 8 & 11h15 a 11h45 & \makecell{MAT\_2EGB\\(DINA TOPÓN)} & \makecell{ING\_2EGB\\(MARCIA HERRERA VÁSQUEZ)} & \makecell{ING\_2EGB\\(MARCIA HERRERA VÁSQUEZ)} & \makecell{MAT\_2EGB\\(DINA TOPÓN)} & \makecell{PLA\_2EGB\\(LIZ DÍAZ)} \\ \hline
# 9 & 11h45 a 12h15 & \makecell{LEC\_2EGB\\(ALISON PLAZA)} & \makecell{ING\_2EGB\\(MARCIA HERRERA VÁSQUEZ)} & \makecell{LEN\_2EGB\\(SOFÍA YÉPEZ)} & \makecell{EDU\_2EGB\\(EF ESPECIAL)} & \makecell{PLA\_2EGB\\(LIZ DÍAZ)} \\ \hline
# 10 & 12h15 a 12h45 & \makecell{LEC\_2EGB\\(ALISON PLAZA)} & \makecell{ING\_2EGB\\(MARCIA HERRERA VÁSQUEZ)} & \makecell{LEN\_2EGB\\(SOFÍA YÉPEZ)} & \makecell{EDU\_2EGB\\(EF ESPECIAL)} & \makecell{SOC\_2EGB\\(ALBITA QUILLUPANGUI)} \\ \hline
# 11 & 12h45 a 13h15 & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} \\ \hline
# 12 & 13h15 a 13h45 & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} \\ \hline
# 13 & 13h45 a 14h15 & \makecell{DES\_2EGB\\(MISHEL SALTOS)} & \makecell{MAT\_2EGB\\(DINA TOPÓN)} & \makecell{SOC\_2EGB\\(ALBITA QUILLUPANGUI)} & \makecell{LEN\_2EGB\\(SOFÍA YÉPEZ)} & \makecell{MUS\_2EGB\\(LUIS JÁCOME)} \\ \hline
# 14 & 14h15 a 14h45 & \makecell{DES\_2EGB\\(MISHEL SALTOS)} & \makecell{MAT\_2EGB\\(DINA TOPÓN)} & \makecell{SOC\_2EGB\\(ALBITA QUILLUPANGUI)} & \makecell{LEN\_2EGB\\(SOFÍA YÉPEZ)} & \makecell{DAN\_2EGB\\(PAOLA LÓPEZ)} \\ \hline
# 15 & 14h45 a 15h15 & \makecell{CAL\_2EGB\\(JAIR CRIOLLO)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{CIE\_2EGB\\(DIANA SÁNCHEZ)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{LEN\_2EGB\\(SOFÍA YÉPEZ)} \\ \hline
# 16 & 15h15 a 15h45 & \makecell{EXP\_2EGB\\(JOSÉ LUIS HERNÁNDEZ)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{CIE\_2EGB\\(DIANA SÁNCHEZ)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{LEN\_2EGB\\(SOFÍA YÉPEZ)} \\ \hline
# Act. Final & 15h45 a 16h00 & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} \\ \hline
# \end{tabular}
# \label{tab:2EGB_Afectuosos}
# \end{table}
# \end{landscape}
#
#
#
# % === HORARIO: 2EGB Amables ===
# \begin{landscape}
# \begin{table}[H]
# \centering
# \scriptsize
# \caption{Horario para 2EGB Amables}
# \setlength{\arrayrulewidth}{1pt}
# \arrayrulecolor{black}
# \begin{tabular}{|c|c|c|c|c|c|c|}
# \specialrule{1pt}{0pt}{0pt}
# \rowcolor{white}
# \textbf{Hora} & \textbf{Horario} & \textbf{Lunes} & \textbf{Martes} & \textbf{Miércoles} & \textbf{Jueves} & \textbf{Viernes} \\ \specialrule{1pt}{0pt}{0pt}
# Act. Inicial & 7h30 a 7h45 & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} \\ \hline
# 1 & 7h45 a 8h15 & \makecell{MAT\_2EGB\\(DINA TOPÓN)} & \makecell{LEN\_2EGB\\(SOFÍA YÉPEZ)} & \cellcolor{yellow!30}\textbf{EVALEV} & \makecell{MAT\_2EGB\\(DINA TOPÓN)} & \makecell{LEN\_2EGB\\(SOFÍA YÉPEZ)} \\ \hline
# 2 & 8h15 a 8h45 & \makecell{MAT\_2EGB\\(DINA TOPÓN)} & \makecell{LEN\_2EGB\\(SOFÍA YÉPEZ)} & \cellcolor{yellow!30}\textbf{EVALEV} & \makecell{MAT\_2EGB\\(DINA TOPÓN)} & \makecell{LEN\_2EGB\\(SOFÍA YÉPEZ)} \\ \hline
# 3 & 8h45 a 9h15 & \makecell{LEC\_2EGB\\(ALISON PLAZA)} & \makecell{DER\_2EGB\\(CORALÍA CÓRDOVA)} & \makecell{LEN\_2EGB\\(SOFÍA YÉPEZ)} & \makecell{INV\_2EGB\\(KARLA LAZCANO)} & \makecell{NAT\_2EGB\\(MARIANA HIDALGO)} \\ \hline
# 4 & 9h15 a 9h45 & \makecell{NAT\_2EGB\\(MARIANA HIDALGO)} & \makecell{COM\_2EGB\\(ERIKA CAIZATOA)} & \makecell{LEN\_2EGB\\(SOFÍA YÉPEZ)} & \makecell{SPE\_2EGB\\(CHRISTIAN SOLANO)} & \makecell{NAT\_2EGB\\(MARIANA HIDALGO)} \\ \hline
# 5 & 9h45 a 10h15 & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} \\ \hline
# 6 & 10h15 a 10h45 & \makecell{NAT\_2EGB\\(MARIANA HIDALGO)} & \makecell{MAT\_2EGB\\(DINA TOPÓN)} & \makecell{SAL\_2EGB\\(VANESSA ESPÍN)} & \makecell{ING\_2EGB\\(MARCIA HERRERA VÁSQUEZ)} & \makecell{ING\_2EGB\\(MARCIA HERRERA VÁSQUEZ)} \\ \hline
# 7 & 10h45 a 11h15 & \makecell{ING\_2EGB\\(MARCIA HERRERA VÁSQUEZ)} & \makecell{MAT\_2EGB\\(DINA TOPÓN)} & \makecell{ECO\_2EGB\\(MARJURIE JÁCOME)} & \makecell{PLA\_2EGB\\(LIZ DÍAZ)} & \makecell{ING\_2EGB\\(MARCIA HERRERA VÁSQUEZ)} \\ \hline
# 8 & 11h15 a 11h45 & \makecell{ING\_2EGB\\(MARCIA HERRERA VÁSQUEZ)} & \makecell{MAT\_2EGB\\(DINA TOPÓN)} & \makecell{MAT\_2EGB\\(DINA TOPÓN)} & \makecell{PLA\_2EGB\\(LIZ DÍAZ)} & \makecell{ING\_2EGB\\(MARCIA HERRERA VÁSQUEZ)} \\ \hline
# 9 & 11h45 a 12h15 & \makecell{PRO\_2EGB\\(LUDWIN GUALOTUÑA)} & \makecell{SOC\_2EGB\\(ALBITA QUILLUPANGUI)} & \makecell{MAT\_2EGB\\(DINA TOPÓN)} & \makecell{LEC\_2EGB\\(ALISON PLAZA)} & \makecell{LEC\_2EGB\\(ALISON PLAZA)} \\ \hline
# 10 & 12h15 a 12h45 & \makecell{PRO\_2EGB\\(LUDWIN GUALOTUÑA)} & \makecell{SOC\_2EGB\\(ALBITA QUILLUPANGUI)} & \makecell{MAT\_2EGB\\(DINA TOPÓN)} & \makecell{SOC\_2EGB\\(ALBITA QUILLUPANGUI)} & \makecell{LEC\_2EGB\\(ALISON PLAZA)} \\ \hline
# 11 & 12h45 a 13h15 & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} \\ \hline
# 12 & 13h15 a 13h45 & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} \\ \hline
# 13 & 13h45 a 14h15 & \makecell{CIE\_2EGB\\(DIANA SÁNCHEZ)} & \makecell{DES\_2EGB\\(MISHEL SALTOS)} & \makecell{CIE\_2EGB\\(DIANA SÁNCHEZ)} & \makecell{EDU\_2EGB\\(EF ESPECIAL)} & \makecell{DAN\_2EGB\\(PAOLA LÓPEZ)} \\ \hline
# 14 & 14h15 a 14h45 & \makecell{CIE\_2EGB\\(DIANA SÁNCHEZ)} & \makecell{DES\_2EGB\\(MISHEL SALTOS)} & \makecell{CIE\_2EGB\\(DIANA SÁNCHEZ)} & \makecell{EDU\_2EGB\\(EF ESPECIAL)} & \makecell{MUS\_2EGB\\(LUIS JÁCOME)} \\ \hline
# 15 & 14h45 a 15h15 & \makecell{EXP\_2EGB\\(JOSÉ LUIS HERNÁNDEZ)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{ROB\_2EGB\\(DAVID CASTRO)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{MAT\_2EGB\\(DINA TOPÓN)} \\ \hline
# 16 & 15h15 a 15h45 & \makecell{CAL\_2EGB\\(JAIR CRIOLLO)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{ROB\_2EGB\\(DAVID CASTRO)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{MAT\_2EGB\\(DINA TOPÓN)} \\ \hline
# Act. Final & 15h45 a 16h00 & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} \\ \hline
# \end{tabular}
# \label{tab:2EGB_Amables}
# \end{table}
# \end{landscape}
#
#
#
# % === HORARIO: 2EGB Amigables ===
# \begin{landscape}
# \begin{table}[H]
# \centering
# \scriptsize
# \caption{Horario para 2EGB Amigables}
# \setlength{\arrayrulewidth}{1pt}
# \arrayrulecolor{black}
# \begin{tabular}{|c|c|c|c|c|c|c|}
# \specialrule{1pt}{0pt}{0pt}
# \rowcolor{white}
# \textbf{Hora} & \textbf{Horario} & \textbf{Lunes} & \textbf{Martes} & \textbf{Miércoles} & \textbf{Jueves} & \textbf{Viernes} \\ \specialrule{1pt}{0pt}{0pt}
# Act. Inicial & 7h30 a 7h45 & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} \\ \hline
# 1 & 7h45 a 8h15 & \makecell{LEC\_2EGB\\(ALISON PLAZA)} & \makecell{MAT\_2EGB\\(DINA TOPÓN)} & \cellcolor{yellow!30}\textbf{EVALEV} & \makecell{LEN\_2EGB\\(SOFÍA YÉPEZ)} & \makecell{ING\_2EGB\\(MARCIA HERRERA VÁSQUEZ)} \\ \hline
# 2 & 8h15 a 8h45 & \makecell{LEC\_2EGB\\(ALISON PLAZA)} & \makecell{MAT\_2EGB\\(DINA TOPÓN)} & \cellcolor{yellow!30}\textbf{EVALEV} & \makecell{LEN\_2EGB\\(SOFÍA YÉPEZ)} & \makecell{ING\_2EGB\\(MARCIA HERRERA VÁSQUEZ)} \\ \hline
# 3 & 8h45 a 9h15 & \makecell{ROB\_2EGB\\(DAVID CASTRO)} & \makecell{ECO\_2EGB\\(MARJURIE JÁCOME)} & \makecell{COM\_2EGB\\(ERIKA CAIZATOA)} & \makecell{MAT\_2EGB\\(DINA TOPÓN)} & \makecell{SPE\_2EGB\\(CHRISTIAN SOLANO)} \\ \hline
# 4 & 9h15 a 9h45 & \makecell{ROB\_2EGB\\(DAVID CASTRO)} & \makecell{SAL\_2EGB\\(VANESSA ESPÍN)} & \makecell{DER\_2EGB\\(CORALÍA CÓRDOVA)} & \makecell{MAT\_2EGB\\(DINA TOPÓN)} & \makecell{INV\_2EGB\\(KARLA LAZCANO)} \\ \hline
# 5 & 9h45 a 10h15 & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} \\ \hline
# 6 & 10h15 a 10h45 & \makecell{ING\_2EGB\\(MARCIA HERRERA VÁSQUEZ)} & \makecell{SOC\_2EGB\\(ALBITA QUILLUPANGUI)} & \makecell{DES\_2EGB\\(MISHEL SALTOS)} & \makecell{LEC\_2EGB\\(ALISON PLAZA)} & \makecell{MAT\_2EGB\\(DINA TOPÓN)} \\ \hline
# 7 & 10h45 a 11h15 & \makecell{DAN\_2EGB\\(PAOLA LÓPEZ)} & \makecell{PRO\_2EGB\\(LUDWIN GUALOTUÑA)} & \makecell{DES\_2EGB\\(MISHEL SALTOS)} & \makecell{EDU\_2EGB\\(EF ESPECIAL)} & \makecell{MAT\_2EGB\\(DINA TOPÓN)} \\ \hline
# 8 & 11h15 a 11h45 & \makecell{MUS\_2EGB\\(LUIS JÁCOME)} & \makecell{PRO\_2EGB\\(LUDWIN GUALOTUÑA)} & \makecell{CAL\_2EGB\\(JAIR CRIOLLO)} & \makecell{EDU\_2EGB\\(EF ESPECIAL)} & \makecell{LEC\_2EGB\\(ALISON PLAZA)} \\ \hline
# 9 & 11h45 a 12h15 & \makecell{PLA\_2EGB\\(LIZ DÍAZ)} & \makecell{CIE\_2EGB\\(DIANA SÁNCHEZ)} & \makecell{EXP\_2EGB\\(JOSÉ LUIS HERNÁNDEZ)} & \makecell{ING\_2EGB\\(MARCIA HERRERA VÁSQUEZ)} & \makecell{LEN\_2EGB\\(SOFÍA YÉPEZ)} \\ \hline
# 10 & 12h15 a 12h45 & \makecell{PLA\_2EGB\\(LIZ DÍAZ)} & \makecell{CIE\_2EGB\\(DIANA SÁNCHEZ)} & \makecell{ING\_2EGB\\(MARCIA HERRERA VÁSQUEZ)} & \makecell{ING\_2EGB\\(MARCIA HERRERA VÁSQUEZ)} & \makecell{LEN\_2EGB\\(SOFÍA YÉPEZ)} \\ \hline
# 11 & 12h45 a 13h15 & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} \\ \hline
# 12 & 13h15 a 13h45 & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} \\ \hline
# 13 & 13h45 a 14h15 & \makecell{MAT\_2EGB\\(DINA TOPÓN)} & \makecell{LEN\_2EGB\\(SOFÍA YÉPEZ)} & \makecell{MAT\_2EGB\\(DINA TOPÓN)} & \makecell{MAT\_2EGB\\(DINA TOPÓN)} & \makecell{NAT\_2EGB\\(MARIANA HIDALGO)} \\ \hline
# 14 & 14h15 a 14h45 & \makecell{MAT\_2EGB\\(DINA TOPÓN)} & \makecell{LEN\_2EGB\\(SOFÍA YÉPEZ)} & \makecell{MAT\_2EGB\\(DINA TOPÓN)} & \makecell{MAT\_2EGB\\(DINA TOPÓN)} & \makecell{NAT\_2EGB\\(MARIANA HIDALGO)} \\ \hline
# 15 & 14h45 a 15h15 & \makecell{CIE\_2EGB\\(DIANA SÁNCHEZ)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{NAT\_2EGB\\(MARIANA HIDALGO)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{SOC\_2EGB\\(ALBITA QUILLUPANGUI)} \\ \hline
# 16 & 15h15 a 15h45 & \makecell{CIE\_2EGB\\(DIANA SÁNCHEZ)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{NAT\_2EGB\\(MARIANA HIDALGO)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{SOC\_2EGB\\(ALBITA QUILLUPANGUI)} \\ \hline
# Act. Final & 15h45 a 16h00 & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} \\ \hline
# \end{tabular}
# \label{tab:2EGB_Amigables}
# \end{table}
# \end{landscape}
#
#
#
# % === HORARIO: 2EGB Amistosos ===
# \begin{landscape}
# \begin{table}[H]
# \centering
# \scriptsize
# \caption{Horario para 2EGB Amistosos}
# \setlength{\arrayrulewidth}{1pt}
# \arrayrulecolor{black}
# \begin{tabular}{|c|c|c|c|c|c|c|}
# \specialrule{1pt}{0pt}{0pt}
# \rowcolor{white}
# \textbf{Hora} & \textbf{Horario} & \textbf{Lunes} & \textbf{Martes} & \textbf{Miércoles} & \textbf{Jueves} & \textbf{Viernes} \\ \specialrule{1pt}{0pt}{0pt}
# Act. Inicial & 7h30 a 7h45 & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} \\ \hline
# 1 & 7h45 a 8h15 & \makecell{ING\_2EGB\\(MARCIA HERRERA VÁSQUEZ)} & \makecell{NAT\_2EGB\\(MARIANA HIDALGO)} & \cellcolor{yellow!30}\textbf{EVALEV} & \makecell{ROB\_2EGB\\(DAVID CASTRO)} & \makecell{LEC\_2EGB\\(ALISON PLAZA)} \\ \hline
# 2 & 8h15 a 8h45 & \makecell{ING\_2EGB\\(MARCIA HERRERA VÁSQUEZ)} & \makecell{NAT\_2EGB\\(MARIANA HIDALGO)} & \cellcolor{yellow!30}\textbf{EVALEV} & \makecell{ROB\_2EGB\\(DAVID CASTRO)} & \makecell{LEC\_2EGB\\(ALISON PLAZA)} \\ \hline
# 3 & 8h45 a 9h15 & \makecell{ING\_2EGB\\(MARCIA HERRERA VÁSQUEZ)} & \makecell{SAL\_2EGB\\(VANESSA ESPÍN)} & \makecell{DER\_2EGB\\(CORALÍA CÓRDOVA)} & \makecell{LEN\_2EGB\\(SOFÍA YÉPEZ)} & \makecell{INV\_2EGB\\(KARLA LAZCANO)} \\ \hline
# 4 & 9h15 a 9h45 & \makecell{LEN\_2EGB\\(SOFÍA YÉPEZ)} & \makecell{ECO\_2EGB\\(MARJURIE JÁCOME)} & \makecell{COM\_2EGB\\(ERIKA CAIZATOA)} & \makecell{LEN\_2EGB\\(SOFÍA YÉPEZ)} & \makecell{SPE\_2EGB\\(CHRISTIAN SOLANO)} \\ \hline
# 5 & 9h45 a 10h15 & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} \\ \hline
# 6 & 10h15 a 10h45 & \makecell{SOC\_2EGB\\(ALBITA QUILLUPANGUI)} & \makecell{PLA\_2EGB\\(LIZ DÍAZ)} & \makecell{MAT\_2EGB\\(DINA TOPÓN)} & \makecell{LEN\_2EGB\\(SOFÍA YÉPEZ)} & \makecell{DES\_2EGB\\(MISHEL SALTOS)} \\ \hline
# 7 & 10h45 a 11h15 & \makecell{MUS\_2EGB\\(LUIS JÁCOME)} & \makecell{PLA\_2EGB\\(LIZ DÍAZ)} & \makecell{MAT\_2EGB\\(DINA TOPÓN)} & \makecell{SOC\_2EGB\\(ALBITA QUILLUPANGUI)} & \makecell{LEN\_2EGB\\(SOFÍA YÉPEZ)} \\ \hline
# 8 & 11h15 a 11h45 & \makecell{DAN\_2EGB\\(PAOLA LÓPEZ)} & \makecell{DES\_2EGB\\(MISHEL SALTOS)} & \makecell{EXP\_2EGB\\(JOSÉ LUIS HERNÁNDEZ)} & \makecell{SOC\_2EGB\\(ALBITA QUILLUPANGUI)} & \makecell{LEN\_2EGB\\(SOFÍA YÉPEZ)} \\ \hline
# 9 & 11h45 a 12h15 & \makecell{MAT\_2EGB\\(DINA TOPÓN)} & \makecell{MAT\_2EGB\\(DINA TOPÓN)} & \makecell{CAL\_2EGB\\(JAIR CRIOLLO)} & \makecell{MAT\_2EGB\\(DINA TOPÓN)} & \makecell{CIE\_2EGB\\(DIANA SÁNCHEZ)} \\ \hline
# 10 & 12h15 a 12h45 & \makecell{MAT\_2EGB\\(DINA TOPÓN)} & \makecell{MAT\_2EGB\\(DINA TOPÓN)} & \makecell{NAT\_2EGB\\(MARIANA HIDALGO)} & \makecell{MAT\_2EGB\\(DINA TOPÓN)} & \makecell{CIE\_2EGB\\(DIANA SÁNCHEZ)} \\ \hline
# 11 & 12h45 a 13h15 & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} \\ \hline
# 12 & 13h15 a 13h45 & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} \\ \hline
# 13 & 13h45 a 14h15 & \makecell{EDU\_2EGB\\(EF ESPECIAL)} & \makecell{CIE\_2EGB\\(DIANA SÁNCHEZ)} & \makecell{NAT\_2EGB\\(MARIANA HIDALGO)} & \makecell{LEC\_2EGB\\(ALISON PLAZA)} & \makecell{MAT\_2EGB\\(DINA TOPÓN)} \\ \hline
# 14 & 14h15 a 14h45 & \makecell{EDU\_2EGB\\(EF ESPECIAL)} & \makecell{CIE\_2EGB\\(DIANA SÁNCHEZ)} & \makecell{ING\_2EGB\\(MARCIA HERRERA VÁSQUEZ)} & \makecell{LEC\_2EGB\\(ALISON PLAZA)} & \makecell{MAT\_2EGB\\(DINA TOPÓN)} \\ \hline
# 15 & 14h45 a 15h15 & \makecell{PRO\_2EGB\\(LUDWIN GUALOTUÑA)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{MAT\_2EGB\\(DINA TOPÓN)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{ING\_2EGB\\(MARCIA HERRERA VÁSQUEZ)} \\ \hline
# 16 & 15h15 a 15h45 & \makecell{PRO\_2EGB\\(LUDWIN GUALOTUÑA)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{MAT\_2EGB\\(DINA TOPÓN)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{ING\_2EGB\\(MARCIA HERRERA VÁSQUEZ)} \\ \hline
# Act. Final & 15h45 a 16h00 & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} \\ \hline
# \end{tabular}
# \label{tab:2EGB_Amistosos}
# \end{table}
# \end{landscape}
#
#
#
# % === HORARIO: 3EGB Colaboradores ===
# \begin{landscape}
# \begin{table}[H]
# \centering
# \scriptsize
# \caption{Horario para 3EGB Colaboradores}
# \setlength{\arrayrulewidth}{1pt}
# \arrayrulecolor{black}
# \begin{tabular}{|c|c|c|c|c|c|c|}
# \specialrule{1pt}{0pt}{0pt}
# \rowcolor{white}
# \textbf{Hora} & \textbf{Horario} & \textbf{Lunes} & \textbf{Martes} & \textbf{Miércoles} & \textbf{Jueves} & \textbf{Viernes} \\ \specialrule{1pt}{0pt}{0pt}
# Act. Inicial & 7h30 a 7h45 & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} \\ \hline
# 1 & 7h45 a 8h15 & \makecell{LEN\_3EGB\\(SOFÍA YÉPEZ)} & \makecell{MAT\_3EGB\\(MARCIA HERRERA)} & \cellcolor{yellow!30}\textbf{EVALEV} & \makecell{MAT\_3EGB\\(MARCIA HERRERA)} & \makecell{ING\_3EGB\\(SOLEDAD REVELO)} \\ \hline
# 2 & 8h15 a 8h45 & \makecell{LEN\_3EGB\\(SOFÍA YÉPEZ)} & \makecell{MAT\_3EGB\\(MARCIA HERRERA)} & \cellcolor{yellow!30}\textbf{EVALEV} & \makecell{MAT\_3EGB\\(MARCIA HERRERA)} & \makecell{ING\_3EGB\\(SOLEDAD REVELO)} \\ \hline
# 3 & 8h45 a 9h15 & \makecell{ING\_3EGB\\(SOLEDAD REVELO)} & \makecell{SPE\_3EGB\\(CHRISTIAN SOLANO)} & \makecell{EDU\_3EGB\\(EF ESPECIAL)} & \makecell{MAT\_3EGB\\(MARCIA HERRERA)} & \makecell{EXP\_3EGB\\(JOSÉ LUIS HERNÁNDEZ)} \\ \hline
# 4 & 9h15 a 9h45 & \makecell{ING\_3EGB\\(SOLEDAD REVELO)} & \makecell{INV\_3EGB\\(KARLA LAZCANO)} & \makecell{EDU\_3EGB\\(EF ESPECIAL)} & \makecell{SOC\_3EGB\\(ALBITA QUILLUPANGUI)} & \makecell{CAL\_3EGB\\(JAIR CRIOLLO)} \\ \hline
# 5 & 9h45 a 10h15 & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} \\ \hline
# 6 & 10h15 a 10h45 & \makecell{LEC\_3EGB\\(ALISON PLAZA)} & \makecell{LEN\_3EGB\\(SOFÍA YÉPEZ)} & \makecell{MAT\_3EGB\\(MARCIA HERRERA)} & \makecell{NAT\_3EGB\\(MARIANA HIDALGO)} & \makecell{NAT\_3EGB\\(MARIANA HIDALGO)} \\ \hline
# 7 & 10h45 a 11h15 & \makecell{PRO\_3EGB\\(LUDWIN GUALOTUÑA)} & \makecell{LEN\_3EGB\\(SOFÍA YÉPEZ)} & \makecell{MAT\_3EGB\\(MARCIA HERRERA)} & \makecell{ECO\_3EGB\\(MARJURIE JÁCOME)} & \makecell{MUS\_3EGB\\(LUIS JÁCOME)} \\ \hline
# 8 & 11h15 a 11h45 & \makecell{PRO\_3EGB\\(LUDWIN GUALOTUÑA)} & \makecell{LEC\_3EGB\\(ALISON PLAZA)} & \makecell{MAT\_3EGB\\(MARCIA HERRERA)} & \makecell{SAL\_3EGB\\(VANESSA ESPÍN)} & \makecell{DAN\_3EGB\\(PAOLA LÓPEZ)} \\ \hline
# 9 & 11h45 a 12h15 & \makecell{MAT\_3EGB\\(MARCIA HERRERA)} & \makecell{ROB\_3EGB\\(DAVID CASTRO)} & \makecell{PLA\_3EGB\\(LIZ DÍAZ)} & \makecell{LEN\_3EGB\\(SOFÍA YÉPEZ)} & \makecell{MAT\_3EGB\\(MARCIA HERRERA)} \\ \hline
# 10 & 12h15 a 12h45 & \makecell{MAT\_3EGB\\(MARCIA HERRERA)} & \makecell{ROB\_3EGB\\(DAVID CASTRO)} & \makecell{PLA\_3EGB\\(LIZ DÍAZ)} & \makecell{LEN\_3EGB\\(SOFÍA YÉPEZ)} & \makecell{MAT\_3EGB\\(MARCIA HERRERA)} \\ \hline
# 11 & 12h45 a 13h15 & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} \\ \hline
# 12 & 13h15 a 13h45 & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} \\ \hline
# 13 & 13h45 a 14h15 & \makecell{NAT\_3EGB\\(MARIANA HIDALGO)} & \makecell{SOC\_3EGB\\(ALBITA QUILLUPANGUI)} & \makecell{ING\_3EGB\\(SOLEDAD REVELO)} & \makecell{COM\_3EGB\\(ERIKA CAIZATOA)} & \makecell{PEN\_3EGB\\(XIMENA AGUIRRE)} \\ \hline
# 14 & 14h15 a 14h45 & \makecell{NAT\_3EGB\\(MARIANA HIDALGO)} & \makecell{SOC\_3EGB\\(ALBITA QUILLUPANGUI)} & \makecell{ING\_3EGB\\(SOLEDAD REVELO)} & \makecell{DER\_3EGB\\(CORALÍA CÓRDOVA)} & \makecell{PEN\_3EGB\\(XIMENA AGUIRRE)} \\ \hline
# 15 & 14h45 a 15h15 & \makecell{DES\_3EGB\\(MISHEL SALTOS)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{PEN\_3EGB\\(XIMENA AGUIRRE)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{LEC\_3EGB\\(ALISON PLAZA)} \\ \hline
# 16 & 15h15 a 15h45 & \makecell{DES\_3EGB\\(MISHEL SALTOS)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{PEN\_3EGB\\(XIMENA AGUIRRE)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{LEC\_3EGB\\(ALISON PLAZA)} \\ \hline
# Act. Final & 15h45 a 16h00 & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} \\ \hline
# \end{tabular}
# \label{tab:3EGB_Colaboradores}
# \end{table}
# \end{landscape}
#
#
#
# % === HORARIO: 3EGB Conciliadores ===
# \begin{landscape}
# \begin{table}[H]
# \centering
# \scriptsize
# \caption{Horario para 3EGB Conciliadores}
# \setlength{\arrayrulewidth}{1pt}
# \arrayrulecolor{black}
# \begin{tabular}{|c|c|c|c|c|c|c|}
# \specialrule{1pt}{0pt}{0pt}
# \rowcolor{white}
# \textbf{Hora} & \textbf{Horario} & \textbf{Lunes} & \textbf{Martes} & \textbf{Miércoles} & \textbf{Jueves} & \textbf{Viernes} \\ \specialrule{1pt}{0pt}{0pt}
# Act. Inicial & 7h30 a 7h45 & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} \\ \hline
# 1 & 7h45 a 8h15 & \makecell{PRO\_3EGB\\(LUDWIN GUALOTUÑA)} & \makecell{SOC\_3EGB\\(ALBITA QUILLUPANGUI)} & \cellcolor{yellow!30}\textbf{EVALEV} & \makecell{NAT\_3EGB\\(MARIANA HIDALGO)} & \makecell{PEN\_3EGB\\(XIMENA AGUIRRE)} \\ \hline
# 2 & 8h15 a 8h45 & \makecell{PRO\_3EGB\\(LUDWIN GUALOTUÑA)} & \makecell{SOC\_3EGB\\(ALBITA QUILLUPANGUI)} & \cellcolor{yellow!30}\textbf{EVALEV} & \makecell{NAT\_3EGB\\(MARIANA HIDALGO)} & \makecell{PEN\_3EGB\\(XIMENA AGUIRRE)} \\ \hline
# 3 & 8h45 a 9h15 & \makecell{MAT\_3EGB\\(MARCIA HERRERA)} & \makecell{INV\_3EGB\\(KARLA LAZCANO)} & \makecell{DES\_3EGB\\(MISHEL SALTOS)} & \makecell{LEC\_3EGB\\(ALISON PLAZA)} & \makecell{CAL\_3EGB\\(JAIR CRIOLLO)} \\ \hline
# 4 & 9h15 a 9h45 & \makecell{MAT\_3EGB\\(MARCIA HERRERA)} & \makecell{SPE\_3EGB\\(CHRISTIAN SOLANO)} & \makecell{DES\_3EGB\\(MISHEL SALTOS)} & \makecell{LEC\_3EGB\\(ALISON PLAZA)} & \makecell{EXP\_3EGB\\(JOSÉ LUIS HERNÁNDEZ)} \\ \hline
# 5 & 9h45 a 10h15 & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} \\ \hline
# 6 & 10h15 a 10h45 & \makecell{LEN\_3EGB\\(SOFÍA YÉPEZ)} & \makecell{MAT\_3EGB\\(MARCIA HERRERA)} & \makecell{LEN\_3EGB\\(SOFÍA YÉPEZ)} & \makecell{SOC\_3EGB\\(ALBITA QUILLUPANGUI)} & \makecell{LEN\_3EGB\\(SOFÍA YÉPEZ)} \\ \hline
# 7 & 10h45 a 11h15 & \makecell{LEN\_3EGB\\(SOFÍA YÉPEZ)} & \makecell{MAT\_3EGB\\(MARCIA HERRERA)} & \makecell{LEN\_3EGB\\(SOFÍA YÉPEZ)} & \makecell{SAL\_3EGB\\(VANESSA ESPÍN)} & \makecell{DAN\_3EGB\\(PAOLA LÓPEZ)} \\ \hline
# 8 & 11h15 a 11h45 & \makecell{LEC\_3EGB\\(ALISON PLAZA)} & \makecell{NAT\_3EGB\\(MARIANA HIDALGO)} & \makecell{LEN\_3EGB\\(SOFÍA YÉPEZ)} & \makecell{ECO\_3EGB\\(MARJURIE JÁCOME)} & \makecell{MUS\_3EGB\\(LUIS JÁCOME)} \\ \hline
# 9 & 11h45 a 12h15 & \makecell{PEN\_3EGB\\(XIMENA AGUIRRE)} & \makecell{NAT\_3EGB\\(MARIANA HIDALGO)} & \makecell{ING\_3EGB\\(SOLEDAD REVELO)} & \makecell{MAT\_3EGB\\(MARCIA HERRERA)} & \makecell{ING\_3EGB\\(SOLEDAD REVELO)} \\ \hline
# 10 & 12h15 a 12h45 & \makecell{PEN\_3EGB\\(XIMENA AGUIRRE)} & \makecell{LEC\_3EGB\\(ALISON PLAZA)} & \makecell{ING\_3EGB\\(SOLEDAD REVELO)} & \makecell{MAT\_3EGB\\(MARCIA HERRERA)} & \makecell{ING\_3EGB\\(SOLEDAD REVELO)} \\ \hline
# 11 & 12h45 a 13h15 & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} \\ \hline
# 12 & 13h15 a 13h45 & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} \\ \hline
# 13 & 13h45 a 14h15 & \makecell{MAT\_3EGB\\(MARCIA HERRERA)} & \makecell{ROB\_3EGB\\(DAVID CASTRO)} & \makecell{EDU\_3EGB\\(EF ESPECIAL)} & \makecell{DER\_3EGB\\(CORALÍA CÓRDOVA)} & \makecell{PLA\_3EGB\\(LIZ DÍAZ)} \\ \hline
# 14 & 14h15 a 14h45 & \makecell{MAT\_3EGB\\(MARCIA HERRERA)} & \makecell{ROB\_3EGB\\(DAVID CASTRO)} & \makecell{EDU\_3EGB\\(EF ESPECIAL)} & \makecell{COM\_3EGB\\(ERIKA CAIZATOA)} & \makecell{PLA\_3EGB\\(LIZ DÍAZ)} \\ \hline
# 15 & 14h45 a 15h15 & \makecell{ING\_3EGB\\(SOLEDAD REVELO)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{MAT\_3EGB\\(MARCIA HERRERA)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{MAT\_3EGB\\(MARCIA HERRERA)} \\ \hline
# 16 & 15h15 a 15h45 & \makecell{ING\_3EGB\\(SOLEDAD REVELO)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{MAT\_3EGB\\(MARCIA HERRERA)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{MAT\_3EGB\\(MARCIA HERRERA)} \\ \hline
# Act. Final & 15h45 a 16h00 & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} \\ \hline
# \end{tabular}
# \label{tab:3EGB_Conciliadores}
# \end{table}
# \end{landscape}
#
#
#
# % === HORARIO: 3EGB Cordiales ===
# \begin{landscape}
# \begin{table}[H]
# \centering
# \scriptsize
# \caption{Horario para 3EGB Cordiales}
# \setlength{\arrayrulewidth}{1pt}
# \arrayrulecolor{black}
# \begin{tabular}{|c|c|c|c|c|c|c|}
# \specialrule{1pt}{0pt}{0pt}
# \rowcolor{white}
# \textbf{Hora} & \textbf{Horario} & \textbf{Lunes} & \textbf{Martes} & \textbf{Miércoles} & \textbf{Jueves} & \textbf{Viernes} \\ \specialrule{1pt}{0pt}{0pt}
# Act. Inicial & 7h30 a 7h45 & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} \\ \hline
# 1 & 7h45 a 8h15 & \makecell{MAT\_3EGB\\(MARCIA HERRERA)} & \makecell{ING\_3EGB\\(SOLEDAD REVELO)} & \cellcolor{yellow!30}\textbf{EVALEV} & \makecell{DAN\_3EGB\\(PAOLA LÓPEZ)} & \makecell{ROB\_3EGB\\(DAVID CASTRO)} \\ \hline
# 2 & 8h15 a 8h45 & \makecell{MAT\_3EGB\\(MARCIA HERRERA)} & \makecell{ING\_3EGB\\(SOLEDAD REVELO)} & \cellcolor{yellow!30}\textbf{EVALEV} & \makecell{MUS\_3EGB\\(LUIS JÁCOME)} & \makecell{ROB\_3EGB\\(DAVID CASTRO)} \\ \hline
# 3 & 8h45 a 9h15 & \makecell{SAL\_3EGB\\(VANESSA ESPÍN)} & \makecell{MAT\_3EGB\\(MARCIA HERRERA)} & \makecell{INV\_3EGB\\(KARLA LAZCANO)} & \makecell{ING\_3EGB\\(SOLEDAD REVELO)} & \makecell{MAT\_3EGB\\(MARCIA HERRERA)} \\ \hline
# 4 & 9h15 a 9h45 & \makecell{ECO\_3EGB\\(MARJURIE JÁCOME)} & \makecell{MAT\_3EGB\\(MARCIA HERRERA)} & \makecell{SPE\_3EGB\\(CHRISTIAN SOLANO)} & \makecell{ING\_3EGB\\(SOLEDAD REVELO)} & \makecell{SOC\_3EGB\\(ALBITA QUILLUPANGUI)} \\ \hline
# 5 & 9h45 a 10h15 & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} \\ \hline
# ...
# 10 & 12h15 a 12h45 & \makecell{GEO\_2BGU\\(LEONARDO ESPINOSA)} & \makecell{ROB\_2BGU\\(DAVID RÓGEL)} & \makecell{QUI\_2BGU\\(MAYRA QUISHPE)} & \makecell{FIS\_2BGU\\(JOSÉ NICOLALDE)} & \makecell{DES\_2BGU\\(JANETH MELO)} \\ \hline
# 11 & 12h45 a 13h15 & \makecell{LEC\_2BGU\\(PATY FLORES)} & \makecell{MAT\_2BGU\\(ISAAC NÚÑEZ)} & \makecell{LEN\_2BGU\\(ANDRÉS OLMEDO)} & \makecell{SOC\_2BGU\\(ISABEL GARCÍA)} & \makecell{FIS\_2BGU\\(JOSÉ NICOLALDE)} \\ \hline
# 12 & 13h15 a 13h45 & \makecell{LEC\_2BGU\\(PATY FLORES)} & \makecell{MAT\_2BGU\\(ISAAC NÚÑEZ)} & \makecell{LEN\_2BGU\\(ANDRÉS OLMEDO)} & \makecell{SOC\_2BGU\\(ISABEL GARCÍA)} & \makecell{FIS\_2BGU\\(JOSÉ NICOLALDE)} \\ \hline
# 13 & 13h45 a 14h15 & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} \\ \hline
# 14 & 14h15 a 14h45 & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} \\ \hline
# 15 & 14h45 a 15h15 & \makecell{SPE\_2BGU\\(CHRISTIAN SOLANO)} & \makecell{SAL\_2BGU\\(VANESSA ESPÍN)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{ING\_2BGU\\(INGLES ESPECIAL)} & \cellcolor{orange!20}\textbf{CLUBS} \\ \hline
# 16 & 15h15 a 15h45 & \makecell{INV\_2BGU\\(KARLA LAZCANO)} & \makecell{ECO\_2BGU\\(MARJURIE JÁCOME)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{ING\_2BGU\\(INGLES ESPECIAL)} & \cellcolor{orange!20}\textbf{CLUBS} \\ \hline
# Act. Final & 15h45 a 16h00 & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} \\ \hline
# \end{tabular}
# \label{tab:2BGU_Proactivos}
# \end{table}
# \end{landscape}
#
#
#
# % === HORARIO: 3BGU Empáticos ===
# \begin{landscape}
# \begin{table}[H]
# \centering
# \scriptsize
# \caption{Horario para 3BGU Empáticos}
# \setlength{\arrayrulewidth}{1pt}
# \arrayrulecolor{black}
# \begin{tabular}{|c|c|c|c|c|c|c|}
# \specialrule{1pt}{0pt}{0pt}
# \rowcolor{white}
# \textbf{Hora} & \textbf{Horario} & \textbf{Lunes} & \textbf{Martes} & \textbf{Miércoles} & \textbf{Jueves} & \textbf{Viernes} \\ \specialrule{1pt}{0pt}{0pt}
# Act. Inicial & 7h30 a 7h45 & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} \\ \hline
# 1 & 7h45 a 8h15 & \makecell{NAT\_3BGU\\(CARLOS BENALCÁZAR)} & \makecell{QUI\_3BGU\\(MAYRA QUISHPE)} & \cellcolor{yellow!30}\textbf{EVALEV} & \makecell{ROB\_3BGU\\(DAVID RÓGEL)} & \makecell{ING\_3BGU\\(INGLES ESPECIAL)} \\ \hline
# 2 & 8h15 a 8h45 & \makecell{NAT\_3BGU\\(CARLOS BENALCÁZAR)} & \makecell{QUI\_3BGU\\(MAYRA QUISHPE)} & \cellcolor{yellow!30}\textbf{EVALEV} & \makecell{ROB\_3BGU\\(DAVID RÓGEL)} & \makecell{ING\_3BGU\\(INGLES ESPECIAL)} \\ \hline
# 3 & 8h45 a 9h15 & \makecell{GEO\_3BGU\\(LEONARDO ESPINOSA)} & \makecell{SOC\_3BGU\\(ISABEL GARCÍA)} & \makecell{LEN\_3BGU\\(ANDRÉS OLMEDO)} & \makecell{MAT\_3BGU\\(LEONARDO ESPINOSA)} & \makecell{EDU\_3BGU\\(EF ESPECIAL)} \\ \hline
# 4 & 9h15 a 9h45 & \makecell{GEO\_3BGU\\(LEONARDO ESPINOSA)} & \makecell{SOC\_3BGU\\(ISABEL GARCÍA)} & \makecell{EDU\_3BGU\\(EF ESPECIAL)} & \makecell{MAT\_3BGU\\(LEONARDO ESPINOSA)} & \makecell{MAT\_3BGU\\(LEONARDO ESPINOSA)} \\ \hline
# 5 & 9h45 a 10h15 & \makecell{GEO\_3BGU\\(LEONARDO ESPINOSA)} & \makecell{NAT\_3BGU\\(CARLOS BENALCÁZAR)} & \makecell{LEC\_3BGU\\(PATY FLORES)} & \makecell{PEN\_3BGU\\(ANITA BARRENO)} & \makecell{MAT\_3BGU\\(LEONARDO ESPINOSA)} \\ \hline
# 6 & 10h15 a 10h45 & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} \\ \hline
# 7 & 10h45 a 11h15 & \makecell{LEN\_3BGU\\(ANDRÉS OLMEDO)} & \makecell{PEN\_3BGU\\(ANITA BARRENO)} & \makecell{DER\_3BGU\\(CORALÍA CÓRDOVA)} & \makecell{EMP\_3BGU\\(MARÍA BELÉN MALDONADO)} & \makecell{SOC\_3BGU\\(ISABEL GARCÍA)} \\ \hline
# 8 & 11h15 a 11h45 & \makecell{LEN\_3BGU\\(ANDRÉS OLMEDO)} & \makecell{PEN\_3BGU\\(ANITA BARRENO)} & \makecell{COM\_3BGU\\(ERIKA CAIZATOA)} & \makecell{EMP\_3BGU\\(MARÍA BELÉN MALDONADO)} & \makecell{SOC\_3BGU\\(ISABEL GARCÍA)} \\ \hline
# 9 & 11h45 a 12h15 & \makecell{FIS\_3BGU\\(JOSÉ NICOLALDE)} & \makecell{PLA\_3BGU\\(KEVIN VICENTE)} & \makecell{FIS\_3BGU\\(JOSÉ NICOLALDE)} & \makecell{ING\_3BGU\\(INGLES ESPECIAL)} & \makecell{PRO\_3BGU\\(MARCO SAFADI)} \\ \hline
# 10 & 12h15 a 12h45 & \makecell{FIS\_3BGU\\(JOSÉ NICOLALDE)} & \makecell{PLA\_3BGU\\(KEVIN VICENTE)} & \makecell{FIS\_3BGU\\(JOSÉ NICOLALDE)} & \makecell{ING\_3BGU\\(INGLES ESPECIAL)} & \makecell{PRO\_3BGU\\(MARCO SAFADI)} \\ \hline
# 11 & 12h45 a 13h15 & \makecell{ING\_3BGU\\(INGLES ESPECIAL)} & \makecell{MAT\_3BGU\\(LEONARDO ESPINOSA)} & \makecell{ECO\_3BGU\\(MARJURIE JÁCOME)} & \makecell{QUI\_3BGU\\(MAYRA QUISHPE)} & \makecell{LEC\_3BGU\\(PATY FLORES)} \\ \hline
# 12 & 13h15 a 13h45 & \makecell{ING\_3BGU\\(INGLES ESPECIAL)} & \makecell{MAT\_3BGU\\(LEONARDO ESPINOSA)} & \makecell{SAL\_3BGU\\(VANESSA ESPÍN)} & \makecell{QUI\_3BGU\\(MAYRA QUISHPE)} & \makecell{LEC\_3BGU\\(PATY FLORES)} \\ \hline
# 13 & 13h45 a 14h15 & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} \\ \hline
# 14 & 14h15 a 14h45 & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} \\ \hline
# 15 & 14h45 a 15h15 & \makecell{EST\_3BGU\\(JONATHAN CASTRO)} & \makecell{SPE\_3BGU\\(CHRISTIAN SOLANO)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{DES\_3BGU\\(JANETH MELO)} & \cellcolor{orange!20}\textbf{CLUBS} \\ \hline
# 16 & 15h15 a 15h45 & \makecell{EST\_3BGU\\(JONATHAN CASTRO)} & \makecell{INV\_3BGU\\(KARLA LAZCANO)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{DES\_3BGU\\(JANETH MELO)} & \cellcolor{orange!20}\textbf{CLUBS} \\ \hline
# Act. Final & 15h45 a 16h00 & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} \\ \hline
# \end{tabular}
# \label{tab:3BGU_Empáticos}
# \end{table}
# \end{landscape}
#
#
#
# % === HORARIO: 3BGU Solidarios ===
# \begin{landscape}
# \begin{table}[H]
# \centering
# \scriptsize
# \caption{Horario para 3BGU Solidarios}
# \setlength{\arrayrulewidth}{1pt}
# \arrayrulecolor{black}
# \begin{tabular}{|c|c|c|c|c|c|c|}
# \specialrule{1pt}{0pt}{0pt}
# \rowcolor{white}
# \textbf{Hora} & \textbf{Horario} & \textbf{Lunes} & \textbf{Martes} & \textbf{Miércoles} & \textbf{Jueves} & \textbf{Viernes} \\ \specialrule{1pt}{0pt}{0pt}
# Act. Inicial & 7h30 a 7h45 & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} \\ \hline
# 1 & 7h45 a 8h15 & \makecell{MAT\_3BGU\\(LEONARDO ESPINOSA)} & \makecell{FIS\_3BGU\\(JOSÉ NICOLALDE)} & \cellcolor{yellow!30}\textbf{EVALEV} & \makecell{FIS\_3BGU\\(JOSÉ NICOLALDE)} & \makecell{ING\_3BGU\\(INGLES ESPECIAL)} \\ \hline
# 2 & 8h15 a 8h45 & \makecell{MAT\_3BGU\\(LEONARDO ESPINOSA)} & \makecell{FIS\_3BGU\\(JOSÉ NICOLALDE)} & \cellcolor{yellow!30}\textbf{EVALEV} & \makecell{FIS\_3BGU\\(JOSÉ NICOLALDE)} & \makecell{ING\_3BGU\\(INGLES ESPECIAL)} \\ \hline
# 3 & 8h45 a 9h15 & \makecell{PEN\_3BGU\\(ANITA BARRENO)} & \makecell{QUI\_3BGU\\(MAYRA QUISHPE)} & \makecell{QUI\_3BGU\\(MAYRA QUISHPE)} & \makecell{ROB\_3BGU\\(DAVID RÓGEL)} & \makecell{LEN\_3BGU\\(ANDRÉS OLMEDO)} \\ \hline
# 4 & 9h15 a 9h45 & \makecell{NAT\_3BGU\\(CARLOS BENALCÁZAR)} & \makecell{QUI\_3BGU\\(MAYRA QUISHPE)} & \makecell{QUI\_3BGU\\(MAYRA QUISHPE)} & \makecell{ROB\_3BGU\\(DAVID RÓGEL)} & \makecell{PRO\_3BGU\\(MARCO SAFADI)} \\ \hline
# 5 & 9h45 a 10h15 & \makecell{NAT\_3BGU\\(CARLOS BENALCÁZAR)} & \makecell{LEC\_3BGU\\(PATY FLORES)} & \makecell{NAT\_3BGU\\(CARLOS BENALCÁZAR)} & \makecell{GEO\_3BGU\\(LEONARDO ESPINOSA)} & \makecell{PRO\_3BGU\\(MARCO SAFADI)} \\ \hline
# 6 & 10h15 a 10h45 & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} \\ \hline
# 7 & 10h45 a 11h15 & \makecell{SOC\_3BGU\\(ISABEL GARCÍA)} & \makecell{MAT\_3BGU\\(LEONARDO ESPINOSA)} & \makecell{COM\_3BGU\\(ERIKA CAIZATOA)} & \makecell{PEN\_3BGU\\(ANITA BARRENO)} & \makecell{GEO\_3BGU\\(LEONARDO ESPINOSA)} \\ \hline
# 8 & 11h15 a 11h45 & \makecell{SOC\_3BGU\\(ISABEL GARCÍA)} & \makecell{MAT\_3BGU\\(LEONARDO ESPINOSA)} & \makecell{DER\_3BGU\\(CORALÍA CÓRDOVA)} & \makecell{PEN\_3BGU\\(ANITA BARRENO)} & \makecell{GEO\_3BGU\\(LEONARDO ESPINOSA)} \\ \hline
# 9 & 11h45 a 12h15 & \makecell{LEN\_3BGU\\(ANDRÉS OLMEDO)} & \makecell{SOC\_3BGU\\(ISABEL GARCÍA)} & \makecell{MAT\_3BGU\\(LEONARDO ESPINOSA)} & \makecell{ING\_3BGU\\(INGLES ESPECIAL)} & \makecell{EDU\_3BGU\\(EF ESPECIAL)} \\ \hline
# 10 & 12h15 a 12h45 & \makecell{LEN\_3BGU\\(ANDRÉS OLMEDO)} & \makecell{SOC\_3BGU\\(ISABEL GARCÍA)} & \makecell{MAT\_3BGU\\(LEONARDO ESPINOSA)} & \makecell{ING\_3BGU\\(INGLES ESPECIAL)} & \makecell{EDU\_3BGU\\(EF ESPECIAL)} \\ \hline
# 11 & 12h45 a 13h15 & \makecell{ING\_3BGU\\(INGLES ESPECIAL)} & \makecell{PLA\_3BGU\\(KEVIN VICENTE)} & \makecell{SAL\_3BGU\\(VANESSA ESPÍN)} & \makecell{LEC\_3BGU\\(PATY FLORES)} & \makecell{EMP\_3BGU\\(MARÍA BELÉN MALDONADO)} \\ \hline
# 12 & 13h15 a 13h45 & \makecell{ING\_3BGU\\(INGLES ESPECIAL)} & \makecell{PLA\_3BGU\\(KEVIN VICENTE)} & \makecell{ECO\_3BGU\\(MARJURIE JÁCOME)} & \makecell{LEC\_3BGU\\(PATY FLORES)} & \makecell{EMP\_3BGU\\(MARÍA BELÉN MALDONADO)} \\ \hline
# 13 & 13h45 a 14h15 & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} \\ \hline
# 14 & 14h15 a 14h45 & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} \\ \hline
# 15 & 14h45 a 15h15 & \makecell{EST\_3BGU\\(JONATHAN CASTRO)} & \makecell{INV\_3BGU\\(KARLA LAZCANO)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{DES\_3BGU\\(JANETH MELO)} & \cellcolor{orange!20}\textbf{CLUBS} \\ \hline
# 16 & 15h15 a 15h45 & \makecell{EST\_3BGU\\(JONATHAN CASTRO)} & \makecell{SPE\_3BGU\\(CHRISTIAN SOLANO)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{DES\_3BGU\\(JANETH MELO)} & \cellcolor{orange!20}\textbf{CLUBS} \\ \hline
# Act. Final & 15h45 a 16h00 & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} \\ \hline
# \end{tabular}
# \label{tab:3BGU_Solidarios}
# \end{table}
# \end{landscape}
#
#
#
# % === HORARIO: 3BGU Vanguardistas ===
# \begin{landscape}
# \begin{table}[H]
# \centering
# \scriptsize
# \caption{Horario para 3BGU Vanguardistas}
# \setlength{\arrayrulewidth}{1pt}
# \arrayrulecolor{black}
# \begin{tabular}{|c|c|c|c|c|c|c|}
# \specialrule{1pt}{0pt}{0pt}
# \rowcolor{white}
# \textbf{Hora} & \textbf{Horario} & \textbf{Lunes} & \textbf{Martes} & \textbf{Miércoles} & \textbf{Jueves} & \textbf{Viernes} \\ \specialrule{1pt}{0pt}{0pt}
# Act. Inicial & 7h30 a 7h45 & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} \\ \hline
# 1 & 7h45 a 8h15 & \makecell{FIS\_3BGU\\(JOSÉ NICOLALDE)} & \makecell{NAT\_3BGU\\(CARLOS BENALCÁZAR)} & \cellcolor{yellow!30}\textbf{EVALEV} & \makecell{DER\_3BGU\\(CORALÍA CÓRDOVA)} & \makecell{ING\_3BGU\\(INGLES ESPECIAL)} \\ \hline
# 2 & 8h15 a 8h45 & \makecell{FIS\_3BGU\\(JOSÉ NICOLALDE)} & \makecell{NAT\_3BGU\\(CARLOS BENALCÁZAR)} & \cellcolor{yellow!30}\textbf{EVALEV} & \makecell{COM\_3BGU\\(ERIKA CAIZATOA)} & \makecell{ING\_3BGU\\(INGLES ESPECIAL)} \\ \hline
# 3 & 8h45 a 9h15 & \makecell{QUI\_3BGU\\(MAYRA QUISHPE)} & \makecell{PEN\_3BGU\\(ANITA BARRENO)} & \makecell{LEC\_3BGU\\(PATY FLORES)} & \makecell{EDU\_3BGU\\(EF ESPECIAL)} & \makecell{GEO\_3BGU\\(LEONARDO ESPINOSA)} \\ \hline
# 4 & 9h15 a 9h45 & \makecell{QUI\_3BGU\\(MAYRA QUISHPE)} & \makecell{PEN\_3BGU\\(ANITA BARRENO)} & \makecell{FIS\_3BGU\\(JOSÉ NICOLALDE)} & \makecell{EDU\_3BGU\\(EF ESPECIAL)} & \makecell{EMP\_3BGU\\(MARÍA BELÉN MALDONADO)} \\ \hline
# 5 & 9h45 a 10h15 & \makecell{PEN\_3BGU\\(ANITA BARRENO)} & \makecell{LEN\_3BGU\\(ANDRÉS OLMEDO)} & \makecell{FIS\_3BGU\\(JOSÉ NICOLALDE)} & \makecell{NAT\_3BGU\\(CARLOS BENALCÁZAR)} & \makecell{EMP\_3BGU\\(MARÍA BELÉN MALDONADO)} \\ \hline
# 6 & 10h15 a 10h45 & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} & \cellcolor{cyan!20}\textbf{RECESO} \\ \hline
# 7 & 10h45 a 11h15 & \makecell{MAT\_3BGU\\(LEONARDO ESPINOSA)} & \makecell{PLA\_3BGU\\(KEVIN VICENTE)} & \makecell{ROB\_3BGU\\(DAVID RÓGEL)} & \makecell{GEO\_3BGU\\(LEONARDO ESPINOSA)} & \makecell{PRO\_3BGU\\(MARCO SAFADI)} \\ \hline
# 8 & 11h15 a 11h45 & \makecell{MAT\_3BGU\\(LEONARDO ESPINOSA)} & \makecell{PLA\_3BGU\\(KEVIN VICENTE)} & \makecell{ROB\_3BGU\\(DAVID RÓGEL)} & \makecell{GEO\_3BGU\\(LEONARDO ESPINOSA)} & \makecell{PRO\_3BGU\\(MARCO SAFADI)} \\ \hline
# 9 & 11h45 a 12h15 & \makecell{LEC\_3BGU\\(PATY FLORES)} & \makecell{MAT\_3BGU\\(LEONARDO ESPINOSA)} & \makecell{SOC\_3BGU\\(ISABEL GARCÍA)} & \makecell{ING\_3BGU\\(INGLES ESPECIAL)} & \makecell{LEN\_3BGU\\(ANDRÉS OLMEDO)} \\ \hline
# 10 & 12h15 a 12h45 & \makecell{LEC\_3BGU\\(PATY FLORES)} & \makecell{MAT\_3BGU\\(LEONARDO ESPINOSA)} & \makecell{SOC\_3BGU\\(ISABEL GARCÍA)} & \makecell{ING\_3BGU\\(INGLES ESPECIAL)} & \makecell{LEN\_3BGU\\(ANDRÉS OLMEDO)} \\ \hline
# 11 & 12h45 a 13h15 & \makecell{ING\_3BGU\\(INGLES ESPECIAL)} & \makecell{SOC\_3BGU\\(ISABEL GARCÍA)} & \makecell{MAT\_3BGU\\(LEONARDO ESPINOSA)} & \makecell{SPE\_3BGU\\(CHRISTIAN SOLANO)} & \makecell{QUI\_3BGU\\(MAYRA QUISHPE)} \\ \hline
# 12 & 13h15 a 13h45 & \makecell{ING\_3BGU\\(INGLES ESPECIAL)} & \makecell{SOC\_3BGU\\(ISABEL GARCÍA)} & \makecell{MAT\_3BGU\\(LEONARDO ESPINOSA)} & \makecell{INV\_3BGU\\(KARLA LAZCANO)} & \makecell{QUI\_3BGU\\(MAYRA QUISHPE)} \\ \hline
# 13 & 13h45 a 14h15 & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} \\ \hline
# 14 & 14h15 a 14h45 & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} & \cellcolor{teal!20}\textbf{ALMUERZO} \\ \hline
# 15 & 14h45 a 15h15 & \makecell{EST\_3BGU\\(JONATHAN CASTRO)} & \makecell{ECO\_3BGU\\(MARJURIE JÁCOME)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{DES\_3BGU\\(JANETH MELO)} & \cellcolor{orange!20}\textbf{CLUBS} \\ \hline
# 16 & 15h15 a 15h45 & \makecell{EST\_3BGU\\(JONATHAN CASTRO)} & \makecell{SAL\_3BGU\\(VANESSA ESPÍN)} & \cellcolor{orange!20}\textbf{CLUBS} & \makecell{DES\_3BGU\\(JANETH MELO)} & \cellcolor{orange!20}\textbf{CLUBS} \\ \hline
# Act. Final & 15h45 a 16h00 & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} & \cellcolor{purple!20}\textbf{TUTORIA} \\ \hline
# \end{tabular}
# \label{tab:3BGU_Vanguardistas}
# \end{table}
# \end{landscape}
