# %% [markdown]
# ## 🔗 Montar Google Drive para acceder a archivos del Scheduling Problem
#
# Este bloque conecta Google Colab con Google Drive. Es necesario para poder cargar o guardar archivos relacionados con el algoritmo genético aplicado al problema de generación de horarios escolares. Asegura acceso a datos como los cromosomas iniciales, los logs de evolución, y los archivos con los mejores individuos encontrados.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 📂 Cargar datasets del Scheduling Problem desde Google Drive
#
# Este bloque carga los datasets principales que definen las condiciones del problema de generación de horarios:
#
# - `docentes.csv`: contiene los profesores y las materias que dictan.
# - `materias.csv`: define cada materia con su respectivo nivel y carga horaria.
# - `paralelos.csv`: lista los cursos y aulas por cada nivel educativo.
# - `horarios.csv`: define los rangos de tiempo disponibles para la asignación.
#
# Estos datos son fundamentales para la construcción de cromosomas válidos y la evaluación del fitness en cada generación del algoritmo genético.

# %%
import pandas as pd
import random

ruta = '/content/drive/MyDrive/Tesis_MSDS'
# Cargar los datos
docentes = pd.read_csv(ruta+"/docentes.csv")
materias = pd.read_csv(ruta+"/materias.csv")
paralelos = pd.read_csv(ruta+"/paralelos.csv")
horarios = pd.read_csv(ruta+"/horarios.csv")

# %% [markdown]
# ## 🧹 Preprocesamiento: Unificación de docentes por asignatura especializada
#
# Este bloque aplica reglas de unificación de nombres de docentes para ciertas materias específicas, con el objetivo de mantener consistencia en la asignación horaria durante el proceso evolutivo:
#
# - **Inglés desde 7mo EGB en adelante**: Se consolidan los docentes `DAISY HERRERA`, `ELIZABETH PUGA` y `SIMONE AYALA` bajo el identificador común `INGLES ESPECIAL`.
# - **Educación Física desde 3ro EGB**: Se unifican `NANCY LINCANGO`, `CARLOS MORALES` e `IVÁN MALDONADO` como `EF ESPECIAL`.
#
# Esta estandarización permite asegurar que estas materias sean asignadas de forma sincronizada entre paralelos del mismo nivel durante la construcción de cromosomas y aplicación de restricciones duras.

# %%
#Unificar docentes de inglés a partir de 7mo EGB
docentes=docentes.drop(docentes[docentes['Nombres']=='ELIZABETH PUGA'].index)
docentes=docentes.drop(docentes[docentes['Nombres']=='SIMONE AYALA'].index)
docentes["Nombres"] = docentes["Nombres"].replace("DAISY HERRERA", "INGLES ESPECIAL")

#Unificar docentes de Educación Física a partir de 3ro EGB
docentes=docentes.drop(docentes[docentes['Nombres']=='CARLOS MORALES'].index)
docentes=docentes.drop(docentes[docentes['Nombres']=='IVÁN MALDONADO'].index)
docentes["Nombres"] = docentes["Nombres"].replace("NANCY LINCANGO", "EF ESPECIAL")

docentes.reset_index()

# %% [markdown]
# ## 🧾 Normalización de códigos de asignaturas por docente
#
# Este bloque transforma la columna `Codigo` del dataset de docentes, que originalmente contiene conjuntos de códigos como strings (`{'MAT_3EGB', 'LEN_3EGB'}`), en un formato plano y legible para el modelo genético.
#
# ### Transformaciones aplicadas:
# - 🔍 **Limpieza**: Se eliminan caracteres como `{}`, comillas simples y espacios extra.
# - 🔄 **Explosión de filas**: Cada código de materia impartido por un docente pasa a una fila separada.
#
# Esto es esencial para permitir una asignación precisa durante la generación y evaluación de cromosomas, ya que cada código representa una materia que debe ser distribuida en el horario.

# %%
df=docentes.copy()
# Limpiar la columna 'Codigo': eliminar llaves y comillas simples
df["Codigo"] = df["Codigo"].str.replace(r"[{}']", "", regex=True)

# Separar los códigos por coma y expandir en filas individuales
docentes = df.assign(Codigo=df["Codigo"].str.split(", ")).explode("Codigo")

docentes.head(5)
# Out:
#    index             Nombres            Cargo      Materia     Codigo
# 0      0          MALENA OÑA  Tiempo completo     LENGUAJE   LEN_1EGB
# 1      1        ALISON PLAZA  Tiempo completo     LECTORES   LEC_1EGB
# 1      1        ALISON PLAZA  Tiempo completo     LECTORES   LEC_2EGB
# 1      1        ALISON PLAZA  Tiempo completo     LECTORES   LEC_3EGB
# 2      2         SOFÍA YÉPEZ  Tiempo completo     LENGUAJE   LEN_3EGB
# 2      2         SOFÍA YÉPEZ  Tiempo completo     LENGUAJE   LEN_2EGB
# 3      3       ROSITA ALBUJA  Tiempo completo     LENGUAJE   LEN_5EGB
# 3      3       ROSITA ALBUJA  Tiempo completo     LENGUAJE   LEN_4EGB
# 4      4       NARCISA MUÑOZ  Tiempo completo     LENGUAJE   LEN_6EGB
# 4      4       NARCISA MUÑOZ  Tiempo completo     LENGUAJE   LEN_7EGB
# 5      5       ANDRÉS OLMEDO  Tiempo completo     LENGUAJE  LEN_10EGB
# 5      5       ANDRÉS OLMEDO  Tiempo completo     LENGUAJE   LEN_1BGU
# 5      5       ANDRÉS OLMEDO  Tiempo completo     LENGUAJE   LEN_3BGU
# 5      5       ANDRÉS OLMEDO  Tiempo completo     LENGUAJE   LEN_8EGB
# 5      5       ANDRÉS OLMEDO  Tiempo completo     LENGUAJE   LEN_9EGB
# 5      5       ANDRÉS OLMEDO  Tiempo completo     LENGUAJE   LEN_2BGU
# 6      6  FERNANDA CAÑIZARES  Tiempo completo  PENSAMIENTO   PEN_1EGB
# 7      7      XIMENA AGUIRRE    Subdirector/a  PENSAMIENTO   PEN_3EGB
# 7      7      XIMENA AGUIRRE    Subdirector/a  PENSAMIENTO   PEN_4EGB
# 8      8        RUTH PORTERO    Subdirector/a  PENSAMIENTO   PEN_5EGB

# %% [markdown]
# ## 🧠 Construcción de diccionario profesor ↔ código de materia
#
# Este bloque crea un diccionario que asocia directamente cada código de materia con el nombre del docente correspondiente.
#
# ### Objetivo:
# Permitir una consulta eficiente del docente responsable de una materia específica, lo cual es clave para:
# - Asignar correctamente los docentes al construir cada cromosoma.
# - Aplicar restricciones como la no duplicación de docentes en simultáneo.
#
# ### Transformaciones aplicadas:
# - Limpieza de strings tipo `{‘LEN_3EGB’, ‘LEN_2EGB’}` para extraer códigos individuales.
# - Creación del diccionario `dic_profesores` en formato:
#   ```python
#   {'LEN_3EGB': 'MALENA OÑA', 'EST_10EGB': 'SANTIAGO CALLE', ...}

# %%
import pandas as pd
df=docentes.copy()
# Carga del archivo CSV
df = docentes

# Identifica las columnas
col_codigo = 'Codigo'
col_profesor = 'Nombres'

# Diccionario resultado
dic_profesores = {}

for _, row in df.iterrows():
    raw = row[col_codigo]
    if pd.isna(raw):
        continue

    # Convertimos a cadena y eliminamos espacios exteriores
    s = str(raw).strip()

    # Si empieza por '{' o '[' acabamos quitando delimitadores
    if s.startswith('{') and s.endswith('}'):
        # Quitamos las llaves
        s = s[1:-1]
    elif s.startswith('[') and s.endswith(']'):
        # Quitamos los corchetes
        s = s[1:-1]

    # Ahora s es algo como "'LEC_1EGB', 'LEC_3EGB', 'LEC_2EGB'"
    # Partimos por comas y limpiamos comillas
    codes = []
    for part in s.split(','):
        part = part.strip().strip("'\"")  # quita comillas simples o dobles
        if part:
            codes.append(part)

    # Asociamos cada código con el profesor
    for code in codes:
        dic_profesores[code] = row[col_profesor]

# Ejemplo de uso:
for ejemplo in ['LEN_3EGB', 'PEN_10EGB', 'EST_10EGB']:
    prof = dic_profesores.get(ejemplo, 'No encontrado')
    print(f"Profesor de {ejemplo}: {prof}")
# Out:
# Profesor de LEN_3EGB: SOFÍA YÉPEZ
# Profesor de PEN_10EGB: MIREYA BRITO
# Profesor de EST_10EGB: JONATHAN CASTRO

# %%
dic_profesores['LEN_1EGB']
# Out:
# 'MALENA OÑA'

# %% [markdown]
# ## 📅 Definición de parámetros y restricciones de horario
#
# Este bloque define las funciones auxiliares y restricciones necesarias para construir cromosomas válidos, tomando en cuenta reglas propias del calendario escolar del colegio.
#
# ### Componentes definidos:
#
# - `dias_semana`: Lista base de días laborables.
# - `obtener_materias_por_nivel(nivel)`: Devuelve la lista de códigos de materia correspondientes a un nivel educativo específico (por ejemplo, 8EGB).
# - `obtener_docente_por_materia_codigo(codigo)`: Consulta el docente responsable de un código de materia usando el diccionario `dic_profesores`.
# - `es_horario_valido(nivel, dia, hora)`: Verifica si un horario específico es válido para un determinado nivel. Esta función incorpora:
#   - Restricciones por **receso** y **almuerzo**.
#   - Bloqueos por eventos institucionales como **Evalev** y **Clubs extracurriculares**.
#   - Diferenciación por nivel educativo y día de la semana.
#
# Estas validaciones son fundamentales para asegurar que las asignaciones generadas durante el algoritmo evolutivo cumplan con las restricciones duras del problema de Scheduling.

# %%
# Lista de días de la semana
dias_semana = ["Lunes", "Martes", "Miércoles", "Jueves", "Viernes"]

# Filtrar materias según nivel
def obtener_materias_por_nivel(nivel):
    return materias[materias["Nivel"] == nivel]["Código"].tolist()

# Obtener docente que imparte la materia
def obtener_docente_por_materia_codigo(codigo_materia):
    return dic_profesores.get(codigo_materia, None)

def es_horario_valido(nivel, dia, hora):
    # Receso
    if nivel in ["1EGB", "2EGB", "3EGB"] and hora == 5:
        return False
    if nivel not in ["1EGB", "2EGB", "3EGB"] and hora == 6:
        return False

    # Almuerzo
    if nivel in ["1EGB", "2EGB", "3EGB", "4EGB", "5EGB", "6EGB", "7EGB"] and hora in [11, 12]:
        return False
    if nivel in ["8EGB", "9EGB", "10EGB", "1BGU", "2BGU", "3BGU"] and hora in [13, 14]:
        return False

    # Evalev
    if dia == "Miércoles" and hora in [1, 2]:
        return False

    # Clubs
    if nivel == "1EGB" and ((dia == "Lunes" and hora in [15, 16]) or (dia == "Jueves" and hora in [13, 14])):
        return False
    if nivel in ["2EGB", "3EGB", "4EGB", "5EGB", "6EGB", "7EGB"] and dia in ["Martes", "Jueves"] and hora in [15, 16]:
        return False
    if nivel in ["8EGB", "9EGB", "10EGB", "1BGU", "2BGU", "3BGU"] and dia in ["Miércoles", "Viernes"] and hora in [15, 16]:
        return False

    return True

# %% [markdown]
# ## 🧮 Función de ordenamiento de cromosomas por nivel, aula, día y hora
#
# Esta función organiza los genes de un cromosoma en un orden lógico y jerárquico para facilitar su análisis, visualización y depuración.
#
# ### Criterios de ordenamiento aplicados:
# 1. **Nivel educativo** en el orden oficial: de 1EGB hasta 3BGU.
# 2. **Paralelo** en orden alfabético.
# 3. **Día de la semana**: de lunes a viernes.
# 4. **Hora**: en orden creciente (desde la primera hora del día).
#
# Esto garantiza que el cromosoma tenga una estructura consistente a lo largo del proceso evolutivo, lo cual es útil tanto para el monitoreo como para asegurar una correcta interpretación por parte de los operadores genéticos.
#
# > 💡 Esta función no altera el contenido del cromosoma, solo su orden para facilitar operaciones posteriores.

# %%
def ordenar_cromosoma(cromosoma):
    """
    Ordena la lista de genes por:
      1) Nivel, en el orden 1EGB→2EGB→…→10EGB→1BGU→2BGU→3BGU
      2) Paralelo (alfabéticamente)
      3) Día de la semana (Lunes→Viernes)
      4) Hora (ascendente)
    """
    # 1) Definir orden explícito de niveles
    niveles_orden = [
        "1EGB","2EGB","3EGB","4EGB","5EGB","6EGB","7EGB",
        "8EGB","9EGB","10EGB",
        "1BGU","2BGU","3BGU"
    ]
    idx_nivel = {niv: i for i, niv in enumerate(niveles_orden)}

    # 2) Orden de días
    dias_orden = {dia: i for i, dia in enumerate(["Lunes","Martes","Miércoles","Jueves","Viernes"])}

    # 3) Sort usando key múltiple
    cromosoma_ordenado = sorted(
        cromosoma,
        key=lambda gen: (
            idx_nivel.get(gen[0], 999),  # Nivel (por si hay alguno inesperado)
            gen[1],                       # Paralelo
            dias_orden[gen[2]],           # Día según dias_orden
            gen[3]                        # Hora
        )
    )
    return cromosoma_ordenado

# %% [markdown]
# ## ⏰ Asignación sincronizada de materias en múltiples aulas por nivel
#
# Esta función permite asignar una misma materia (`codigo_materia`) a múltiples aulas simultáneamente dentro de uno o más niveles educativos. Se asegura de que todas las asignaciones compartan el mismo día y hora, respetando las restricciones del modelo.
#
# ### Parámetros:
# - `cromosoma`: lista actual de genes a modificar.
# - `niveles_target`: niveles educativos involucrados en la sincronización (por ejemplo, `["7EGB", "8EGB", "9EGB"]`).
# - `codigo_materia`: código único de la materia a asignar (por ejemplo, `"ING_7EGB"`).
# - `cantidad_horas`: número total de bloques a asignar para esta materia.
# - `en_parejas`: si `True`, se asignan **bloques dobles continuos** (por ejemplo, para materias con sesiones extendidas).
#
# ### Características clave:
# - Utiliza `es_horario_valido` para verificar que los bloques estén disponibles y no caigan en recesos, almuerzos o eventos institucionales.
# - Aplica verificación cruzada para evitar colisiones de horario en todas las aulas y niveles involucrados.
# - El resultado es un cromosoma actualizado con las nuevas asignaciones sincronizadas.
#
# Esta función es fundamental para materias como **Inglés Especial** o **Educación Física**, que deben dictarse en paralelo entre varias aulas del mismo nivel.

# %%
def asignar_misma_hora_multiple_aulas_actualizado(cromosoma, niveles_target, codigo_materia, cantidad_horas, en_parejas=False):
    aulas_por_nivel = {
        nivel: paralelos.loc[paralelos["Nivel"] == nivel, "Nombre_paralelo"].tolist()
        for nivel in niveles_target
    }

    posibles_slots = []
    for dia in dias_semana:
        for h in range(1, 17 if not en_parejas else 16):
            if en_parejas and not all(es_horario_valido(n, dia, h) and es_horario_valido(n, dia, h+1) for n in niveles_target):
                continue
            if not en_parejas and not all(es_horario_valido(n, dia, h) for n in niveles_target):
                continue
            posibles_slots.append((dia, h))

    random.shuffle(posibles_slots)
    horas_asignadas = 0

    for dia, hora in posibles_slots:
        ocupado = False
        for nivel in niveles_target:
            for aula in aulas_por_nivel[nivel]:
                if any((g[0] == nivel and g[1] == aula and g[2] == dia and g[3] == hora) or
                       (en_parejas and g[0] == nivel and g[1] == aula and g[2] == dia and g[3] == hora+1)
                       for g in cromosoma):
                    ocupado = True
                    break
        if ocupado:
            continue

        for nivel in niveles_target:
            for aula in aulas_por_nivel[nivel]:
                docente = obtener_docente_por_materia_codigo(codigo_materia)
                cromosoma.append((nivel, aula, dia, hora, codigo_materia, docente))
                if en_parejas:
                    cromosoma.append((nivel, aula, dia, hora+1, codigo_materia, docente))

        horas_asignadas += 2 if en_parejas else 1
        if horas_asignadas >= cantidad_horas:
            break

    return cromosoma

# %% [markdown]
# ## 🧬 Generación de cromosoma inicial con bloques sincronizados y asignaciones estructuradas
#
# Esta función construye un cromosoma válido para el problema de Scheduling Educativo. Cada cromosoma representa un horario completo con todas las asignaciones posibles de materias, aulas, días y docentes, cumpliendo con restricciones duras como horarios válidos y franjas especiales por nivel.
#
# ### Fases principales de la generación:
#
# #### 1️⃣ **Asignaciones especiales sincronizadas por nivel**
# - Materias como **INGLES ESPECIAL**, **ESTUDIOS SOCIALES**, **DESARROLLO PERSONAL** o **CIUDADANÍA** se asignan en bloques comunes para todas las aulas de un mismo nivel, usando la función `asignar_misma_hora_multiple_aulas_actualizado`.
#
# #### 2️⃣ **Asignación por pares preferidos**
# - Se crean bloques de clases en pares, respetando combinaciones pedagógicas predefinidas como:
#   - `DER` ↔ `COM`
#   - `SPE` ↔ `INV`
#   - `SAL` ↔ `ECO`
#   - `EXP` ↔ `RAZ` / `CAL`
#   - `DAN` ↔ `MUS`
# - Estos pares se asignan en bloques contiguos (slots dobles) en días y horas válidas.
#
# #### 3️⃣ **Relleno de ranuras restantes**
# - Se llena el resto del horario con las materias disponibles según la carga horaria restante, validando siempre:
#   - Que el horario sea válido (`es_horario_valido`)
#   - Que no exista una asignación previa en el mismo bloque
#
# #### 4️⃣ **Orden final**
# - El cromosoma generado se ordena al final por nivel, paralelo, día y hora para mantener consistencia y facilitar el análisis visual y evolutivo.
#
# > ⚠️ Cada cromosoma generado es diferente, ya que intervienen decisiones aleatorias (`random.shuffle`, `random.choice`) tanto en la selección de materias como en la ubicación de horarios, lo que aporta diversidad genética inicial a la población.

# %%
import random

def generar_cromosoma():
    cromosoma = []
    niveles = paralelos["Nivel"].unique()

    # 1. Asignaciones comunes por nivel
    niveles_ingles = ["7EGB", "8EGB", "9EGB", "10EGB", "1BGU", "2BGU", "3BGU"]
    for nivel in niveles_ingles:
        cod = f"ING_{nivel}"
        cromosoma = asignar_misma_hora_multiple_aulas_actualizado(cromosoma, [nivel], cod, cantidad_horas=6, en_parejas=True)

    cromosoma = asignar_misma_hora_multiple_aulas_actualizado(cromosoma, ["3BGU"], "EST_3BGU", cantidad_horas=2, en_parejas=True)
    cromosoma = asignar_misma_hora_multiple_aulas_actualizado(cromosoma, ["3BGU"], "DES_3BGU", cantidad_horas=2, en_parejas=True)
    cromosoma = asignar_misma_hora_multiple_aulas_actualizado(cromosoma, ["1BGU"], "CIU_1BGU", cantidad_horas=1, en_parejas=False)
    cromosoma = asignar_misma_hora_multiple_aulas_actualizado(cromosoma, ["2BGU"], "CIU_2BGU", cantidad_horas=1, en_parejas=False)

    # 2. Pares preferidos
    pares_pref = {
        "DER": "COM",
        "SPE": "INV",
        "SAL": "ECO",
        "EXP": ["RAZ", "CAL"],
        "DAN": "MUS"
    }

    for nivel in niveles:
        aulas = paralelos.loc[paralelos["Nivel"] == nivel, "Nombre_paralelo"]
        materias_nivel = materias[materias["Nivel"] == nivel]

        for aula in aulas:
            bolsa = []
            for _, row in materias_nivel.iterrows():
                bolsa += [row["Código"]] * int(row["Horas"])

            bolsa = [c for c in bolsa if not any(g[0] == nivel and g[1] == aula and g[4] == c for g in cromosoma)]

            # Buscar ranuras dobles disponibles
            slots_pares = []
            for dia in dias_semana:
                horas_validas = sorted(h for h in range(1, 16)
                    if es_horario_valido(nivel, dia, h)
                    and es_horario_valido(nivel, dia, h+1)
                    and not any(g[0] == nivel and g[1] == aula and g[2] == dia and g[3] in [h, h+1] for g in cromosoma))
                for h in horas_validas:
                    if h + 1 in horas_validas:
                        slots_pares.append((dia, h))

            lista_pares = []
            claves = list(pares_pref.keys())
            random.shuffle(claves)
            for pref in claves:
                pareja = pares_pref[pref]
                cods1 = [c for c in bolsa if c.startswith(pref)]
                if isinstance(pareja, list):
                    cods2 = [c for c in bolsa if any(c.startswith(p) for p in pareja)]
                else:
                    cods2 = [c for c in bolsa if c.startswith(pareja)]
                num = min(len(cods1), len(cods2))

                for _ in range(num):
                    c1 = cods1.pop(); bolsa.remove(c1)
                    if isinstance(pareja, list):
                        c2 = next(c for c in cods2 if any(c.startswith(p) for p in pareja))
                        cods2.remove(c2)
                    else:
                        c2 = cods2.pop()
                    bolsa.remove(c2)

                    # 🔁 Orden aleatorio de la pareja
                    pareja_ordenada = [c1, c2]
                    random.shuffle(pareja_ordenada)
                    lista_pares.append(tuple(pareja_ordenada))


            random.shuffle(lista_pares)
            random.shuffle(slots_pares)
            for (dia, h), (c1, c2) in zip(slots_pares, lista_pares):
                d1 = obtener_docente_por_materia_codigo(c1)
                d2 = obtener_docente_por_materia_codigo(c2)
                cromosoma.append((nivel, aula, dia, h, c1, d1))
                cromosoma.append((nivel, aula, dia, h+1, c2, d2))

            # 3. Relleno final
            for dia in dias_semana:
                for hora in range(1, 17):
                    if not es_horario_valido(nivel, dia, hora):
                        continue
                    if any(g[0] == nivel and g[1] == aula and g[2] == dia and g[3] == hora for g in cromosoma):
                        continue
                    if bolsa:
                        idx = random.randrange(len(bolsa))
                        c = bolsa.pop(idx)
                        d = obtener_docente_por_materia_codigo(c)
                        cromosoma.append((nivel, aula, dia, hora, c, d))

    return ordenar_cromosoma(cromosoma)

# %%
# Generar cromosoma y mostrar validación
cromosoma_ejemplo = generar_cromosoma()
print(f"Total de genes generados: {len(cromosoma_ejemplo)}")

# Mostrar los primeros 5 genes
for gen in cromosoma_ejemplo[:]:
    print(gen)
# Out:
# Total de genes generados: 2832
# ('1EGB', 'Ejemplares', 'Lunes', 1, 'EST_1EGB', 'SANTIAGO CALLE')
# ('1EGB', 'Ejemplares', 'Lunes', 2, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Ejemplares', 'Lunes', 3, 'LEC_1EGB', 'ALISON PLAZA')
# ('1EGB', 'Ejemplares', 'Lunes', 4, 'EST_1EGB', 'SANTIAGO CALLE')
# ('1EGB', 'Ejemplares', 'Lunes', 6, 'INV_1EGB', 'KARLA LAZCANO')
# ('1EGB', 'Ejemplares', 'Lunes', 7, 'SPE_1EGB', 'CHRISTIAN SOLANO')
# ('1EGB', 'Ejemplares', 'Lunes', 7, 'SAL_1EGB', 'VANESSA ESPÍN')
# ('1EGB', 'Ejemplares', 'Lunes', 8, 'ECO_1EGB', 'MARJURIE JÁCOME')
# ('1EGB', 'Ejemplares', 'Lunes', 9, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Ejemplares', 'Lunes', 10, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Ejemplares', 'Lunes', 13, 'PEN_1EGB', 'FERNANDA CAÑIZARES')
# ('1EGB', 'Ejemplares', 'Lunes', 14, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Ejemplares', 'Martes', 1, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Ejemplares', 'Martes', 2, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Ejemplares', 'Martes', 3, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Ejemplares', 'Martes', 4, 'ESP_1EGB', 'MERY VENEGAS')
# ('1EGB', 'Ejemplares', 'Martes', 6, 'PEN_1EGB', 'FERNANDA CAÑIZARES')
# ('1EGB', 'Ejemplares', 'Martes', 7, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Ejemplares', 'Martes', 8, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Ejemplares', 'Martes', 9, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Ejemplares', 'Martes', 10, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Ejemplares', 'Martes', 13, 'ESP_1EGB', 'MERY VENEGAS')
# ('1EGB', 'Ejemplares', 'Martes', 14, 'EDU_1EGB', 'EF ESPECIAL')
# ('1EGB', 'Ejemplares', 'Martes', 15, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Ejemplares', 'Martes', 16, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Ejemplares', 'Miércoles', 3, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Ejemplares', 'Miércoles', 4, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Ejemplares', 'Miércoles', 6, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Ejemplares', 'Miércoles', 7, 'EST_1EGB', 'SANTIAGO CALLE')
# ('1EGB', 'Ejemplares', 'Miércoles', 8, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Ejemplares', 'Miércoles', 9, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Ejemplares', 'Miércoles', 10, 'DES_1EGB', 'ANDREA MACIAS')
# ('1EGB', 'Ejemplares', 'Miércoles', 13, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Ejemplares', 'Miércoles', 14, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Ejemplares', 'Miércoles', 15, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Ejemplares', 'Miércoles', 16, 'ROB_1EGB', 'JENNY CHICAIZA')
# ('1EGB', 'Ejemplares', 'Jueves', 1, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Ejemplares', 'Jueves', 2, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Ejemplares', 'Jueves', 3, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Ejemplares', 'Jueves', 4, 'EXT_1EGB', 'MARIEL RODRIGUEZ')
# ('1EGB', 'Ejemplares', 'Jueves', 6, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Ejemplares', 'Jueves', 7, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Ejemplares', 'Jueves', 8, 'LEC_1EGB', 'ALISON PLAZA')
# ('1EGB', 'Ejemplares', 'Jueves', 9, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Ejemplares', 'Jueves', 10, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Ejemplares', 'Jueves', 15, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Ejemplares', 'Jueves', 16, 'LEC_1EGB', 'ALISON PLAZA')
# ('1EGB', 'Ejemplares', 'Viernes', 1, 'DES_1EGB', 'ANDREA MACIAS')
# ('1EGB', 'Ejemplares', 'Viernes', 2, 'DAN_1EGB', 'PAOLA LÓPEZ')
# ('1EGB', 'Ejemplares', 'Viernes', 3, 'MUS_1EGB', 'LUIS JÁCOME')
# ('1EGB', 'Ejemplares', 'Viernes', 4, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Ejemplares', 'Viernes', 6, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Ejemplares', 'Viernes', 7, 'COM_1EGB', 'ERIKA CAIZATOA')
# ('1EGB', 'Ejemplares', 'Viernes', 8, 'DER_1EGB', 'CORALÍA CÓRDOVA')
# ('1EGB', 'Ejemplares', 'Viernes', 9, 'ROB_1EGB', 'JENNY CHICAIZA')
# ('1EGB', 'Ejemplares', 'Viernes', 10, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Ejemplares', 'Viernes', 13, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Ejemplares', 'Viernes', 14, 'EDU_1EGB', 'EF ESPECIAL')
# ('1EGB', 'Ejemplares', 'Viernes', 15, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Entusiastas', 'Lunes', 1, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Entusiastas', 'Lunes', 2, 'ESP_1EGB', 'MERY VENEGAS')
# ('1EGB', 'Entusiastas', 'Lunes', 3, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Entusiastas', 'Lunes', 4, 'ROB_1EGB', 'JENNY CHICAIZA')
# ('1EGB', 'Entusiastas', 'Lunes', 6, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Entusiastas', 'Lunes', 7, 'MUS_1EGB', 'LUIS JÁCOME')
# ('1EGB', 'Entusiastas', 'Lunes', 8, 'DAN_1EGB', 'PAOLA LÓPEZ')
# ('1EGB', 'Entusiastas', 'Lunes', 9, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Entusiastas', 'Lunes', 10, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Entusiastas', 'Lunes', 13, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Entusiastas', 'Lunes', 14, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Entusiastas', 'Martes', 1, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Entusiastas', 'Martes', 2, 'SPE_1EGB', 'CHRISTIAN SOLANO')
# ('1EGB', 'Entusiastas', 'Martes', 3, 'INV_1EGB', 'KARLA LAZCANO')
# ('1EGB', 'Entusiastas', 'Martes', 4, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Entusiastas', 'Martes', 6, 'SAL_1EGB', 'VANESSA ESPÍN')
# ('1EGB', 'Entusiastas', 'Martes', 7, 'ECO_1EGB', 'MARJURIE JÁCOME')
# ('1EGB', 'Entusiastas', 'Martes', 8, 'PEN_1EGB', 'FERNANDA CAÑIZARES')
# ('1EGB', 'Entusiastas', 'Martes', 9, 'EDU_1EGB', 'EF ESPECIAL')
# ('1EGB', 'Entusiastas', 'Martes', 10, 'DES_1EGB', 'ANDREA MACIAS')
# ('1EGB', 'Entusiastas', 'Martes', 13, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Entusiastas', 'Martes', 14, 'EST_1EGB', 'SANTIAGO CALLE')
# ('1EGB', 'Entusiastas', 'Martes', 15, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Entusiastas', 'Martes', 16, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Entusiastas', 'Miércoles', 3, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Entusiastas', 'Miércoles', 4, 'LEC_1EGB', 'ALISON PLAZA')
# ('1EGB', 'Entusiastas', 'Miércoles', 6, 'LEC_1EGB', 'ALISON PLAZA')
# ('1EGB', 'Entusiastas', 'Miércoles', 7, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Entusiastas', 'Miércoles', 8, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Entusiastas', 'Miércoles', 9, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Entusiastas', 'Miércoles', 10, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Entusiastas', 'Miércoles', 13, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Entusiastas', 'Miércoles', 14, 'EDU_1EGB', 'EF ESPECIAL')
# ('1EGB', 'Entusiastas', 'Miércoles', 15, 'EST_1EGB', 'SANTIAGO CALLE')
# ('1EGB', 'Entusiastas', 'Miércoles', 16, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Entusiastas', 'Jueves', 1, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Entusiastas', 'Jueves', 2, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Entusiastas', 'Jueves', 3, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Entusiastas', 'Jueves', 4, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Entusiastas', 'Jueves', 6, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Entusiastas', 'Jueves', 7, 'LEC_1EGB', 'ALISON PLAZA')
# ('1EGB', 'Entusiastas', 'Jueves', 8, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Entusiastas', 'Jueves', 9, 'ROB_1EGB', 'JENNY CHICAIZA')
# ('1EGB', 'Entusiastas', 'Jueves', 10, 'ESP_1EGB', 'MERY VENEGAS')
# ('1EGB', 'Entusiastas', 'Jueves', 15, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Entusiastas', 'Jueves', 16, 'PEN_1EGB', 'FERNANDA CAÑIZARES')
# ('1EGB', 'Entusiastas', 'Viernes', 1, 'COM_1EGB', 'ERIKA CAIZATOA')
# ('1EGB', 'Entusiastas', 'Viernes', 2, 'DER_1EGB', 'CORALÍA CÓRDOVA')
# ('1EGB', 'Entusiastas', 'Viernes', 3, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Entusiastas', 'Viernes', 4, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Entusiastas', 'Viernes', 6, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Entusiastas', 'Viernes', 7, 'EXT_1EGB', 'MARIEL RODRIGUEZ')
# ('1EGB', 'Entusiastas', 'Viernes', 8, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Entusiastas', 'Viernes', 9, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Entusiastas', 'Viernes', 10, 'EST_1EGB', 'SANTIAGO CALLE')
# ('1EGB', 'Entusiastas', 'Viernes', 13, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Entusiastas', 'Viernes', 14, 'DES_1EGB', 'ANDREA MACIAS')
# ('1EGB', 'Entusiastas', 'Viernes', 15, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Entusiastas', 'Viernes', 16, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Estudiosos', 'Lunes', 1, 'ROB_1EGB', 'JENNY CHICAIZA')
# ('1EGB', 'Estudiosos', 'Lunes', 2, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Estudiosos', 'Lunes', 3, 'PEN_1EGB', 'FERNANDA CAÑIZARES')
# ('1EGB', 'Estudiosos', 'Lunes', 4, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Estudiosos', 'Lunes', 6, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Estudiosos', 'Lunes', 7, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Estudiosos', 'Lunes', 8, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Estudiosos', 'Lunes', 9, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Estudiosos', 'Lunes', 10, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Estudiosos', 'Lunes', 13, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Estudiosos', 'Lunes', 14, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Estudiosos', 'Martes', 1, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Estudiosos', 'Martes', 2, 'EST_1EGB', 'SANTIAGO CALLE')
# ('1EGB', 'Estudiosos', 'Martes', 3, 'EST_1EGB', 'SANTIAGO CALLE')
# ('1EGB', 'Estudiosos', 'Martes', 4, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Estudiosos', 'Martes', 6, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Estudiosos', 'Martes', 7, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Estudiosos', 'Martes', 8, 'PEN_1EGB', 'FERNANDA CAÑIZARES')
# ('1EGB', 'Estudiosos', 'Martes', 9, 'ESP_1EGB', 'MERY VENEGAS')
# ('1EGB', 'Estudiosos', 'Martes', 10, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Estudiosos', 'Martes', 13, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Estudiosos', 'Martes', 14, 'EDU_1EGB', 'EF ESPECIAL')
# ('1EGB', 'Estudiosos', 'Martes', 15, 'DES_1EGB', 'ANDREA MACIAS')
# ('1EGB', 'Estudiosos', 'Martes', 16, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Estudiosos', 'Miércoles', 3, 'EDU_1EGB', 'EF ESPECIAL')
# ('1EGB', 'Estudiosos', 'Miércoles', 4, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Estudiosos', 'Miércoles', 6, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Estudiosos', 'Miércoles', 7, 'SPE_1EGB', 'CHRISTIAN SOLANO')
# ('1EGB', 'Estudiosos', 'Miércoles', 8, 'INV_1EGB', 'KARLA LAZCANO')
# ('1EGB', 'Estudiosos', 'Miércoles', 9, 'LEC_1EGB', 'ALISON PLAZA')
# ('1EGB', 'Estudiosos', 'Miércoles', 10, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Estudiosos', 'Miércoles', 13, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Estudiosos', 'Miércoles', 14, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Estudiosos', 'Miércoles', 15, 'DES_1EGB', 'ANDREA MACIAS')
# ('1EGB', 'Estudiosos', 'Miércoles', 16, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Estudiosos', 'Jueves', 1, 'ESP_1EGB', 'MERY VENEGAS')
# ('1EGB', 'Estudiosos', 'Jueves', 2, 'DER_1EGB', 'CORALÍA CÓRDOVA')
# ('1EGB', 'Estudiosos', 'Jueves', 3, 'COM_1EGB', 'ERIKA CAIZATOA')
# ('1EGB', 'Estudiosos', 'Jueves', 4, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Estudiosos', 'Jueves', 6, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Estudiosos', 'Jueves', 7, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Estudiosos', 'Jueves', 8, 'MUS_1EGB', 'LUIS JÁCOME')
# ('1EGB', 'Estudiosos', 'Jueves', 9, 'DAN_1EGB', 'PAOLA LÓPEZ')
# ('1EGB', 'Estudiosos', 'Jueves', 10, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Estudiosos', 'Jueves', 15, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Estudiosos', 'Jueves', 16, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Estudiosos', 'Viernes', 1, 'SAL_1EGB', 'VANESSA ESPÍN')
# ('1EGB', 'Estudiosos', 'Viernes', 2, 'ECO_1EGB', 'MARJURIE JÁCOME')
# ('1EGB', 'Estudiosos', 'Viernes', 3, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Estudiosos', 'Viernes', 4, 'LEC_1EGB', 'ALISON PLAZA')
# ('1EGB', 'Estudiosos', 'Viernes', 6, 'EST_1EGB', 'SANTIAGO CALLE')
# ('1EGB', 'Estudiosos', 'Viernes', 7, 'ROB_1EGB', 'JENNY CHICAIZA')
# ('1EGB', 'Estudiosos', 'Viernes', 8, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Estudiosos', 'Viernes', 9, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Estudiosos', 'Viernes', 10, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Estudiosos', 'Viernes', 13, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Estudiosos', 'Viernes', 14, 'EXT_1EGB', 'MARIEL RODRIGUEZ')
# ('1EGB', 'Estudiosos', 'Viernes', 15, 'LEC_1EGB', 'ALISON PLAZA')
# ('1EGB', 'Estudiosos', 'Viernes', 16, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Exitosos', 'Lunes', 1, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Exitosos', 'Lunes', 2, 'DES_1EGB', 'ANDREA MACIAS')
# ('1EGB', 'Exitosos', 'Lunes', 3, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Exitosos', 'Lunes', 4, 'ESP_1EGB', 'MERY VENEGAS')
# ('1EGB', 'Exitosos', 'Lunes', 6, 'ROB_1EGB', 'JENNY CHICAIZA')
# ('1EGB', 'Exitosos', 'Lunes', 7, 'DAN_1EGB', 'PAOLA LÓPEZ')
# ('1EGB', 'Exitosos', 'Lunes', 8, 'MUS_1EGB', 'LUIS JÁCOME')
# ('1EGB', 'Exitosos', 'Lunes', 9, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Exitosos', 'Lunes', 10, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Exitosos', 'Lunes', 13, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Exitosos', 'Lunes', 14, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Exitosos', 'Martes', 1, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Exitosos', 'Martes', 2, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Exitosos', 'Martes', 3, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Exitosos', 'Martes', 4, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Exitosos', 'Martes', 6, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Exitosos', 'Martes', 7, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Exitosos', 'Martes', 8, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Exitosos', 'Martes', 9, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Exitosos', 'Martes', 10, 'PEN_1EGB', 'FERNANDA CAÑIZARES')
# ('1EGB', 'Exitosos', 'Martes', 13, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Exitosos', 'Martes', 14, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Exitosos', 'Martes', 15, 'PEN_1EGB', 'FERNANDA CAÑIZARES')
# ('1EGB', 'Exitosos', 'Martes', 16, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Exitosos', 'Miércoles', 3, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Exitosos', 'Miércoles', 4, 'LEC_1EGB', 'ALISON PLAZA')
# ('1EGB', 'Exitosos', 'Miércoles', 6, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Exitosos', 'Miércoles', 7, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Exitosos', 'Miércoles', 8, 'SAL_1EGB', 'VANESSA ESPÍN')
# ('1EGB', 'Exitosos', 'Miércoles', 9, 'ECO_1EGB', 'MARJURIE JÁCOME')
# ('1EGB', 'Exitosos', 'Miércoles', 10, 'ESP_1EGB', 'MERY VENEGAS')
# ('1EGB', 'Exitosos', 'Miércoles', 13, 'LEC_1EGB', 'ALISON PLAZA')
# ('1EGB', 'Exitosos', 'Miércoles', 14, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Exitosos', 'Miércoles', 15, 'DES_1EGB', 'ANDREA MACIAS')
# ('1EGB', 'Exitosos', 'Miércoles', 16, 'EXT_1EGB', 'MARIEL RODRIGUEZ')
# ('1EGB', 'Exitosos', 'Jueves', 1, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Exitosos', 'Jueves', 2, 'SPE_1EGB', 'CHRISTIAN SOLANO')
# ('1EGB', 'Exitosos', 'Jueves', 3, 'INV_1EGB', 'KARLA LAZCANO')
# ('1EGB', 'Exitosos', 'Jueves', 4, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Exitosos', 'Jueves', 6, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Exitosos', 'Jueves', 7, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Exitosos', 'Jueves', 8, 'EST_1EGB', 'SANTIAGO CALLE')
# ('1EGB', 'Exitosos', 'Jueves', 9, 'EST_1EGB', 'SANTIAGO CALLE')
# ('1EGB', 'Exitosos', 'Jueves', 10, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Exitosos', 'Jueves', 15, 'EST_1EGB', 'SANTIAGO CALLE')
# ('1EGB', 'Exitosos', 'Jueves', 16, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Exitosos', 'Viernes', 1, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Exitosos', 'Viernes', 2, 'LEC_1EGB', 'ALISON PLAZA')
# ('1EGB', 'Exitosos', 'Viernes', 3, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Exitosos', 'Viernes', 4, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Exitosos', 'Viernes', 6, 'EDU_1EGB', 'EF ESPECIAL')
# ('1EGB', 'Exitosos', 'Viernes', 7, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Exitosos', 'Viernes', 8, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Exitosos', 'Viernes', 9, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Exitosos', 'Viernes', 10, 'ROB_1EGB', 'JENNY CHICAIZA')
# ('1EGB', 'Exitosos', 'Viernes', 13, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Exitosos', 'Viernes', 14, 'COM_1EGB', 'ERIKA CAIZATOA')
# ('1EGB', 'Exitosos', 'Viernes', 15, 'DER_1EGB', 'CORALÍA CÓRDOVA')
# ('1EGB', 'Exitosos', 'Viernes', 16, 'EDU_1EGB', 'EF ESPECIAL')
# ('2EGB', 'Afectuosos', 'Lunes', 1, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Afectuosos', 'Lunes', 2, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Afectuosos', 'Lunes', 3, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Afectuosos', 'Lunes', 4, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Afectuosos', 'Lunes', 6, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Afectuosos', 'Lunes', 7, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Afectuosos', 'Lunes', 8, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Afectuosos', 'Lunes', 9, 'DES_2EGB', 'MISHEL SALTOS')
# ('2EGB', 'Afectuosos', 'Lunes', 10, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Afectuosos', 'Lunes', 13, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Afectuosos', 'Lunes', 14, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Afectuosos', 'Lunes', 15, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Afectuosos', 'Lunes', 16, 'SOC_2EGB', 'ALBITA QUILLUPANGUI')
# ('2EGB', 'Afectuosos', 'Martes', 1, 'EDU_2EGB', 'EF ESPECIAL')
# ('2EGB', 'Afectuosos', 'Martes', 2, 'PLA_2EGB', 'LIZ DÍAZ')
# ('2EGB', 'Afectuosos', 'Martes', 3, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Afectuosos', 'Martes', 4, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Afectuosos', 'Martes', 6, 'SPE_2EGB', 'CHRISTIAN SOLANO')
# ('2EGB', 'Afectuosos', 'Martes', 7, 'INV_2EGB', 'KARLA LAZCANO')
# ('2EGB', 'Afectuosos', 'Martes', 7, 'SAL_2EGB', 'VANESSA ESPÍN')
# ('2EGB', 'Afectuosos', 'Martes', 8, 'ECO_2EGB', 'MARJURIE JÁCOME')
# ('2EGB', 'Afectuosos', 'Martes', 9, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Afectuosos', 'Martes', 10, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Afectuosos', 'Martes', 13, 'ROB_2EGB', 'DAVID CASTRO')
# ('2EGB', 'Afectuosos', 'Martes', 14, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Afectuosos', 'Miércoles', 3, 'SOC_2EGB', 'ALBITA QUILLUPANGUI')
# ('2EGB', 'Afectuosos', 'Miércoles', 4, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Afectuosos', 'Miércoles', 6, 'MUS_2EGB', 'LUIS JÁCOME')
# ('2EGB', 'Afectuosos', 'Miércoles', 7, 'DAN_2EGB', 'PAOLA LÓPEZ')
# ('2EGB', 'Afectuosos', 'Miércoles', 8, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Afectuosos', 'Miércoles', 9, 'ROB_2EGB', 'DAVID CASTRO')
# ('2EGB', 'Afectuosos', 'Miércoles', 10, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Afectuosos', 'Miércoles', 13, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Afectuosos', 'Miércoles', 14, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Afectuosos', 'Miércoles', 15, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Afectuosos', 'Miércoles', 16, 'PLA_2EGB', 'LIZ DÍAZ')
# ('2EGB', 'Afectuosos', 'Jueves', 1, 'SOC_2EGB', 'ALBITA QUILLUPANGUI')
# ('2EGB', 'Afectuosos', 'Jueves', 2, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Afectuosos', 'Jueves', 3, 'EDU_2EGB', 'EF ESPECIAL')
# ('2EGB', 'Afectuosos', 'Jueves', 4, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Afectuosos', 'Jueves', 6, 'COM_2EGB', 'ERIKA CAIZATOA')
# ('2EGB', 'Afectuosos', 'Jueves', 7, 'DER_2EGB', 'CORALÍA CÓRDOVA')
# ('2EGB', 'Afectuosos', 'Jueves', 8, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Afectuosos', 'Jueves', 9, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Afectuosos', 'Jueves', 10, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Afectuosos', 'Jueves', 13, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Afectuosos', 'Jueves', 14, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Afectuosos', 'Viernes', 1, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Afectuosos', 'Viernes', 2, 'EXP_2EGB', 'JOSÉ LUIS HERNÁNDEZ')
# ('2EGB', 'Afectuosos', 'Viernes', 3, 'CAL_2EGB', 'JAIR CRIOLLO')
# ('2EGB', 'Afectuosos', 'Viernes', 4, 'DES_2EGB', 'MISHEL SALTOS')
# ('2EGB', 'Afectuosos', 'Viernes', 6, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Afectuosos', 'Viernes', 7, 'PRO_2EGB', 'LUDWIN GUALOTUÑA')
# ('2EGB', 'Afectuosos', 'Viernes', 8, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Afectuosos', 'Viernes', 9, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Afectuosos', 'Viernes', 10, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Afectuosos', 'Viernes', 13, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Afectuosos', 'Viernes', 14, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Afectuosos', 'Viernes', 15, 'PRO_2EGB', 'LUDWIN GUALOTUÑA')
# ('2EGB', 'Amables', 'Lunes', 1, 'ROB_2EGB', 'DAVID CASTRO')
# ('2EGB', 'Amables', 'Lunes', 2, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Amables', 'Lunes', 3, 'PRO_2EGB', 'LUDWIN GUALOTUÑA')
# ('2EGB', 'Amables', 'Lunes', 4, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amables', 'Lunes', 6, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amables', 'Lunes', 7, 'EDU_2EGB', 'EF ESPECIAL')
# ('2EGB', 'Amables', 'Lunes', 8, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amables', 'Lunes', 9, 'SOC_2EGB', 'ALBITA QUILLUPANGUI')
# ('2EGB', 'Amables', 'Lunes', 10, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amables', 'Lunes', 13, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amables', 'Lunes', 14, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amables', 'Lunes', 15, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Amables', 'Lunes', 16, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amables', 'Martes', 1, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Amables', 'Martes', 2, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Amables', 'Martes', 3, 'ROB_2EGB', 'DAVID CASTRO')
# ('2EGB', 'Amables', 'Martes', 4, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amables', 'Martes', 6, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Amables', 'Martes', 7, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amables', 'Martes', 8, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Amables', 'Martes', 9, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amables', 'Martes', 10, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Amables', 'Martes', 13, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amables', 'Martes', 14, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amables', 'Miércoles', 3, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amables', 'Miércoles', 4, 'PRO_2EGB', 'LUDWIN GUALOTUÑA')
# ('2EGB', 'Amables', 'Miércoles', 6, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amables', 'Miércoles', 7, 'EDU_2EGB', 'EF ESPECIAL')
# ('2EGB', 'Amables', 'Miércoles', 8, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amables', 'Miércoles', 9, 'SOC_2EGB', 'ALBITA QUILLUPANGUI')
# ('2EGB', 'Amables', 'Miércoles', 10, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amables', 'Miércoles', 13, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amables', 'Miércoles', 14, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amables', 'Miércoles', 15, 'PLA_2EGB', 'LIZ DÍAZ')
# ('2EGB', 'Amables', 'Miércoles', 16, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Amables', 'Jueves', 1, 'DER_2EGB', 'CORALÍA CÓRDOVA')
# ('2EGB', 'Amables', 'Jueves', 2, 'COM_2EGB', 'ERIKA CAIZATOA')
# ('2EGB', 'Amables', 'Jueves', 3, 'PLA_2EGB', 'LIZ DÍAZ')
# ('2EGB', 'Amables', 'Jueves', 4, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amables', 'Jueves', 6, 'DES_2EGB', 'MISHEL SALTOS')
# ('2EGB', 'Amables', 'Jueves', 7, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amables', 'Jueves', 8, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amables', 'Jueves', 9, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Amables', 'Jueves', 10, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Amables', 'Jueves', 13, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amables', 'Jueves', 14, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Amables', 'Viernes', 1, 'ECO_2EGB', 'MARJURIE JÁCOME')
# ('2EGB', 'Amables', 'Viernes', 2, 'SAL_2EGB', 'VANESSA ESPÍN')
# ('2EGB', 'Amables', 'Viernes', 2, 'DAN_2EGB', 'PAOLA LÓPEZ')
# ('2EGB', 'Amables', 'Viernes', 3, 'MUS_2EGB', 'LUIS JÁCOME')
# ('2EGB', 'Amables', 'Viernes', 4, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amables', 'Viernes', 6, 'CAL_2EGB', 'JAIR CRIOLLO')
# ('2EGB', 'Amables', 'Viernes', 7, 'EXP_2EGB', 'JOSÉ LUIS HERNÁNDEZ')
# ('2EGB', 'Amables', 'Viernes', 8, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Amables', 'Viernes', 9, 'DES_2EGB', 'MISHEL SALTOS')
# ('2EGB', 'Amables', 'Viernes', 10, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amables', 'Viernes', 13, 'SOC_2EGB', 'ALBITA QUILLUPANGUI')
# ('2EGB', 'Amables', 'Viernes', 14, 'INV_2EGB', 'KARLA LAZCANO')
# ('2EGB', 'Amables', 'Viernes', 15, 'SPE_2EGB', 'CHRISTIAN SOLANO')
# ('2EGB', 'Amigables', 'Lunes', 1, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Amigables', 'Lunes', 2, 'PRO_2EGB', 'LUDWIN GUALOTUÑA')
# ('2EGB', 'Amigables', 'Lunes', 3, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amigables', 'Lunes', 4, 'PRO_2EGB', 'LUDWIN GUALOTUÑA')
# ('2EGB', 'Amigables', 'Lunes', 6, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Amigables', 'Lunes', 7, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Amigables', 'Lunes', 8, 'CAL_2EGB', 'JAIR CRIOLLO')
# ('2EGB', 'Amigables', 'Lunes', 9, 'EXP_2EGB', 'JOSÉ LUIS HERNÁNDEZ')
# ('2EGB', 'Amigables', 'Lunes', 10, 'DES_2EGB', 'MISHEL SALTOS')
# ('2EGB', 'Amigables', 'Lunes', 13, 'DES_2EGB', 'MISHEL SALTOS')
# ('2EGB', 'Amigables', 'Lunes', 14, 'SAL_2EGB', 'VANESSA ESPÍN')
# ('2EGB', 'Amigables', 'Lunes', 15, 'ECO_2EGB', 'MARJURIE JÁCOME')
# ('2EGB', 'Amigables', 'Lunes', 16, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amigables', 'Martes', 1, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amigables', 'Martes', 2, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Amigables', 'Martes', 3, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amigables', 'Martes', 4, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Amigables', 'Martes', 6, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amigables', 'Martes', 7, 'SOC_2EGB', 'ALBITA QUILLUPANGUI')
# ('2EGB', 'Amigables', 'Martes', 8, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amigables', 'Martes', 9, 'PLA_2EGB', 'LIZ DÍAZ')
# ('2EGB', 'Amigables', 'Martes', 10, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Amigables', 'Martes', 13, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Amigables', 'Martes', 14, 'EDU_2EGB', 'EF ESPECIAL')
# ('2EGB', 'Amigables', 'Miércoles', 3, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amigables', 'Miércoles', 4, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amigables', 'Miércoles', 6, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amigables', 'Miércoles', 7, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amigables', 'Miércoles', 8, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amigables', 'Miércoles', 9, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Amigables', 'Miércoles', 10, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Amigables', 'Miércoles', 13, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amigables', 'Miércoles', 14, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amigables', 'Miércoles', 15, 'SOC_2EGB', 'ALBITA QUILLUPANGUI')
# ('2EGB', 'Amigables', 'Miércoles', 16, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amigables', 'Jueves', 1, 'SPE_2EGB', 'CHRISTIAN SOLANO')
# ('2EGB', 'Amigables', 'Jueves', 2, 'INV_2EGB', 'KARLA LAZCANO')
# ('2EGB', 'Amigables', 'Jueves', 3, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amigables', 'Jueves', 4, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amigables', 'Jueves', 6, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amigables', 'Jueves', 7, 'SOC_2EGB', 'ALBITA QUILLUPANGUI')
# ('2EGB', 'Amigables', 'Jueves', 8, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amigables', 'Jueves', 9, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amigables', 'Jueves', 10, 'EDU_2EGB', 'EF ESPECIAL')
# ('2EGB', 'Amigables', 'Jueves', 13, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amigables', 'Jueves', 14, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amigables', 'Viernes', 1, 'DER_2EGB', 'CORALÍA CÓRDOVA')
# ('2EGB', 'Amigables', 'Viernes', 2, 'COM_2EGB', 'ERIKA CAIZATOA')
# ('2EGB', 'Amigables', 'Viernes', 3, 'ROB_2EGB', 'DAVID CASTRO')
# ('2EGB', 'Amigables', 'Viernes', 4, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Amigables', 'Viernes', 6, 'ROB_2EGB', 'DAVID CASTRO')
# ('2EGB', 'Amigables', 'Viernes', 7, 'DAN_2EGB', 'PAOLA LÓPEZ')
# ('2EGB', 'Amigables', 'Viernes', 8, 'MUS_2EGB', 'LUIS JÁCOME')
# ('2EGB', 'Amigables', 'Viernes', 9, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Amigables', 'Viernes', 10, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amigables', 'Viernes', 13, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amigables', 'Viernes', 14, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amigables', 'Viernes', 15, 'PLA_2EGB', 'LIZ DÍAZ')
# ('2EGB', 'Amigables', 'Viernes', 16, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Amistosos', 'Lunes', 1, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amistosos', 'Lunes', 2, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amistosos', 'Lunes', 3, 'EDU_2EGB', 'EF ESPECIAL')
# ('2EGB', 'Amistosos', 'Lunes', 4, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Amistosos', 'Lunes', 6, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Amistosos', 'Lunes', 7, 'ROB_2EGB', 'DAVID CASTRO')
# ('2EGB', 'Amistosos', 'Lunes', 8, 'EDU_2EGB', 'EF ESPECIAL')
# ('2EGB', 'Amistosos', 'Lunes', 9, 'SOC_2EGB', 'ALBITA QUILLUPANGUI')
# ('2EGB', 'Amistosos', 'Lunes', 10, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amistosos', 'Lunes', 13, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Amistosos', 'Lunes', 14, 'ROB_2EGB', 'DAVID CASTRO')
# ('2EGB', 'Amistosos', 'Lunes', 15, 'DES_2EGB', 'MISHEL SALTOS')
# ('2EGB', 'Amistosos', 'Lunes', 16, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amistosos', 'Martes', 1, 'PRO_2EGB', 'LUDWIN GUALOTUÑA')
# ('2EGB', 'Amistosos', 'Martes', 2, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amistosos', 'Martes', 3, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Amistosos', 'Martes', 4, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amistosos', 'Martes', 6, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Amistosos', 'Martes', 7, 'PLA_2EGB', 'LIZ DÍAZ')
# ('2EGB', 'Amistosos', 'Martes', 8, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Amistosos', 'Martes', 9, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amistosos', 'Martes', 10, 'SOC_2EGB', 'ALBITA QUILLUPANGUI')
# ('2EGB', 'Amistosos', 'Martes', 13, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amistosos', 'Martes', 14, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amistosos', 'Miércoles', 3, 'PRO_2EGB', 'LUDWIN GUALOTUÑA')
# ('2EGB', 'Amistosos', 'Miércoles', 4, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Amistosos', 'Miércoles', 6, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Amistosos', 'Miércoles', 7, 'CAL_2EGB', 'JAIR CRIOLLO')
# ('2EGB', 'Amistosos', 'Miércoles', 8, 'EXP_2EGB', 'JOSÉ LUIS HERNÁNDEZ')
# ('2EGB', 'Amistosos', 'Miércoles', 8, 'SPE_2EGB', 'CHRISTIAN SOLANO')
# ('2EGB', 'Amistosos', 'Miércoles', 9, 'INV_2EGB', 'KARLA LAZCANO')
# ('2EGB', 'Amistosos', 'Miércoles', 10, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amistosos', 'Miércoles', 13, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amistosos', 'Miércoles', 14, 'DER_2EGB', 'CORALÍA CÓRDOVA')
# ('2EGB', 'Amistosos', 'Miércoles', 15, 'COM_2EGB', 'ERIKA CAIZATOA')
# ('2EGB', 'Amistosos', 'Miércoles', 16, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amistosos', 'Jueves', 1, 'MUS_2EGB', 'LUIS JÁCOME')
# ('2EGB', 'Amistosos', 'Jueves', 2, 'DAN_2EGB', 'PAOLA LÓPEZ')
# ('2EGB', 'Amistosos', 'Jueves', 3, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amistosos', 'Jueves', 4, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amistosos', 'Jueves', 6, 'SAL_2EGB', 'VANESSA ESPÍN')
# ('2EGB', 'Amistosos', 'Jueves', 7, 'ECO_2EGB', 'MARJURIE JÁCOME')
# ('2EGB', 'Amistosos', 'Jueves', 8, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amistosos', 'Jueves', 9, 'SOC_2EGB', 'ALBITA QUILLUPANGUI')
# ('2EGB', 'Amistosos', 'Jueves', 10, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amistosos', 'Jueves', 13, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Amistosos', 'Jueves', 14, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Amistosos', 'Viernes', 1, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amistosos', 'Viernes', 2, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amistosos', 'Viernes', 3, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Amistosos', 'Viernes', 4, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amistosos', 'Viernes', 6, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Amistosos', 'Viernes', 7, 'DES_2EGB', 'MISHEL SALTOS')
# ('2EGB', 'Amistosos', 'Viernes', 8, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amistosos', 'Viernes', 9, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amistosos', 'Viernes', 10, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amistosos', 'Viernes', 13, 'PLA_2EGB', 'LIZ DÍAZ')
# ('2EGB', 'Amistosos', 'Viernes', 14, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amistosos', 'Viernes', 15, 'MAT_2EGB', 'DINA TOPÓN')
# ('3EGB', 'Colaboradores', 'Lunes', 1, 'DER_3EGB', 'CORALÍA CÓRDOVA')
# ('3EGB', 'Colaboradores', 'Lunes', 2, 'COM_3EGB', 'ERIKA CAIZATOA')
# ('3EGB', 'Colaboradores', 'Lunes', 3, 'PRO_3EGB', 'LUDWIN GUALOTUÑA')
# ('3EGB', 'Colaboradores', 'Lunes', 4, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Colaboradores', 'Lunes', 6, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Colaboradores', 'Lunes', 7, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Colaboradores', 'Lunes', 8, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Colaboradores', 'Lunes', 9, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Colaboradores', 'Lunes', 10, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Colaboradores', 'Lunes', 13, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Colaboradores', 'Lunes', 14, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Colaboradores', 'Lunes', 15, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Colaboradores', 'Lunes', 16, 'SOC_3EGB', 'ALBITA QUILLUPANGUI')
# ('3EGB', 'Colaboradores', 'Martes', 1, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Colaboradores', 'Martes', 2, 'SOC_3EGB', 'ALBITA QUILLUPANGUI')
# ('3EGB', 'Colaboradores', 'Martes', 3, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Colaboradores', 'Martes', 4, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Colaboradores', 'Martes', 6, 'SAL_3EGB', 'VANESSA ESPÍN')
# ('3EGB', 'Colaboradores', 'Martes', 7, 'ECO_3EGB', 'MARJURIE JÁCOME')
# ('3EGB', 'Colaboradores', 'Martes', 8, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Colaboradores', 'Martes', 9, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Colaboradores', 'Martes', 10, 'DES_3EGB', 'MISHEL SALTOS')
# ('3EGB', 'Colaboradores', 'Martes', 13, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Colaboradores', 'Martes', 14, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Colaboradores', 'Miércoles', 3, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Colaboradores', 'Miércoles', 4, 'EDU_3EGB', 'EF ESPECIAL')
# ('3EGB', 'Colaboradores', 'Miércoles', 6, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Colaboradores', 'Miércoles', 7, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Colaboradores', 'Miércoles', 8, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Colaboradores', 'Miércoles', 9, 'SOC_3EGB', 'ALBITA QUILLUPANGUI')
# ('3EGB', 'Colaboradores', 'Miércoles', 10, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Colaboradores', 'Miércoles', 13, 'DAN_3EGB', 'PAOLA LÓPEZ')
# ('3EGB', 'Colaboradores', 'Miércoles', 14, 'MUS_3EGB', 'LUIS JÁCOME')
# ('3EGB', 'Colaboradores', 'Miércoles', 15, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Colaboradores', 'Miércoles', 16, 'PLA_3EGB', 'LIZ DÍAZ')
# ('3EGB', 'Colaboradores', 'Jueves', 1, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Colaboradores', 'Jueves', 2, 'EXP_3EGB', 'JOSÉ LUIS HERNÁNDEZ')
# ('3EGB', 'Colaboradores', 'Jueves', 3, 'CAL_3EGB', 'JAIR CRIOLLO')
# ('3EGB', 'Colaboradores', 'Jueves', 4, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Colaboradores', 'Jueves', 6, 'SPE_3EGB', 'CHRISTIAN SOLANO')
# ('3EGB', 'Colaboradores', 'Jueves', 7, 'INV_3EGB', 'KARLA LAZCANO')
# ('3EGB', 'Colaboradores', 'Jueves', 8, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Colaboradores', 'Jueves', 9, 'DES_3EGB', 'MISHEL SALTOS')
# ('3EGB', 'Colaboradores', 'Jueves', 10, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Colaboradores', 'Jueves', 13, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Colaboradores', 'Jueves', 14, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Colaboradores', 'Viernes', 1, 'PLA_3EGB', 'LIZ DÍAZ')
# ('3EGB', 'Colaboradores', 'Viernes', 2, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Colaboradores', 'Viernes', 3, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Colaboradores', 'Viernes', 4, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Colaboradores', 'Viernes', 6, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Colaboradores', 'Viernes', 7, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Colaboradores', 'Viernes', 8, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Colaboradores', 'Viernes', 9, 'PRO_3EGB', 'LUDWIN GUALOTUÑA')
# ('3EGB', 'Colaboradores', 'Viernes', 10, 'EDU_3EGB', 'EF ESPECIAL')
# ('3EGB', 'Colaboradores', 'Viernes', 13, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Colaboradores', 'Viernes', 14, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Colaboradores', 'Viernes', 15, 'ROB_3EGB', 'DAVID CASTRO')
# ('3EGB', 'Colaboradores', 'Viernes', 16, 'ROB_3EGB', 'DAVID CASTRO')
# ('3EGB', 'Conciliadores', 'Lunes', 1, 'INV_3EGB', 'KARLA LAZCANO')
# ('3EGB', 'Conciliadores', 'Lunes', 2, 'SPE_3EGB', 'CHRISTIAN SOLANO')
# ('3EGB', 'Conciliadores', 'Lunes', 3, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Conciliadores', 'Lunes', 4, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Conciliadores', 'Lunes', 6, 'EXP_3EGB', 'JOSÉ LUIS HERNÁNDEZ')
# ('3EGB', 'Conciliadores', 'Lunes', 7, 'CAL_3EGB', 'JAIR CRIOLLO')
# ('3EGB', 'Conciliadores', 'Lunes', 8, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Conciliadores', 'Lunes', 9, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Conciliadores', 'Lunes', 10, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Conciliadores', 'Lunes', 13, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Conciliadores', 'Lunes', 14, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Conciliadores', 'Lunes', 15, 'DES_3EGB', 'MISHEL SALTOS')
# ('3EGB', 'Conciliadores', 'Lunes', 16, 'ROB_3EGB', 'DAVID CASTRO')
# ('3EGB', 'Conciliadores', 'Martes', 1, 'COM_3EGB', 'ERIKA CAIZATOA')
# ('3EGB', 'Conciliadores', 'Martes', 2, 'DER_3EGB', 'CORALÍA CÓRDOVA')
# ('3EGB', 'Conciliadores', 'Martes', 3, 'SOC_3EGB', 'ALBITA QUILLUPANGUI')
# ('3EGB', 'Conciliadores', 'Martes', 4, 'ROB_3EGB', 'DAVID CASTRO')
# ('3EGB', 'Conciliadores', 'Martes', 6, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Conciliadores', 'Martes', 7, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Conciliadores', 'Martes', 8, 'PLA_3EGB', 'LIZ DÍAZ')
# ('3EGB', 'Conciliadores', 'Martes', 9, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Conciliadores', 'Martes', 10, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Conciliadores', 'Martes', 13, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Conciliadores', 'Martes', 14, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Conciliadores', 'Miércoles', 3, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Conciliadores', 'Miércoles', 4, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Conciliadores', 'Miércoles', 6, 'EDU_3EGB', 'EF ESPECIAL')
# ('3EGB', 'Conciliadores', 'Miércoles', 7, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Conciliadores', 'Miércoles', 8, 'SAL_3EGB', 'VANESSA ESPÍN')
# ('3EGB', 'Conciliadores', 'Miércoles', 9, 'ECO_3EGB', 'MARJURIE JÁCOME')
# ('3EGB', 'Conciliadores', 'Miércoles', 10, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Conciliadores', 'Miércoles', 13, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Conciliadores', 'Miércoles', 14, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Conciliadores', 'Miércoles', 15, 'EDU_3EGB', 'EF ESPECIAL')
# ('3EGB', 'Conciliadores', 'Miércoles', 16, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Conciliadores', 'Jueves', 1, 'PRO_3EGB', 'LUDWIN GUALOTUÑA')
# ('3EGB', 'Conciliadores', 'Jueves', 2, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Conciliadores', 'Jueves', 3, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Conciliadores', 'Jueves', 4, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Conciliadores', 'Jueves', 6, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Conciliadores', 'Jueves', 7, 'DAN_3EGB', 'PAOLA LÓPEZ')
# ('3EGB', 'Conciliadores', 'Jueves', 8, 'MUS_3EGB', 'LUIS JÁCOME')
# ('3EGB', 'Conciliadores', 'Jueves', 9, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Conciliadores', 'Jueves', 10, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Conciliadores', 'Jueves', 13, 'SOC_3EGB', 'ALBITA QUILLUPANGUI')
# ('3EGB', 'Conciliadores', 'Jueves', 14, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Conciliadores', 'Viernes', 1, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Conciliadores', 'Viernes', 2, 'PLA_3EGB', 'LIZ DÍAZ')
# ('3EGB', 'Conciliadores', 'Viernes', 3, 'DES_3EGB', 'MISHEL SALTOS')
# ('3EGB', 'Conciliadores', 'Viernes', 4, 'SOC_3EGB', 'ALBITA QUILLUPANGUI')
# ('3EGB', 'Conciliadores', 'Viernes', 6, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Conciliadores', 'Viernes', 7, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Conciliadores', 'Viernes', 8, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Conciliadores', 'Viernes', 9, 'PRO_3EGB', 'LUDWIN GUALOTUÑA')
# ('3EGB', 'Conciliadores', 'Viernes', 10, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Conciliadores', 'Viernes', 13, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Conciliadores', 'Viernes', 14, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Conciliadores', 'Viernes', 15, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Conciliadores', 'Viernes', 16, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Cordiales', 'Lunes', 1, 'DES_3EGB', 'MISHEL SALTOS')
# ('3EGB', 'Cordiales', 'Lunes', 2, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Cordiales', 'Lunes', 3, 'SOC_3EGB', 'ALBITA QUILLUPANGUI')
# ('3EGB', 'Cordiales', 'Lunes', 4, 'SOC_3EGB', 'ALBITA QUILLUPANGUI')
# ('3EGB', 'Cordiales', 'Lunes', 6, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Cordiales', 'Lunes', 7, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Cordiales', 'Lunes', 8, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Cordiales', 'Lunes', 9, 'SOC_3EGB', 'ALBITA QUILLUPANGUI')
# ('3EGB', 'Cordiales', 'Lunes', 10, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Cordiales', 'Lunes', 13, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Cordiales', 'Lunes', 14, 'ECO_3EGB', 'MARJURIE JÁCOME')
# ('3EGB', 'Cordiales', 'Lunes', 15, 'SAL_3EGB', 'VANESSA ESPÍN')
# ('3EGB', 'Cordiales', 'Lunes', 16, 'DES_3EGB', 'MISHEL SALTOS')
# ('3EGB', 'Cordiales', 'Martes', 1, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Cordiales', 'Martes', 2, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Cordiales', 'Martes', 3, 'ROB_3EGB', 'DAVID CASTRO')
# ('3EGB', 'Cordiales', 'Martes', 4, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Cordiales', 'Martes', 6, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Cordiales', 'Martes', 7, 'PRO_3EGB', 'LUDWIN GUALOTUÑA')
# ('3EGB', 'Cordiales', 'Martes', 8, 'EDU_3EGB', 'EF ESPECIAL')
# ('3EGB', 'Cordiales', 'Martes', 9, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Cordiales', 'Martes', 10, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Cordiales', 'Martes', 13, 'PRO_3EGB', 'LUDWIN GUALOTUÑA')
# ('3EGB', 'Cordiales', 'Martes', 14, 'PLA_3EGB', 'LIZ DÍAZ')
# ('3EGB', 'Cordiales', 'Miércoles', 3, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Cordiales', 'Miércoles', 4, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Cordiales', 'Miércoles', 6, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Cordiales', 'Miércoles', 7, 'CAL_3EGB', 'JAIR CRIOLLO')
# ('3EGB', 'Cordiales', 'Miércoles', 8, 'EXP_3EGB', 'JOSÉ LUIS HERNÁNDEZ')
# ('3EGB', 'Cordiales', 'Miércoles', 9, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Cordiales', 'Miércoles', 10, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Cordiales', 'Miércoles', 13, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Cordiales', 'Miércoles', 14, 'ROB_3EGB', 'DAVID CASTRO')
# ('3EGB', 'Cordiales', 'Miércoles', 15, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Cordiales', 'Miércoles', 16, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Cordiales', 'Jueves', 1, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Cordiales', 'Jueves', 2, 'PLA_3EGB', 'LIZ DÍAZ')
# ('3EGB', 'Cordiales', 'Jueves', 3, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Cordiales', 'Jueves', 4, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Cordiales', 'Jueves', 6, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Cordiales', 'Jueves', 7, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Cordiales', 'Jueves', 8, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Cordiales', 'Jueves', 9, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Cordiales', 'Jueves', 10, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Cordiales', 'Jueves', 13, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Cordiales', 'Jueves', 14, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Cordiales', 'Viernes', 1, 'EDU_3EGB', 'EF ESPECIAL')
# ('3EGB', 'Cordiales', 'Viernes', 2, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Cordiales', 'Viernes', 3, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Cordiales', 'Viernes', 4, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Cordiales', 'Viernes', 6, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Cordiales', 'Viernes', 7, 'DER_3EGB', 'CORALÍA CÓRDOVA')
# ('3EGB', 'Cordiales', 'Viernes', 8, 'COM_3EGB', 'ERIKA CAIZATOA')
# ('3EGB', 'Cordiales', 'Viernes', 9, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Cordiales', 'Viernes', 10, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Cordiales', 'Viernes', 13, 'SPE_3EGB', 'CHRISTIAN SOLANO')
# ('3EGB', 'Cordiales', 'Viernes', 14, 'DAN_3EGB', 'PAOLA LÓPEZ')
# ('3EGB', 'Cordiales', 'Viernes', 14, 'INV_3EGB', 'KARLA LAZCANO')
# ('3EGB', 'Cordiales', 'Viernes', 15, 'MUS_3EGB', 'LUIS JÁCOME')
# ('3EGB', 'Creativos', 'Lunes', 1, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Creativos', 'Lunes', 2, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Creativos', 'Lunes', 3, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Creativos', 'Lunes', 4, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Creativos', 'Lunes', 6, 'PRO_3EGB', 'LUDWIN GUALOTUÑA')
# ('3EGB', 'Creativos', 'Lunes', 7, 'PLA_3EGB', 'LIZ DÍAZ')
# ('3EGB', 'Creativos', 'Lunes', 8, 'SPE_3EGB', 'CHRISTIAN SOLANO')
# ('3EGB', 'Creativos', 'Lunes', 9, 'INV_3EGB', 'KARLA LAZCANO')
# ('3EGB', 'Creativos', 'Lunes', 10, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Creativos', 'Lunes', 13, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Creativos', 'Lunes', 14, 'SAL_3EGB', 'VANESSA ESPÍN')
# ('3EGB', 'Creativos', 'Lunes', 15, 'ECO_3EGB', 'MARJURIE JÁCOME')
# ('3EGB', 'Creativos', 'Lunes', 16, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Creativos', 'Martes', 1, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Creativos', 'Martes', 2, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Creativos', 'Martes', 3, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Creativos', 'Martes', 4, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Creativos', 'Martes', 6, 'COM_3EGB', 'ERIKA CAIZATOA')
# ('3EGB', 'Creativos', 'Martes', 7, 'DER_3EGB', 'CORALÍA CÓRDOVA')
# ('3EGB', 'Creativos', 'Martes', 8, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Creativos', 'Martes', 9, 'SOC_3EGB', 'ALBITA QUILLUPANGUI')
# ('3EGB', 'Creativos', 'Martes', 10, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Creativos', 'Martes', 13, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Creativos', 'Martes', 14, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Creativos', 'Miércoles', 3, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Creativos', 'Miércoles', 4, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Creativos', 'Miércoles', 6, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Creativos', 'Miércoles', 7, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Creativos', 'Miércoles', 8, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Creativos', 'Miércoles', 9, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Creativos', 'Miércoles', 10, 'EDU_3EGB', 'EF ESPECIAL')
# ('3EGB', 'Creativos', 'Miércoles', 13, 'ROB_3EGB', 'DAVID CASTRO')
# ('3EGB', 'Creativos', 'Miércoles', 14, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Creativos', 'Miércoles', 15, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Creativos', 'Miércoles', 16, 'PLA_3EGB', 'LIZ DÍAZ')
# ('3EGB', 'Creativos', 'Jueves', 1, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Creativos', 'Jueves', 2, 'CAL_3EGB', 'JAIR CRIOLLO')
# ('3EGB', 'Creativos', 'Jueves', 3, 'EXP_3EGB', 'JOSÉ LUIS HERNÁNDEZ')
# ('3EGB', 'Creativos', 'Jueves', 4, 'ROB_3EGB', 'DAVID CASTRO')
# ('3EGB', 'Creativos', 'Jueves', 6, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Creativos', 'Jueves', 7, 'DAN_3EGB', 'PAOLA LÓPEZ')
# ('3EGB', 'Creativos', 'Jueves', 8, 'MUS_3EGB', 'LUIS JÁCOME')
# ('3EGB', 'Creativos', 'Jueves', 9, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Creativos', 'Jueves', 10, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Creativos', 'Jueves', 13, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Creativos', 'Jueves', 14, 'SOC_3EGB', 'ALBITA QUILLUPANGUI')
# ('3EGB', 'Creativos', 'Viernes', 1, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Creativos', 'Viernes', 2, 'EDU_3EGB', 'EF ESPECIAL')
# ('3EGB', 'Creativos', 'Viernes', 3, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Creativos', 'Viernes', 4, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Creativos', 'Viernes', 6, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Creativos', 'Viernes', 7, 'PRO_3EGB', 'LUDWIN GUALOTUÑA')
# ('3EGB', 'Creativos', 'Viernes', 8, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Creativos', 'Viernes', 9, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Creativos', 'Viernes', 10, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Creativos', 'Viernes', 13, 'SOC_3EGB', 'ALBITA QUILLUPANGUI')
# ('3EGB', 'Creativos', 'Viernes', 14, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Creativos', 'Viernes', 15, 'DES_3EGB', 'MISHEL SALTOS')
# ('3EGB', 'Creativos', 'Viernes', 16, 'DES_3EGB', 'MISHEL SALTOS')
# ('4EGB', 'Optimistas', 'Lunes', 1, 'DES_4EGB', 'MISHEL SALTOS')
# ('4EGB', 'Optimistas', 'Lunes', 2, 'ING_4EGB', 'SOLEDAD REVELO')
# ('4EGB', 'Optimistas', 'Lunes', 3, 'PEN_4EGB', 'XIMENA AGUIRRE')
# ('4EGB', 'Optimistas', 'Lunes', 4, 'ROB_4EGB', 'DAVID CASTRO')
# ('4EGB', 'Optimistas', 'Lunes', 5, 'ING_4EGB', 'SOLEDAD REVELO')
# ('4EGB', 'Optimistas', 'Lunes', 7, 'MAT_4EGB', 'PATY ARIAS')
# ('4EGB', 'Optimistas', 'Lunes', 8, 'LEN_4EGB', 'ROSITA ALBUJA')
# ('4EGB', 'Optimistas', 'Lunes', 9, 'SOC_4EGB', 'ALBITA QUILLUPANGUI')
# ('4EGB', 'Optimistas', 'Lunes', 10, 'NAT_4EGB', 'DIANA SÁNCHEZ')
# ('4EGB', 'Optimistas', 'Lunes', 13, 'MAT_4EGB', 'PATY ARIAS')
# ('4EGB', 'Optimistas', 'Lunes', 14, 'PEN_4EGB', 'XIMENA AGUIRRE')
# ('4EGB', 'Optimistas', 'Lunes', 15, 'MAT_4EGB', 'PATY ARIAS')
# ('4EGB', 'Optimistas', 'Lunes', 16, 'ING_4EGB', 'SOLEDAD REVELO')
# ('4EGB', 'Optimistas', 'Martes', 1, 'MAT_4EGB', 'PATY ARIAS')
# ('4EGB', 'Optimistas', 'Martes', 2, 'SOC_4EGB', 'ALBITA QUILLUPANGUI')
# ...
# ('2BGU', 'Justos', 'Viernes', 12, 'FIS_2BGU', 'JOSÉ NICOLALDE')
# ('2BGU', 'Proactivos', 'Lunes', 1, 'SOC_2BGU', 'ISABEL GARCÍA')
# ('2BGU', 'Proactivos', 'Lunes', 2, 'MAT_2BGU', 'ISAAC NÚÑEZ')
# ('2BGU', 'Proactivos', 'Lunes', 3, 'PRO_2BGU', 'MARCO SAFADI')
# ('2BGU', 'Proactivos', 'Lunes', 4, 'PEN_2BGU', 'ANITA BARRENO')
# ('2BGU', 'Proactivos', 'Lunes', 5, 'PEN_2BGU', 'ANITA BARRENO')
# ('2BGU', 'Proactivos', 'Lunes', 7, 'ING_2BGU', 'INGLES ESPECIAL')
# ('2BGU', 'Proactivos', 'Lunes', 8, 'ING_2BGU', 'INGLES ESPECIAL')
# ('2BGU', 'Proactivos', 'Lunes', 9, 'LEC_2BGU', 'PATY FLORES')
# ('2BGU', 'Proactivos', 'Lunes', 10, 'INV_2BGU', 'KARLA LAZCANO')
# ('2BGU', 'Proactivos', 'Lunes', 11, 'SPE_2BGU', 'CHRISTIAN SOLANO')
# ('2BGU', 'Proactivos', 'Lunes', 12, 'SOC_2BGU', 'ISABEL GARCÍA')
# ('2BGU', 'Proactivos', 'Lunes', 15, 'FIS_2BGU', 'JOSÉ NICOLALDE')
# ('2BGU', 'Proactivos', 'Lunes', 16, 'FIS_2BGU', 'JOSÉ NICOLALDE')
# ('2BGU', 'Proactivos', 'Martes', 1, 'ING_2BGU', 'INGLES ESPECIAL')
# ('2BGU', 'Proactivos', 'Martes', 2, 'ING_2BGU', 'INGLES ESPECIAL')
# ('2BGU', 'Proactivos', 'Martes', 3, 'DER_2BGU', 'CORALÍA CÓRDOVA')
# ('2BGU', 'Proactivos', 'Martes', 4, 'COM_2BGU', 'ERIKA CAIZATOA')
# ('2BGU', 'Proactivos', 'Martes', 5, 'QUI_2BGU', 'MAYRA QUISHPE')
# ('2BGU', 'Proactivos', 'Martes', 7, 'DES_2BGU', 'JANETH MELO')
# ('2BGU', 'Proactivos', 'Martes', 8, 'MAT_2BGU', 'ISAAC NÚÑEZ')
# ('2BGU', 'Proactivos', 'Martes', 9, 'PLA_2BGU', 'KEVIN VICENTE')
# ('2BGU', 'Proactivos', 'Martes', 10, 'ROB_2BGU', 'DAVID RÓGEL')
# ('2BGU', 'Proactivos', 'Martes', 11, 'EST_2BGU', 'JONATHAN CASTRO')
# ('2BGU', 'Proactivos', 'Martes', 12, 'GEO_2BGU', 'LEONARDO ESPINOSA')
# ('2BGU', 'Proactivos', 'Martes', 15, 'NAT_2BGU', 'CARLOS BENALCÁZAR')
# ('2BGU', 'Proactivos', 'Martes', 16, 'LEN_2BGU', 'ANDRÉS OLMEDO')
# ('2BGU', 'Proactivos', 'Miércoles', 3, 'EMP_2BGU', 'MARÍA BELÉN MALDONADO')
# ('2BGU', 'Proactivos', 'Miércoles', 4, 'CIU_2BGU', None)
# ('2BGU', 'Proactivos', 'Miércoles', 5, 'SOC_2BGU', 'ISABEL GARCÍA')
# ('2BGU', 'Proactivos', 'Miércoles', 7, 'ROB_2BGU', 'DAVID RÓGEL')
# ('2BGU', 'Proactivos', 'Miércoles', 8, 'MAT_2BGU', 'ISAAC NÚÑEZ')
# ('2BGU', 'Proactivos', 'Miércoles', 9, 'EST_2BGU', 'JONATHAN CASTRO')
# ('2BGU', 'Proactivos', 'Miércoles', 10, 'EMP_2BGU', 'MARÍA BELÉN MALDONADO')
# ('2BGU', 'Proactivos', 'Miércoles', 11, 'GEO_2BGU', 'LEONARDO ESPINOSA')
# ('2BGU', 'Proactivos', 'Miércoles', 12, 'EDU_2BGU', 'EF ESPECIAL')
# ('2BGU', 'Proactivos', 'Jueves', 1, 'PEN_2BGU', 'ANITA BARRENO')
# ('2BGU', 'Proactivos', 'Jueves', 2, 'MAT_2BGU', 'ISAAC NÚÑEZ')
# ('2BGU', 'Proactivos', 'Jueves', 3, 'LEC_2BGU', 'PATY FLORES')
# ('2BGU', 'Proactivos', 'Jueves', 4, 'QUI_2BGU', 'MAYRA QUISHPE')
# ('2BGU', 'Proactivos', 'Jueves', 5, 'GEO_2BGU', 'LEONARDO ESPINOSA')
# ('2BGU', 'Proactivos', 'Jueves', 7, 'EDU_2BGU', 'EF ESPECIAL')
# ('2BGU', 'Proactivos', 'Jueves', 8, 'FIS_2BGU', 'JOSÉ NICOLALDE')
# ('2BGU', 'Proactivos', 'Jueves', 9, 'ECO_2BGU', 'MARJURIE JÁCOME')
# ('2BGU', 'Proactivos', 'Jueves', 10, 'SAL_2BGU', 'VANESSA ESPÍN')
# ('2BGU', 'Proactivos', 'Jueves', 11, 'MAT_2BGU', 'ISAAC NÚÑEZ')
# ('2BGU', 'Proactivos', 'Jueves', 12, 'DES_2BGU', 'JANETH MELO')
# ('2BGU', 'Proactivos', 'Jueves', 15, 'MAT_2BGU', 'ISAAC NÚÑEZ')
# ('2BGU', 'Proactivos', 'Jueves', 16, 'PRO_2BGU', 'MARCO SAFADI')
# ('2BGU', 'Proactivos', 'Viernes', 1, 'QUI_2BGU', 'MAYRA QUISHPE')
# ('2BGU', 'Proactivos', 'Viernes', 2, 'ING_2BGU', 'INGLES ESPECIAL')
# ('2BGU', 'Proactivos', 'Viernes', 3, 'ING_2BGU', 'INGLES ESPECIAL')
# ('2BGU', 'Proactivos', 'Viernes', 4, 'QUI_2BGU', 'MAYRA QUISHPE')
# ('2BGU', 'Proactivos', 'Viernes', 5, 'PLA_2BGU', 'KEVIN VICENTE')
# ('2BGU', 'Proactivos', 'Viernes', 7, 'SOC_2BGU', 'ISABEL GARCÍA')
# ('2BGU', 'Proactivos', 'Viernes', 8, 'LEN_2BGU', 'ANDRÉS OLMEDO')
# ('2BGU', 'Proactivos', 'Viernes', 9, 'NAT_2BGU', 'CARLOS BENALCÁZAR')
# ('2BGU', 'Proactivos', 'Viernes', 10, 'NAT_2BGU', 'CARLOS BENALCÁZAR')
# ('2BGU', 'Proactivos', 'Viernes', 11, 'LEC_2BGU', 'PATY FLORES')
# ('2BGU', 'Proactivos', 'Viernes', 12, 'FIS_2BGU', 'JOSÉ NICOLALDE')
# ('3BGU', 'Empáticos', 'Lunes', 1, 'SOC_3BGU', 'ISABEL GARCÍA')
# ('3BGU', 'Empáticos', 'Lunes', 2, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Empáticos', 'Lunes', 3, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Empáticos', 'Lunes', 4, 'NAT_3BGU', 'CARLOS BENALCÁZAR')
# ('3BGU', 'Empáticos', 'Lunes', 5, 'FIS_3BGU', 'JOSÉ NICOLALDE')
# ('3BGU', 'Empáticos', 'Lunes', 7, 'QUI_3BGU', 'MAYRA QUISHPE')
# ('3BGU', 'Empáticos', 'Lunes', 8, 'SOC_3BGU', 'ISABEL GARCÍA')
# ('3BGU', 'Empáticos', 'Lunes', 9, 'QUI_3BGU', 'MAYRA QUISHPE')
# ('3BGU', 'Empáticos', 'Lunes', 10, 'DER_3BGU', 'CORALÍA CÓRDOVA')
# ('3BGU', 'Empáticos', 'Lunes', 11, 'COM_3BGU', 'ERIKA CAIZATOA')
# ('3BGU', 'Empáticos', 'Lunes', 12, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Empáticos', 'Lunes', 15, 'ROB_3BGU', 'DAVID RÓGEL')
# ('3BGU', 'Empáticos', 'Lunes', 16, 'LEN_3BGU', 'ANDRÉS OLMEDO')
# ('3BGU', 'Empáticos', 'Martes', 1, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Empáticos', 'Martes', 2, 'PEN_3BGU', 'ANITA BARRENO')
# ('3BGU', 'Empáticos', 'Martes', 3, 'GEO_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Empáticos', 'Martes', 4, 'EST_3BGU', 'JONATHAN CASTRO')
# ('3BGU', 'Empáticos', 'Martes', 5, 'EST_3BGU', 'JONATHAN CASTRO')
# ('3BGU', 'Empáticos', 'Martes', 7, 'LEC_3BGU', 'PATY FLORES')
# ('3BGU', 'Empáticos', 'Martes', 8, 'FIS_3BGU', 'JOSÉ NICOLALDE')
# ('3BGU', 'Empáticos', 'Martes', 9, 'ECO_3BGU', 'MARJURIE JÁCOME')
# ('3BGU', 'Empáticos', 'Martes', 10, 'SAL_3BGU', 'VANESSA ESPÍN')
# ('3BGU', 'Empáticos', 'Martes', 11, 'LEN_3BGU', 'ANDRÉS OLMEDO')
# ('3BGU', 'Empáticos', 'Martes', 12, 'PLA_3BGU', 'KEVIN VICENTE')
# ('3BGU', 'Empáticos', 'Martes', 15, 'FIS_3BGU', 'JOSÉ NICOLALDE')
# ('3BGU', 'Empáticos', 'Martes', 16, 'PEN_3BGU', 'ANITA BARRENO')
# ('3BGU', 'Empáticos', 'Miércoles', 3, 'ROB_3BGU', 'DAVID RÓGEL')
# ('3BGU', 'Empáticos', 'Miércoles', 4, 'SOC_3BGU', 'ISABEL GARCÍA')
# ('3BGU', 'Empáticos', 'Miércoles', 5, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Empáticos', 'Miércoles', 7, 'LEC_3BGU', 'PATY FLORES')
# ('3BGU', 'Empáticos', 'Miércoles', 8, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Empáticos', 'Miércoles', 9, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Empáticos', 'Miércoles', 10, 'NAT_3BGU', 'CARLOS BENALCÁZAR')
# ('3BGU', 'Empáticos', 'Miércoles', 11, 'PRO_3BGU', 'MARCO SAFADI')
# ('3BGU', 'Empáticos', 'Miércoles', 12, 'PLA_3BGU', 'KEVIN VICENTE')
# ('3BGU', 'Empáticos', 'Jueves', 1, 'PEN_3BGU', 'ANITA BARRENO')
# ('3BGU', 'Empáticos', 'Jueves', 2, 'DES_3BGU', 'JANETH MELO')
# ('3BGU', 'Empáticos', 'Jueves', 3, 'DES_3BGU', 'JANETH MELO')
# ('3BGU', 'Empáticos', 'Jueves', 4, 'LEN_3BGU', 'ANDRÉS OLMEDO')
# ('3BGU', 'Empáticos', 'Jueves', 5, 'EMP_3BGU', 'MARÍA BELÉN MALDONADO')
# ('3BGU', 'Empáticos', 'Jueves', 7, 'EDU_3BGU', 'EF ESPECIAL')
# ('3BGU', 'Empáticos', 'Jueves', 8, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Empáticos', 'Jueves', 9, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Empáticos', 'Jueves', 10, 'EMP_3BGU', 'MARÍA BELÉN MALDONADO')
# ('3BGU', 'Empáticos', 'Jueves', 11, 'QUI_3BGU', 'MAYRA QUISHPE')
# ('3BGU', 'Empáticos', 'Jueves', 12, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Empáticos', 'Jueves', 15, 'EDU_3BGU', 'EF ESPECIAL')
# ('3BGU', 'Empáticos', 'Jueves', 16, 'LEC_3BGU', 'PATY FLORES')
# ('3BGU', 'Empáticos', 'Viernes', 1, 'GEO_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Empáticos', 'Viernes', 2, 'INV_3BGU', 'KARLA LAZCANO')
# ('3BGU', 'Empáticos', 'Viernes', 3, 'SPE_3BGU', 'CHRISTIAN SOLANO')
# ('3BGU', 'Empáticos', 'Viernes', 4, 'QUI_3BGU', 'MAYRA QUISHPE')
# ('3BGU', 'Empáticos', 'Viernes', 5, 'GEO_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Empáticos', 'Viernes', 7, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Empáticos', 'Viernes', 8, 'FIS_3BGU', 'JOSÉ NICOLALDE')
# ('3BGU', 'Empáticos', 'Viernes', 9, 'SOC_3BGU', 'ISABEL GARCÍA')
# ('3BGU', 'Empáticos', 'Viernes', 10, 'PRO_3BGU', 'MARCO SAFADI')
# ('3BGU', 'Empáticos', 'Viernes', 11, 'NAT_3BGU', 'CARLOS BENALCÁZAR')
# ('3BGU', 'Empáticos', 'Viernes', 12, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Solidarios', 'Lunes', 1, 'GEO_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Solidarios', 'Lunes', 2, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Solidarios', 'Lunes', 3, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Solidarios', 'Lunes', 4, 'LEC_3BGU', 'PATY FLORES')
# ('3BGU', 'Solidarios', 'Lunes', 5, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Solidarios', 'Lunes', 7, 'ECO_3BGU', 'MARJURIE JÁCOME')
# ('3BGU', 'Solidarios', 'Lunes', 8, 'SAL_3BGU', 'VANESSA ESPÍN')
# ('3BGU', 'Solidarios', 'Lunes', 9, 'SOC_3BGU', 'ISABEL GARCÍA')
# ('3BGU', 'Solidarios', 'Lunes', 10, 'INV_3BGU', 'KARLA LAZCANO')
# ('3BGU', 'Solidarios', 'Lunes', 11, 'SPE_3BGU', 'CHRISTIAN SOLANO')
# ('3BGU', 'Solidarios', 'Lunes', 12, 'SOC_3BGU', 'ISABEL GARCÍA')
# ('3BGU', 'Solidarios', 'Lunes', 15, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Solidarios', 'Lunes', 16, 'LEC_3BGU', 'PATY FLORES')
# ('3BGU', 'Solidarios', 'Martes', 1, 'FIS_3BGU', 'JOSÉ NICOLALDE')
# ('3BGU', 'Solidarios', 'Martes', 2, 'LEN_3BGU', 'ANDRÉS OLMEDO')
# ('3BGU', 'Solidarios', 'Martes', 3, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Solidarios', 'Martes', 4, 'EST_3BGU', 'JONATHAN CASTRO')
# ('3BGU', 'Solidarios', 'Martes', 5, 'EST_3BGU', 'JONATHAN CASTRO')
# ('3BGU', 'Solidarios', 'Martes', 7, 'EMP_3BGU', 'MARÍA BELÉN MALDONADO')
# ('3BGU', 'Solidarios', 'Martes', 8, 'NAT_3BGU', 'CARLOS BENALCÁZAR')
# ('3BGU', 'Solidarios', 'Martes', 9, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Solidarios', 'Martes', 10, 'PEN_3BGU', 'ANITA BARRENO')
# ('3BGU', 'Solidarios', 'Martes', 11, 'NAT_3BGU', 'CARLOS BENALCÁZAR')
# ('3BGU', 'Solidarios', 'Martes', 12, 'EDU_3BGU', 'EF ESPECIAL')
# ('3BGU', 'Solidarios', 'Martes', 15, 'QUI_3BGU', 'MAYRA QUISHPE')
# ('3BGU', 'Solidarios', 'Martes', 16, 'QUI_3BGU', 'MAYRA QUISHPE')
# ('3BGU', 'Solidarios', 'Miércoles', 3, 'PEN_3BGU', 'ANITA BARRENO')
# ('3BGU', 'Solidarios', 'Miércoles', 4, 'GEO_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Solidarios', 'Miércoles', 5, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Solidarios', 'Miércoles', 7, 'SOC_3BGU', 'ISABEL GARCÍA')
# ('3BGU', 'Solidarios', 'Miércoles', 8, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Solidarios', 'Miércoles', 9, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Solidarios', 'Miércoles', 10, 'PRO_3BGU', 'MARCO SAFADI')
# ('3BGU', 'Solidarios', 'Miércoles', 11, 'QUI_3BGU', 'MAYRA QUISHPE')
# ('3BGU', 'Solidarios', 'Miércoles', 12, 'EMP_3BGU', 'MARÍA BELÉN MALDONADO')
# ('3BGU', 'Solidarios', 'Jueves', 1, 'PLA_3BGU', 'KEVIN VICENTE')
# ('3BGU', 'Solidarios', 'Jueves', 2, 'DES_3BGU', 'JANETH MELO')
# ('3BGU', 'Solidarios', 'Jueves', 3, 'DES_3BGU', 'JANETH MELO')
# ('3BGU', 'Solidarios', 'Jueves', 4, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Solidarios', 'Jueves', 5, 'PEN_3BGU', 'ANITA BARRENO')
# ('3BGU', 'Solidarios', 'Jueves', 7, 'PLA_3BGU', 'KEVIN VICENTE')
# ('3BGU', 'Solidarios', 'Jueves', 8, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Solidarios', 'Jueves', 9, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Solidarios', 'Jueves', 10, 'QUI_3BGU', 'MAYRA QUISHPE')
# ('3BGU', 'Solidarios', 'Jueves', 11, 'ROB_3BGU', 'DAVID RÓGEL')
# ('3BGU', 'Solidarios', 'Jueves', 12, 'NAT_3BGU', 'CARLOS BENALCÁZAR')
# ('3BGU', 'Solidarios', 'Jueves', 15, 'FIS_3BGU', 'JOSÉ NICOLALDE')
# ('3BGU', 'Solidarios', 'Jueves', 16, 'SOC_3BGU', 'ISABEL GARCÍA')
# ('3BGU', 'Solidarios', 'Viernes', 1, 'COM_3BGU', 'ERIKA CAIZATOA')
# ('3BGU', 'Solidarios', 'Viernes', 2, 'DER_3BGU', 'CORALÍA CÓRDOVA')
# ('3BGU', 'Solidarios', 'Viernes', 3, 'PRO_3BGU', 'MARCO SAFADI')
# ('3BGU', 'Solidarios', 'Viernes', 4, 'LEN_3BGU', 'ANDRÉS OLMEDO')
# ('3BGU', 'Solidarios', 'Viernes', 5, 'FIS_3BGU', 'JOSÉ NICOLALDE')
# ('3BGU', 'Solidarios', 'Viernes', 7, 'GEO_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Solidarios', 'Viernes', 8, 'FIS_3BGU', 'JOSÉ NICOLALDE')
# ('3BGU', 'Solidarios', 'Viernes', 9, 'ROB_3BGU', 'DAVID RÓGEL')
# ('3BGU', 'Solidarios', 'Viernes', 10, 'LEC_3BGU', 'PATY FLORES')
# ('3BGU', 'Solidarios', 'Viernes', 11, 'LEN_3BGU', 'ANDRÉS OLMEDO')
# ('3BGU', 'Solidarios', 'Viernes', 12, 'EDU_3BGU', 'EF ESPECIAL')
# ('3BGU', 'Vanguardistas', 'Lunes', 1, 'NAT_3BGU', 'CARLOS BENALCÁZAR')
# ('3BGU', 'Vanguardistas', 'Lunes', 2, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Vanguardistas', 'Lunes', 3, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Vanguardistas', 'Lunes', 4, 'QUI_3BGU', 'MAYRA QUISHPE')
# ('3BGU', 'Vanguardistas', 'Lunes', 5, 'GEO_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Vanguardistas', 'Lunes', 7, 'LEN_3BGU', 'ANDRÉS OLMEDO')
# ('3BGU', 'Vanguardistas', 'Lunes', 8, 'EMP_3BGU', 'MARÍA BELÉN MALDONADO')
# ('3BGU', 'Vanguardistas', 'Lunes', 9, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Vanguardistas', 'Lunes', 10, 'SAL_3BGU', 'VANESSA ESPÍN')
# ('3BGU', 'Vanguardistas', 'Lunes', 11, 'ECO_3BGU', 'MARJURIE JÁCOME')
# ('3BGU', 'Vanguardistas', 'Lunes', 12, 'EMP_3BGU', 'MARÍA BELÉN MALDONADO')
# ('3BGU', 'Vanguardistas', 'Lunes', 15, 'FIS_3BGU', 'JOSÉ NICOLALDE')
# ('3BGU', 'Vanguardistas', 'Lunes', 16, 'NAT_3BGU', 'CARLOS BENALCÁZAR')
# ('3BGU', 'Vanguardistas', 'Martes', 1, 'LEN_3BGU', 'ANDRÉS OLMEDO')
# ('3BGU', 'Vanguardistas', 'Martes', 2, 'QUI_3BGU', 'MAYRA QUISHPE')
# ('3BGU', 'Vanguardistas', 'Martes', 3, 'LEC_3BGU', 'PATY FLORES')
# ('3BGU', 'Vanguardistas', 'Martes', 4, 'EST_3BGU', 'JONATHAN CASTRO')
# ('3BGU', 'Vanguardistas', 'Martes', 5, 'EST_3BGU', 'JONATHAN CASTRO')
# ('3BGU', 'Vanguardistas', 'Martes', 7, 'SOC_3BGU', 'ISABEL GARCÍA')
# ('3BGU', 'Vanguardistas', 'Martes', 8, 'GEO_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Vanguardistas', 'Martes', 9, 'ROB_3BGU', 'DAVID RÓGEL')
# ('3BGU', 'Vanguardistas', 'Martes', 10, 'FIS_3BGU', 'JOSÉ NICOLALDE')
# ('3BGU', 'Vanguardistas', 'Martes', 11, 'PEN_3BGU', 'ANITA BARRENO')
# ('3BGU', 'Vanguardistas', 'Martes', 12, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Vanguardistas', 'Martes', 15, 'PRO_3BGU', 'MARCO SAFADI')
# ('3BGU', 'Vanguardistas', 'Martes', 16, 'LEC_3BGU', 'PATY FLORES')
# ('3BGU', 'Vanguardistas', 'Miércoles', 3, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Vanguardistas', 'Miércoles', 4, 'PLA_3BGU', 'KEVIN VICENTE')
# ('3BGU', 'Vanguardistas', 'Miércoles', 5, 'LEC_3BGU', 'PATY FLORES')
# ('3BGU', 'Vanguardistas', 'Miércoles', 7, 'PLA_3BGU', 'KEVIN VICENTE')
# ('3BGU', 'Vanguardistas', 'Miércoles', 8, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Vanguardistas', 'Miércoles', 9, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Vanguardistas', 'Miércoles', 10, 'ROB_3BGU', 'DAVID RÓGEL')
# ('3BGU', 'Vanguardistas', 'Miércoles', 11, 'LEN_3BGU', 'ANDRÉS OLMEDO')
# ('3BGU', 'Vanguardistas', 'Miércoles', 12, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Vanguardistas', 'Jueves', 1, 'EDU_3BGU', 'EF ESPECIAL')
# ('3BGU', 'Vanguardistas', 'Jueves', 2, 'DES_3BGU', 'JANETH MELO')
# ('3BGU', 'Vanguardistas', 'Jueves', 3, 'DES_3BGU', 'JANETH MELO')
# ('3BGU', 'Vanguardistas', 'Jueves', 4, 'FIS_3BGU', 'JOSÉ NICOLALDE')
# ('3BGU', 'Vanguardistas', 'Jueves', 5, 'EDU_3BGU', 'EF ESPECIAL')
# ('3BGU', 'Vanguardistas', 'Jueves', 7, 'PRO_3BGU', 'MARCO SAFADI')
# ('3BGU', 'Vanguardistas', 'Jueves', 8, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Vanguardistas', 'Jueves', 9, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Vanguardistas', 'Jueves', 10, 'FIS_3BGU', 'JOSÉ NICOLALDE')
# ('3BGU', 'Vanguardistas', 'Jueves', 11, 'PEN_3BGU', 'ANITA BARRENO')
# ('3BGU', 'Vanguardistas', 'Jueves', 12, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Vanguardistas', 'Jueves', 15, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Vanguardistas', 'Jueves', 16, 'NAT_3BGU', 'CARLOS BENALCÁZAR')
# ('3BGU', 'Vanguardistas', 'Viernes', 1, 'SOC_3BGU', 'ISABEL GARCÍA')
# ('3BGU', 'Vanguardistas', 'Viernes', 2, 'SPE_3BGU', 'CHRISTIAN SOLANO')
# ('3BGU', 'Vanguardistas', 'Viernes', 3, 'INV_3BGU', 'KARLA LAZCANO')
# ('3BGU', 'Vanguardistas', 'Viernes', 4, 'SOC_3BGU', 'ISABEL GARCÍA')
# ('3BGU', 'Vanguardistas', 'Viernes', 5, 'PEN_3BGU', 'ANITA BARRENO')
# ('3BGU', 'Vanguardistas', 'Viernes', 7, 'DER_3BGU', 'CORALÍA CÓRDOVA')
# ('3BGU', 'Vanguardistas', 'Viernes', 8, 'COM_3BGU', 'ERIKA CAIZATOA')
# ('3BGU', 'Vanguardistas', 'Viernes', 9, 'GEO_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Vanguardistas', 'Viernes', 10, 'SOC_3BGU', 'ISABEL GARCÍA')
# ('3BGU', 'Vanguardistas', 'Viernes', 11, 'QUI_3BGU', 'MAYRA QUISHPE')
# ('3BGU', 'Vanguardistas', 'Viernes', 12, 'QUI_3BGU', 'MAYRA QUISHPE')

# %% [markdown]
# ## 📊 Conteo de asignaciones por aula dentro de un cromosoma
#
# Esta función permite auditar cuántas asignaciones horarias tiene cada aula en un cromosoma generado. Se utiliza para verificar el equilibrio en la distribución de bloques por paralelo y nivel.
#
# ### ¿Qué hace exactamente?
# - Recorre todos los genes del cromosoma.
# - Agrupa por `(Nivel, Aula)`.
# - Devuelve un `Counter` con el número total de asignaciones por aula.
#
# ### Aplicaciones:
# - Validar si las aulas están cumpliendo con la carga horaria total.
# - Detectar asignaciones insuficientes o excesivas por curso.
# - Monitorear la convergencia estructural del algoritmo evolutivo.
#
# > 💡 Esta función es útil tanto para diagnósticos en la población inicial como para evaluar consistencia al final del proceso evolutivo.

# %%
from collections import Counter

def contar_asignaciones_por_aula(cromosoma):
    """
    Devuelve un Counter cuyas claves son tuplas (Nivel, Aula)
    y los valores el número de genes asignados a esa aula.
    """
    contador = Counter((nivel, aula) for nivel, aula, *_ in cromosoma)
    return contador

# Uso:
ctr = contar_asignaciones_por_aula(cromosoma_ejemplo)
for (nivel, aula), num_genes in ctr.items():
    print(f"{nivel} • {aula}: {num_genes}")
# Out:
# 1EGB • Ejemplares: 59
# 1EGB • Entusiastas: 59
# 1EGB • Estudiosos: 59
# 1EGB • Exitosos: 59
# 2EGB • Afectuosos: 59
# 2EGB • Amables: 59
# 2EGB • Amigables: 59
# 2EGB • Amistosos: 59
# 3EGB • Colaboradores: 59
# 3EGB • Conciliadores: 59
# 3EGB • Cordiales: 59
# 3EGB • Creativos: 59
# 4EGB • Optimistas: 59
# 4EGB • Ordenados: 59
# 4EGB • Organizados: 59
# 4EGB • Originales: 59
# 5EGB • Admirables: 59
# 5EGB • Afectivos: 59
# 5EGB • Aplicados: 59
# 5EGB • Atentos: 59
# 6EGB • Ecuánimes: 59
# 6EGB • Emprendedores: 59
# 6EGB • Excelentes: 59
# 6EGB • Expresivos: 59
# 7EGB • Reflexivos: 59
# 7EGB • Resilientes: 59
# 7EGB • Respetuosos: 59
# 7EGB • Responsables: 59
# 8EGB • Decididos: 59
# 8EGB • Diligentes: 59
# 8EGB • Dinámicos: 59
# 8EGB • Disciplinados: 59
# 9EGB • Altruistas: 59
# 9EGB • Asertivos: 59
# 9EGB • Audaces: 59
# 9EGB • Auténticos: 59
# 10EGB • Pacifistas: 59
# 10EGB • Perspicaces: 59
# 10EGB • Positivos: 59
# 1BGU • Confiables: 59
# 1BGU • Integros: 59
# 1BGU • Leales: 59
# 2BGU • Honestos: 59
# 2BGU • Justos: 59
# 2BGU • Proactivos: 59
# 3BGU • Empáticos: 59
# 3BGU • Solidarios: 59
# 3BGU • Vanguardistas: 59

# %% [markdown]
# ## 🧾 Conteo de horas asignadas por materia en cada aula
#
# Esta función convierte un cromosoma en una tabla estructurada que muestra cuántas horas ha sido asignada cada materia en cada paralelo.
#
# ### Funcionalidad:
# - Transforma el cromosoma (lista de tuplas) en un `DataFrame`.
# - Agrupa por `(Nivel, Aula, Código_materia)` para contar cuántas veces aparece cada materia.
# - Devuelve un `DataFrame` ordenado que permite comparar lo asignado con lo esperado.
#
# ### Aplicaciones:
# - Verificar si las materias cumplen con su carga horaria oficial.
# - Identificar desbalances o errores de asignación por curso.
# - Monitorear la coherencia interna de cromosomas generados por el algoritmo evolutivo.
#
# > ✅ Este resumen es especialmente útil al final de la evolución para validar la factibilidad de los horarios generados.

# %%
import pandas as pd

def contar_horas_por_materia(cromosoma):
    """
    Recibe:
        cromosoma: lista de tuplas
           (Nivel, Aula, Día, Hora, Código_materia, Docente)
    Devuelve un DataFrame con el número de horas asignadas por materia en cada aula.
    """
    # 1) Convertir la lista de genes en un DataFrame
    df = pd.DataFrame(
        cromosoma,
        columns=["Nivel", "Aula", "Día", "Hora", "Código_materia", "Docente"]
    )

    # 2) Agrupar por Nivel, Aula y Código_materia, y contar ocurrencias (horas)
    resumen = (
        df
        .groupby(["Nivel", "Aula", "Código_materia"])
        .size()
        .reset_index(name="Horas_asignadas")
        .sort_values(["Nivel", "Aula", "Código_materia"])
    )

    return resumen

# Ejemplo de uso:
df_horas = contar_horas_por_materia(cromosoma_ejemplo)
df_horas
# Out:
#       Nivel        Aula Código_materia  Horas_asignadas
# 0     10EGB  Pacifistas      BIO_10EGB                3
# 1     10EGB  Pacifistas      COM_10EGB                1
# 2     10EGB  Pacifistas      DAN_10EGB                1
# 3     10EGB  Pacifistas      DER_10EGB                1
# 4     10EGB  Pacifistas      DES_10EGB                2
# ...     ...         ...            ...              ...
# 1095   9EGB  Auténticos       QUI_9EGB                6
# 1096   9EGB  Auténticos       ROB_9EGB                2
# 1097   9EGB  Auténticos       SAL_9EGB                1
# 1098   9EGB  Auténticos       SOC_9EGB                3
# 1099   9EGB  Auténticos       SPE_9EGB                1
#
# [1100 rows x 4 columns]

# %% [markdown]
# ## 🔍 Verificación de materias con carga horaria incompleta por aula
#
# Esta función compara la cantidad de horas **asignadas** vs. **requeridas** para cada materia en cada aula, identificando aquellas que no cumplen con su carga horaria establecida.
#
# ### ¿Qué hace esta función?
# 1. Convierte el cromosoma en un `DataFrame` para análisis tabular.
# 2. Calcula cuántas horas ha sido asignada cada materia por curso y paralelo.
# 3. Replica la estructura esperada de materias por aula a partir de los archivos `materias.csv` y `paralelos.csv`.
# 4. Compara lo asignado con lo requerido.
# 5. Devuelve un `DataFrame` con aquellas materias que tienen **horas faltantes**.
#
# ### Aplicaciones:
# - Diagnóstico inmediato de **inconsistencias estructurales** en un cromosoma.
# - Verificación post-evolutiva para asegurar **factibilidad horaria**.
# - Guía para penalizaciones dentro de la función fitness.
#
# > ✅ Este paso es crítico para garantizar que todas las materias se impartan el número adecuado de veces según lo planificado por el colegio.

# %%
import pandas as pd

def verificar_materias_faltantes(cromosoma, materias_df, paralelos_df):
    """
    Compara la cantidad de horas asignadas vs requeridas para cada materia en cada aula.

    Retorna un DataFrame con las materias faltantes por aula.
    """
    # 1. Convertir cromosoma a DataFrame
    df_crom = pd.DataFrame(cromosoma, columns=["Nivel", "Aula", "Día", "Hora", "Código", "Docente"])

    # 2. Contar horas asignadas por materia por aula
    asignadas = (
        df_crom.groupby(["Nivel", "Aula", "Código"])
        .size()
        .reset_index(name="Horas_asignadas")
    )

    # 3. Expandir requerimientos por aula
    requeridas = pd.merge(
        paralelos_df[["Nivel", "Nombre_paralelo"]],
        materias_df,
        on="Nivel",
        how="left"
    ).rename(columns={"Nombre_paralelo": "Aula", "Código": "Código", "Horas": "Horas_requeridas"})

    # 4. Unir ambas tablas
    comparacion = pd.merge(
        requeridas,
        asignadas,
        how="left",
        on=["Nivel", "Aula", "Código"]
    )

    comparacion["Horas_asignadas"] = comparacion["Horas_asignadas"].fillna(0).astype(int)
    comparacion["Faltan"] = comparacion["Horas_requeridas"] - comparacion["Horas_asignadas"]

    # 5. Filtrar las que faltan
    faltantes = comparacion[comparacion["Faltan"] > 0].sort_values(["Nivel", "Aula", "Código"])

    return faltantes

# %%
faltantes_df = verificar_materias_faltantes(cromosoma_ejemplo, materias, paralelos)
display(faltantes_df)
# Out:
# Empty DataFrame
# Columns: [Nivel, Aula, Materias, Código, Horas_requeridas, Horas_asignadas, Faltan]
# Index: []

# %% [markdown]
# ## 🧱 Evaluación de restricciones duras en el cromosoma
#
# Esta función calcula una penalización acumulativa que representa cuántas **restricciones duras** se han violado en un cromosoma generado. Estas restricciones son consideradas **obligatorias** para la validez del horario.
#
# ### 📋 Restricciones aplicadas:
#
# 1. **🔗 Continuidad de sesiones**
#    - Penaliza si una misma materia se asigna el mismo día pero con un hueco mayor a 2 horas (solo si tiene más de 1 hora total en la semana).
#
# 2. **📚 Exceso de bloques continuos**
#    - Si una materia aparece más de 3 veces de forma consecutiva el mismo día, se penaliza (excepto para casos pedagógicos específicos como MAT/LEN en 1EGB o MAT en 2EGB).
#
# 3. **🚫 Cruces de docentes**
#    - Se penaliza fuertemente si un docente aparece asignado a más de un paralelo en el mismo bloque horario.
#    - Se consideran **excepciones específicas** por nombre y materia (por ejemplo, docentes de materias especiales como `EF ESPECIAL`, `INGLES ESPECIAL` o asignaturas de ciudadanía en BGU).
#
# ### ⚖️ Penalización:
# - Penalizaciones pequeñas (0.1) para continuidad.
# - Moderadas (2) para excesos seguidos.
# - Fuertes (20×n) por cruces de docentes.
#
# > Esta función se usa como parte del componente **fitness** en el algoritmo genético, y su correcta implementación garantiza la **factibilidad estructural mínima** del horario.

# %%
from collections import defaultdict

# Asumimos que este diccionario ya fue creado previamente
horas_por_materia = dict(zip(materias["Código"], materias["Horas"]))

def evaluar_restricciones_duras(cromosoma):
    penalizaciones = 0

    sesiones_por_materia = defaultdict(lambda: defaultdict(int))  # materia -> día -> cantidad
    sesiones_por_hora = defaultdict(list)  # (día, hora) -> lista de materias

    materia_actual = None
    dia_actual = None
    hora_anterior = None

    # 1. Verificación de continuidad sin ordenar, aprovechando el orden del cromosoma
    for nivel, aula, dia, hora, materia, docente in cromosoma:
        dia = dia
        hora = int(hora)

        # Verificación de continuidad
        if materia != materia_actual or dia != dia_actual:
            # reiniciamos el seguimiento
            materia_actual = materia
            dia_actual = dia
            hora_anterior = hora
        else:
            # comparación directa, sin ordenar
            if horas_por_materia.get(materia, 0) > 1 and (hora - hora_anterior > 2):
                penalizaciones += 0.1

                # LOG de trazabilidad
                #print(f"[SIN CONTINUIDAD] {materia} en {nivel}-{aula} con {docente} el día {dia} entre hora {hora_anterior} y {hora}")

            hora_anterior = hora

        # Recuento para otras restricciones
        sesiones_por_materia[materia][dia] += 1
        sesiones_por_hora[(dia, hora)].append(materia)

    # 2. Restricción: más de 3 horas continuas de una misma materia
    materia_anterior = None
    dia_anterior = None
    racha_continua = 1

    for i in range(1, len(cromosoma)):
        _, _, dia_act, hora_act, materia_act, _ = cromosoma[i]
        _, _, dia_ant, hora_ant, materia_ant, _ = cromosoma[i - 1]

        if nivel == "1EGB" and (materia == "MAT_1EGB" or materia == "LEN_1EGB"):
          continue

        if nivel == "2EGB" and materia == "MAT_2EGB":
          continue

        if materia_act == materia_ant and dia_act == dia_ant and int(hora_act) == int(hora_ant) + 1:
            racha_continua += 1
            if racha_continua > 3:
                penalizaciones += 2  # penalización moderada por exceso de continuidad
        else:
            racha_continua = 1  # reiniciar contador si cambia la materia o no es consecutiva

    # 3. Cruces de docentes en el mismo horario (con excepciones por nombre y cargo)
    docentes_en_tiempo = defaultdict(lambda: defaultdict(set))  # (día, hora) -> docente -> set de paralelos
    cargos_docentes = dict(zip(docentes["Nombres"], docentes["Cargo"]))  # asume que 'docentes' está cargado

    for nivel, paralelo, dia, hora, materia, docente in cromosoma:
        # Excepciones:
        if docente in {"EF ESPECIAL", "INGLES ESPECIAL"}:
            continue
        if docente == "JONATHAN CASTRO" and nivel == "3BGU":
            continue
        if docente == "JANETH MELO" and nivel == "3BGU":
            continue
        if materia == "CIU_1BGU" and  nivel=="1BGU":
            continue
        if materia == "CIU_2BGU" and  nivel=="2BGU":
            continue

        docentes_en_tiempo[(dia, hora)][docente].add(paralelo)

    for (dia, hora), docentes_dict in docentes_en_tiempo.items():
        for docente, paralelos in docentes_dict.items():
            if len(paralelos) > 1:
                # conflicto = f"[CRUCE] Docente: {docente} asignado a paralelos {sorted(paralelos)} el día {dia}, hora {hora}"
                # print(conflicto)
                penalizaciones += 20 * (len(paralelos) - 1)  # penalización fuerte por cruce real

    return penalizaciones

# %% [markdown]
# ## 🌿 Evaluación de restricciones blandas en el cromosoma
#
# Esta función calcula penalizaciones asociadas al incumplimiento de **restricciones blandas**, es decir, condiciones deseables que no invalidan el horario pero sí afectan su calidad pedagógica y organizacional.
#
# ### 📋 Restricciones consideradas:
#
# 1. **🕘 Medio tiempo**
#    - Docentes con contrato de medio tiempo no deben impartir clases luego de la hora 10.
#    - Penalización: +2 por cada sesión fuera del rango permitido.
#
# 2. **👶 Maternidad**
#    - Docentes en régimen de maternidad no deben tener sesiones más allá de la hora 14.
#    - Penalización: +2 por cada infracción.
#
# 3. *(Planificada pero no operativa)*
#    **📚 Diversidad de materias por día**
#    - El bloque incluye una estructura para detectar si hay demasiadas materias distintas por día en un aula, pero **actualmente no se registra información en `materias_por_dia`**, por lo tanto **no influye en la penalización** todavía.
#
# ### ✨ Propósito:
# Estas restricciones permiten incorporar aspectos humanos y pedagógicos que mejoran la **satisfacción del personal docente** y la **fluidez del horario**, influyendo indirectamente en la evolución de soluciones más aceptables.
#
# > 🔧 Esta función se combina en el fitness como `β · penalización_blanda`, con un peso menor que las restricciones duras.

# %%
def evaluar_restricciones_blandas(cromosoma):
    penalizaciones = 0

    # Crear diccionarios rápidos de cargos y docentes
    cargo_docente = dict(zip(docentes["Nombres"], docentes["Cargo"]))

    sesiones_por_dia_docente = defaultdict(lambda: defaultdict(list))  # docente -> día -> horas
    materias_por_dia = defaultdict(set)

    for nivel, aula, dia, hora, materia, docente in cromosoma:
        if not materia.isupper():
            continue

        # 1. Horario de medio tiempo (mañana = hasta 12pm => Hora 8)
        if cargo_docente.get(docente) == "Medio tiempo" and int(hora) > 10:
            penalizaciones += 2

        # 2. Maternidad (última hora debe ser máximo la 14)
        if cargo_docente.get(docente) == "Maternidad" and int(hora) > 14:
            penalizaciones += 2

        # Registrar para posibles evaluaciones futuras
        sesiones_por_dia_docente[docente][dia].append(int(hora))

    for (aula, dia), codigos in materias_por_dia.items():
        if len(codigos) > 3:
            penalizaciones += (len(codigos) - 3)

    return penalizaciones

# %% [markdown]
# ## 🧮 Función fitness con ponderación de restricciones duras y blandas
#
# Esta función evalúa la calidad (fitness) de un cromosoma considerando las penalizaciones acumuladas por el incumplimiento de restricciones:
#
# ### ⚖️ Fórmula utilizada:
# $
# \text{fitness} = \frac{1}{1 + (\alpha \cdot \text{penalización}_\text{dura} + \beta \cdot \text{penalización}_\text{blanda})}
# $
#
# ### Parámetros:
# - `alpha`: peso asignado a las restricciones duras (por defecto: 1.0).
# - `beta`: peso asignado a las restricciones blandas (por defecto: 0.2).
#
# ### ¿Qué representa el resultado?
# - Un valor cercano a **1.0** indica un cromosoma muy bueno (baja penalización).
# - Un valor cercano a **0.0** indica un cromosoma altamente penalizado.
#
# > 🧠 Esta métrica guía el proceso evolutivo, permitiendo seleccionar, cruzar y mutar aquellos cromosomas que respetan más las reglas institucionales del horario escolar.

# %%
# Función fitness con ponderaciones para restricciones duras y blandas
def fitness(cromosoma, alpha=1.0, beta=0.2):
    penal_duras = evaluar_restricciones_duras(cromosoma)
    penal_blandas = evaluar_restricciones_blandas(cromosoma)

    penal_total = alpha * penal_duras + beta * penal_blandas
    score = 1 / (1 + penal_total)

    return score

# %% [markdown]
# ## 🧩 Función de fitness con evaluación por nivel (split)
#
# Esta función calcula el `fitness` total de un cromosoma y, adicionalmente, descompone el resultado por **nivel educativo** (1EGB, 2EGB, ..., 3BGU). Esto permite realizar análisis más detallados sobre el rendimiento evolutivo de cada subhorario.
#
# ### ¿Cómo funciona?
#
# - Se agrupan los genes del cromosoma según su nivel (`gen[0]`).
# - Se evalúa cada subconjunto (`subcromosoma`) usando la función tradicional `fitness()`.
# - Se guarda el `fitness` por nivel en un diccionario.
# - Se retorna tanto el `fitness` total del cromosoma completo como el diccionario por split.
#
# ### Retorna:
# - `total_fitness`: fitness completo del cromosoma.
# - `fitness_por_split`: diccionario con la forma `{nivel: score}`.
#
# ### Aplicaciones:
# - 📊 Visualización de progreso por nivel en la evolución.
# - 📉 Detección de niveles que impiden mejorar el fitness global.
# - 🔍 Posibilita estrategias de evolución adaptativa por subgrupo.
#
# > ⚠️ Actualmente, `total_fitness` se recalcula en cada iteración dentro del loop, lo que es redundante. Podría optimizarse llamando a `fitness(cromosoma)` una sola vez antes del bucle.

# %%
def fitness_con_split(cromosoma, alpha=1.0, beta=0.2):
    from collections import defaultdict

    # Agrupar genes por nivel (gen[0] es el nivel)
    genes_por_nivel = defaultdict(list)
    for gen in cromosoma:
        nivel = gen[0]
        genes_por_nivel[nivel].append(gen)

    fitness_por_split = {}
    total_fitness = 0

    for nivel, subcromosoma in genes_por_nivel.items():
        # Calcular fitness del subcromosoma con función tradicional
        score_nivel = fitness(subcromosoma, alpha=alpha, beta=beta)
        fitness_por_split[nivel] = score_nivel
        total_fitness = fitness(cromosoma)

    return total_fitness, fitness_por_split

# %% [markdown]
# ## 🌱 Generación de la población inicial para el algoritmo genético
#
# Este bloque crea la población base sobre la cual el algoritmo genético comenzará su evolución. Incluye tanto conocimiento previo como diversidad genética.
#
# ### Estructura del proceso:
#
# 1. **📥 Carga de un cromosoma histórico**
#    - Se importa un horario real del colegio (por ejemplo, el del año anterior) desde un archivo `.txt`.
#    - Esta solución válida se incluye directamente en la población para preservar una base de calidad.
#
# 2. **🧬 Generación de nuevos cromosomas**
#    - Se generan cromosomas aleatorios usando la función `generar_cromosoma()`, que respeta las restricciones del problema.
#    - Esto garantiza diversidad genética y aumenta las posibilidades de encontrar soluciones óptimas en generaciones futuras.
#
# ### Parámetro:
# - `tamano_poblacion`: cantidad total de cromosomas iniciales (por defecto: 100).
#
# > Esta combinación de conocimiento previo y soluciones aleatorias acelera la convergencia y mejora la calidad evolutiva desde las primeras generaciones.

# %%
def cargar_cromosoma_desde_txt(nombre_archivo):
    cromosoma = []
    with open(nombre_archivo, "r", encoding="utf-8") as f:
        for linea in f:
            linea = linea.strip()
            if linea:
                cromosoma.append(eval(linea))
    return cromosoma

def generar_poblacion_inicial(tamano_poblacion=100, ruta_horario_valido=ruta + "/Horario_LEV.txt"):
    poblacion = []


    # ✅ 1. Cargar el cromosoma válido del año anterior
    cromosoma_historico = cargar_cromosoma_desde_txt(ruta_horario_valido)
    poblacion.append(cromosoma_historico)

    # ✅ 2. Generar cromosomas adicionales
    while len(poblacion) < tamano_poblacion:
        cromosoma_nuevo = generar_cromosoma()
        poblacion.append(cromosoma_nuevo)

    return poblacion

# Generar la población inicial
poblacion_inicial = generar_poblacion_inicial(tamano_poblacion=100)

# %% [markdown]
# 🔵 **Flujo general del ciclo genético:**
#
# 1. **Evaluar fitness** de la población inicial.
# 2. **Seleccionar padres** (basado en fitness, por ejemplo, torneo, ruleta, elitismo).
# 3. **Aplicar crossover** (cruce de padres para generar hijos).
# 4. **Aplicar mutación** (alterar genes de hijos con cierta probabilidad).
# 5. **Evaluar fitness** de los nuevos individuos.
# 6. **Formar nueva población** (reemplazar parcialmente o completamente).
# 7. **Repetir** desde el paso 2 hasta cumplir el criterio de parada (n generaciones o fitness deseado).

# %% [markdown]
# ## ⚙️ Evaluación paralela del fitness en la población
#
# Estas funciones permiten evaluar el fitness de múltiples cromosomas en paralelo, acelerando significativamente el proceso evolutivo en cada generación del algoritmo genético.
#
# ### Funciones definidas:
#
# - `evaluar2(cromosoma)`: versión directa que llama a `fitness()` sobre un cromosoma.
# - `evaluar2_split(cromosoma)`: evalúa un cromosoma completo y retorna el fitness por nivel (`split_info`) mediante `fitness_con_split()`.
# - `evaluar_fitness_poblacion(poblacion)`: evalúa toda la población utilizando **hilos paralelos** (`ThreadPoolExecutor`), mejorando el rendimiento computacional.
#
# ### Parámetros clave:
# - `alpha`, `beta`: ponderaciones para restricciones duras y blandas.
# - `num_procesos`: número de núcleos lógicos que se usarán para la evaluación concurrente.
#
# > 💡 La evaluación paralela es crítica cuando el tamaño de la población es grande (e.g., >100 cromosomas), ya que reduce el tiempo por generación sin afectar la calidad de la evaluación.

# %%
from concurrent.futures import ProcessPoolExecutor
import os

def evaluar2_split(cromosoma, alpha=1.0, beta=0.2):
    score, split_info = fitness_con_split(cromosoma, alpha=alpha, beta=beta)
    return score, split_info
def evaluar2(cromosoma, alpha=1.0, beta=0.2):
        return fitness(cromosoma, alpha=alpha, beta=beta)

def evaluar_fitness_poblacion(poblacion, alpha=1.0, beta=0.2, num_procesos=2):
    from concurrent.futures import ThreadPoolExecutor

    with ThreadPoolExecutor(max_workers=num_procesos) as executor:
        resultados = list(executor.map(
            lambda cromo: fitness(cromo, alpha=alpha, beta=beta),
            poblacion
        ))

    return resultados

# %% [markdown]
# ## 🧠 Evaluación paralela del fitness por nivel (con split) en toda la población
#
# Esta función permite evaluar en paralelo todos los cromosomas de la población, retornando tanto el `fitness global` como un `detalle por nivel educativo` (split) de cada cromosoma.
#
# ### Características:
# - Usa `ProcessPoolExecutor` para aprovechar múltiples núcleos físicos y evitar el GIL de Python.
# - Cada cromosoma es evaluado mediante `evaluar2_split()`, que calcula:
#   - `fitness global` total del cromosoma.
#   - `fitness por nivel` desglosado.
#
# ### ¿Qué retorna?
# - `fitness_scores`: lista de valores de fitness global, uno por cromosoma.
# - `fitness_por_split`: lista de diccionarios `{nivel: score}`, uno por cromosoma.
#
# ### Aplicaciones:
# - 🔍 Análisis de convergencia por nivel educativo (1EGB a 3BGU).
# - 📊 Visualización de avances diferenciados dentro de la población.
# - 🎯 Selección dirigida o estrategias de evolución específicas por subgrupo.
#
# > 🧬 Esta evaluación enriquecida es útil en problemas **multinivel** como el scheduling educativo, donde cada nivel tiene sus propias restricciones, docentes y prioridades.

# %%
def evaluar_fitness_poblacion_con_split(poblacion, alpha=1.0, beta=0.2, num_procesos=None):
    if num_procesos is None:
        num_procesos = os.cpu_count()

    with ProcessPoolExecutor(max_workers=num_procesos) as executor:
        resultados = list(executor.map(evaluar2_split, poblacion))

    # Separar los valores globales y los diccionarios por split
    fitness_scores = [r[0] for r in resultados]
    fitness_por_split = [r[1] for r in resultados]

    return fitness_scores, fitness_por_split

# %% [markdown]
# ## 🧬 Selección de padres mediante elitismo (fitness general)
#
# Esta función implementa una estrategia de **selección elitista**, donde se escogen los cromosomas con mejor fitness dentro de la población para ser usados como padres en la siguiente generación del algoritmo genético.
#
# ### ¿Cómo funciona?
# 1. Combina cada cromosoma con su respectivo valor de fitness.
# 2. Ordena la población de mayor a menor score de fitness.
# 3. Selecciona los `cantidad_padres` mejores individuos (sin duplicación).
#
# ### Parámetros:
# - `poblacion`: lista de cromosomas.
# - `fitness_poblacion`: lista de valores de fitness asociados a la población.
# - `cantidad_padres`: número de padres a seleccionar para reproducir.
#
# ### Aplicaciones:
# - 🧠 Mantiene soluciones de alta calidad a lo largo de las generaciones.
# - 🚫 Evita que soluciones válidas se pierdan por azar.
# - 📈 Favorece la convergencia rápida del algoritmo.
#
# > 🔍 Este mecanismo se puede complementar con otras estrategias de diversidad como **torneos** o **ruleta**, si se desea evitar estancamientos evolutivos.

# %%
# Función para seleccionar padres usando elitismo con fitness general
def seleccionar_padres_elitismo(poblacion, fitness_poblacion, cantidad_padres=20):
    # Combinar cromosomas con sus valores de fitness
    poblacion_con_fitness = list(zip(poblacion, fitness_poblacion))

    # Ordenar de mayor a menor fitness
    poblacion_con_fitness.sort(key=lambda x: x[1], reverse=True)

    # Seleccionar los mejores 'cantidad_padres' cromosomas
    padres_seleccionados = [individuo for individuo, fitness in poblacion_con_fitness[:cantidad_padres]]

    return padres_seleccionados

# Ejemplo de uso
cantidad_padres = 20
padres = seleccionar_padres_elitismo(poblacion_inicial, fitness_inicial, cantidad_padres=cantidad_padres)

print(f"Total de padres seleccionados: {len(padres)}")
# Out:
# Total de padres seleccionados: 20

# %% [markdown]
# ## 🧬 Estrategia de Crossover: `crossover_hibrido_heuristico_burke`
#
# Este operador se basa en el enfoque de Burke et al. (1995) adaptado a la estructura y restricciones del problema de generación de horarios escolares con materias sincronizadas, bloques contiguos y restricciones docentes.
#
# ---
#
# ### 🔢 Fases del Crossover
#
# ### 🧩 FASE 1 – Herencia de Bloques Sincronizados
# - Se heredan bloques completos por materia y nivel.
# - Se selecciona un padre como fuente de la franja horaria (día y hora).
# - Se valida disponibilidad de esa franja para todas las aulas del nivel.
# - Se insertan todas las asignaciones del bloque, **manteniendo sincronización por nivel**.
#
# **Materias tratadas como bloques sincronizados:**
# - `INGLES ESPECIAL` (7EGB–3BGU)
# - `CIU_1BGU`, `CIU_2BGU`
# - Materias dictadas por `JONATHAN CASTRO` y `JANETH MELO` en 3BGU
#
# ---

# %%
from collections import defaultdict

def extraer_bloques_sincronizados_por_materia_y_nivel(cromosoma):
    """
    Extrae bloques sincronizados por (nivel, materia/docente) del cromosoma.
    Devuelve un diccionario: (materia_o_docente, nivel) -> { (día, hora): [genes] }
    """
    bloques = defaultdict(lambda: defaultdict(list))

    for gen in cromosoma:
        nivel, aula, dia, hora, materia, docente = gen

        # INGLÉS ESPECIAL: sincronizado por nivel desde 7EGB en adelante
        if materia == "INGLES ESPECIAL" and nivel in ["7EGB", "8EGB", "9EGB", "10EGB", "1BGU", "2BGU", "3BGU"]:
            bloques[("INGLES ESPECIAL", nivel)][(dia, hora)].append(gen)

        # JONATHAN CASTRO o JANETH MELO en 3BGU
        if (nivel == "3BGU" and materia == "EST_3BGU") or (nivel == "3BGU" and materia == "DES_3BGU"):
            bloques[(materia, nivel)][(dia, hora)].append(gen)

        # Ciudadanía sincronizada
        if (nivel == "1BGU" and materia == "CIU_1BGU") or (nivel == "2BGU" and materia == "CIU_2BGU"):
            bloques[(materia, nivel)][(dia, hora)].append(gen)

    return bloques

from collections import Counter
import pandas as pd

def seleccionar_y_heredar_bloques_sincronizados(padre1, padre2):
    """
    Reescritura basada en el generador:
    - Para cada materia sincronizada por nivel, se identifica en qué franja horaria se asigna en cada padre.
    - Se elige la franja más frecuente y se replica esa franja para todas las aulas del nivel en el hijo.
    """
    hijo = []
    bloques_padres = padre1 + padre2

    materias_especiales = [
        ("INGLES ESPECIAL", "7EGB"), ("INGLES ESPECIAL", "8EGB"), ("INGLES ESPECIAL", "9EGB"),
        ("INGLES ESPECIAL", "10EGB"), ("INGLES ESPECIAL", "1BGU"), ("INGLES ESPECIAL", "2BGU"), ("INGLES ESPECIAL", "3BGU"),
        ("EST_3BGU", "3BGU"), ("DES_3BGU", "3BGU"),
        ("CIU_1BGU", "1BGU"), ("CIU_2BGU", "2BGU")
    ]

    for materia, nivel in materias_especiales:
        # Contar franjas de aparición en los padres
        franjas = [
            (g[2], g[3]) for g in bloques_padres
            if g[4] == materia and g[0] == nivel
        ]
        if not franjas:
            continue

        franja_mas_comun = Counter(franjas).most_common(1)[0][0]
        dia, hora = franja_mas_comun

        # Aplicar a todas las aulas del nivel
        aulas = paralelos.loc[paralelos["Nivel"] == nivel, "Nombre_paralelo"].tolist()
        for aula in aulas:
            docente = obtener_docente_por_materia_codigo(materia)
            hijo.append((nivel, aula, dia, hora, materia, docente))
            # Si es en parejas, añadir la segunda hora
            if materia in ["INGLES ESPECIAL", "EST_3BGU", "DES_3BGU"]:
                hijo.append((nivel, aula, dia, hora + 1, materia, docente))

    return hijo

# %% [markdown]
# ## 🔗 Extracción de bloques contiguos de materias emparejadas por nivel y aula
#
# Esta función identifica pares de materias que aparecen **de forma contigua** (una seguida de la otra en el horario) y que representan **combinaciones pedagógicas válidas**, como:
# - `DER` + `COM`
# - `SPE` + `INV`
# - `EXP` + `CAL` o `RAZ`
# - `DAN` + `MUS` (y viceversa)
#
# ### ¿Qué hace?
# - Recorre el cromosoma nivel por nivel, aula por aula.
# - Busca bloques de dos horas seguidas el mismo día.
# - Si detecta un par válido según las reglas pedagógicas, lo registra.

# %%
def extraer_bloques_contiguos_por_nivel(cromosoma):
    """
    Extrae todos los pares de materias contiguas válidas por nivel y aula.
    Devuelve un diccionario: (nivel, aula) -> lista de tuplas [(hora, (materia1, materia2), (dia))]
    """
    pares_validos = {
        "DER": "COM",
        "SPE": "INV",
        "SAL": "ECO",
        "EXP_CAL": ("EXP", "CAL"),
        "EXP_RAZ": ("EXP", "RAZ"),
        "DAN_MUS": ("DAN", "MUS"),
        "MUS_DAN": ("MUS", "DAN")
    }

    bloques_contiguos = defaultdict(list)

    for nivel, aula, dia, hora, materia, _ in cromosoma:
        # Buscar siguiente hora en el mismo día
        siguiente = [
            g for g in cromosoma
            if g[0] == nivel and g[1] == aula and g[2] == dia and g[3] == hora + 1
        ]
        if not siguiente:
            continue

        siguiente_materia = siguiente[0][4]
        par = (materia, siguiente_materia)

        # Evaluar si es un par válido
        if (materia.startswith("DER") and siguiente_materia.startswith("COM")) or \
           (materia.startswith("COM") and siguiente_materia.startswith("DER")) or \
           (materia.startswith("SPE") and siguiente_materia.startswith("INV")) or \
           (materia.startswith("INV") and siguiente_materia.startswith("SPE")) or \
           (materia.startswith("SAL") and siguiente_materia.startswith("ECO")) or \
           (materia.startswith("ECO") and siguiente_materia.startswith("SAL")) or \
           (materia.startswith("EXP") and siguiente_materia.startswith("CAL")) or \
           (materia.startswith("CAL") and siguiente_materia.startswith("EXP")) or \
           (materia.startswith("RAZ") and siguiente_materia.startswith("EXP")) or \
           (materia.startswith("EXP") and siguiente_materia.startswith("RAZ")) or \
           (materia.startswith("DAN") and siguiente_materia.startswith("MUS")) or \
           (materia.startswith("MUS") and siguiente_materia.startswith("DAN")):

            bloques_contiguos[(nivel, aula)].append((dia, hora, (materia, siguiente_materia)))

    return bloques_contiguos

# %% [markdown]
# ### 🔗 FASE 2 – Inserción de Pares Contiguos (2 bloques)
# - Se procesan pares de materias que deben ir juntas y contiguas (ej. `DER–COM`, `SPE–INV`, etc.).
# - Se busca su aparición contigua en alguno de los padres.
# - Se inserta en el hijo en un bloque de dos periodos consecutivos `(hora, hora+1)`.
# - Se respeta la cuota de cada materia y la validez del horario.
#
# ---

# %%
# Reimportar librerías necesarias después del reinicio
from collections import defaultdict
import random
import pandas as pd


def seleccionar_y_heredar_materias_en_pares(padre1, padre2, obtener_docente_por_materia_codigo):
    """
    FASE 2 corregida:
    - Hereda pares de materias contiguas desde ambos padres.
    - Solo se asigna un par válido por aula (ej. DER–COM, SPE–INV, etc.).
    - Evita duplicación del mismo par en distintas franjas para un mismo aula.
    """
    hijo = []
    sesiones_hijo = set()

    pares_pref = [
        ("DER", "COM"), ("SPE", "INV"), ("SAL", "ECO"),
        ("EXP", "CAL"), ("EXP", "RAZ"), ("RAZ", "EXP"), ("CAL", "EXP"),
        ("DAN", "MUS"), ("MUS", "DAN")
    ]

    # Combinar pares contiguos válidos desde ambos padres
    bloques_p1 = extraer_bloques_contiguos_por_nivel(padre1)
    bloques_p2 = extraer_bloques_contiguos_por_nivel(padre2)
    claves = set(bloques_p1.keys()).union(bloques_p2.keys())

    asignados_por_aula = defaultdict(set)  # (nivel, aula) -> set de (prefijo1, prefijo2)

    for clave in claves:
        nivel, aula = clave
        bloques1 = bloques_p1.get(clave, [])
        bloques2 = bloques_p2.get(clave, [])
        todos_los_pares = bloques1 + bloques2
        vistos = set()

        for dia, hora, (m1, m2) in todos_los_pares:
            clave_fr = (dia, hora, m1, m2)
            if clave_fr in vistos:
                continue
            vistos.add(clave_fr)

            if (nivel, aula, dia, hora) in sesiones_hijo or (nivel, aula, dia, hora + 1) in sesiones_hijo:
                continue

            # Detectar los prefijos
            pref1, pref2 = m1.split("_")[0], m2.split("_")[0]
            par_actual = tuple(sorted((pref1, pref2)))

            # Validar si es un par permitido
            if par_actual not in [tuple(sorted(p)) for p in pares_pref]:
                continue

            # Verificar si ya fue asignado este par en esa aula
            if par_actual in asignados_por_aula[(nivel, aula)]:
                continue

            # Asignar el par
            d1 = obtener_docente_por_materia_codigo(m1)
            d2 = obtener_docente_por_materia_codigo(m2)
            hijo.append((nivel, aula, dia, hora, m1, d1))
            hijo.append((nivel, aula, dia, hora + 1, m2, d2))

            sesiones_hijo.add((nivel, aula, dia, hora))
            sesiones_hijo.add((nivel, aula, dia, hora + 1))
            asignados_por_aula[(nivel, aula)].add(par_actual)

    return hijo

# %% [markdown]
# ### ⚙️ FASE 3 – Asignación del Resto de Materias
# - Para cada aula, se construye una "bolsa" con materias restantes según cuota.
# - Se recorren los slots libres válidos del horario (`es_horario_valido`) e insertan materias restantes de forma aleatoria o por heurística.
# - Se asegura que el total de asignaciones por aula sea exactamente **59**.
#
# ---

# %%
from collections import defaultdict
import random

from collections import defaultdict
import random

def asignar_materias_restantes_con_herencia(
    cromosoma_actual,
    materias_df,
    paralelos,
    horas_por_materia,
    obtener_docente_por_materia_codigo,
    es_horario_valido,
    padre1,
    padre2
):
    """
    Completa el cromosoma asegurando que cada aula tenga 59 genes.
    Preserva la herencia de horarios desde los padres si es posible.
    Si no, asigna en espacios disponibles como fallback.
    """
    cromosoma = list(cromosoma_actual)
    sesiones_ocupadas = {(n, a, d, h) for n, a, d, h, _, _ in cromosoma}
    cuenta_materias = defaultdict(lambda: defaultdict(int))  # (nivel, aula) -> materia -> count

    # Inicializar conteo por materia por aula
    for n, a, _, _, m, _ in cromosoma:
        cuenta_materias[(n, a)][m] += 1

    niveles = paralelos["Nivel"].unique()
    dias_semana = ["Lunes", "Martes", "Miércoles", "Jueves", "Viernes"]

    for nivel in niveles:
        aulas = paralelos.loc[paralelos["Nivel"] == nivel, "Nombre_paralelo"]
        materias_nivel = materias_df[materias_df["Nivel"] == nivel]["Código"].tolist()

        for aula in aulas:
            genes_aula = [g for g in cromosoma if g[0] == nivel and g[1] == aula]
            total_actual = len(genes_aula)
            if total_actual >= 59:
                continue

            bolsa = []
            for cod in materias_nivel:
                horas_necesarias = horas_por_materia.get(cod, 0)
                actuales = cuenta_materias[(nivel, aula)].get(cod, 0)
                faltantes = max(0, horas_necesarias - actuales)
                bolsa += [cod] * faltantes

            random.shuffle(bolsa)
            for cod in bolsa:
                docente = obtener_docente_por_materia_codigo(cod)
                heredado = False

                # Intentar heredar franja desde padres
                for padre in [padre1, padre2]:
                    for n, a, d, h, m, _ in padre:
                        if n == nivel and a == aula and m == cod and (n, a, d, h) not in sesiones_ocupadas and es_horario_valido(n, d, h):
                            cromosoma.append((n, a, d, h, m, docente))
                            sesiones_ocupadas.add((n, a, d, h))
                            cuenta_materias[(n, a)][m] += 1
                            heredado = True
                            break
                    if heredado:
                        break

                # Si no se pudo heredar, asignar en espacio libre
                if not heredado:
                    for d in dias_semana:
                        for h in range(1, 17):
                            if (nivel, aula, d, h) in sesiones_ocupadas:
                                continue
                            if not es_horario_valido(nivel, d, h):
                                continue
                            cromosoma.append((nivel, aula, d, h, cod, docente))
                            sesiones_ocupadas.add((nivel, aula, d, h))
                            cuenta_materias[(nivel, aula)][cod] += 1
                            break
                        else:
                            continue
                        break

    return cromosoma

# %% [markdown]
# ### 🛠️ Reglas Generales
# - Ningún `(nivel, aula, día, hora)` debe contener más de una asignación.
# - No se deben omitir materias, se garantiza un cromosoma completo con **2832 genes**.
# - Los docentes se asignan dinámicamente con la función:
#   `obtener_docente_por_materia_codigo(materia)`
# - Todo bloque se valida antes de ser insertado para garantizar factibilidad.
#
# ---
#
# ### 📌 Referencia
# Adaptado del paper:
# **"A Hybrid Genetic Algorithm for Highly Constrained Timetabling Problems"**
# Rupert Weare, Edmund Burke & Dave Elliman (1995)

# %%
def crossover_hibrido_heuristico_burke(padre1, padre2):
    """
    Crossover híbrido basado en Burke et al. (1995) adaptado para el problema de scheduling escolar.
    Integra:
    - Fase 1: Herencia de bloques sincronizados por nivel.
    - Fase 2: Herencia de bloques contiguos por aula (pares de materias).
    - Fase 3: Asignación de materias restantes preservando herencia horaria.

    Variables globales requeridas:
    - materias, paralelos, horas_por_materia
    - obtener_docente_por_materia_codigo, es_horario_valido
    """
    # FASE 1: bloques sincronizados (como INGLÉS ESPECIAL o CIU)
    hijo = seleccionar_y_heredar_bloques_sincronizados(padre1, padre2)

    # FASE 2: bloques contiguos válidos (parejas como DER-COM)
    hijo += seleccionar_y_heredar_materias_en_pares(padre1, padre2, obtener_docente_por_materia_codigo)

    # FASE 3: completar con herencia prioritaria
    hijo = asignar_materias_restantes_con_herencia(
        cromosoma_actual=hijo,
        materias_df=materias,
        paralelos=paralelos,
        horas_por_materia=horas_por_materia,
        obtener_docente_por_materia_codigo=obtener_docente_por_materia_codigo,
        es_horario_valido=es_horario_valido,
        padre1=padre1,
        padre2=padre2
    )

    return ordenar_cromosoma(hijo)

# Ejemplo de uso
hijo_ejemplo = crossover_hibrido_heuristico_burke(padres[3], padres[5]) #2 y  10

# Inspección de genes
print(f"Total de genes generados: {len(hijo_ejemplo)}")
for gen in hijo_ejemplo[:]:
    print(gen)
# Out:
# Total de genes generados: 2832
# ('1EGB', 'Ejemplares', 'Lunes', 1, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Ejemplares', 'Lunes', 2, 'PEN_1EGB', 'FERNANDA CAÑIZARES')
# ('1EGB', 'Ejemplares', 'Lunes', 3, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Ejemplares', 'Lunes', 4, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Ejemplares', 'Lunes', 6, 'EXT_1EGB', 'MARIEL RODRIGUEZ')
# ('1EGB', 'Ejemplares', 'Lunes', 7, 'LEC_1EGB', 'ALISON PLAZA')
# ('1EGB', 'Ejemplares', 'Lunes', 8, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Ejemplares', 'Lunes', 9, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Ejemplares', 'Lunes', 10, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Ejemplares', 'Lunes', 13, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Ejemplares', 'Lunes', 14, 'PEN_1EGB', 'FERNANDA CAÑIZARES')
# ('1EGB', 'Ejemplares', 'Martes', 1, 'ECO_1EGB', 'MARJURIE JÁCOME')
# ('1EGB', 'Ejemplares', 'Martes', 2, 'SAL_1EGB', 'VANESSA ESPÍN')
# ('1EGB', 'Ejemplares', 'Martes', 3, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Ejemplares', 'Martes', 4, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Ejemplares', 'Martes', 6, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Ejemplares', 'Martes', 7, 'EST_1EGB', 'SANTIAGO CALLE')
# ('1EGB', 'Ejemplares', 'Martes', 8, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Ejemplares', 'Martes', 9, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Ejemplares', 'Martes', 10, 'EST_1EGB', 'SANTIAGO CALLE')
# ('1EGB', 'Ejemplares', 'Martes', 13, 'EDU_1EGB', 'EF ESPECIAL')
# ('1EGB', 'Ejemplares', 'Martes', 14, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Ejemplares', 'Martes', 15, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Ejemplares', 'Martes', 16, 'DES_1EGB', 'ANDREA MACIAS')
# ('1EGB', 'Ejemplares', 'Miércoles', 3, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Ejemplares', 'Miércoles', 4, 'LEC_1EGB', 'ALISON PLAZA')
# ('1EGB', 'Ejemplares', 'Miércoles', 6, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Ejemplares', 'Miércoles', 7, 'MUS_1EGB', 'LUIS JÁCOME')
# ('1EGB', 'Ejemplares', 'Miércoles', 8, 'DAN_1EGB', 'PAOLA LÓPEZ')
# ('1EGB', 'Ejemplares', 'Miércoles', 9, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Ejemplares', 'Miércoles', 10, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Ejemplares', 'Miércoles', 13, 'ESP_1EGB', 'MERY VENEGAS')
# ('1EGB', 'Ejemplares', 'Miércoles', 14, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Ejemplares', 'Miércoles', 15, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Ejemplares', 'Miércoles', 16, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Ejemplares', 'Jueves', 1, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Ejemplares', 'Jueves', 2, 'DER_1EGB', 'CORALÍA CÓRDOVA')
# ('1EGB', 'Ejemplares', 'Jueves', 3, 'COM_1EGB', 'ERIKA CAIZATOA')
# ('1EGB', 'Ejemplares', 'Jueves', 4, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Ejemplares', 'Jueves', 6, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Ejemplares', 'Jueves', 7, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Ejemplares', 'Jueves', 8, 'EST_1EGB', 'SANTIAGO CALLE')
# ('1EGB', 'Ejemplares', 'Jueves', 9, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Ejemplares', 'Jueves', 10, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Ejemplares', 'Jueves', 15, 'DES_1EGB', 'ANDREA MACIAS')
# ('1EGB', 'Ejemplares', 'Jueves', 16, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Ejemplares', 'Viernes', 1, 'ROB_1EGB', 'JENNY CHICAIZA')
# ('1EGB', 'Ejemplares', 'Viernes', 2, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Ejemplares', 'Viernes', 3, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Ejemplares', 'Viernes', 4, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Ejemplares', 'Viernes', 6, 'ESP_1EGB', 'MERY VENEGAS')
# ('1EGB', 'Ejemplares', 'Viernes', 7, 'EDU_1EGB', 'EF ESPECIAL')
# ('1EGB', 'Ejemplares', 'Viernes', 8, 'SPE_1EGB', 'CHRISTIAN SOLANO')
# ('1EGB', 'Ejemplares', 'Viernes', 9, 'INV_1EGB', 'KARLA LAZCANO')
# ('1EGB', 'Ejemplares', 'Viernes', 10, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Ejemplares', 'Viernes', 13, 'LEC_1EGB', 'ALISON PLAZA')
# ('1EGB', 'Ejemplares', 'Viernes', 14, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Ejemplares', 'Viernes', 15, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Ejemplares', 'Viernes', 16, 'ROB_1EGB', 'JENNY CHICAIZA')
# ('1EGB', 'Entusiastas', 'Lunes', 1, 'EST_1EGB', 'SANTIAGO CALLE')
# ('1EGB', 'Entusiastas', 'Lunes', 2, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Entusiastas', 'Lunes', 3, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Entusiastas', 'Lunes', 4, 'LEC_1EGB', 'ALISON PLAZA')
# ('1EGB', 'Entusiastas', 'Lunes', 6, 'ROB_1EGB', 'JENNY CHICAIZA')
# ('1EGB', 'Entusiastas', 'Lunes', 7, 'LEC_1EGB', 'ALISON PLAZA')
# ('1EGB', 'Entusiastas', 'Lunes', 8, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Entusiastas', 'Lunes', 9, 'LEC_1EGB', 'ALISON PLAZA')
# ('1EGB', 'Entusiastas', 'Lunes', 10, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Entusiastas', 'Lunes', 13, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Entusiastas', 'Lunes', 14, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Entusiastas', 'Martes', 1, 'PEN_1EGB', 'FERNANDA CAÑIZARES')
# ('1EGB', 'Entusiastas', 'Martes', 2, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Entusiastas', 'Martes', 3, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Entusiastas', 'Martes', 4, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Entusiastas', 'Martes', 6, 'ECO_1EGB', 'MARJURIE JÁCOME')
# ('1EGB', 'Entusiastas', 'Martes', 7, 'SAL_1EGB', 'VANESSA ESPÍN')
# ('1EGB', 'Entusiastas', 'Martes', 8, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Entusiastas', 'Martes', 9, 'EDU_1EGB', 'EF ESPECIAL')
# ('1EGB', 'Entusiastas', 'Martes', 10, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Entusiastas', 'Martes', 13, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Entusiastas', 'Martes', 14, 'EST_1EGB', 'SANTIAGO CALLE')
# ('1EGB', 'Entusiastas', 'Martes', 15, 'ROB_1EGB', 'JENNY CHICAIZA')
# ('1EGB', 'Entusiastas', 'Martes', 16, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Entusiastas', 'Miércoles', 3, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Entusiastas', 'Miércoles', 4, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Entusiastas', 'Miércoles', 6, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Entusiastas', 'Miércoles', 7, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Entusiastas', 'Miércoles', 8, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Entusiastas', 'Miércoles', 9, 'DES_1EGB', 'ANDREA MACIAS')
# ('1EGB', 'Entusiastas', 'Miércoles', 10, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Entusiastas', 'Miércoles', 13, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Entusiastas', 'Miércoles', 14, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Entusiastas', 'Miércoles', 15, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Entusiastas', 'Miércoles', 16, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Entusiastas', 'Jueves', 1, 'EXT_1EGB', 'MARIEL RODRIGUEZ')
# ('1EGB', 'Entusiastas', 'Jueves', 2, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Entusiastas', 'Jueves', 3, 'ESP_1EGB', 'MERY VENEGAS')
# ('1EGB', 'Entusiastas', 'Jueves', 4, 'EST_1EGB', 'SANTIAGO CALLE')
# ('1EGB', 'Entusiastas', 'Jueves', 6, 'SPE_1EGB', 'CHRISTIAN SOLANO')
# ('1EGB', 'Entusiastas', 'Jueves', 7, 'INV_1EGB', 'KARLA LAZCANO')
# ('1EGB', 'Entusiastas', 'Jueves', 8, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Entusiastas', 'Jueves', 9, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Entusiastas', 'Jueves', 10, 'DES_1EGB', 'ANDREA MACIAS')
# ('1EGB', 'Entusiastas', 'Jueves', 15, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Entusiastas', 'Jueves', 16, 'PEN_1EGB', 'FERNANDA CAÑIZARES')
# ('1EGB', 'Entusiastas', 'Viernes', 1, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Entusiastas', 'Viernes', 2, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Entusiastas', 'Viernes', 3, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Entusiastas', 'Viernes', 4, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Entusiastas', 'Viernes', 6, 'ESP_1EGB', 'MERY VENEGAS')
# ('1EGB', 'Entusiastas', 'Viernes', 7, 'COM_1EGB', 'ERIKA CAIZATOA')
# ('1EGB', 'Entusiastas', 'Viernes', 8, 'DER_1EGB', 'CORALÍA CÓRDOVA')
# ('1EGB', 'Entusiastas', 'Viernes', 9, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Entusiastas', 'Viernes', 10, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Entusiastas', 'Viernes', 13, 'MUS_1EGB', 'LUIS JÁCOME')
# ('1EGB', 'Entusiastas', 'Viernes', 14, 'DAN_1EGB', 'PAOLA LÓPEZ')
# ('1EGB', 'Entusiastas', 'Viernes', 15, 'EDU_1EGB', 'EF ESPECIAL')
# ('1EGB', 'Entusiastas', 'Viernes', 16, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Estudiosos', 'Lunes', 1, 'MUS_1EGB', 'LUIS JÁCOME')
# ('1EGB', 'Estudiosos', 'Lunes', 2, 'DAN_1EGB', 'PAOLA LÓPEZ')
# ('1EGB', 'Estudiosos', 'Lunes', 3, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Estudiosos', 'Lunes', 4, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Estudiosos', 'Lunes', 6, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Estudiosos', 'Lunes', 7, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Estudiosos', 'Lunes', 8, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Estudiosos', 'Lunes', 9, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Estudiosos', 'Lunes', 10, 'DES_1EGB', 'ANDREA MACIAS')
# ('1EGB', 'Estudiosos', 'Lunes', 13, 'EDU_1EGB', 'EF ESPECIAL')
# ('1EGB', 'Estudiosos', 'Lunes', 14, 'EST_1EGB', 'SANTIAGO CALLE')
# ('1EGB', 'Estudiosos', 'Martes', 1, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Estudiosos', 'Martes', 2, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Estudiosos', 'Martes', 3, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Estudiosos', 'Martes', 4, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Estudiosos', 'Martes', 6, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Estudiosos', 'Martes', 7, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Estudiosos', 'Martes', 8, 'COM_1EGB', 'ERIKA CAIZATOA')
# ('1EGB', 'Estudiosos', 'Martes', 9, 'DER_1EGB', 'CORALÍA CÓRDOVA')
# ('1EGB', 'Estudiosos', 'Martes', 10, 'LEC_1EGB', 'ALISON PLAZA')
# ('1EGB', 'Estudiosos', 'Martes', 13, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Estudiosos', 'Martes', 14, 'ESP_1EGB', 'MERY VENEGAS')
# ('1EGB', 'Estudiosos', 'Martes', 15, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Estudiosos', 'Martes', 16, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Estudiosos', 'Miércoles', 3, 'LEC_1EGB', 'ALISON PLAZA')
# ('1EGB', 'Estudiosos', 'Miércoles', 4, 'DES_1EGB', 'ANDREA MACIAS')
# ('1EGB', 'Estudiosos', 'Miércoles', 6, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Estudiosos', 'Miércoles', 7, 'SPE_1EGB', 'CHRISTIAN SOLANO')
# ('1EGB', 'Estudiosos', 'Miércoles', 8, 'INV_1EGB', 'KARLA LAZCANO')
# ('1EGB', 'Estudiosos', 'Miércoles', 9, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Estudiosos', 'Miércoles', 10, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Estudiosos', 'Miércoles', 13, 'ECO_1EGB', 'MARJURIE JÁCOME')
# ('1EGB', 'Estudiosos', 'Miércoles', 14, 'SAL_1EGB', 'VANESSA ESPÍN')
# ('1EGB', 'Estudiosos', 'Miércoles', 15, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Estudiosos', 'Miércoles', 16, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Estudiosos', 'Jueves', 1, 'EST_1EGB', 'SANTIAGO CALLE')
# ('1EGB', 'Estudiosos', 'Jueves', 2, 'ROB_1EGB', 'JENNY CHICAIZA')
# ('1EGB', 'Estudiosos', 'Jueves', 3, 'LEC_1EGB', 'ALISON PLAZA')
# ('1EGB', 'Estudiosos', 'Jueves', 4, 'EXT_1EGB', 'MARIEL RODRIGUEZ')
# ('1EGB', 'Estudiosos', 'Jueves', 6, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Estudiosos', 'Jueves', 7, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Estudiosos', 'Jueves', 8, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Estudiosos', 'Jueves', 9, 'ROB_1EGB', 'JENNY CHICAIZA')
# ('1EGB', 'Estudiosos', 'Jueves', 10, 'ESP_1EGB', 'MERY VENEGAS')
# ('1EGB', 'Estudiosos', 'Jueves', 15, 'PEN_1EGB', 'FERNANDA CAÑIZARES')
# ('1EGB', 'Estudiosos', 'Jueves', 16, 'EST_1EGB', 'SANTIAGO CALLE')
# ('1EGB', 'Estudiosos', 'Viernes', 1, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Estudiosos', 'Viernes', 2, 'PEN_1EGB', 'FERNANDA CAÑIZARES')
# ('1EGB', 'Estudiosos', 'Viernes', 3, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Estudiosos', 'Viernes', 4, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Estudiosos', 'Viernes', 6, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Estudiosos', 'Viernes', 7, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Estudiosos', 'Viernes', 8, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Estudiosos', 'Viernes', 9, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Estudiosos', 'Viernes', 10, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Estudiosos', 'Viernes', 13, 'EDU_1EGB', 'EF ESPECIAL')
# ('1EGB', 'Estudiosos', 'Viernes', 14, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Estudiosos', 'Viernes', 15, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Estudiosos', 'Viernes', 16, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Exitosos', 'Lunes', 1, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Exitosos', 'Lunes', 2, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Exitosos', 'Lunes', 3, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Exitosos', 'Lunes', 4, 'EDU_1EGB', 'EF ESPECIAL')
# ('1EGB', 'Exitosos', 'Lunes', 6, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Exitosos', 'Lunes', 7, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Exitosos', 'Lunes', 8, 'PEN_1EGB', 'FERNANDA CAÑIZARES')
# ('1EGB', 'Exitosos', 'Lunes', 9, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Exitosos', 'Lunes', 10, 'DES_1EGB', 'ANDREA MACIAS')
# ('1EGB', 'Exitosos', 'Lunes', 13, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Exitosos', 'Lunes', 14, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Exitosos', 'Martes', 1, 'DER_1EGB', 'CORALÍA CÓRDOVA')
# ('1EGB', 'Exitosos', 'Martes', 2, 'COM_1EGB', 'ERIKA CAIZATOA')
# ('1EGB', 'Exitosos', 'Martes', 3, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Exitosos', 'Martes', 4, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Exitosos', 'Martes', 6, 'SPE_1EGB', 'CHRISTIAN SOLANO')
# ('1EGB', 'Exitosos', 'Martes', 7, 'INV_1EGB', 'KARLA LAZCANO')
# ('1EGB', 'Exitosos', 'Martes', 8, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Exitosos', 'Martes', 9, 'ESP_1EGB', 'MERY VENEGAS')
# ('1EGB', 'Exitosos', 'Martes', 10, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Exitosos', 'Martes', 13, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Exitosos', 'Martes', 14, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Exitosos', 'Martes', 15, 'DES_1EGB', 'ANDREA MACIAS')
# ('1EGB', 'Exitosos', 'Martes', 16, 'EXT_1EGB', 'MARIEL RODRIGUEZ')
# ('1EGB', 'Exitosos', 'Miércoles', 3, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Exitosos', 'Miércoles', 4, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Exitosos', 'Miércoles', 6, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Exitosos', 'Miércoles', 7, 'ECO_1EGB', 'MARJURIE JÁCOME')
# ('1EGB', 'Exitosos', 'Miércoles', 8, 'SAL_1EGB', 'VANESSA ESPÍN')
# ('1EGB', 'Exitosos', 'Miércoles', 9, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Exitosos', 'Miércoles', 10, 'EDU_1EGB', 'EF ESPECIAL')
# ('1EGB', 'Exitosos', 'Miércoles', 13, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Exitosos', 'Miércoles', 14, 'EST_1EGB', 'SANTIAGO CALLE')
# ('1EGB', 'Exitosos', 'Miércoles', 15, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Exitosos', 'Miércoles', 16, 'ESP_1EGB', 'MERY VENEGAS')
# ('1EGB', 'Exitosos', 'Jueves', 1, 'ROB_1EGB', 'JENNY CHICAIZA')
# ('1EGB', 'Exitosos', 'Jueves', 2, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Exitosos', 'Jueves', 3, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Exitosos', 'Jueves', 4, 'ROB_1EGB', 'JENNY CHICAIZA')
# ('1EGB', 'Exitosos', 'Jueves', 6, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Exitosos', 'Jueves', 7, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Exitosos', 'Jueves', 8, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Exitosos', 'Jueves', 9, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Exitosos', 'Jueves', 10, 'EST_1EGB', 'SANTIAGO CALLE')
# ('1EGB', 'Exitosos', 'Jueves', 15, 'LEC_1EGB', 'ALISON PLAZA')
# ('1EGB', 'Exitosos', 'Jueves', 16, 'LEC_1EGB', 'ALISON PLAZA')
# ('1EGB', 'Exitosos', 'Viernes', 1, 'MUS_1EGB', 'LUIS JÁCOME')
# ('1EGB', 'Exitosos', 'Viernes', 2, 'DAN_1EGB', 'PAOLA LÓPEZ')
# ('1EGB', 'Exitosos', 'Viernes', 3, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Exitosos', 'Viernes', 4, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Exitosos', 'Viernes', 6, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Exitosos', 'Viernes', 7, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Exitosos', 'Viernes', 8, 'LEC_1EGB', 'ALISON PLAZA')
# ('1EGB', 'Exitosos', 'Viernes', 9, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Exitosos', 'Viernes', 10, 'PEN_1EGB', 'FERNANDA CAÑIZARES')
# ('1EGB', 'Exitosos', 'Viernes', 13, 'EST_1EGB', 'SANTIAGO CALLE')
# ('1EGB', 'Exitosos', 'Viernes', 14, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Exitosos', 'Viernes', 15, 'NAT_1EGB', 'MARIANA HIDALGO')
# ('1EGB', 'Exitosos', 'Viernes', 16, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('2EGB', 'Afectuosos', 'Lunes', 1, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Afectuosos', 'Lunes', 2, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Afectuosos', 'Lunes', 3, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Afectuosos', 'Lunes', 4, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Afectuosos', 'Lunes', 6, 'PLA_2EGB', 'LIZ DÍAZ')
# ('2EGB', 'Afectuosos', 'Lunes', 7, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Afectuosos', 'Lunes', 8, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Afectuosos', 'Lunes', 9, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Afectuosos', 'Lunes', 10, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Afectuosos', 'Lunes', 13, 'COM_2EGB', 'ERIKA CAIZATOA')
# ('2EGB', 'Afectuosos', 'Lunes', 14, 'DER_2EGB', 'CORALÍA CÓRDOVA')
# ('2EGB', 'Afectuosos', 'Lunes', 15, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Afectuosos', 'Lunes', 16, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Afectuosos', 'Martes', 1, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Afectuosos', 'Martes', 2, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Afectuosos', 'Martes', 3, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Afectuosos', 'Martes', 4, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Afectuosos', 'Martes', 6, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Afectuosos', 'Martes', 7, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Afectuosos', 'Martes', 8, 'PRO_2EGB', 'LUDWIN GUALOTUÑA')
# ('2EGB', 'Afectuosos', 'Martes', 9, 'DES_2EGB', 'MISHEL SALTOS')
# ('2EGB', 'Afectuosos', 'Martes', 10, 'PRO_2EGB', 'LUDWIN GUALOTUÑA')
# ('2EGB', 'Afectuosos', 'Martes', 13, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Afectuosos', 'Martes', 14, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Afectuosos', 'Miércoles', 3, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Afectuosos', 'Miércoles', 4, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Afectuosos', 'Miércoles', 6, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Afectuosos', 'Miércoles', 7, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Afectuosos', 'Miércoles', 8, 'DAN_2EGB', 'PAOLA LÓPEZ')
# ('2EGB', 'Afectuosos', 'Miércoles', 9, 'MUS_2EGB', 'LUIS JÁCOME')
# ('2EGB', 'Afectuosos', 'Miércoles', 10, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Afectuosos', 'Miércoles', 13, 'EDU_2EGB', 'EF ESPECIAL')
# ('2EGB', 'Afectuosos', 'Miércoles', 14, 'ECO_2EGB', 'MARJURIE JÁCOME')
# ('2EGB', 'Afectuosos', 'Miércoles', 15, 'SAL_2EGB', 'VANESSA ESPÍN')
# ('2EGB', 'Afectuosos', 'Miércoles', 16, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Afectuosos', 'Jueves', 1, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Afectuosos', 'Jueves', 2, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Afectuosos', 'Jueves', 3, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Afectuosos', 'Jueves', 4, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Afectuosos', 'Jueves', 6, 'SOC_2EGB', 'ALBITA QUILLUPANGUI')
# ('2EGB', 'Afectuosos', 'Jueves', 7, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Afectuosos', 'Jueves', 8, 'EXP_2EGB', 'JOSÉ LUIS HERNÁNDEZ')
# ('2EGB', 'Afectuosos', 'Jueves', 9, 'CAL_2EGB', 'JAIR CRIOLLO')
# ('2EGB', 'Afectuosos', 'Jueves', 10, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Afectuosos', 'Jueves', 13, 'PLA_2EGB', 'LIZ DÍAZ')
# ('2EGB', 'Afectuosos', 'Jueves', 14, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Afectuosos', 'Viernes', 1, 'ROB_2EGB', 'DAVID CASTRO')
# ('2EGB', 'Afectuosos', 'Viernes', 2, 'SPE_2EGB', 'CHRISTIAN SOLANO')
# ('2EGB', 'Afectuosos', 'Viernes', 3, 'INV_2EGB', 'KARLA LAZCANO')
# ('2EGB', 'Afectuosos', 'Viernes', 4, 'EDU_2EGB', 'EF ESPECIAL')
# ('2EGB', 'Afectuosos', 'Viernes', 6, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Afectuosos', 'Viernes', 7, 'SOC_2EGB', 'ALBITA QUILLUPANGUI')
# ('2EGB', 'Afectuosos', 'Viernes', 8, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Afectuosos', 'Viernes', 9, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Afectuosos', 'Viernes', 10, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Afectuosos', 'Viernes', 13, 'SOC_2EGB', 'ALBITA QUILLUPANGUI')
# ('2EGB', 'Afectuosos', 'Viernes', 14, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Afectuosos', 'Viernes', 15, 'DES_2EGB', 'MISHEL SALTOS')
# ('2EGB', 'Afectuosos', 'Viernes', 16, 'ROB_2EGB', 'DAVID CASTRO')
# ('2EGB', 'Amables', 'Lunes', 1, 'CAL_2EGB', 'JAIR CRIOLLO')
# ('2EGB', 'Amables', 'Lunes', 2, 'EXP_2EGB', 'JOSÉ LUIS HERNÁNDEZ')
# ('2EGB', 'Amables', 'Lunes', 3, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amables', 'Lunes', 4, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amables', 'Lunes', 6, 'PRO_2EGB', 'LUDWIN GUALOTUÑA')
# ('2EGB', 'Amables', 'Lunes', 7, 'DES_2EGB', 'MISHEL SALTOS')
# ('2EGB', 'Amables', 'Lunes', 8, 'SOC_2EGB', 'ALBITA QUILLUPANGUI')
# ('2EGB', 'Amables', 'Lunes', 9, 'PLA_2EGB', 'LIZ DÍAZ')
# ('2EGB', 'Amables', 'Lunes', 10, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Amables', 'Lunes', 13, 'EDU_2EGB', 'EF ESPECIAL')
# ('2EGB', 'Amables', 'Lunes', 14, 'SPE_2EGB', 'CHRISTIAN SOLANO')
# ('2EGB', 'Amables', 'Lunes', 15, 'INV_2EGB', 'KARLA LAZCANO')
# ('2EGB', 'Amables', 'Lunes', 16, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Amables', 'Martes', 1, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amables', 'Martes', 2, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amables', 'Martes', 3, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amables', 'Martes', 4, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Amables', 'Martes', 6, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Amables', 'Martes', 7, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amables', 'Martes', 8, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amables', 'Martes', 9, 'DES_2EGB', 'MISHEL SALTOS')
# ('2EGB', 'Amables', 'Martes', 10, 'PLA_2EGB', 'LIZ DÍAZ')
# ('2EGB', 'Amables', 'Martes', 13, 'ROB_2EGB', 'DAVID CASTRO')
# ('2EGB', 'Amables', 'Martes', 14, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Amables', 'Miércoles', 3, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Amables', 'Miércoles', 4, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amables', 'Miércoles', 6, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amables', 'Miércoles', 7, 'ECO_2EGB', 'MARJURIE JÁCOME')
# ('2EGB', 'Amables', 'Miércoles', 8, 'SAL_2EGB', 'VANESSA ESPÍN')
# ('2EGB', 'Amables', 'Miércoles', 9, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amables', 'Miércoles', 10, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Amables', 'Miércoles', 13, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amables', 'Miércoles', 14, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Amables', 'Miércoles', 15, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amables', 'Miércoles', 16, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Amables', 'Jueves', 1, 'SOC_2EGB', 'ALBITA QUILLUPANGUI')
# ('2EGB', 'Amables', 'Jueves', 2, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Amables', 'Jueves', 3, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amables', 'Jueves', 4, 'PRO_2EGB', 'LUDWIN GUALOTUÑA')
# ('2EGB', 'Amables', 'Jueves', 6, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amables', 'Jueves', 7, 'SOC_2EGB', 'ALBITA QUILLUPANGUI')
# ('2EGB', 'Amables', 'Jueves', 8, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amables', 'Jueves', 9, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amables', 'Jueves', 10, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amables', 'Jueves', 13, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Amables', 'Jueves', 14, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amables', 'Viernes', 1, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amables', 'Viernes', 2, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amables', 'Viernes', 3, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amables', 'Viernes', 4, 'EDU_2EGB', 'EF ESPECIAL')
# ('2EGB', 'Amables', 'Viernes', 6, 'MUS_2EGB', 'LUIS JÁCOME')
# ('2EGB', 'Amables', 'Viernes', 7, 'DAN_2EGB', 'PAOLA LÓPEZ')
# ('2EGB', 'Amables', 'Viernes', 8, 'DER_2EGB', 'CORALÍA CÓRDOVA')
# ('2EGB', 'Amables', 'Viernes', 9, 'COM_2EGB', 'ERIKA CAIZATOA')
# ('2EGB', 'Amables', 'Viernes', 10, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amables', 'Viernes', 13, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Amables', 'Viernes', 14, 'ROB_2EGB', 'DAVID CASTRO')
# ('2EGB', 'Amables', 'Viernes', 15, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amables', 'Viernes', 16, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amigables', 'Lunes', 1, 'PLA_2EGB', 'LIZ DÍAZ')
# ('2EGB', 'Amigables', 'Lunes', 2, 'SPE_2EGB', 'CHRISTIAN SOLANO')
# ('2EGB', 'Amigables', 'Lunes', 3, 'INV_2EGB', 'KARLA LAZCANO')
# ('2EGB', 'Amigables', 'Lunes', 4, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Amigables', 'Lunes', 6, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amigables', 'Lunes', 7, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Amigables', 'Lunes', 8, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amigables', 'Lunes', 9, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amigables', 'Lunes', 10, 'EDU_2EGB', 'EF ESPECIAL')
# ('2EGB', 'Amigables', 'Lunes', 13, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Amigables', 'Lunes', 14, 'DAN_2EGB', 'PAOLA LÓPEZ')
# ('2EGB', 'Amigables', 'Lunes', 15, 'MUS_2EGB', 'LUIS JÁCOME')
# ('2EGB', 'Amigables', 'Lunes', 16, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amigables', 'Martes', 1, 'SOC_2EGB', 'ALBITA QUILLUPANGUI')
# ('2EGB', 'Amigables', 'Martes', 2, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amigables', 'Martes', 3, 'ROB_2EGB', 'DAVID CASTRO')
# ('2EGB', 'Amigables', 'Martes', 4, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Amigables', 'Martes', 6, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amigables', 'Martes', 7, 'DES_2EGB', 'MISHEL SALTOS')
# ('2EGB', 'Amigables', 'Martes', 8, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amigables', 'Martes', 9, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Amigables', 'Martes', 10, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amigables', 'Martes', 13, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amigables', 'Martes', 14, 'PRO_2EGB', 'LUDWIN GUALOTUÑA')
# ('2EGB', 'Amigables', 'Miércoles', 3, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Amigables', 'Miércoles', 4, 'SOC_2EGB', 'ALBITA QUILLUPANGUI')
# ('2EGB', 'Amigables', 'Miércoles', 6, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Amigables', 'Miércoles', 7, 'SAL_2EGB', 'VANESSA ESPÍN')
# ('2EGB', 'Amigables', 'Miércoles', 8, 'ECO_2EGB', 'MARJURIE JÁCOME')
# ('2EGB', 'Amigables', 'Miércoles', 9, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amigables', 'Miércoles', 10, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amigables', 'Miércoles', 13, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amigables', 'Miércoles', 14, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amigables', 'Miércoles', 15, 'EDU_2EGB', 'EF ESPECIAL')
# ('2EGB', 'Amigables', 'Miércoles', 16, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Amigables', 'Jueves', 1, 'DES_2EGB', 'MISHEL SALTOS')
# ('2EGB', 'Amigables', 'Jueves', 2, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amigables', 'Jueves', 3, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Amigables', 'Jueves', 4, 'PLA_2EGB', 'LIZ DÍAZ')
# ('2EGB', 'Amigables', 'Jueves', 6, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amigables', 'Jueves', 7, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Amigables', 'Jueves', 8, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amigables', 'Jueves', 9, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Amigables', 'Jueves', 10, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amigables', 'Jueves', 13, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amigables', 'Jueves', 14, 'ROB_2EGB', 'DAVID CASTRO')
# ('2EGB', 'Amigables', 'Viernes', 1, 'CAL_2EGB', 'JAIR CRIOLLO')
# ('2EGB', 'Amigables', 'Viernes', 2, 'EXP_2EGB', 'JOSÉ LUIS HERNÁNDEZ')
# ('2EGB', 'Amigables', 'Viernes', 3, 'SOC_2EGB', 'ALBITA QUILLUPANGUI')
# ('2EGB', 'Amigables', 'Viernes', 4, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amigables', 'Viernes', 6, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amigables', 'Viernes', 7, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amigables', 'Viernes', 8, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amigables', 'Viernes', 9, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amigables', 'Viernes', 10, 'PRO_2EGB', 'LUDWIN GUALOTUÑA')
# ('2EGB', 'Amigables', 'Viernes', 13, 'DER_2EGB', 'CORALÍA CÓRDOVA')
# ('2EGB', 'Amigables', 'Viernes', 14, 'COM_2EGB', 'ERIKA CAIZATOA')
# ('2EGB', 'Amigables', 'Viernes', 15, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amigables', 'Viernes', 16, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Amistosos', 'Lunes', 1, 'ROB_2EGB', 'DAVID CASTRO')
# ('2EGB', 'Amistosos', 'Lunes', 2, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amistosos', 'Lunes', 3, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amistosos', 'Lunes', 4, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Amistosos', 'Lunes', 6, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amistosos', 'Lunes', 7, 'DES_2EGB', 'MISHEL SALTOS')
# ('2EGB', 'Amistosos', 'Lunes', 8, 'PLA_2EGB', 'LIZ DÍAZ')
# ('2EGB', 'Amistosos', 'Lunes', 9, 'SOC_2EGB', 'ALBITA QUILLUPANGUI')
# ('2EGB', 'Amistosos', 'Lunes', 10, 'SOC_2EGB', 'ALBITA QUILLUPANGUI')
# ('2EGB', 'Amistosos', 'Lunes', 13, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Amistosos', 'Lunes', 14, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amistosos', 'Lunes', 15, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amistosos', 'Lunes', 16, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Amistosos', 'Martes', 1, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amistosos', 'Martes', 2, 'EXP_2EGB', 'JOSÉ LUIS HERNÁNDEZ')
# ('2EGB', 'Amistosos', 'Martes', 3, 'CAL_2EGB', 'JAIR CRIOLLO')
# ('2EGB', 'Amistosos', 'Martes', 4, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amistosos', 'Martes', 6, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amistosos', 'Martes', 7, 'SPE_2EGB', 'CHRISTIAN SOLANO')
# ('2EGB', 'Amistosos', 'Martes', 8, 'INV_2EGB', 'KARLA LAZCANO')
# ('2EGB', 'Amistosos', 'Martes', 9, 'ROB_2EGB', 'DAVID CASTRO')
# ('2EGB', 'Amistosos', 'Martes', 10, 'EDU_2EGB', 'EF ESPECIAL')
# ('2EGB', 'Amistosos', 'Martes', 13, 'EDU_2EGB', 'EF ESPECIAL')
# ('2EGB', 'Amistosos', 'Martes', 14, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amistosos', 'Miércoles', 3, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Amistosos', 'Miércoles', 4, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amistosos', 'Miércoles', 6, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Amistosos', 'Miércoles', 7, 'SOC_2EGB', 'ALBITA QUILLUPANGUI')
# ('2EGB', 'Amistosos', 'Miércoles', 8, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amistosos', 'Miércoles', 9, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Amistosos', 'Miércoles', 10, 'PRO_2EGB', 'LUDWIN GUALOTUÑA')
# ('2EGB', 'Amistosos', 'Miércoles', 13, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Amistosos', 'Miércoles', 14, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Amistosos', 'Miércoles', 15, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amistosos', 'Miércoles', 16, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amistosos', 'Jueves', 1, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amistosos', 'Jueves', 2, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amistosos', 'Jueves', 3, 'CIE_2EGB', 'DIANA SÁNCHEZ')
# ('2EGB', 'Amistosos', 'Jueves', 4, 'DES_2EGB', 'MISHEL SALTOS')
# ('2EGB', 'Amistosos', 'Jueves', 6, 'MUS_2EGB', 'LUIS JÁCOME')
# ('2EGB', 'Amistosos', 'Jueves', 7, 'DAN_2EGB', 'PAOLA LÓPEZ')
# ('2EGB', 'Amistosos', 'Jueves', 8, 'PLA_2EGB', 'LIZ DÍAZ')
# ('2EGB', 'Amistosos', 'Jueves', 9, 'PRO_2EGB', 'LUDWIN GUALOTUÑA')
# ('2EGB', 'Amistosos', 'Jueves', 10, 'LEC_2EGB', 'ALISON PLAZA')
# ('2EGB', 'Amistosos', 'Jueves', 13, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amistosos', 'Jueves', 14, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amistosos', 'Viernes', 1, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amistosos', 'Viernes', 2, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Amistosos', 'Viernes', 3, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amistosos', 'Viernes', 4, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amistosos', 'Viernes', 6, 'SAL_2EGB', 'VANESSA ESPÍN')
# ('2EGB', 'Amistosos', 'Viernes', 7, 'ECO_2EGB', 'MARJURIE JÁCOME')
# ('2EGB', 'Amistosos', 'Viernes', 8, 'DER_2EGB', 'CORALÍA CÓRDOVA')
# ('2EGB', 'Amistosos', 'Viernes', 9, 'COM_2EGB', 'ERIKA CAIZATOA')
# ('2EGB', 'Amistosos', 'Viernes', 10, 'MAT_2EGB', 'DINA TOPÓN')
# ('2EGB', 'Amistosos', 'Viernes', 13, 'NAT_2EGB', 'MARIANA HIDALGO')
# ('2EGB', 'Amistosos', 'Viernes', 14, 'ING_2EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('2EGB', 'Amistosos', 'Viernes', 15, 'LEN_2EGB', 'SOFÍA YÉPEZ')
# ('2EGB', 'Amistosos', 'Viernes', 16, 'MAT_2EGB', 'DINA TOPÓN')
# ('3EGB', 'Colaboradores', 'Lunes', 1, 'SOC_3EGB', 'ALBITA QUILLUPANGUI')
# ('3EGB', 'Colaboradores', 'Lunes', 2, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Colaboradores', 'Lunes', 3, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Colaboradores', 'Lunes', 4, 'PLA_3EGB', 'LIZ DÍAZ')
# ('3EGB', 'Colaboradores', 'Lunes', 6, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Colaboradores', 'Lunes', 7, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Colaboradores', 'Lunes', 8, 'ROB_3EGB', 'DAVID CASTRO')
# ('3EGB', 'Colaboradores', 'Lunes', 9, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Colaboradores', 'Lunes', 10, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Colaboradores', 'Lunes', 13, 'MUS_3EGB', 'LUIS JÁCOME')
# ('3EGB', 'Colaboradores', 'Lunes', 14, 'DAN_3EGB', 'PAOLA LÓPEZ')
# ('3EGB', 'Colaboradores', 'Lunes', 15, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Colaboradores', 'Lunes', 16, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Colaboradores', 'Martes', 1, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Colaboradores', 'Martes', 2, 'PLA_3EGB', 'LIZ DÍAZ')
# ('3EGB', 'Colaboradores', 'Martes', 3, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Colaboradores', 'Martes', 4, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Colaboradores', 'Martes', 6, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Colaboradores', 'Martes', 7, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Colaboradores', 'Martes', 8, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Colaboradores', 'Martes', 9, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Colaboradores', 'Martes', 10, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Colaboradores', 'Martes', 13, 'DES_3EGB', 'MISHEL SALTOS')
# ('3EGB', 'Colaboradores', 'Martes', 14, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Colaboradores', 'Miércoles', 3, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Colaboradores', 'Miércoles', 4, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Colaboradores', 'Miércoles', 6, 'EXP_3EGB', 'JOSÉ LUIS HERNÁNDEZ')
# ('3EGB', 'Colaboradores', 'Miércoles', 7, 'CAL_3EGB', 'JAIR CRIOLLO')
# ('3EGB', 'Colaboradores', 'Miércoles', 8, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Colaboradores', 'Miércoles', 9, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Colaboradores', 'Miércoles', 10, 'SOC_3EGB', 'ALBITA QUILLUPANGUI')
# ('3EGB', 'Colaboradores', 'Miércoles', 13, 'EDU_3EGB', 'EF ESPECIAL')
# ('3EGB', 'Colaboradores', 'Miércoles', 14, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Colaboradores', 'Miércoles', 15, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Colaboradores', 'Miércoles', 16, 'DES_3EGB', 'MISHEL SALTOS')
# ('3EGB', 'Colaboradores', 'Jueves', 1, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Colaboradores', 'Jueves', 2, 'SAL_3EGB', 'VANESSA ESPÍN')
# ('3EGB', 'Colaboradores', 'Jueves', 3, 'ECO_3EGB', 'MARJURIE JÁCOME')
# ('3EGB', 'Colaboradores', 'Jueves', 4, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Colaboradores', 'Jueves', 6, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Colaboradores', 'Jueves', 7, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Colaboradores', 'Jueves', 8, 'SPE_3EGB', 'CHRISTIAN SOLANO')
# ('3EGB', 'Colaboradores', 'Jueves', 9, 'INV_3EGB', 'KARLA LAZCANO')
# ('3EGB', 'Colaboradores', 'Jueves', 10, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Colaboradores', 'Jueves', 13, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Colaboradores', 'Jueves', 14, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Colaboradores', 'Viernes', 1, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Colaboradores', 'Viernes', 2, 'COM_3EGB', 'ERIKA CAIZATOA')
# ('3EGB', 'Colaboradores', 'Viernes', 3, 'DER_3EGB', 'CORALÍA CÓRDOVA')
# ('3EGB', 'Colaboradores', 'Viernes', 4, 'PRO_3EGB', 'LUDWIN GUALOTUÑA')
# ('3EGB', 'Colaboradores', 'Viernes', 6, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Colaboradores', 'Viernes', 7, 'SOC_3EGB', 'ALBITA QUILLUPANGUI')
# ('3EGB', 'Colaboradores', 'Viernes', 8, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Colaboradores', 'Viernes', 9, 'ROB_3EGB', 'DAVID CASTRO')
# ('3EGB', 'Colaboradores', 'Viernes', 10, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Colaboradores', 'Viernes', 13, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Colaboradores', 'Viernes', 14, 'PRO_3EGB', 'LUDWIN GUALOTUÑA')
# ('3EGB', 'Colaboradores', 'Viernes', 15, 'EDU_3EGB', 'EF ESPECIAL')
# ('3EGB', 'Colaboradores', 'Viernes', 16, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Conciliadores', 'Lunes', 1, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Conciliadores', 'Lunes', 2, 'INV_3EGB', 'KARLA LAZCANO')
# ('3EGB', 'Conciliadores', 'Lunes', 3, 'SPE_3EGB', 'CHRISTIAN SOLANO')
# ('3EGB', 'Conciliadores', 'Lunes', 4, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Conciliadores', 'Lunes', 6, 'DER_3EGB', 'CORALÍA CÓRDOVA')
# ('3EGB', 'Conciliadores', 'Lunes', 7, 'COM_3EGB', 'ERIKA CAIZATOA')
# ('3EGB', 'Conciliadores', 'Lunes', 8, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Conciliadores', 'Lunes', 9, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Conciliadores', 'Lunes', 10, 'ROB_3EGB', 'DAVID CASTRO')
# ('3EGB', 'Conciliadores', 'Lunes', 13, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Conciliadores', 'Lunes', 14, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Conciliadores', 'Lunes', 15, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Conciliadores', 'Lunes', 16, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Conciliadores', 'Martes', 1, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Conciliadores', 'Martes', 2, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Conciliadores', 'Martes', 3, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Conciliadores', 'Martes', 4, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Conciliadores', 'Martes', 6, 'SOC_3EGB', 'ALBITA QUILLUPANGUI')
# ('3EGB', 'Conciliadores', 'Martes', 7, 'ECO_3EGB', 'MARJURIE JÁCOME')
# ('3EGB', 'Conciliadores', 'Martes', 8, 'SAL_3EGB', 'VANESSA ESPÍN')
# ('3EGB', 'Conciliadores', 'Martes', 9, 'SOC_3EGB', 'ALBITA QUILLUPANGUI')
# ('3EGB', 'Conciliadores', 'Martes', 10, 'SOC_3EGB', 'ALBITA QUILLUPANGUI')
# ('3EGB', 'Conciliadores', 'Martes', 13, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Conciliadores', 'Martes', 14, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Conciliadores', 'Miércoles', 3, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Conciliadores', 'Miércoles', 4, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Conciliadores', 'Miércoles', 6, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Conciliadores', 'Miércoles', 7, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Conciliadores', 'Miércoles', 8, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Conciliadores', 'Miércoles', 9, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Conciliadores', 'Miércoles', 10, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Conciliadores', 'Miércoles', 13, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Conciliadores', 'Miércoles', 14, 'EXP_3EGB', 'JOSÉ LUIS HERNÁNDEZ')
# ('3EGB', 'Conciliadores', 'Miércoles', 15, 'CAL_3EGB', 'JAIR CRIOLLO')
# ('3EGB', 'Conciliadores', 'Miércoles', 16, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Conciliadores', 'Jueves', 1, 'PRO_3EGB', 'LUDWIN GUALOTUÑA')
# ('3EGB', 'Conciliadores', 'Jueves', 2, 'EDU_3EGB', 'EF ESPECIAL')
# ('3EGB', 'Conciliadores', 'Jueves', 3, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Conciliadores', 'Jueves', 4, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Conciliadores', 'Jueves', 6, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Conciliadores', 'Jueves', 7, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Conciliadores', 'Jueves', 8, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Conciliadores', 'Jueves', 9, 'DES_3EGB', 'MISHEL SALTOS')
# ('3EGB', 'Conciliadores', 'Jueves', 10, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Conciliadores', 'Jueves', 13, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Conciliadores', 'Jueves', 14, 'PRO_3EGB', 'LUDWIN GUALOTUÑA')
# ('3EGB', 'Conciliadores', 'Viernes', 1, 'DAN_3EGB', 'PAOLA LÓPEZ')
# ('3EGB', 'Conciliadores', 'Viernes', 2, 'MUS_3EGB', 'LUIS JÁCOME')
# ('3EGB', 'Conciliadores', 'Viernes', 3, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Conciliadores', 'Viernes', 4, 'ROB_3EGB', 'DAVID CASTRO')
# ('3EGB', 'Conciliadores', 'Viernes', 6, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Conciliadores', 'Viernes', 7, 'DES_3EGB', 'MISHEL SALTOS')
# ('3EGB', 'Conciliadores', 'Viernes', 8, 'PLA_3EGB', 'LIZ DÍAZ')
# ('3EGB', 'Conciliadores', 'Viernes', 9, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Conciliadores', 'Viernes', 10, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Conciliadores', 'Viernes', 13, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Conciliadores', 'Viernes', 14, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Conciliadores', 'Viernes', 15, 'PLA_3EGB', 'LIZ DÍAZ')
# ('3EGB', 'Conciliadores', 'Viernes', 16, 'EDU_3EGB', 'EF ESPECIAL')
# ('3EGB', 'Cordiales', 'Lunes', 1, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Cordiales', 'Lunes', 2, 'SAL_3EGB', 'VANESSA ESPÍN')
# ('3EGB', 'Cordiales', 'Lunes', 3, 'ECO_3EGB', 'MARJURIE JÁCOME')
# ('3EGB', 'Cordiales', 'Lunes', 4, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Cordiales', 'Lunes', 6, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Cordiales', 'Lunes', 7, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Cordiales', 'Lunes', 8, 'SOC_3EGB', 'ALBITA QUILLUPANGUI')
# ('3EGB', 'Cordiales', 'Lunes', 9, 'ROB_3EGB', 'DAVID CASTRO')
# ('3EGB', 'Cordiales', 'Lunes', 10, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Cordiales', 'Lunes', 13, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Cordiales', 'Lunes', 14, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Cordiales', 'Lunes', 15, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Cordiales', 'Lunes', 16, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Cordiales', 'Martes', 1, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Cordiales', 'Martes', 2, 'EDU_3EGB', 'EF ESPECIAL')
# ('3EGB', 'Cordiales', 'Martes', 3, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Cordiales', 'Martes', 4, 'PRO_3EGB', 'LUDWIN GUALOTUÑA')
# ('3EGB', 'Cordiales', 'Martes', 6, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Cordiales', 'Martes', 7, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Cordiales', 'Martes', 8, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Cordiales', 'Martes', 9, 'PLA_3EGB', 'LIZ DÍAZ')
# ('3EGB', 'Cordiales', 'Martes', 10, 'ROB_3EGB', 'DAVID CASTRO')
# ('3EGB', 'Cordiales', 'Martes', 13, 'EDU_3EGB', 'EF ESPECIAL')
# ('3EGB', 'Cordiales', 'Martes', 14, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Cordiales', 'Miércoles', 3, 'PRO_3EGB', 'LUDWIN GUALOTUÑA')
# ('3EGB', 'Cordiales', 'Miércoles', 4, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Cordiales', 'Miércoles', 6, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Cordiales', 'Miércoles', 7, 'PLA_3EGB', 'LIZ DÍAZ')
# ('3EGB', 'Cordiales', 'Miércoles', 8, 'DAN_3EGB', 'PAOLA LÓPEZ')
# ('3EGB', 'Cordiales', 'Miércoles', 9, 'MUS_3EGB', 'LUIS JÁCOME')
# ('3EGB', 'Cordiales', 'Miércoles', 10, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Cordiales', 'Miércoles', 13, 'DES_3EGB', 'MISHEL SALTOS')
# ('3EGB', 'Cordiales', 'Miércoles', 14, 'SPE_3EGB', 'CHRISTIAN SOLANO')
# ('3EGB', 'Cordiales', 'Miércoles', 15, 'INV_3EGB', 'KARLA LAZCANO')
# ('3EGB', 'Cordiales', 'Miércoles', 16, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Cordiales', 'Jueves', 1, 'CAL_3EGB', 'JAIR CRIOLLO')
# ('3EGB', 'Cordiales', 'Jueves', 2, 'EXP_3EGB', 'JOSÉ LUIS HERNÁNDEZ')
# ('3EGB', 'Cordiales', 'Jueves', 3, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Cordiales', 'Jueves', 4, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Cordiales', 'Jueves', 6, 'DER_3EGB', 'CORALÍA CÓRDOVA')
# ('3EGB', 'Cordiales', 'Jueves', 7, 'COM_3EGB', 'ERIKA CAIZATOA')
# ('3EGB', 'Cordiales', 'Jueves', 8, 'SOC_3EGB', 'ALBITA QUILLUPANGUI')
# ('3EGB', 'Cordiales', 'Jueves', 9, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Cordiales', 'Jueves', 10, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Cordiales', 'Jueves', 13, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Cordiales', 'Jueves', 14, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Cordiales', 'Viernes', 1, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Cordiales', 'Viernes', 2, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Cordiales', 'Viernes', 3, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Cordiales', 'Viernes', 4, 'DES_3EGB', 'MISHEL SALTOS')
# ('3EGB', 'Cordiales', 'Viernes', 6, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Cordiales', 'Viernes', 7, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Cordiales', 'Viernes', 8, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Cordiales', 'Viernes', 9, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Cordiales', 'Viernes', 10, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Cordiales', 'Viernes', 13, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Cordiales', 'Viernes', 14, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Cordiales', 'Viernes', 15, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Cordiales', 'Viernes', 16, 'SOC_3EGB', 'ALBITA QUILLUPANGUI')
# ('3EGB', 'Creativos', 'Lunes', 1, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Creativos', 'Lunes', 2, 'COM_3EGB', 'ERIKA CAIZATOA')
# ('3EGB', 'Creativos', 'Lunes', 3, 'DER_3EGB', 'CORALÍA CÓRDOVA')
# ('3EGB', 'Creativos', 'Lunes', 4, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Creativos', 'Lunes', 6, 'EDU_3EGB', 'EF ESPECIAL')
# ('3EGB', 'Creativos', 'Lunes', 7, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Creativos', 'Lunes', 8, 'EDU_3EGB', 'EF ESPECIAL')
# ('3EGB', 'Creativos', 'Lunes', 9, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Creativos', 'Lunes', 10, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Creativos', 'Lunes', 13, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Creativos', 'Lunes', 14, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Creativos', 'Lunes', 15, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Creativos', 'Lunes', 16, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Creativos', 'Martes', 1, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Creativos', 'Martes', 2, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Creativos', 'Martes', 3, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Creativos', 'Martes', 4, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Creativos', 'Martes', 6, 'SOC_3EGB', 'ALBITA QUILLUPANGUI')
# ('3EGB', 'Creativos', 'Martes', 7, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Creativos', 'Martes', 8, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Creativos', 'Martes', 9, 'SOC_3EGB', 'ALBITA QUILLUPANGUI')
# ('3EGB', 'Creativos', 'Martes', 10, 'PLA_3EGB', 'LIZ DÍAZ')
# ('3EGB', 'Creativos', 'Martes', 13, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Creativos', 'Martes', 14, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Creativos', 'Miércoles', 3, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Creativos', 'Miércoles', 4, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Creativos', 'Miércoles', 6, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Creativos', 'Miércoles', 7, 'MUS_3EGB', 'LUIS JÁCOME')
# ('3EGB', 'Creativos', 'Miércoles', 8, 'DAN_3EGB', 'PAOLA LÓPEZ')
# ('3EGB', 'Creativos', 'Miércoles', 9, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Creativos', 'Miércoles', 10, 'PRO_3EGB', 'LUDWIN GUALOTUÑA')
# ('3EGB', 'Creativos', 'Miércoles', 13, 'EXP_3EGB', 'JOSÉ LUIS HERNÁNDEZ')
# ('3EGB', 'Creativos', 'Miércoles', 14, 'CAL_3EGB', 'JAIR CRIOLLO')
# ('3EGB', 'Creativos', 'Miércoles', 15, 'LEN_3EGB', 'SOFÍA YÉPEZ')
# ('3EGB', 'Creativos', 'Miércoles', 16, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Creativos', 'Jueves', 1, 'SPE_3EGB', 'CHRISTIAN SOLANO')
# ('3EGB', 'Creativos', 'Jueves', 2, 'INV_3EGB', 'KARLA LAZCANO')
# ('3EGB', 'Creativos', 'Jueves', 3, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Creativos', 'Jueves', 4, 'DES_3EGB', 'MISHEL SALTOS')
# ('3EGB', 'Creativos', 'Jueves', 6, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Creativos', 'Jueves', 7, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Creativos', 'Jueves', 8, 'SOC_3EGB', 'ALBITA QUILLUPANGUI')
# ('3EGB', 'Creativos', 'Jueves', 9, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Creativos', 'Jueves', 10, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Creativos', 'Jueves', 13, 'LEC_3EGB', 'ALISON PLAZA')
# ('3EGB', 'Creativos', 'Jueves', 14, 'ROB_3EGB', 'DAVID CASTRO')
# ('3EGB', 'Creativos', 'Viernes', 1, 'ROB_3EGB', 'DAVID CASTRO')
# ('3EGB', 'Creativos', 'Viernes', 2, 'PLA_3EGB', 'LIZ DÍAZ')
# ('3EGB', 'Creativos', 'Viernes', 3, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Creativos', 'Viernes', 4, 'DES_3EGB', 'MISHEL SALTOS')
# ('3EGB', 'Creativos', 'Viernes', 6, 'NAT_3EGB', 'MARIANA HIDALGO')
# ('3EGB', 'Creativos', 'Viernes', 7, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Creativos', 'Viernes', 8, 'ECO_3EGB', 'MARJURIE JÁCOME')
# ('3EGB', 'Creativos', 'Viernes', 9, 'SAL_3EGB', 'VANESSA ESPÍN')
# ('3EGB', 'Creativos', 'Viernes', 10, 'PRO_3EGB', 'LUDWIN GUALOTUÑA')
# ('3EGB', 'Creativos', 'Viernes', 13, 'ING_3EGB', 'SOLEDAD REVELO')
# ('3EGB', 'Creativos', 'Viernes', 14, 'MAT_3EGB', 'MARCIA HERRERA')
# ('3EGB', 'Creativos', 'Viernes', 15, 'PEN_3EGB', 'XIMENA AGUIRRE')
# ('3EGB', 'Creativos', 'Viernes', 16, 'MAT_3EGB', 'MARCIA HERRERA')
# ('4EGB', 'Optimistas', 'Lunes', 1, 'PLA_4EGB', 'LIZ DÍAZ')
# ('4EGB', 'Optimistas', 'Lunes', 2, 'LEN_4EGB', 'ROSITA ALBUJA')
# ('4EGB', 'Optimistas', 'Lunes', 3, 'INV_4EGB', 'KARLA LAZCANO')
# ('4EGB', 'Optimistas', 'Lunes', 4, 'SPE_4EGB', 'CHRISTIAN SOLANO')
# ('4EGB', 'Optimistas', 'Lunes', 5, 'NAT_4EGB', 'DIANA SÁNCHEZ')
# ('4EGB', 'Optimistas', 'Lunes', 7, 'NAT_4EGB', 'DIANA SÁNCHEZ')
# ('4EGB', 'Optimistas', 'Lunes', 8, 'ECO_4EGB', 'MARJURIE JÁCOME')
# ('4EGB', 'Optimistas', 'Lunes', 9, 'SAL_4EGB', 'VANESSA ESPÍN')
# ('4EGB', 'Optimistas', 'Lunes', 10, 'DES_4EGB', 'MISHEL SALTOS')
# ('4EGB', 'Optimistas', 'Lunes', 13, 'PEN_4EGB', 'XIMENA AGUIRRE')
# ('4EGB', 'Optimistas', 'Lunes', 14, 'MAT_4EGB', 'PATY ARIAS')
# ('4EGB', 'Optimistas', 'Lunes', 15, 'PEN_4EGB', 'XIMENA AGUIRRE')
# ('4EGB', 'Optimistas', 'Lunes', 16, 'LEC_4EGB', 'ANITA ARROBA')
# ('4EGB', 'Optimistas', 'Martes', 1, 'ING_4EGB', 'SOLEDAD REVELO')
# ('4EGB', 'Optimistas', 'Martes', 2, 'CAL_4EGB', 'JAIR CRIOLLO')
# ...
# ('2BGU', 'Justos', 'Viernes', 12, 'EDU_2BGU', 'EF ESPECIAL')
# ('2BGU', 'Proactivos', 'Lunes', 1, 'CIU_2BGU', None)
# ('2BGU', 'Proactivos', 'Lunes', 2, 'FIS_2BGU', 'JOSÉ NICOLALDE')
# ('2BGU', 'Proactivos', 'Lunes', 3, 'ING_2BGU', 'INGLES ESPECIAL')
# ('2BGU', 'Proactivos', 'Lunes', 4, 'ING_2BGU', 'INGLES ESPECIAL')
# ('2BGU', 'Proactivos', 'Lunes', 5, 'QUI_2BGU', 'MAYRA QUISHPE')
# ('2BGU', 'Proactivos', 'Lunes', 7, 'EDU_2BGU', 'EF ESPECIAL')
# ('2BGU', 'Proactivos', 'Lunes', 8, 'DER_2BGU', 'CORALÍA CÓRDOVA')
# ('2BGU', 'Proactivos', 'Lunes', 9, 'COM_2BGU', 'ERIKA CAIZATOA')
# ('2BGU', 'Proactivos', 'Lunes', 10, 'EMP_2BGU', 'MARÍA BELÉN MALDONADO')
# ('2BGU', 'Proactivos', 'Lunes', 11, 'EST_2BGU', 'JONATHAN CASTRO')
# ('2BGU', 'Proactivos', 'Lunes', 12, 'PEN_2BGU', 'ANITA BARRENO')
# ('2BGU', 'Proactivos', 'Lunes', 15, 'GEO_2BGU', 'LEONARDO ESPINOSA')
# ('2BGU', 'Proactivos', 'Lunes', 16, 'DES_2BGU', 'JANETH MELO')
# ('2BGU', 'Proactivos', 'Martes', 1, 'LEC_2BGU', 'PATY FLORES')
# ('2BGU', 'Proactivos', 'Martes', 2, 'ING_2BGU', 'INGLES ESPECIAL')
# ('2BGU', 'Proactivos', 'Martes', 3, 'ING_2BGU', 'INGLES ESPECIAL')
# ('2BGU', 'Proactivos', 'Martes', 4, 'LEC_2BGU', 'PATY FLORES')
# ('2BGU', 'Proactivos', 'Martes', 5, 'MAT_2BGU', 'ISAAC NÚÑEZ')
# ('2BGU', 'Proactivos', 'Martes', 7, 'LEN_2BGU', 'ANDRÉS OLMEDO')
# ('2BGU', 'Proactivos', 'Martes', 8, 'PRO_2BGU', 'MARCO SAFADI')
# ('2BGU', 'Proactivos', 'Martes', 9, 'PLA_2BGU', 'KEVIN VICENTE')
# ('2BGU', 'Proactivos', 'Martes', 10, 'SOC_2BGU', 'ISABEL GARCÍA')
# ('2BGU', 'Proactivos', 'Martes', 11, 'FIS_2BGU', 'JOSÉ NICOLALDE')
# ('2BGU', 'Proactivos', 'Martes', 12, 'FIS_2BGU', 'JOSÉ NICOLALDE')
# ('2BGU', 'Proactivos', 'Martes', 15, 'QUI_2BGU', 'MAYRA QUISHPE')
# ('2BGU', 'Proactivos', 'Martes', 16, 'PLA_2BGU', 'KEVIN VICENTE')
# ('2BGU', 'Proactivos', 'Miércoles', 3, 'ROB_2BGU', 'DAVID RÓGEL')
# ('2BGU', 'Proactivos', 'Miércoles', 4, 'PRO_2BGU', 'MARCO SAFADI')
# ('2BGU', 'Proactivos', 'Miércoles', 5, 'FIS_2BGU', 'JOSÉ NICOLALDE')
# ('2BGU', 'Proactivos', 'Miércoles', 7, 'DES_2BGU', 'JANETH MELO')
# ('2BGU', 'Proactivos', 'Miércoles', 8, 'ING_2BGU', 'INGLES ESPECIAL')
# ('2BGU', 'Proactivos', 'Miércoles', 9, 'ING_2BGU', 'INGLES ESPECIAL')
# ('2BGU', 'Proactivos', 'Miércoles', 10, 'SPE_2BGU', 'CHRISTIAN SOLANO')
# ('2BGU', 'Proactivos', 'Miércoles', 11, 'INV_2BGU', 'KARLA LAZCANO')
# ('2BGU', 'Proactivos', 'Miércoles', 12, 'NAT_2BGU', 'CARLOS BENALCÁZAR')
# ('2BGU', 'Proactivos', 'Jueves', 1, 'QUI_2BGU', 'MAYRA QUISHPE')
# ('2BGU', 'Proactivos', 'Jueves', 2, 'ROB_2BGU', 'DAVID RÓGEL')
# ('2BGU', 'Proactivos', 'Jueves', 3, 'PEN_2BGU', 'ANITA BARRENO')
# ('2BGU', 'Proactivos', 'Jueves', 4, 'GEO_2BGU', 'LEONARDO ESPINOSA')
# ('2BGU', 'Proactivos', 'Jueves', 5, 'GEO_2BGU', 'LEONARDO ESPINOSA')
# ('2BGU', 'Proactivos', 'Jueves', 7, 'MAT_2BGU', 'ISAAC NÚÑEZ')
# ('2BGU', 'Proactivos', 'Jueves', 8, 'EDU_2BGU', 'EF ESPECIAL')
# ('2BGU', 'Proactivos', 'Jueves', 9, 'MAT_2BGU', 'ISAAC NÚÑEZ')
# ('2BGU', 'Proactivos', 'Jueves', 10, 'LEN_2BGU', 'ANDRÉS OLMEDO')
# ('2BGU', 'Proactivos', 'Jueves', 11, 'MAT_2BGU', 'ISAAC NÚÑEZ')
# ('2BGU', 'Proactivos', 'Jueves', 12, 'EMP_2BGU', 'MARÍA BELÉN MALDONADO')
# ('2BGU', 'Proactivos', 'Jueves', 15, 'LEC_2BGU', 'PATY FLORES')
# ('2BGU', 'Proactivos', 'Jueves', 16, 'MAT_2BGU', 'ISAAC NÚÑEZ')
# ('2BGU', 'Proactivos', 'Viernes', 1, 'SOC_2BGU', 'ISABEL GARCÍA')
# ('2BGU', 'Proactivos', 'Viernes', 2, 'EST_2BGU', 'JONATHAN CASTRO')
# ('2BGU', 'Proactivos', 'Viernes', 3, 'SOC_2BGU', 'ISABEL GARCÍA')
# ('2BGU', 'Proactivos', 'Viernes', 4, 'NAT_2BGU', 'CARLOS BENALCÁZAR')
# ('2BGU', 'Proactivos', 'Viernes', 5, 'PEN_2BGU', 'ANITA BARRENO')
# ('2BGU', 'Proactivos', 'Viernes', 7, 'MAT_2BGU', 'ISAAC NÚÑEZ')
# ('2BGU', 'Proactivos', 'Viernes', 8, 'QUI_2BGU', 'MAYRA QUISHPE')
# ('2BGU', 'Proactivos', 'Viernes', 9, 'NAT_2BGU', 'CARLOS BENALCÁZAR')
# ('2BGU', 'Proactivos', 'Viernes', 10, 'SAL_2BGU', 'VANESSA ESPÍN')
# ('2BGU', 'Proactivos', 'Viernes', 11, 'ECO_2BGU', 'MARJURIE JÁCOME')
# ('2BGU', 'Proactivos', 'Viernes', 12, 'SOC_2BGU', 'ISABEL GARCÍA')
# ('3BGU', 'Empáticos', 'Lunes', 1, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Empáticos', 'Lunes', 2, 'LEN_3BGU', 'ANDRÉS OLMEDO')
# ('3BGU', 'Empáticos', 'Lunes', 3, 'QUI_3BGU', 'MAYRA QUISHPE')
# ('3BGU', 'Empáticos', 'Lunes', 4, 'SOC_3BGU', 'ISABEL GARCÍA')
# ('3BGU', 'Empáticos', 'Lunes', 5, 'PEN_3BGU', 'ANITA BARRENO')
# ('3BGU', 'Empáticos', 'Lunes', 7, 'INV_3BGU', 'KARLA LAZCANO')
# ('3BGU', 'Empáticos', 'Lunes', 8, 'SPE_3BGU', 'CHRISTIAN SOLANO')
# ('3BGU', 'Empáticos', 'Lunes', 9, 'SOC_3BGU', 'ISABEL GARCÍA')
# ('3BGU', 'Empáticos', 'Lunes', 10, 'FIS_3BGU', 'JOSÉ NICOLALDE')
# ('3BGU', 'Empáticos', 'Lunes', 11, 'FIS_3BGU', 'JOSÉ NICOLALDE')
# ('3BGU', 'Empáticos', 'Lunes', 12, 'FIS_3BGU', 'JOSÉ NICOLALDE')
# ('3BGU', 'Empáticos', 'Lunes', 15, 'ROB_3BGU', 'DAVID RÓGEL')
# ('3BGU', 'Empáticos', 'Lunes', 16, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Empáticos', 'Martes', 1, 'SOC_3BGU', 'ISABEL GARCÍA')
# ('3BGU', 'Empáticos', 'Martes', 2, 'EST_3BGU', 'JONATHAN CASTRO')
# ('3BGU', 'Empáticos', 'Martes', 3, 'EST_3BGU', 'JONATHAN CASTRO')
# ('3BGU', 'Empáticos', 'Martes', 4, 'NAT_3BGU', 'CARLOS BENALCÁZAR')
# ('3BGU', 'Empáticos', 'Martes', 5, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Empáticos', 'Martes', 7, 'NAT_3BGU', 'CARLOS BENALCÁZAR')
# ('3BGU', 'Empáticos', 'Martes', 8, 'EDU_3BGU', 'EF ESPECIAL')
# ('3BGU', 'Empáticos', 'Martes', 9, 'DES_3BGU', 'JANETH MELO')
# ('3BGU', 'Empáticos', 'Martes', 10, 'DES_3BGU', 'JANETH MELO')
# ('3BGU', 'Empáticos', 'Martes', 11, 'LEC_3BGU', 'PATY FLORES')
# ('3BGU', 'Empáticos', 'Martes', 12, 'PLA_3BGU', 'KEVIN VICENTE')
# ('3BGU', 'Empáticos', 'Martes', 15, 'LEC_3BGU', 'PATY FLORES')
# ('3BGU', 'Empáticos', 'Martes', 16, 'PEN_3BGU', 'ANITA BARRENO')
# ('3BGU', 'Empáticos', 'Miércoles', 3, 'LEN_3BGU', 'ANDRÉS OLMEDO')
# ('3BGU', 'Empáticos', 'Miércoles', 4, 'QUI_3BGU', 'MAYRA QUISHPE')
# ('3BGU', 'Empáticos', 'Miércoles', 5, 'PRO_3BGU', 'MARCO SAFADI')
# ('3BGU', 'Empáticos', 'Miércoles', 7, 'ECO_3BGU', 'MARJURIE JÁCOME')
# ('3BGU', 'Empáticos', 'Miércoles', 8, 'SAL_3BGU', 'VANESSA ESPÍN')
# ('3BGU', 'Empáticos', 'Miércoles', 9, 'ROB_3BGU', 'DAVID RÓGEL')
# ('3BGU', 'Empáticos', 'Miércoles', 10, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Empáticos', 'Miércoles', 11, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Empáticos', 'Miércoles', 12, 'EDU_3BGU', 'EF ESPECIAL')
# ('3BGU', 'Empáticos', 'Jueves', 1, 'LEN_3BGU', 'ANDRÉS OLMEDO')
# ('3BGU', 'Empáticos', 'Jueves', 2, 'NAT_3BGU', 'CARLOS BENALCÁZAR')
# ('3BGU', 'Empáticos', 'Jueves', 3, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Empáticos', 'Jueves', 4, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Empáticos', 'Jueves', 5, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Empáticos', 'Jueves', 7, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Empáticos', 'Jueves', 8, 'PLA_3BGU', 'KEVIN VICENTE')
# ('3BGU', 'Empáticos', 'Jueves', 9, 'FIS_3BGU', 'JOSÉ NICOLALDE')
# ('3BGU', 'Empáticos', 'Jueves', 10, 'QUI_3BGU', 'MAYRA QUISHPE')
# ('3BGU', 'Empáticos', 'Jueves', 11, 'PEN_3BGU', 'ANITA BARRENO')
# ('3BGU', 'Empáticos', 'Jueves', 12, 'LEC_3BGU', 'PATY FLORES')
# ('3BGU', 'Empáticos', 'Jueves', 15, 'EMP_3BGU', 'MARÍA BELÉN MALDONADO')
# ('3BGU', 'Empáticos', 'Jueves', 16, 'GEO_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Empáticos', 'Viernes', 1, 'GEO_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Empáticos', 'Viernes', 2, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Empáticos', 'Viernes', 3, 'COM_3BGU', 'ERIKA CAIZATOA')
# ('3BGU', 'Empáticos', 'Viernes', 4, 'DER_3BGU', 'CORALÍA CÓRDOVA')
# ('3BGU', 'Empáticos', 'Viernes', 5, 'QUI_3BGU', 'MAYRA QUISHPE')
# ('3BGU', 'Empáticos', 'Viernes', 7, 'EMP_3BGU', 'MARÍA BELÉN MALDONADO')
# ('3BGU', 'Empáticos', 'Viernes', 8, 'SOC_3BGU', 'ISABEL GARCÍA')
# ('3BGU', 'Empáticos', 'Viernes', 9, 'GEO_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Empáticos', 'Viernes', 10, 'PRO_3BGU', 'MARCO SAFADI')
# ('3BGU', 'Empáticos', 'Viernes', 11, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Empáticos', 'Viernes', 12, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Solidarios', 'Lunes', 1, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Solidarios', 'Lunes', 2, 'SOC_3BGU', 'ISABEL GARCÍA')
# ('3BGU', 'Solidarios', 'Lunes', 3, 'LEC_3BGU', 'PATY FLORES')
# ('3BGU', 'Solidarios', 'Lunes', 4, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Solidarios', 'Lunes', 5, 'LEN_3BGU', 'ANDRÉS OLMEDO')
# ('3BGU', 'Solidarios', 'Lunes', 7, 'SAL_3BGU', 'VANESSA ESPÍN')
# ('3BGU', 'Solidarios', 'Lunes', 8, 'ECO_3BGU', 'MARJURIE JÁCOME')
# ('3BGU', 'Solidarios', 'Lunes', 9, 'NAT_3BGU', 'CARLOS BENALCÁZAR')
# ('3BGU', 'Solidarios', 'Lunes', 10, 'DER_3BGU', 'CORALÍA CÓRDOVA')
# ('3BGU', 'Solidarios', 'Lunes', 11, 'COM_3BGU', 'ERIKA CAIZATOA')
# ('3BGU', 'Solidarios', 'Lunes', 12, 'PLA_3BGU', 'KEVIN VICENTE')
# ('3BGU', 'Solidarios', 'Lunes', 15, 'EMP_3BGU', 'MARÍA BELÉN MALDONADO')
# ('3BGU', 'Solidarios', 'Lunes', 16, 'ROB_3BGU', 'DAVID RÓGEL')
# ('3BGU', 'Solidarios', 'Martes', 1, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Solidarios', 'Martes', 2, 'EST_3BGU', 'JONATHAN CASTRO')
# ('3BGU', 'Solidarios', 'Martes', 3, 'EST_3BGU', 'JONATHAN CASTRO')
# ('3BGU', 'Solidarios', 'Martes', 4, 'EMP_3BGU', 'MARÍA BELÉN MALDONADO')
# ('3BGU', 'Solidarios', 'Martes', 5, 'PEN_3BGU', 'ANITA BARRENO')
# ('3BGU', 'Solidarios', 'Martes', 7, 'QUI_3BGU', 'MAYRA QUISHPE')
# ('3BGU', 'Solidarios', 'Martes', 8, 'FIS_3BGU', 'JOSÉ NICOLALDE')
# ('3BGU', 'Solidarios', 'Martes', 9, 'DES_3BGU', 'JANETH MELO')
# ('3BGU', 'Solidarios', 'Martes', 10, 'DES_3BGU', 'JANETH MELO')
# ('3BGU', 'Solidarios', 'Martes', 11, 'GEO_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Solidarios', 'Martes', 12, 'PEN_3BGU', 'ANITA BARRENO')
# ('3BGU', 'Solidarios', 'Martes', 15, 'PRO_3BGU', 'MARCO SAFADI')
# ('3BGU', 'Solidarios', 'Martes', 16, 'LEC_3BGU', 'PATY FLORES')
# ('3BGU', 'Solidarios', 'Miércoles', 3, 'FIS_3BGU', 'JOSÉ NICOLALDE')
# ('3BGU', 'Solidarios', 'Miércoles', 4, 'SOC_3BGU', 'ISABEL GARCÍA')
# ('3BGU', 'Solidarios', 'Miércoles', 5, 'SOC_3BGU', 'ISABEL GARCÍA')
# ('3BGU', 'Solidarios', 'Miércoles', 7, 'LEN_3BGU', 'ANDRÉS OLMEDO')
# ('3BGU', 'Solidarios', 'Miércoles', 8, 'ROB_3BGU', 'DAVID RÓGEL')
# ('3BGU', 'Solidarios', 'Miércoles', 9, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Solidarios', 'Miércoles', 10, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Solidarios', 'Miércoles', 11, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Solidarios', 'Miércoles', 12, 'EDU_3BGU', 'EF ESPECIAL')
# ('3BGU', 'Solidarios', 'Jueves', 1, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Solidarios', 'Jueves', 2, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Solidarios', 'Jueves', 3, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Solidarios', 'Jueves', 4, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Solidarios', 'Jueves', 5, 'PLA_3BGU', 'KEVIN VICENTE')
# ('3BGU', 'Solidarios', 'Jueves', 7, 'NAT_3BGU', 'CARLOS BENALCÁZAR')
# ('3BGU', 'Solidarios', 'Jueves', 8, 'LEC_3BGU', 'PATY FLORES')
# ('3BGU', 'Solidarios', 'Jueves', 9, 'INV_3BGU', 'KARLA LAZCANO')
# ('3BGU', 'Solidarios', 'Jueves', 10, 'SPE_3BGU', 'CHRISTIAN SOLANO')
# ('3BGU', 'Solidarios', 'Jueves', 11, 'GEO_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Solidarios', 'Jueves', 12, 'NAT_3BGU', 'CARLOS BENALCÁZAR')
# ('3BGU', 'Solidarios', 'Jueves', 15, 'PRO_3BGU', 'MARCO SAFADI')
# ('3BGU', 'Solidarios', 'Jueves', 16, 'FIS_3BGU', 'JOSÉ NICOLALDE')
# ('3BGU', 'Solidarios', 'Viernes', 1, 'QUI_3BGU', 'MAYRA QUISHPE')
# ('3BGU', 'Solidarios', 'Viernes', 2, 'PEN_3BGU', 'ANITA BARRENO')
# ('3BGU', 'Solidarios', 'Viernes', 3, 'EDU_3BGU', 'EF ESPECIAL')
# ('3BGU', 'Solidarios', 'Viernes', 4, 'LEN_3BGU', 'ANDRÉS OLMEDO')
# ('3BGU', 'Solidarios', 'Viernes', 5, 'SOC_3BGU', 'ISABEL GARCÍA')
# ('3BGU', 'Solidarios', 'Viernes', 7, 'GEO_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Solidarios', 'Viernes', 8, 'QUI_3BGU', 'MAYRA QUISHPE')
# ('3BGU', 'Solidarios', 'Viernes', 9, 'QUI_3BGU', 'MAYRA QUISHPE')
# ('3BGU', 'Solidarios', 'Viernes', 10, 'FIS_3BGU', 'JOSÉ NICOLALDE')
# ('3BGU', 'Solidarios', 'Viernes', 11, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Solidarios', 'Viernes', 12, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Vanguardistas', 'Lunes', 1, 'QUI_3BGU', 'MAYRA QUISHPE')
# ('3BGU', 'Vanguardistas', 'Lunes', 2, 'PRO_3BGU', 'MARCO SAFADI')
# ('3BGU', 'Vanguardistas', 'Lunes', 3, 'FIS_3BGU', 'JOSÉ NICOLALDE')
# ('3BGU', 'Vanguardistas', 'Lunes', 4, 'PLA_3BGU', 'KEVIN VICENTE')
# ('3BGU', 'Vanguardistas', 'Lunes', 5, 'FIS_3BGU', 'JOSÉ NICOLALDE')
# ('3BGU', 'Vanguardistas', 'Lunes', 7, 'FIS_3BGU', 'JOSÉ NICOLALDE')
# ('3BGU', 'Vanguardistas', 'Lunes', 8, 'GEO_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Vanguardistas', 'Lunes', 9, 'COM_3BGU', 'ERIKA CAIZATOA')
# ('3BGU', 'Vanguardistas', 'Lunes', 10, 'DER_3BGU', 'CORALÍA CÓRDOVA')
# ('3BGU', 'Vanguardistas', 'Lunes', 11, 'GEO_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Vanguardistas', 'Lunes', 12, 'FIS_3BGU', 'JOSÉ NICOLALDE')
# ('3BGU', 'Vanguardistas', 'Lunes', 15, 'SOC_3BGU', 'ISABEL GARCÍA')
# ('3BGU', 'Vanguardistas', 'Lunes', 16, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Vanguardistas', 'Martes', 1, 'QUI_3BGU', 'MAYRA QUISHPE')
# ('3BGU', 'Vanguardistas', 'Martes', 2, 'EST_3BGU', 'JONATHAN CASTRO')
# ('3BGU', 'Vanguardistas', 'Martes', 3, 'EST_3BGU', 'JONATHAN CASTRO')
# ('3BGU', 'Vanguardistas', 'Martes', 4, 'PEN_3BGU', 'ANITA BARRENO')
# ('3BGU', 'Vanguardistas', 'Martes', 5, 'GEO_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Vanguardistas', 'Martes', 7, 'NAT_3BGU', 'CARLOS BENALCÁZAR')
# ('3BGU', 'Vanguardistas', 'Martes', 8, 'SOC_3BGU', 'ISABEL GARCÍA')
# ('3BGU', 'Vanguardistas', 'Martes', 9, 'DES_3BGU', 'JANETH MELO')
# ('3BGU', 'Vanguardistas', 'Martes', 10, 'DES_3BGU', 'JANETH MELO')
# ('3BGU', 'Vanguardistas', 'Martes', 11, 'PLA_3BGU', 'KEVIN VICENTE')
# ('3BGU', 'Vanguardistas', 'Martes', 12, 'NAT_3BGU', 'CARLOS BENALCÁZAR')
# ('3BGU', 'Vanguardistas', 'Martes', 15, 'LEC_3BGU', 'PATY FLORES')
# ('3BGU', 'Vanguardistas', 'Martes', 16, 'LEC_3BGU', 'PATY FLORES')
# ('3BGU', 'Vanguardistas', 'Miércoles', 3, 'QUI_3BGU', 'MAYRA QUISHPE')
# ('3BGU', 'Vanguardistas', 'Miércoles', 4, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Vanguardistas', 'Miércoles', 5, 'ROB_3BGU', 'DAVID RÓGEL')
# ('3BGU', 'Vanguardistas', 'Miércoles', 7, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Vanguardistas', 'Miércoles', 8, 'LEN_3BGU', 'ANDRÉS OLMEDO')
# ('3BGU', 'Vanguardistas', 'Miércoles', 9, 'LEN_3BGU', 'ANDRÉS OLMEDO')
# ('3BGU', 'Vanguardistas', 'Miércoles', 10, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Vanguardistas', 'Miércoles', 11, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Vanguardistas', 'Miércoles', 12, 'LEN_3BGU', 'ANDRÉS OLMEDO')
# ('3BGU', 'Vanguardistas', 'Jueves', 1, 'LEC_3BGU', 'PATY FLORES')
# ('3BGU', 'Vanguardistas', 'Jueves', 2, 'ROB_3BGU', 'DAVID RÓGEL')
# ('3BGU', 'Vanguardistas', 'Jueves', 3, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Vanguardistas', 'Jueves', 4, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Vanguardistas', 'Jueves', 5, 'QUI_3BGU', 'MAYRA QUISHPE')
# ('3BGU', 'Vanguardistas', 'Jueves', 7, 'EDU_3BGU', 'EF ESPECIAL')
# ('3BGU', 'Vanguardistas', 'Jueves', 8, 'EDU_3BGU', 'EF ESPECIAL')
# ('3BGU', 'Vanguardistas', 'Jueves', 9, 'EMP_3BGU', 'MARÍA BELÉN MALDONADO')
# ('3BGU', 'Vanguardistas', 'Jueves', 10, 'SAL_3BGU', 'VANESSA ESPÍN')
# ('3BGU', 'Vanguardistas', 'Jueves', 11, 'ECO_3BGU', 'MARJURIE JÁCOME')
# ('3BGU', 'Vanguardistas', 'Jueves', 12, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Vanguardistas', 'Jueves', 15, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Vanguardistas', 'Jueves', 16, 'MAT_3BGU', 'LEONARDO ESPINOSA')
# ('3BGU', 'Vanguardistas', 'Viernes', 1, 'NAT_3BGU', 'CARLOS BENALCÁZAR')
# ('3BGU', 'Vanguardistas', 'Viernes', 2, 'EMP_3BGU', 'MARÍA BELÉN MALDONADO')
# ('3BGU', 'Vanguardistas', 'Viernes', 3, 'PEN_3BGU', 'ANITA BARRENO')
# ('3BGU', 'Vanguardistas', 'Viernes', 4, 'SOC_3BGU', 'ISABEL GARCÍA')
# ('3BGU', 'Vanguardistas', 'Viernes', 5, 'PEN_3BGU', 'ANITA BARRENO')
# ('3BGU', 'Vanguardistas', 'Viernes', 7, 'INV_3BGU', 'KARLA LAZCANO')
# ('3BGU', 'Vanguardistas', 'Viernes', 8, 'SPE_3BGU', 'CHRISTIAN SOLANO')
# ('3BGU', 'Vanguardistas', 'Viernes', 9, 'PRO_3BGU', 'MARCO SAFADI')
# ('3BGU', 'Vanguardistas', 'Viernes', 10, 'SOC_3BGU', 'ISABEL GARCÍA')
# ('3BGU', 'Vanguardistas', 'Viernes', 11, 'ING_3BGU', 'INGLES ESPECIAL')
# ('3BGU', 'Vanguardistas', 'Viernes', 12, 'ING_3BGU', 'INGLES ESPECIAL')

# %%
# Uso:
ctr = contar_asignaciones_por_aula(hijo_ejemplo)
for (nivel, aula), num_genes in ctr.items():
    print(f"{nivel} • {aula}: {num_genes}")
# Out:
# 1EGB • Ejemplares: 59
# 1EGB • Entusiastas: 59
# 1EGB • Estudiosos: 59
# 1EGB • Exitosos: 59
# 2EGB • Afectuosos: 59
# 2EGB • Amables: 59
# 2EGB • Amigables: 59
# 2EGB • Amistosos: 59
# 3EGB • Colaboradores: 59
# 3EGB • Conciliadores: 59
# 3EGB • Cordiales: 59
# 3EGB • Creativos: 59
# 4EGB • Optimistas: 59
# 4EGB • Ordenados: 59
# 4EGB • Organizados: 59
# 4EGB • Originales: 59
# 5EGB • Admirables: 59
# 5EGB • Afectivos: 59
# 5EGB • Aplicados: 59
# 5EGB • Atentos: 59
# 6EGB • Ecuánimes: 59
# 6EGB • Emprendedores: 59
# 6EGB • Excelentes: 59
# 6EGB • Expresivos: 59
# 7EGB • Reflexivos: 59
# 7EGB • Resilientes: 59
# 7EGB • Respetuosos: 59
# 7EGB • Responsables: 59
# 8EGB • Decididos: 59
# 8EGB • Diligentes: 59
# 8EGB • Dinámicos: 59
# 8EGB • Disciplinados: 59
# 9EGB • Altruistas: 59
# 9EGB • Asertivos: 59
# 9EGB • Audaces: 59
# 9EGB • Auténticos: 59
# 10EGB • Pacifistas: 59
# 10EGB • Perspicaces: 59
# 10EGB • Positivos: 59
# 1BGU • Confiables: 59
# 1BGU • Integros: 59
# 1BGU • Leales: 59
# 2BGU • Honestos: 59
# 2BGU • Justos: 59
# 2BGU • Proactivos: 59
# 3BGU • Empáticos: 59
# 3BGU • Solidarios: 59
# 3BGU • Vanguardistas: 59

# %%
# Ejemplo de uso:
df_horas = contar_horas_por_materia(hijo_ejemplo)
df_horas
# Out:
#       Nivel        Aula Código_materia  Horas_asignadas
# 0     10EGB  Pacifistas      BIO_10EGB                3
# 1     10EGB  Pacifistas      COM_10EGB                1
# 2     10EGB  Pacifistas      DAN_10EGB                1
# 3     10EGB  Pacifistas      DER_10EGB                1
# 4     10EGB  Pacifistas      DES_10EGB                2
# ...     ...         ...            ...              ...
# 1095   9EGB  Auténticos       QUI_9EGB                6
# 1096   9EGB  Auténticos       ROB_9EGB                2
# 1097   9EGB  Auténticos       SAL_9EGB                1
# 1098   9EGB  Auténticos       SOC_9EGB                3
# 1099   9EGB  Auténticos       SPE_9EGB                1
#
# [1100 rows x 4 columns]

# %%
faltantes_df = verificar_materias_faltantes(hijo_ejemplo, materias, paralelos)
display(faltantes_df)
# Out:
# Empty DataFrame
# Columns: [Nivel, Aula, Materias, Código, Horas_requeridas, Horas_asignadas, Faltan]
# Index: []

# %% [markdown]
# ## 🧬 Comparación de herencia genética entre padres e hijo
#
# Esta función permite visualizar de manera detallada **de dónde proviene cada gen** (asignación de materia en una franja horaria) dentro de un cromosoma hijo, en relación con sus dos padres.
#
# ### ¿Qué evalúa?
# Para cada `(nivel, aula, día, hora)`:
# - Si la materia del hijo coincide con la del Padre 1 → 🟦
# - Si coincide con la del Padre 2 → 🟩
# - Si no coincide con ninguno (nuevo valor) → 🟧 (Reconstruido)
#
# ### Resultado:
# Imprime un reporte por aula, donde cada línea muestra:
# - El día
# - La hora
# - La materia asignada
# - La fuente del gen (Padre 1, Padre 2 o Reconstruido)
#
# ### Aplicaciones:
# - 🔍 Auditoría del operador de crossover.
# - 📊 Evaluación cualitativa de la diversidad genética del hijo.
# - 🧠 Análisis de cuánta herencia se preserva y cuánta se genera de forma aleatoria o heurística.
#
# > Esta herramienta es útil tanto en etapas de debugging como para justificar la implementación de estrategias de herencia controlada en el algoritmo evolutivo.

# %%
from collections import defaultdict

def comparar_herencia_genes(padre1, padre2, hijo):
    print("🔍 Comparación de herencia gen por gen\n")

    genes_p1 = {(n, a, d, h): m for n, a, d, h, m, _ in padre1}
    genes_p2 = {(n, a, d, h): m for n, a, d, h, m, _ in padre2}

    herencia_por_bloque = defaultdict(list)

    for gen in hijo:
        nivel, aula, dia, hora, materia_h, _ = gen
        key = (nivel, aula, dia, hora)

        materia_p1 = genes_p1.get(key)
        materia_p2 = genes_p2.get(key)

        if materia_h == materia_p1:
            fuente = "🟦 Padre 1"
        elif materia_h == materia_p2:
            fuente = "🟩 Padre 2"
        else:
            fuente = "🟧 Reconstruido"

        herencia_por_bloque[(nivel, aula)].append((key, materia_h, fuente))

    # Mostrar agrupado
    for (nivel, aula), registros in sorted(herencia_por_bloque.items()):
        print(f"\n📚 Nivel: {nivel} | Aula: {aula}")
        print("-" * 60)
        for (n, a, d, h), mat, src in sorted(registros, key=lambda x: (x[0][2], x[0][3])):  # orden por día y hora
            print(f"{d:<10} {h:>2}h → {mat:<12} ← {src}")
        print("-" * 60)

# %%
comparar_herencia_genes(padres[3], padres[5], hijo_ejemplo)
# Out:
# 🔍 Comparación de herencia gen por gen
#
#
# 📚 Nivel: 10EGB | Aula: Pacifistas
# ------------------------------------------------------------
# Jueves      1h → SOC_10EGB    ← 🟦 Padre 1
# Jueves      2h → DES_10EGB    ← 🟦 Padre 1
# Jueves      3h → BIO_10EGB    ← 🟦 Padre 1
# Jueves      4h → PLA_10EGB    ← 🟦 Padre 1
# Jueves      5h → PEN_10EGB    ← 🟦 Padre 1
# Jueves      7h → QUI_10EGB    ← 🟦 Padre 1
# Jueves      8h → EMP_10EGB    ← 🟦 Padre 1
# Jueves      9h → LEN_10EGB    ← 🟦 Padre 1
# Jueves     10h → LEC_10EGB    ← 🟦 Padre 1
# Jueves     11h → FIS_10EGB    ← 🟦 Padre 1
# Jueves     12h → GEO_10EGB    ← 🟦 Padre 1
# Jueves     15h → PRO_10EGB    ← 🟦 Padre 1
# Jueves     16h → QUI_10EGB    ← 🟦 Padre 1
# Lunes       1h → PEN_10EGB    ← 🟦 Padre 1
# Lunes       2h → LEN_10EGB    ← 🟦 Padre 1
# Lunes       3h → ECO_10EGB    ← 🟦 Padre 1
# Lunes       4h → SAL_10EGB    ← 🟦 Padre 1
# Lunes       5h → FIS_10EGB    ← 🟦 Padre 1
# Lunes       7h → GEO_10EGB    ← 🟦 Padre 1
# Lunes       8h → MAT_10EGB    ← 🟦 Padre 1
# Lunes       9h → MAT_10EGB    ← 🟦 Padre 1
# Lunes      10h → EST_10EGB    ← 🟦 Padre 1
# Lunes      11h → EDU_10EGB    ← 🟦 Padre 1
# Lunes      12h → SOC_10EGB    ← 🟦 Padre 1
# Lunes      15h → LEC_10EGB    ← 🟦 Padre 1
# Lunes      16h → ROB_10EGB    ← 🟦 Padre 1
# Martes      1h → DER_10EGB    ← 🟦 Padre 1
# Martes      2h → COM_10EGB    ← 🟦 Padre 1
# Martes      3h → SPE_10EGB    ← 🟦 Padre 1
# Martes      4h → INV_10EGB    ← 🟦 Padre 1
# Martes      5h → PEN_10EGB    ← 🟦 Padre 1
# Martes      7h → MUS_10EGB    ← 🟦 Padre 1
# Martes      8h → DAN_10EGB    ← 🟦 Padre 1
# Martes      9h → PLA_10EGB    ← 🟦 Padre 1
# Martes     10h → DES_10EGB    ← 🟦 Padre 1
# Martes     11h → PEN_10EGB    ← 🟦 Padre 1
# Martes     12h → ROB_10EGB    ← 🟦 Padre 1
# Martes     15h → ING_10EGB    ← 🟦 Padre 1
# Martes     16h → ING_10EGB    ← 🟦 Padre 1
# Miércoles   3h → EST_10EGB    ← 🟦 Padre 1
# Miércoles   4h → MAT_10EGB    ← 🟦 Padre 1
# Miércoles   5h → PRO_10EGB    ← 🟦 Padre 1
# Miércoles   7h → ING_10EGB    ← 🟦 Padre 1
# Miércoles   8h → ING_10EGB    ← 🟦 Padre 1
# Miércoles   9h → LEC_10EGB    ← 🟦 Padre 1
# Miércoles  10h → MAT_10EGB    ← 🟦 Padre 1
# Miércoles  11h → BIO_10EGB    ← 🟦 Padre 1
# Miércoles  12h → LEC_10EGB    ← 🟦 Padre 1
# Viernes     1h → MAT_10EGB    ← 🟦 Padre 1
# Viernes     2h → SOC_10EGB    ← 🟦 Padre 1
# Viernes     3h → MAT_10EGB    ← 🟦 Padre 1
# Viernes     4h → BIO_10EGB    ← 🟦 Padre 1
# Viernes     5h → EMP_10EGB    ← 🟦 Padre 1
# Viernes     7h → GEO_10EGB    ← 🟦 Padre 1
# Viernes     8h → ING_10EGB    ← 🟦 Padre 1
# Viernes     9h → ING_10EGB    ← 🟦 Padre 1
# Viernes    10h → GEO_10EGB    ← 🟦 Padre 1
# Viernes    11h → QUI_10EGB    ← 🟦 Padre 1
# Viernes    12h → EDU_10EGB    ← 🟦 Padre 1
# ------------------------------------------------------------
#
# 📚 Nivel: 10EGB | Aula: Perspicaces
# ------------------------------------------------------------
# Jueves      1h → EST_10EGB    ← 🟦 Padre 1
# Jueves      2h → EST_10EGB    ← 🟦 Padre 1
# Jueves      3h → EMP_10EGB    ← 🟦 Padre 1
# Jueves      4h → PLA_10EGB    ← 🟦 Padre 1
# Jueves      5h → LEC_10EGB    ← 🟦 Padre 1
# Jueves      7h → PEN_10EGB    ← 🟦 Padre 1
# Jueves      8h → MAT_10EGB    ← 🟦 Padre 1
# Jueves      9h → MUS_10EGB    ← 🟦 Padre 1
# Jueves     10h → DAN_10EGB    ← 🟦 Padre 1
# Jueves     11h → PRO_10EGB    ← 🟦 Padre 1
# Jueves     12h → ROB_10EGB    ← 🟦 Padre 1
# Jueves     15h → GEO_10EGB    ← 🟦 Padre 1
# Jueves     16h → GEO_10EGB    ← 🟦 Padre 1
# Lunes       1h → EDU_10EGB    ← 🟦 Padre 1
# Lunes       2h → SOC_10EGB    ← 🟦 Padre 1
# Lunes       3h → FIS_10EGB    ← 🟦 Padre 1
# Lunes       4h → FIS_10EGB    ← 🟦 Padre 1
# Lunes       5h → MAT_10EGB    ← 🟦 Padre 1
# Lunes       7h → SPE_10EGB    ← 🟦 Padre 1
# Lunes       8h → INV_10EGB    ← 🟦 Padre 1
# Lunes       9h → SOC_10EGB    ← 🟦 Padre 1
# Lunes      10h → PEN_10EGB    ← 🟦 Padre 1
# Lunes      11h → BIO_10EGB    ← 🟦 Padre 1
# Lunes      12h → LEN_10EGB    ← 🟦 Padre 1
# Lunes      15h → BIO_10EGB    ← 🟦 Padre 1
# Lunes      16h → QUI_10EGB    ← 🟦 Padre 1
# Martes      1h → MAT_10EGB    ← 🟦 Padre 1
# Martes      2h → DES_10EGB    ← 🟦 Padre 1
# Martes      3h → COM_10EGB    ← 🟦 Padre 1
# Martes      4h → DER_10EGB    ← 🟦 Padre 1
# Martes      5h → MAT_10EGB    ← 🟦 Padre 1
# Martes      7h → PLA_10EGB    ← 🟦 Padre 1
# Martes      8h → EDU_10EGB    ← 🟦 Padre 1
# Martes      9h → GEO_10EGB    ← 🟦 Padre 1
# Martes     10h → GEO_10EGB    ← 🟦 Padre 1
# Martes     11h → EMP_10EGB    ← 🟦 Padre 1
# Martes     12h → PRO_10EGB    ← 🟦 Padre 1
# Martes     15h → ING_10EGB    ← 🟦 Padre 1
# Martes     16h → ING_10EGB    ← 🟦 Padre 1
# Miércoles   3h → SAL_10EGB    ← 🟦 Padre 1
# Miércoles   4h → ECO_10EGB    ← 🟦 Padre 1
# Miércoles   5h → QUI_10EGB    ← 🟦 Padre 1
# Miércoles   7h → ING_10EGB    ← 🟦 Padre 1
# Miércoles   8h → ING_10EGB    ← 🟦 Padre 1
# Miércoles   9h → QUI_10EGB    ← 🟦 Padre 1
# Miércoles  10h → PEN_10EGB    ← 🟦 Padre 1
# Miércoles  11h → DES_10EGB    ← 🟦 Padre 1
# Miércoles  12h → PEN_10EGB    ← 🟦 Padre 1
# Viernes     1h → SOC_10EGB    ← 🟦 Padre 1
# Viernes     2h → MAT_10EGB    ← 🟦 Padre 1
# Viernes     3h → LEN_10EGB    ← 🟦 Padre 1
# Viernes     4h → LEC_10EGB    ← 🟦 Padre 1
# Viernes     5h → LEC_10EGB    ← 🟦 Padre 1
# Viernes     7h → ROB_10EGB    ← 🟦 Padre 1
# Viernes     8h → ING_10EGB    ← 🟦 Padre 1
# Viernes     9h → ING_10EGB    ← 🟦 Padre 1
# Viernes    10h → LEC_10EGB    ← 🟦 Padre 1
# Viernes    11h → MAT_10EGB    ← 🟦 Padre 1
# Viernes    12h → BIO_10EGB    ← 🟦 Padre 1
# ------------------------------------------------------------
#
# 📚 Nivel: 10EGB | Aula: Positivos
# ------------------------------------------------------------
# Jueves      1h → DES_10EGB    ← 🟦 Padre 1
# Jueves      2h → MAT_10EGB    ← 🟦 Padre 1
# Jueves      3h → COM_10EGB    ← 🟦 Padre 1
# Jueves      4h → DER_10EGB    ← 🟦 Padre 1
# Jueves      5h → PEN_10EGB    ← 🟦 Padre 1
# Jueves      7h → MAT_10EGB    ← 🟦 Padre 1
# Jueves      8h → LEC_10EGB    ← 🟦 Padre 1
# Jueves      9h → ROB_10EGB    ← 🟦 Padre 1
# Jueves     10h → ECO_10EGB    ← 🟦 Padre 1
# Jueves     11h → SAL_10EGB    ← 🟦 Padre 1
# Jueves     12h → BIO_10EGB    ← 🟦 Padre 1
# Jueves     15h → PRO_10EGB    ← 🟦 Padre 1
# Jueves     16h → EDU_10EGB    ← 🟦 Padre 1
# Lunes       1h → QUI_10EGB    ← 🟦 Padre 1
# Lunes       2h → ROB_10EGB    ← 🟦 Padre 1
# Lunes       3h → DAN_10EGB    ← 🟦 Padre 1
# Lunes       4h → MUS_10EGB    ← 🟦 Padre 1
# Lunes       5h → GEO_10EGB    ← 🟦 Padre 1
# Lunes       7h → PEN_10EGB    ← 🟦 Padre 1
# Lunes       8h → GEO_10EGB    ← 🟦 Padre 1
# Lunes       9h → BIO_10EGB    ← 🟦 Padre 1
# Lunes      10h → PRO_10EGB    ← 🟦 Padre 1
# Lunes      11h → QUI_10EGB    ← 🟦 Padre 1
# Lunes      12h → LEN_10EGB    ← 🟦 Padre 1
# Lunes      15h → PLA_10EGB    ← 🟦 Padre 1
# Lunes      16h → DES_10EGB    ← 🟦 Padre 1
# Martes      1h → SOC_10EGB    ← 🟦 Padre 1
# Martes      2h → FIS_10EGB    ← 🟦 Padre 1
# Martes      3h → LEN_10EGB    ← 🟦 Padre 1
# Martes      4h → SOC_10EGB    ← 🟦 Padre 1
# Martes      5h → PLA_10EGB    ← 🟦 Padre 1
# Martes      7h → EST_10EGB    ← 🟦 Padre 1
# Martes      8h → MAT_10EGB    ← 🟦 Padre 1
# Martes      9h → GEO_10EGB    ← 🟦 Padre 1
# Martes     10h → LEC_10EGB    ← 🟦 Padre 1
# Martes     11h → LEC_10EGB    ← 🟦 Padre 1
# Martes     12h → BIO_10EGB    ← 🟦 Padre 1
# Martes     15h → ING_10EGB    ← 🟦 Padre 1
# Martes     16h → ING_10EGB    ← 🟦 Padre 1
# Miércoles   3h → PEN_10EGB    ← 🟦 Padre 1
# Miércoles   4h → FIS_10EGB    ← 🟦 Padre 1
# Miércoles   5h → PEN_10EGB    ← 🟦 Padre 1
# Miércoles   7h → ING_10EGB    ← 🟦 Padre 1
# Miércoles   8h → ING_10EGB    ← 🟦 Padre 1
# Miércoles   9h → GEO_10EGB    ← 🟦 Padre 1
# Miércoles  10h → EMP_10EGB    ← 🟦 Padre 1
# Miércoles  11h → EMP_10EGB    ← 🟦 Padre 1
# Miércoles  12h → LEC_10EGB    ← 🟦 Padre 1
# Viernes     1h → EDU_10EGB    ← 🟦 Padre 1
# Viernes     2h → INV_10EGB    ← 🟦 Padre 1
# Viernes     3h → SPE_10EGB    ← 🟦 Padre 1
# Viernes     4h → SOC_10EGB    ← 🟦 Padre 1
# Viernes     5h → EST_10EGB    ← 🟦 Padre 1
# Viernes     7h → QUI_10EGB    ← 🟦 Padre 1
# Viernes     8h → ING_10EGB    ← 🟦 Padre 1
# Viernes     9h → ING_10EGB    ← 🟦 Padre 1
# Viernes    10h → MAT_10EGB    ← 🟦 Padre 1
# Viernes    11h → MAT_10EGB    ← 🟦 Padre 1
# Viernes    12h → MAT_10EGB    ← 🟦 Padre 1
# ------------------------------------------------------------
#
# 📚 Nivel: 1BGU | Aula: Confiables
# ------------------------------------------------------------
# Jueves      1h → LEN_1BGU     ← 🟦 Padre 1
# Jueves      2h → FIS_1BGU     ← 🟦 Padre 1
# Jueves      3h → LEC_1BGU     ← 🟦 Padre 1
# Jueves      4h → ROB_1BGU     ← 🟦 Padre 1
# Jueves      5h → NAT_1BGU     ← 🟦 Padre 1
# Jueves      7h → MAT_1BGU     ← 🟦 Padre 1
# Jueves      8h → GEO_1BGU     ← 🟦 Padre 1
# Jueves      9h → SOC_1BGU     ← 🟦 Padre 1
# Jueves     10h → LEC_1BGU     ← 🟦 Padre 1
# Jueves     11h → PEN_1BGU     ← 🟦 Padre 1
# Jueves     12h → FIS_1BGU     ← 🟦 Padre 1
# Jueves     15h → ING_1BGU     ← 🟦 Padre 1
# Jueves     16h → ING_1BGU     ← 🟦 Padre 1
# Lunes       1h → MAT_1BGU     ← 🟦 Padre 1
# Lunes       2h → PEN_1BGU     ← 🟦 Padre 1
# Lunes       3h → SOC_1BGU     ← 🟦 Padre 1
# Lunes       4h → ROB_1BGU     ← 🟦 Padre 1
# Lunes       5h → PLA_1BGU     ← 🟦 Padre 1
# Lunes       7h → PLA_1BGU     ← 🟦 Padre 1
# Lunes       8h → INV_1BGU     ← 🟦 Padre 1
# Lunes       9h → SPE_1BGU     ← 🟦 Padre 1
# Lunes      10h → QUI_1BGU     ← 🟦 Padre 1
# Lunes      11h → MAT_1BGU     ← 🟦 Padre 1
# Lunes      12h → NAT_1BGU     ← 🟦 Padre 1
# Lunes      15h → QUI_1BGU     ← 🟦 Padre 1
# Lunes      16h → PRO_1BGU     ← 🟦 Padre 1
# Martes      1h → COM_1BGU     ← 🟦 Padre 1
# Martes      2h → DER_1BGU     ← 🟦 Padre 1
# Martes      3h → EDU_1BGU     ← 🟦 Padre 1
# Martes      4h → ING_1BGU     ← 🟦 Padre 1
# Martes      5h → ING_1BGU     ← 🟦 Padre 1
# Martes      7h → QUI_1BGU     ← 🟦 Padre 1
# Martes      8h → FIS_1BGU     ← 🟦 Padre 1
# Martes      9h → EST_1BGU     ← 🟦 Padre 1
# Martes     10h → CIU_1BGU     ← 🟦 Padre 1
# Martes     11h → EDU_1BGU     ← 🟦 Padre 1
# Martes     12h → GEO_1BGU     ← 🟦 Padre 1
# Martes     15h → SOC_1BGU     ← 🟦 Padre 1
# Martes     16h → PEN_1BGU     ← 🟦 Padre 1
# Miércoles   3h → ECO_1BGU     ← 🟦 Padre 1
# Miércoles   4h → SAL_1BGU     ← 🟦 Padre 1
# Miércoles   5h → LEC_1BGU     ← 🟦 Padre 1
# Miércoles   7h → DES_1BGU     ← 🟦 Padre 1
# Miércoles   8h → MAT_1BGU     ← 🟦 Padre 1
# Miércoles   9h → MAT_1BGU     ← 🟦 Padre 1
# Miércoles  10h → LEN_1BGU     ← 🟦 Padre 1
# Miércoles  11h → SOC_1BGU     ← 🟦 Padre 1
# Miércoles  12h → EST_1BGU     ← 🟦 Padre 1
# Viernes     1h → FIS_1BGU     ← 🟦 Padre 1
# Viernes     2h → GEO_1BGU     ← 🟦 Padre 1
# Viernes     3h → ING_1BGU     ← 🟦 Padre 1
# Viernes     4h → ING_1BGU     ← 🟦 Padre 1
# Viernes     5h → DES_1BGU     ← 🟦 Padre 1
# Viernes     7h → EMP_1BGU     ← 🟦 Padre 1
# Viernes     8h → QUI_1BGU     ← 🟦 Padre 1
# Viernes     9h → PRO_1BGU     ← 🟦 Padre 1
# Viernes    10h → MAT_1BGU     ← 🟦 Padre 1
# Viernes    11h → EMP_1BGU     ← 🟦 Padre 1
# Viernes    12h → NAT_1BGU     ← 🟦 Padre 1
# ------------------------------------------------------------
#
# 📚 Nivel: 1BGU | Aula: Integros
# ------------------------------------------------------------
# Jueves      1h → ECO_1BGU     ← 🟦 Padre 1
# Jueves      2h → SAL_1BGU     ← 🟦 Padre 1
# Jueves      3h → QUI_1BGU     ← 🟦 Padre 1
# Jueves      4h → NAT_1BGU     ← 🟦 Padre 1
# Jueves      5h → DES_1BGU     ← 🟦 Padre 1
# Jueves      7h → SOC_1BGU     ← 🟦 Padre 1
# Jueves      8h → LEN_1BGU     ← 🟦 Padre 1
# Jueves      9h → NAT_1BGU     ← 🟦 Padre 1
# Jueves     10h → SOC_1BGU     ← 🟦 Padre 1
# Jueves     11h → MAT_1BGU     ← 🟦 Padre 1
# Jueves     12h → ROB_1BGU     ← 🟦 Padre 1
# Jueves     15h → ING_1BGU     ← 🟦 Padre 1
# Jueves     16h → ING_1BGU     ← 🟦 Padre 1
# Lunes       1h → SPE_1BGU     ← 🟦 Padre 1
# Lunes       2h → INV_1BGU     ← 🟦 Padre 1
# Lunes       3h → PEN_1BGU     ← 🟦 Padre 1
# Lunes       4h → NAT_1BGU     ← 🟦 Padre 1
# Lunes       5h → LEN_1BGU     ← 🟦 Padre 1
# Lunes       7h → PEN_1BGU     ← 🟦 Padre 1
# Lunes       8h → DER_1BGU     ← 🟦 Padre 1
# Lunes       9h → COM_1BGU     ← 🟦 Padre 1
# Lunes      10h → SOC_1BGU     ← 🟦 Padre 1
# Lunes      11h → DES_1BGU     ← 🟦 Padre 1
# Lunes      12h → SOC_1BGU     ← 🟦 Padre 1
# Lunes      15h → QUI_1BGU     ← 🟦 Padre 1
# Lunes      16h → GEO_1BGU     ← 🟦 Padre 1
# Martes      1h → FIS_1BGU     ← 🟦 Padre 1
# Martes      2h → PLA_1BGU     ← 🟦 Padre 1
# Martes      3h → FIS_1BGU     ← 🟦 Padre 1
# Martes      4h → ING_1BGU     ← 🟦 Padre 1
# Martes      5h → ING_1BGU     ← 🟦 Padre 1
# Martes      7h → MAT_1BGU     ← 🟦 Padre 1
# Martes      8h → GEO_1BGU     ← 🟦 Padre 1
# Martes      9h → EST_1BGU     ← 🟦 Padre 1
# Martes     10h → CIU_1BGU     ← 🟦 Padre 1
# Martes     11h → MAT_1BGU     ← 🟦 Padre 1
# Martes     12h → FIS_1BGU     ← 🟦 Padre 1
# Martes     15h → MAT_1BGU     ← 🟦 Padre 1
# Martes     16h → FIS_1BGU     ← 🟦 Padre 1
# Miércoles   3h → PLA_1BGU     ← 🟦 Padre 1
# Miércoles   4h → EST_1BGU     ← 🟦 Padre 1
# Miércoles   5h → QUI_1BGU     ← 🟦 Padre 1
# Miércoles   7h → LEC_1BGU     ← 🟦 Padre 1
# Miércoles   8h → PRO_1BGU     ← 🟦 Padre 1
# Miércoles   9h → EMP_1BGU     ← 🟦 Padre 1
# Miércoles  10h → MAT_1BGU     ← 🟦 Padre 1
# Miércoles  11h → QUI_1BGU     ← 🟦 Padre 1
# Miércoles  12h → EDU_1BGU     ← 🟦 Padre 1
# Viernes     1h → LEC_1BGU     ← 🟦 Padre 1
# Viernes     2h → EMP_1BGU     ← 🟦 Padre 1
# Viernes     3h → ING_1BGU     ← 🟦 Padre 1
# Viernes     4h → ING_1BGU     ← 🟦 Padre 1
# Viernes     5h → PRO_1BGU     ← 🟦 Padre 1
# Viernes     7h → MAT_1BGU     ← 🟦 Padre 1
# Viernes     8h → GEO_1BGU     ← 🟦 Padre 1
# Viernes     9h → PEN_1BGU     ← 🟦 Padre 1
# Viernes    10h → EDU_1BGU     ← 🟦 Padre 1
# Viernes    11h → ROB_1BGU     ← 🟦 Padre 1
# Viernes    12h → LEC_1BGU     ← 🟦 Padre 1
# ------------------------------------------------------------
#
# 📚 Nivel: 1BGU | Aula: Leales
# ------------------------------------------------------------
# Jueves      1h → LEN_1BGU     ← 🟦 Padre 1
# Jueves      2h → MAT_1BGU     ← 🟦 Padre 1
# Jueves      3h → PEN_1BGU     ← 🟦 Padre 1
# Jueves      4h → DES_1BGU     ← 🟦 Padre 1
# Jueves      5h → FIS_1BGU     ← 🟦 Padre 1
# Jueves      7h → FIS_1BGU     ← 🟦 Padre 1
# Jueves      8h → COM_1BGU     ← 🟦 Padre 1
# Jueves      9h → DER_1BGU     ← 🟦 Padre 1
# Jueves     10h → FIS_1BGU     ← 🟦 Padre 1
# Jueves     11h → LEN_1BGU     ← 🟦 Padre 1
# Jueves     12h → SOC_1BGU     ← 🟦 Padre 1
# Jueves     15h → ING_1BGU     ← 🟦 Padre 1
# Jueves     16h → ING_1BGU     ← 🟦 Padre 1
# Lunes       1h → DES_1BGU     ← 🟦 Padre 1
# Lunes       2h → EDU_1BGU     ← 🟦 Padre 1
# Lunes       3h → EMP_1BGU     ← 🟦 Padre 1
# Lunes       4h → PRO_1BGU     ← 🟦 Padre 1
# Lunes       5h → MAT_1BGU     ← 🟦 Padre 1
# Lunes       7h → PEN_1BGU     ← 🟦 Padre 1
# Lunes       8h → QUI_1BGU     ← 🟦 Padre 1
# Lunes       9h → LEC_1BGU     ← 🟦 Padre 1
# Lunes      10h → MAT_1BGU     ← 🟦 Padre 1
# Lunes      11h → EST_1BGU     ← 🟦 Padre 1
# Lunes      12h → SOC_1BGU     ← 🟦 Padre 1
# Lunes      15h → PLA_1BGU     ← 🟦 Padre 1
# Lunes      16h → SOC_1BGU     ← 🟦 Padre 1
# Martes      1h → NAT_1BGU     ← 🟦 Padre 1
# Martes      2h → EMP_1BGU     ← 🟦 Padre 1
# Martes      3h → MAT_1BGU     ← 🟦 Padre 1
# Martes      4h → ING_1BGU     ← 🟦 Padre 1
# Martes      5h → ING_1BGU     ← 🟦 Padre 1
# Martes      7h → EST_1BGU     ← 🟦 Padre 1
# Martes      8h → SOC_1BGU     ← 🟦 Padre 1
# Martes      9h → MAT_1BGU     ← 🟦 Padre 1
# Martes     10h → CIU_1BGU     ← 🟦 Padre 1
# Martes     11h → QUI_1BGU     ← 🟦 Padre 1
# Martes     12h → GEO_1BGU     ← 🟦 Padre 1
# Martes     15h → GEO_1BGU     ← 🟦 Padre 1
# Martes     16h → MAT_1BGU     ← 🟦 Padre 1
# Miércoles   3h → QUI_1BGU     ← 🟦 Padre 1
# Miércoles   4h → ROB_1BGU     ← 🟦 Padre 1
# Miércoles   5h → GEO_1BGU     ← 🟦 Padre 1
# Miércoles   7h → LEC_1BGU     ← 🟦 Padre 1
# Miércoles   8h → SAL_1BGU     ← 🟦 Padre 1
# Miércoles   9h → ECO_1BGU     ← 🟦 Padre 1
# Miércoles  10h → LEC_1BGU     ← 🟦 Padre 1
# Miércoles  11h → QUI_1BGU     ← 🟦 Padre 1
# Miércoles  12h → NAT_1BGU     ← 🟦 Padre 1
# Viernes     1h → ROB_1BGU     ← 🟦 Padre 1
# Viernes     2h → EDU_1BGU     ← 🟦 Padre 1
# Viernes     3h → ING_1BGU     ← 🟦 Padre 1
# Viernes     4h → ING_1BGU     ← 🟦 Padre 1
# Viernes     5h → PLA_1BGU     ← 🟦 Padre 1
# Viernes     7h → FIS_1BGU     ← 🟦 Padre 1
# Viernes     8h → PEN_1BGU     ← 🟦 Padre 1
# Viernes     9h → NAT_1BGU     ← 🟦 Padre 1
# Viernes    10h → SPE_1BGU     ← 🟦 Padre 1
# Viernes    11h → INV_1BGU     ← 🟦 Padre 1
# Viernes    12h → PRO_1BGU     ← 🟦 Padre 1
# ------------------------------------------------------------
#
# 📚 Nivel: 1EGB | Aula: Ejemplares
# ------------------------------------------------------------
# Jueves      1h → MAT_1EGB     ← 🟦 Padre 1
# Jueves      2h → DER_1EGB     ← 🟩 Padre 2
# Jueves      3h → COM_1EGB     ← 🟩 Padre 2
# Jueves      4h → NAT_1EGB     ← 🟦 Padre 1
# Jueves      6h → NAT_1EGB     ← 🟩 Padre 2
# Jueves      7h → ING_1EGB     ← 🟦 Padre 1
# Jueves      8h → EST_1EGB     ← 🟦 Padre 1
# Jueves      9h → MAT_1EGB     ← 🟦 Padre 1
# Jueves     10h → LEN_1EGB     ← 🟦 Padre 1
# Jueves     15h → DES_1EGB     ← 🟦 Padre 1
# Jueves     16h → LEN_1EGB     ← 🟦 Padre 1
# Lunes       1h → MAT_1EGB     ← 🟦 Padre 1
# Lunes       2h → PEN_1EGB     ← 🟦 Padre 1
# Lunes       3h → MAT_1EGB     ← 🟦 Padre 1
# Lunes       4h → LEN_1EGB     ← 🟦 Padre 1
# Lunes       6h → EXT_1EGB     ← 🟦 Padre 1
# Lunes       7h → LEC_1EGB     ← 🟦 Padre 1
# Lunes       8h → MAT_1EGB     ← 🟦 Padre 1
# Lunes       9h → ING_1EGB     ← 🟦 Padre 1
# Lunes      10h → MAT_1EGB     ← 🟦 Padre 1
# Lunes      13h → MAT_1EGB     ← 🟦 Padre 1
# Lunes      14h → PEN_1EGB     ← 🟦 Padre 1
# Martes      1h → ECO_1EGB     ← 🟦 Padre 1
# Martes      2h → SAL_1EGB     ← 🟧 Reconstruido
# Martes      3h → MAT_1EGB     ← 🟧 Reconstruido
# Martes      4h → MAT_1EGB     ← 🟦 Padre 1
# Martes      6h → ING_1EGB     ← 🟦 Padre 1
# Martes      7h → EST_1EGB     ← 🟩 Padre 2
# Martes      8h → ING_1EGB     ← 🟦 Padre 1
# Martes      9h → LEN_1EGB     ← 🟦 Padre 1
# Martes     10h → EST_1EGB     ← 🟦 Padre 1
# Martes     13h → EDU_1EGB     ← 🟦 Padre 1
# Martes     14h → LEN_1EGB     ← 🟦 Padre 1
# Martes     15h → ING_1EGB     ← 🟦 Padre 1
# Martes     16h → DES_1EGB     ← 🟦 Padre 1
# Miércoles   3h → LEN_1EGB     ← 🟦 Padre 1
# Miércoles   4h → LEC_1EGB     ← 🟦 Padre 1
# Miércoles   6h → MAT_1EGB     ← 🟧 Reconstruido
# Miércoles   7h → MUS_1EGB     ← 🟧 Reconstruido
# Miércoles   8h → DAN_1EGB     ← 🟦 Padre 1
# Miércoles   9h → LEN_1EGB     ← 🟦 Padre 1
# Miércoles  10h → LEN_1EGB     ← 🟦 Padre 1
# Miércoles  13h → ESP_1EGB     ← 🟦 Padre 1
# Miércoles  14h → LEN_1EGB     ← 🟦 Padre 1
# Miércoles  15h → NAT_1EGB     ← 🟦 Padre 1
# Miércoles  16h → LEN_1EGB     ← 🟦 Padre 1
# Viernes     1h → ROB_1EGB     ← 🟦 Padre 1
# Viernes     2h → ING_1EGB     ← 🟦 Padre 1
# Viernes     3h → LEN_1EGB     ← 🟦 Padre 1
# Viernes     4h → MAT_1EGB     ← 🟦 Padre 1
# Viernes     6h → ESP_1EGB     ← 🟦 Padre 1
# Viernes     7h → EDU_1EGB     ← 🟦 Padre 1
# Viernes     8h → SPE_1EGB     ← 🟩 Padre 2
# Viernes     9h → INV_1EGB     ← 🟩 Padre 2
# Viernes    10h → NAT_1EGB     ← 🟦 Padre 1
# Viernes    13h → LEC_1EGB     ← 🟦 Padre 1
# Viernes    14h → LEN_1EGB     ← 🟦 Padre 1
# Viernes    15h → MAT_1EGB     ← 🟧 Reconstruido
# Viernes    16h → ROB_1EGB     ← 🟧 Reconstruido
# ------------------------------------------------------------
#
# 📚 Nivel: 1EGB | Aula: Entusiastas
# ------------------------------------------------------------
# Jueves      1h → EXT_1EGB     ← 🟦 Padre 1
# Jueves      2h → LEN_1EGB     ← 🟦 Padre 1
# Jueves      3h → ESP_1EGB     ← 🟦 Padre 1
# Jueves      4h → EST_1EGB     ← 🟦 Padre 1
# Jueves      6h → SPE_1EGB     ← 🟦 Padre 1
# Jueves      7h → INV_1EGB     ← 🟦 Padre 1
# Jueves      8h → LEN_1EGB     ← 🟦 Padre 1
# Jueves      9h → LEN_1EGB     ← 🟦 Padre 1
# Jueves     10h → DES_1EGB     ← 🟦 Padre 1
# Jueves     15h → LEN_1EGB     ← 🟦 Padre 1
# Jueves     16h → PEN_1EGB     ← 🟦 Padre 1
# Lunes       1h → EST_1EGB     ← 🟦 Padre 1
# Lunes       2h → MAT_1EGB     ← 🟦 Padre 1
# Lunes       3h → LEN_1EGB     ← 🟦 Padre 1
# Lunes       4h → LEC_1EGB     ← 🟦 Padre 1
# Lunes       6h → ROB_1EGB     ← 🟦 Padre 1
# Lunes       7h → LEC_1EGB     ← 🟦 Padre 1
# Lunes       8h → LEN_1EGB     ← 🟦 Padre 1
# Lunes       9h → LEC_1EGB     ← 🟦 Padre 1
# Lunes      10h → MAT_1EGB     ← 🟦 Padre 1
# Lunes      13h → ING_1EGB     ← 🟦 Padre 1
# Lunes      14h → ING_1EGB     ← 🟦 Padre 1
# Martes      1h → PEN_1EGB     ← 🟦 Padre 1
# Martes      2h → LEN_1EGB     ← 🟦 Padre 1
# Martes      3h → NAT_1EGB     ← 🟦 Padre 1
# Martes      4h → NAT_1EGB     ← 🟦 Padre 1
# Martes      6h → ECO_1EGB     ← 🟦 Padre 1
# Martes      7h → SAL_1EGB     ← 🟦 Padre 1
# Martes      8h → MAT_1EGB     ← 🟦 Padre 1
# Martes      9h → EDU_1EGB     ← 🟦 Padre 1
# Martes     10h → LEN_1EGB     ← 🟦 Padre 1
# Martes     13h → MAT_1EGB     ← 🟦 Padre 1
# Martes     14h → EST_1EGB     ← 🟦 Padre 1
# Martes     15h → ROB_1EGB     ← 🟦 Padre 1
# Martes     16h → MAT_1EGB     ← 🟦 Padre 1
# Miércoles   3h → MAT_1EGB     ← 🟦 Padre 1
# Miércoles   4h → MAT_1EGB     ← 🟦 Padre 1
# Miércoles   6h → ING_1EGB     ← 🟦 Padre 1
# Miércoles   7h → LEN_1EGB     ← 🟦 Padre 1
# Miércoles   8h → MAT_1EGB     ← 🟦 Padre 1
# Miércoles   9h → DES_1EGB     ← 🟦 Padre 1
# Miércoles  10h → MAT_1EGB     ← 🟦 Padre 1
# Miércoles  13h → LEN_1EGB     ← 🟦 Padre 1
# Miércoles  14h → MAT_1EGB     ← 🟦 Padre 1
# Miércoles  15h → MAT_1EGB     ← 🟦 Padre 1
# Miércoles  16h → ING_1EGB     ← 🟦 Padre 1
# Viernes     1h → NAT_1EGB     ← 🟦 Padre 1
# Viernes     2h → NAT_1EGB     ← 🟦 Padre 1
# Viernes     3h → ING_1EGB     ← 🟦 Padre 1
# Viernes     4h → LEN_1EGB     ← 🟦 Padre 1
# Viernes     6h → ESP_1EGB     ← 🟦 Padre 1
# Viernes     7h → COM_1EGB     ← 🟦 Padre 1
# Viernes     8h → DER_1EGB     ← 🟦 Padre 1
# Viernes     9h → LEN_1EGB     ← 🟦 Padre 1
# Viernes    10h → ING_1EGB     ← 🟦 Padre 1
# Viernes    13h → MUS_1EGB     ← 🟦 Padre 1
# Viernes    14h → DAN_1EGB     ← 🟦 Padre 1
# Viernes    15h → EDU_1EGB     ← 🟦 Padre 1
# Viernes    16h → MAT_1EGB     ← 🟦 Padre 1
# ------------------------------------------------------------
#
# 📚 Nivel: 1EGB | Aula: Estudiosos
# ------------------------------------------------------------
# Jueves      1h → EST_1EGB     ← 🟦 Padre 1
# Jueves      2h → ROB_1EGB     ← 🟦 Padre 1
# Jueves      3h → LEC_1EGB     ← 🟦 Padre 1
# Jueves      4h → EXT_1EGB     ← 🟦 Padre 1
# Jueves      6h → LEN_1EGB     ← 🟦 Padre 1
# Jueves      7h → ING_1EGB     ← 🟦 Padre 1
# Jueves      8h → LEN_1EGB     ← 🟦 Padre 1
# Jueves      9h → ROB_1EGB     ← 🟦 Padre 1
# Jueves     10h → ESP_1EGB     ← 🟦 Padre 1
# Jueves     15h → PEN_1EGB     ← 🟦 Padre 1
# Jueves     16h → EST_1EGB     ← 🟦 Padre 1
# Lunes       1h → MUS_1EGB     ← 🟦 Padre 1
# Lunes       2h → DAN_1EGB     ← 🟦 Padre 1
# Lunes       3h → ING_1EGB     ← 🟦 Padre 1
# Lunes       4h → NAT_1EGB     ← 🟦 Padre 1
# Lunes       6h → LEN_1EGB     ← 🟦 Padre 1
# Lunes       7h → NAT_1EGB     ← 🟦 Padre 1
# Lunes       8h → LEN_1EGB     ← 🟦 Padre 1
# Lunes       9h → NAT_1EGB     ← 🟦 Padre 1
# Lunes      10h → DES_1EGB     ← 🟦 Padre 1
# Lunes      13h → EDU_1EGB     ← 🟦 Padre 1
# Lunes      14h → EST_1EGB     ← 🟦 Padre 1
# Martes      1h → MAT_1EGB     ← 🟦 Padre 1
# Martes      2h → LEN_1EGB     ← 🟦 Padre 1
# Martes      3h → MAT_1EGB     ← 🟦 Padre 1
# Martes      4h → MAT_1EGB     ← 🟦 Padre 1
# Martes      6h → MAT_1EGB     ← 🟦 Padre 1
# Martes      7h → LEN_1EGB     ← 🟦 Padre 1
# Martes      8h → COM_1EGB     ← 🟦 Padre 1
# Martes      9h → DER_1EGB     ← 🟦 Padre 1
# Martes     10h → LEC_1EGB     ← 🟦 Padre 1
# Martes     13h → MAT_1EGB     ← 🟦 Padre 1
# Martes     14h → ESP_1EGB     ← 🟦 Padre 1
# Martes     15h → MAT_1EGB     ← 🟦 Padre 1
# Martes     16h → LEN_1EGB     ← 🟦 Padre 1
# Miércoles   3h → LEC_1EGB     ← 🟦 Padre 1
# Miércoles   4h → DES_1EGB     ← 🟦 Padre 1
# Miércoles   6h → LEN_1EGB     ← 🟦 Padre 1
# Miércoles   7h → SPE_1EGB     ← 🟦 Padre 1
# Miércoles   8h → INV_1EGB     ← 🟦 Padre 1
# Miércoles   9h → LEN_1EGB     ← 🟦 Padre 1
# Miércoles  10h → MAT_1EGB     ← 🟦 Padre 1
# Miércoles  13h → ECO_1EGB     ← 🟦 Padre 1
# Miércoles  14h → SAL_1EGB     ← 🟦 Padre 1
# Miércoles  15h → ING_1EGB     ← 🟦 Padre 1
# Miércoles  16h → MAT_1EGB     ← 🟦 Padre 1
# Viernes     1h → ING_1EGB     ← 🟦 Padre 1
# Viernes     2h → PEN_1EGB     ← 🟦 Padre 1
# Viernes     3h → LEN_1EGB     ← 🟦 Padre 1
# Viernes     4h → MAT_1EGB     ← 🟦 Padre 1
# Viernes     6h → NAT_1EGB     ← 🟦 Padre 1
# Viernes     7h → MAT_1EGB     ← 🟦 Padre 1
# Viernes     8h → MAT_1EGB     ← 🟦 Padre 1
# Viernes     9h → ING_1EGB     ← 🟦 Padre 1
# Viernes    10h → LEN_1EGB     ← 🟦 Padre 1
# Viernes    13h → EDU_1EGB     ← 🟦 Padre 1
# Viernes    14h → ING_1EGB     ← 🟦 Padre 1
# Viernes    15h → MAT_1EGB     ← 🟦 Padre 1
# Viernes    16h → LEN_1EGB     ← 🟦 Padre 1
# ------------------------------------------------------------
#
# 📚 Nivel: 1EGB | Aula: Exitosos
# ------------------------------------------------------------
# Jueves      1h → ROB_1EGB     ← 🟦 Padre 1
# Jueves      2h → LEN_1EGB     ← 🟦 Padre 1
# Jueves      3h → MAT_1EGB     ← 🟦 Padre 1
# Jueves      4h → ROB_1EGB     ← 🟦 Padre 1
# Jueves      6h → ING_1EGB     ← 🟦 Padre 1
# Jueves      7h → LEN_1EGB     ← 🟦 Padre 1
# Jueves      8h → LEN_1EGB     ← 🟦 Padre 1
# Jueves      9h → MAT_1EGB     ← 🟦 Padre 1
# Jueves     10h → EST_1EGB     ← 🟦 Padre 1
# Jueves     15h → LEC_1EGB     ← 🟦 Padre 1
# Jueves     16h → LEC_1EGB     ← 🟦 Padre 1
# Lunes       1h → LEN_1EGB     ← 🟦 Padre 1
# Lunes       2h → MAT_1EGB     ← 🟦 Padre 1
# Lunes       3h → NAT_1EGB     ← 🟦 Padre 1
# Lunes       4h → EDU_1EGB     ← 🟦 Padre 1
# Lunes       6h → NAT_1EGB     ← 🟦 Padre 1
# Lunes       7h → LEN_1EGB     ← 🟦 Padre 1
# Lunes       8h → PEN_1EGB     ← 🟦 Padre 1
# Lunes       9h → ING_1EGB     ← 🟦 Padre 1
# Lunes      10h → DES_1EGB     ← 🟦 Padre 1
# Lunes      13h → LEN_1EGB     ← 🟦 Padre 1
# Lunes      14h → MAT_1EGB     ← 🟦 Padre 1
# Martes      1h → DER_1EGB     ← 🟦 Padre 1
# Martes      2h → COM_1EGB     ← 🟦 Padre 1
# Martes      3h → MAT_1EGB     ← 🟦 Padre 1
# Martes      4h → LEN_1EGB     ← 🟦 Padre 1
# Martes      6h → SPE_1EGB     ← 🟦 Padre 1
# Martes      7h → INV_1EGB     ← 🟦 Padre 1
# Martes      8h → MAT_1EGB     ← 🟦 Padre 1
# Martes      9h → ESP_1EGB     ← 🟦 Padre 1
# Martes     10h → ING_1EGB     ← 🟦 Padre 1
# Martes     13h → MAT_1EGB     ← 🟦 Padre 1
# Martes     14h → ING_1EGB     ← 🟦 Padre 1
# Martes     15h → DES_1EGB     ← 🟦 Padre 1
# Martes     16h → EXT_1EGB     ← 🟦 Padre 1
# Miércoles   3h → MAT_1EGB     ← 🟦 Padre 1
# Miércoles   4h → MAT_1EGB     ← 🟦 Padre 1
# Miércoles   6h → NAT_1EGB     ← 🟦 Padre 1
# Miércoles   7h → ECO_1EGB     ← 🟦 Padre 1
# Miércoles   8h → SAL_1EGB     ← 🟦 Padre 1
# Miércoles   9h → LEN_1EGB     ← 🟦 Padre 1
# Miércoles  10h → EDU_1EGB     ← 🟦 Padre 1
# Miércoles  13h → ING_1EGB     ← 🟦 Padre 1
# Miércoles  14h → EST_1EGB     ← 🟦 Padre 1
# Miércoles  15h → MAT_1EGB     ← 🟦 Padre 1
# Miércoles  16h → ESP_1EGB     ← 🟦 Padre 1
# Viernes     1h → MUS_1EGB     ← 🟦 Padre 1
# Viernes     2h → DAN_1EGB     ← 🟦 Padre 1
# Viernes     3h → LEN_1EGB     ← 🟦 Padre 1
# Viernes     4h → MAT_1EGB     ← 🟦 Padre 1
# Viernes     6h → LEN_1EGB     ← 🟦 Padre 1
# Viernes     7h → LEN_1EGB     ← 🟦 Padre 1
# Viernes     8h → LEC_1EGB     ← 🟦 Padre 1
# Viernes     9h → LEN_1EGB     ← 🟦 Padre 1
# Viernes    10h → PEN_1EGB     ← 🟦 Padre 1
# Viernes    13h → EST_1EGB     ← 🟦 Padre 1
# Viernes    14h → ING_1EGB     ← 🟦 Padre 1
# Viernes    15h → NAT_1EGB     ← 🟦 Padre 1
# Viernes    16h → MAT_1EGB     ← 🟦 Padre 1
# ------------------------------------------------------------
#
# 📚 Nivel: 2BGU | Aula: Honestos
# ------------------------------------------------------------
# Jueves      1h → PLA_2BGU     ← 🟦 Padre 1
# Jueves      2h → COM_2BGU     ← 🟦 Padre 1
# Jueves      3h → DER_2BGU     ← 🟦 Padre 1
# Jueves      4h → ROB_2BGU     ← 🟦 Padre 1
# Jueves      5h → PEN_2BGU     ← 🟦 Padre 1
# Jueves      7h → PEN_2BGU     ← 🟦 Padre 1
# Jueves      8h → PEN_2BGU     ← 🟦 Padre 1
# Jueves      9h → QUI_2BGU     ← 🟦 Padre 1
# Jueves     10h → FIS_2BGU     ← 🟦 Padre 1
# Jueves     11h → EDU_2BGU     ← 🟦 Padre 1
# Jueves     12h → SOC_2BGU     ← 🟦 Padre 1
# Jueves     15h → SOC_2BGU     ← 🟦 Padre 1
# Jueves     16h → QUI_2BGU     ← 🟦 Padre 1
# Lunes       1h → CIU_2BGU     ← 🟦 Padre 1
# Lunes       2h → LEN_2BGU     ← 🟦 Padre 1
# Lunes       3h → ING_2BGU     ← 🟦 Padre 1
# Lunes       4h → ING_2BGU     ← 🟦 Padre 1
# Lunes       5h → QUI_2BGU     ← 🟦 Padre 1
# Lunes       7h → LEC_2BGU     ← 🟦 Padre 1
# Lunes       8h → EDU_2BGU     ← 🟦 Padre 1
# Lunes       9h → SAL_2BGU     ← 🟦 Padre 1
# Lunes      10h → ECO_2BGU     ← 🟦 Padre 1
# Lunes      11h → GEO_2BGU     ← 🟦 Padre 1
# Lunes      12h → PRO_2BGU     ← 🟦 Padre 1
# Lunes      15h → DES_2BGU     ← 🟦 Padre 1
# Lunes      16h → LEN_2BGU     ← 🟦 Padre 1
# Martes      1h → MAT_2BGU     ← 🟦 Padre 1
# Martes      2h → ING_2BGU     ← 🟦 Padre 1
# Martes      3h → ING_2BGU     ← 🟦 Padre 1
# Martes      4h → NAT_2BGU     ← 🟦 Padre 1
# Martes      5h → GEO_2BGU     ← 🟦 Padre 1
# Martes      7h → SPE_2BGU     ← 🟦 Padre 1
# Martes      8h → INV_2BGU     ← 🟦 Padre 1
# Martes      9h → ROB_2BGU     ← 🟦 Padre 1
# Martes     10h → FIS_2BGU     ← 🟦 Padre 1
# Martes     11h → FIS_2BGU     ← 🟦 Padre 1
# Martes     12h → MAT_2BGU     ← 🟦 Padre 1
# Martes     15h → NAT_2BGU     ← 🟦 Padre 1
# Martes     16h → MAT_2BGU     ← 🟦 Padre 1
# Miércoles   3h → EMP_2BGU     ← 🟦 Padre 1
# Miércoles   4h → LEC_2BGU     ← 🟦 Padre 1
# Miércoles   5h → MAT_2BGU     ← 🟦 Padre 1
# Miércoles   7h → MAT_2BGU     ← 🟦 Padre 1
# Miércoles   8h → ING_2BGU     ← 🟦 Padre 1
# Miércoles   9h → ING_2BGU     ← 🟦 Padre 1
# Miércoles  10h → SOC_2BGU     ← 🟦 Padre 1
# Miércoles  11h → FIS_2BGU     ← 🟦 Padre 1
# Miércoles  12h → EST_2BGU     ← 🟦 Padre 1
# Viernes     1h → PRO_2BGU     ← 🟦 Padre 1
# Viernes     2h → SOC_2BGU     ← 🟦 Padre 1
# Viernes     3h → QUI_2BGU     ← 🟦 Padre 1
# Viernes     4h → MAT_2BGU     ← 🟦 Padre 1
# Viernes     5h → EMP_2BGU     ← 🟦 Padre 1
# Viernes     7h → PLA_2BGU     ← 🟦 Padre 1
# Viernes     8h → LEC_2BGU     ← 🟦 Padre 1
# Viernes     9h → NAT_2BGU     ← 🟦 Padre 1
# Viernes    10h → EST_2BGU     ← 🟦 Padre 1
# Viernes    11h → DES_2BGU     ← 🟦 Padre 1
# Viernes    12h → GEO_2BGU     ← 🟦 Padre 1
# ------------------------------------------------------------
#
# 📚 Nivel: 2BGU | Aula: Justos
# ------------------------------------------------------------
# Jueves      1h → LEN_2BGU     ← 🟦 Padre 1
# Jueves      2h → FIS_2BGU     ← 🟦 Padre 1
# Jueves      3h → FIS_2BGU     ← 🟦 Padre 1
# Jueves      4h → EST_2BGU     ← 🟦 Padre 1
# Jueves      5h → ROB_2BGU     ← 🟦 Padre 1
# Jueves      7h → EMP_2BGU     ← 🟦 Padre 1
# Jueves      8h → SOC_2BGU     ← 🟦 Padre 1
# Jueves      9h → DES_2BGU     ← 🟦 Padre 1
# Jueves     10h → DES_2BGU     ← 🟦 Padre 1
# Jueves     11h → MAT_2BGU     ← 🟦 Padre 1
# Jueves     12h → EST_2BGU     ← 🟦 Padre 1
# Jueves     15h → FIS_2BGU     ← 🟦 Padre 1
# Jueves     16h → GEO_2BGU     ← 🟦 Padre 1
# Lunes       1h → CIU_2BGU     ← 🟦 Padre 1
# Lunes       2h → NAT_2BGU     ← 🟦 Padre 1
# Lunes       3h → ING_2BGU     ← 🟦 Padre 1
# Lunes       4h → ING_2BGU     ← 🟦 Padre 1
# Lunes       5h → LEC_2BGU     ← 🟦 Padre 1
# Lunes       7h → SOC_2BGU     ← 🟦 Padre 1
# Lunes       8h → DER_2BGU     ← 🟦 Padre 1
# Lunes       9h → COM_2BGU     ← 🟦 Padre 1
# Lunes      10h → SAL_2BGU     ← 🟦 Padre 1
# Lunes      11h → ECO_2BGU     ← 🟦 Padre 1
# Lunes      12h → MAT_2BGU     ← 🟦 Padre 1
# Lunes      15h → ROB_2BGU     ← 🟦 Padre 1
# Lunes      16h → NAT_2BGU     ← 🟦 Padre 1
# Martes      1h → MAT_2BGU     ← 🟦 Padre 1
# Martes      2h → ING_2BGU     ← 🟦 Padre 1
# Martes      3h → ING_2BGU     ← 🟦 Padre 1
# Martes      4h → QUI_2BGU     ← 🟦 Padre 1
# Martes      5h → PRO_2BGU     ← 🟦 Padre 1
# Martes      7h → QUI_2BGU     ← 🟦 Padre 1
# Martes      8h → INV_2BGU     ← 🟦 Padre 1
# Martes      9h → SPE_2BGU     ← 🟦 Padre 1
# Martes     10h → NAT_2BGU     ← 🟦 Padre 1
# Martes     11h → LEC_2BGU     ← 🟦 Padre 1
# Martes     12h → SOC_2BGU     ← 🟦 Padre 1
# Martes     15h → EMP_2BGU     ← 🟦 Padre 1
# Martes     16h → LEC_2BGU     ← 🟦 Padre 1
# Miércoles   3h → GEO_2BGU     ← 🟦 Padre 1
# Miércoles   4h → MAT_2BGU     ← 🟦 Padre 1
# Miércoles   5h → PLA_2BGU     ← 🟦 Padre 1
# Miércoles   7h → GEO_2BGU     ← 🟦 Padre 1
# Miércoles   8h → ING_2BGU     ← 🟦 Padre 1
# Miércoles   9h → ING_2BGU     ← 🟦 Padre 1
# Miércoles  10h → EDU_2BGU     ← 🟦 Padre 1
# Miércoles  11h → PEN_2BGU     ← 🟦 Padre 1
# Miércoles  12h → QUI_2BGU     ← 🟦 Padre 1
# Viernes     1h → LEN_2BGU     ← 🟦 Padre 1
# Viernes     2h → SOC_2BGU     ← 🟦 Padre 1
# Viernes     3h → PRO_2BGU     ← 🟦 Padre 1
# Viernes     4h → FIS_2BGU     ← 🟦 Padre 1
# Viernes     5h → PLA_2BGU     ← 🟦 Padre 1
# Viernes     7h → MAT_2BGU     ← 🟦 Padre 1
# Viernes     8h → PEN_2BGU     ← 🟦 Padre 1
# Viernes     9h → QUI_2BGU     ← 🟦 Padre 1
# Viernes    10h → MAT_2BGU     ← 🟦 Padre 1
# Viernes    11h → PEN_2BGU     ← 🟦 Padre 1
# Viernes    12h → EDU_2BGU     ← 🟦 Padre 1
# ------------------------------------------------------------
#
# 📚 Nivel: 2BGU | Aula: Proactivos
# ------------------------------------------------------------
# Jueves      1h → QUI_2BGU     ← 🟦 Padre 1
# Jueves      2h → ROB_2BGU     ← 🟦 Padre 1
# Jueves      3h → PEN_2BGU     ← 🟦 Padre 1
# Jueves      4h → GEO_2BGU     ← 🟦 Padre 1
# Jueves      5h → GEO_2BGU     ← 🟦 Padre 1
# Jueves      7h → MAT_2BGU     ← 🟦 Padre 1
# Jueves      8h → EDU_2BGU     ← 🟦 Padre 1
# Jueves      9h → MAT_2BGU     ← 🟦 Padre 1
# Jueves     10h → LEN_2BGU     ← 🟦 Padre 1
# Jueves     11h → MAT_2BGU     ← 🟦 Padre 1
# Jueves     12h → EMP_2BGU     ← 🟦 Padre 1
# Jueves     15h → LEC_2BGU     ← 🟦 Padre 1
# Jueves     16h → MAT_2BGU     ← 🟦 Padre 1
# Lunes       1h → CIU_2BGU     ← 🟦 Padre 1
# Lunes       2h → FIS_2BGU     ← 🟦 Padre 1
# Lunes       3h → ING_2BGU     ← 🟦 Padre 1
# Lunes       4h → ING_2BGU     ← 🟦 Padre 1
# Lunes       5h → QUI_2BGU     ← 🟦 Padre 1
# Lunes       7h → EDU_2BGU     ← 🟦 Padre 1
# Lunes       8h → DER_2BGU     ← 🟦 Padre 1
# Lunes       9h → COM_2BGU     ← 🟦 Padre 1
# Lunes      10h → EMP_2BGU     ← 🟦 Padre 1
# Lunes      11h → EST_2BGU     ← 🟦 Padre 1
# Lunes      12h → PEN_2BGU     ← 🟦 Padre 1
# Lunes      15h → GEO_2BGU     ← 🟦 Padre 1
# Lunes      16h → DES_2BGU     ← 🟦 Padre 1
# Martes      1h → LEC_2BGU     ← 🟦 Padre 1
# Martes      2h → ING_2BGU     ← 🟦 Padre 1
# Martes      3h → ING_2BGU     ← 🟦 Padre 1
# Martes      4h → LEC_2BGU     ← 🟦 Padre 1
# Martes      5h → MAT_2BGU     ← 🟦 Padre 1
# Martes      7h → LEN_2BGU     ← 🟦 Padre 1
# Martes      8h → PRO_2BGU     ← 🟦 Padre 1
# Martes      9h → PLA_2BGU     ← 🟦 Padre 1
# Martes     10h → SOC_2BGU     ← 🟦 Padre 1
# Martes     11h → FIS_2BGU     ← 🟦 Padre 1
# Martes     12h → FIS_2BGU     ← 🟦 Padre 1
# Martes     15h → QUI_2BGU     ← 🟦 Padre 1
# Martes     16h → PLA_2BGU     ← 🟦 Padre 1
# Miércoles   3h → ROB_2BGU     ← 🟦 Padre 1
# Miércoles   4h → PRO_2BGU     ← 🟦 Padre 1
# Miércoles   5h → FIS_2BGU     ← 🟦 Padre 1
# Miércoles   7h → DES_2BGU     ← 🟦 Padre 1
# Miércoles   8h → ING_2BGU     ← 🟦 Padre 1
# Miércoles   9h → ING_2BGU     ← 🟦 Padre 1
# Miércoles  10h → SPE_2BGU     ← 🟦 Padre 1
# Miércoles  11h → INV_2BGU     ← 🟦 Padre 1
# Miércoles  12h → NAT_2BGU     ← 🟦 Padre 1
# Viernes     1h → SOC_2BGU     ← 🟦 Padre 1
# Viernes     2h → EST_2BGU     ← 🟦 Padre 1
# Viernes     3h → SOC_2BGU     ← 🟦 Padre 1
# Viernes     4h → NAT_2BGU     ← 🟦 Padre 1
# Viernes     5h → PEN_2BGU     ← 🟦 Padre 1
# Viernes     7h → MAT_2BGU     ← 🟦 Padre 1
# Viernes     8h → QUI_2BGU     ← 🟦 Padre 1
# Viernes     9h → NAT_2BGU     ← 🟦 Padre 1
# Viernes    10h → SAL_2BGU     ← 🟦 Padre 1
# Viernes    11h → ECO_2BGU     ← 🟦 Padre 1
# Viernes    12h → SOC_2BGU     ← 🟦 Padre 1
# ------------------------------------------------------------
#
# 📚 Nivel: 2EGB | Aula: Afectuosos
# ------------------------------------------------------------
# Jueves      1h → CIE_2EGB     ← 🟦 Padre 1
# Jueves      2h → MAT_2EGB     ← 🟦 Padre 1
# Jueves      3h → NAT_2EGB     ← 🟦 Padre 1
# Jueves      4h → LEN_2EGB     ← 🟦 Padre 1
# Jueves      6h → SOC_2EGB     ← 🟦 Padre 1
# Jueves      7h → LEN_2EGB     ← 🟦 Padre 1
# Jueves      8h → EXP_2EGB     ← 🟦 Padre 1
# Jueves      9h → CAL_2EGB     ← 🟦 Padre 1
# Jueves     10h → LEN_2EGB     ← 🟦 Padre 1
# Jueves     13h → PLA_2EGB     ← 🟦 Padre 1
# Jueves     14h → NAT_2EGB     ← 🟦 Padre 1
# Lunes       1h → ING_2EGB     ← 🟦 Padre 1
# Lunes       2h → ING_2EGB     ← 🟦 Padre 1
# Lunes       3h → CIE_2EGB     ← 🟦 Padre 1
# Lunes       4h → NAT_2EGB     ← 🟦 Padre 1
# Lunes       6h → PLA_2EGB     ← 🟦 Padre 1
# Lunes       7h → LEC_2EGB     ← 🟦 Padre 1
# Lunes       8h → LEN_2EGB     ← 🟦 Padre 1
# Lunes       9h → MAT_2EGB     ← 🟦 Padre 1
# Lunes      10h → LEN_2EGB     ← 🟦 Padre 1
# Lunes      13h → COM_2EGB     ← 🟦 Padre 1
# Lunes      14h → DER_2EGB     ← 🟦 Padre 1
# Lunes      15h → MAT_2EGB     ← 🟦 Padre 1
# Lunes      16h → MAT_2EGB     ← 🟦 Padre 1
# Martes      1h → LEC_2EGB     ← 🟦 Padre 1
# Martes      2h → MAT_2EGB     ← 🟦 Padre 1
# Martes      3h → CIE_2EGB     ← 🟦 Padre 1
# Martes      4h → MAT_2EGB     ← 🟦 Padre 1
# Martes      6h → CIE_2EGB     ← 🟦 Padre 1
# Martes      7h → ING_2EGB     ← 🟦 Padre 1
# Martes      8h → PRO_2EGB     ← 🟦 Padre 1
# Martes      9h → DES_2EGB     ← 🟦 Padre 1
# Martes     10h → PRO_2EGB     ← 🟦 Padre 1
# Martes     13h → MAT_2EGB     ← 🟦 Padre 1
# Martes     14h → ING_2EGB     ← 🟦 Padre 1
# Miércoles   3h → MAT_2EGB     ← 🟦 Padre 1
# Miércoles   4h → MAT_2EGB     ← 🟦 Padre 1
# Miércoles   6h → ING_2EGB     ← 🟦 Padre 1
# Miércoles   7h → NAT_2EGB     ← 🟦 Padre 1
# Miércoles   8h → DAN_2EGB     ← 🟦 Padre 1
# Miércoles   9h → MUS_2EGB     ← 🟦 Padre 1
# Miércoles  10h → LEC_2EGB     ← 🟦 Padre 1
# Miércoles  13h → EDU_2EGB     ← 🟦 Padre 1
# Miércoles  14h → ECO_2EGB     ← 🟦 Padre 1
# Miércoles  15h → SAL_2EGB     ← 🟦 Padre 1
# Miércoles  16h → ING_2EGB     ← 🟦 Padre 1
# Viernes     1h → ROB_2EGB     ← 🟦 Padre 1
# Viernes     2h → SPE_2EGB     ← 🟦 Padre 1
# Viernes     3h → INV_2EGB     ← 🟦 Padre 1
# Viernes     4h → EDU_2EGB     ← 🟦 Padre 1
# Viernes     6h → MAT_2EGB     ← 🟦 Padre 1
# Viernes     7h → SOC_2EGB     ← 🟦 Padre 1
# Viernes     8h → LEC_2EGB     ← 🟦 Padre 1
# Viernes     9h → LEN_2EGB     ← 🟦 Padre 1
# Viernes    10h → MAT_2EGB     ← 🟦 Padre 1
# Viernes    13h → SOC_2EGB     ← 🟦 Padre 1
# Viernes    14h → MAT_2EGB     ← 🟦 Padre 1
# Viernes    15h → DES_2EGB     ← 🟦 Padre 1
# Viernes    16h → ROB_2EGB     ← 🟦 Padre 1
# ------------------------------------------------------------
#
# 📚 Nivel: 2EGB | Aula: Amables
# ------------------------------------------------------------
# Jueves      1h → SOC_2EGB     ← 🟦 Padre 1
# Jueves      2h → LEC_2EGB     ← 🟦 Padre 1
# Jueves      3h → MAT_2EGB     ← 🟦 Padre 1
# Jueves      4h → PRO_2EGB     ← 🟦 Padre 1
# Jueves      6h → MAT_2EGB     ← 🟦 Padre 1
# Jueves      7h → SOC_2EGB     ← 🟦 Padre 1
# Jueves      8h → ING_2EGB     ← 🟦 Padre 1
# Jueves      9h → MAT_2EGB     ← 🟦 Padre 1
# Jueves     10h → ING_2EGB     ← 🟦 Padre 1
# Jueves     13h → CIE_2EGB     ← 🟦 Padre 1
# Jueves     14h → LEN_2EGB     ← 🟦 Padre 1
# Lunes       1h → CAL_2EGB     ← 🟦 Padre 1
# Lunes       2h → EXP_2EGB     ← 🟦 Padre 1
# Lunes       3h → ING_2EGB     ← 🟦 Padre 1
# Lunes       4h → LEN_2EGB     ← 🟦 Padre 1
# Lunes       6h → PRO_2EGB     ← 🟦 Padre 1
# Lunes       7h → DES_2EGB     ← 🟦 Padre 1
# Lunes       8h → SOC_2EGB     ← 🟦 Padre 1
# Lunes       9h → PLA_2EGB     ← 🟦 Padre 1
# Lunes      10h → NAT_2EGB     ← 🟦 Padre 1
# Lunes      13h → EDU_2EGB     ← 🟦 Padre 1
# Lunes      14h → SPE_2EGB     ← 🟦 Padre 1
# Lunes      15h → INV_2EGB     ← 🟦 Padre 1
# Lunes      16h → LEC_2EGB     ← 🟦 Padre 1
# Martes      1h → LEN_2EGB     ← 🟦 Padre 1
# Martes      2h → MAT_2EGB     ← 🟦 Padre 1
# Martes      3h → MAT_2EGB     ← 🟦 Padre 1
# Martes      4h → CIE_2EGB     ← 🟦 Padre 1
# Martes      6h → LEC_2EGB     ← 🟦 Padre 1
# Martes      7h → MAT_2EGB     ← 🟦 Padre 1
# Martes      8h → LEN_2EGB     ← 🟦 Padre 1
# Martes      9h → DES_2EGB     ← 🟦 Padre 1
# Martes     10h → PLA_2EGB     ← 🟦 Padre 1
# Martes     13h → ROB_2EGB     ← 🟦 Padre 1
# Martes     14h → NAT_2EGB     ← 🟦 Padre 1
# Miércoles   3h → NAT_2EGB     ← 🟦 Padre 1
# Miércoles   4h → LEN_2EGB     ← 🟦 Padre 1
# Miércoles   6h → LEN_2EGB     ← 🟦 Padre 1
# Miércoles   7h → ECO_2EGB     ← 🟦 Padre 1
# Miércoles   8h → SAL_2EGB     ← 🟦 Padre 1
# Miércoles   9h → MAT_2EGB     ← 🟦 Padre 1
# Miércoles  10h → LEC_2EGB     ← 🟦 Padre 1
# Miércoles  13h → MAT_2EGB     ← 🟦 Padre 1
# Miércoles  14h → CIE_2EGB     ← 🟦 Padre 1
# Miércoles  15h → MAT_2EGB     ← 🟦 Padre 1
# Miércoles  16h → NAT_2EGB     ← 🟦 Padre 1
# Viernes     1h → MAT_2EGB     ← 🟦 Padre 1
# Viernes     2h → MAT_2EGB     ← 🟦 Padre 1
# Viernes     3h → MAT_2EGB     ← 🟦 Padre 1
# Viernes     4h → EDU_2EGB     ← 🟦 Padre 1
# Viernes     6h → MUS_2EGB     ← 🟦 Padre 1
# Viernes     7h → DAN_2EGB     ← 🟦 Padre 1
# Viernes     8h → DER_2EGB     ← 🟦 Padre 1
# Viernes     9h → COM_2EGB     ← 🟦 Padre 1
# Viernes    10h → ING_2EGB     ← 🟦 Padre 1
# Viernes    13h → CIE_2EGB     ← 🟦 Padre 1
# Viernes    14h → ROB_2EGB     ← 🟦 Padre 1
# Viernes    15h → ING_2EGB     ← 🟦 Padre 1
# Viernes    16h → ING_2EGB     ← 🟦 Padre 1
# ------------------------------------------------------------
#
# 📚 Nivel: 2EGB | Aula: Amigables
# ------------------------------------------------------------
# Jueves      1h → DES_2EGB     ← 🟦 Padre 1
# Jueves      2h → MAT_2EGB     ← 🟦 Padre 1
# Jueves      3h → NAT_2EGB     ← 🟦 Padre 1
# Jueves      4h → PLA_2EGB     ← 🟦 Padre 1
# Jueves      6h → MAT_2EGB     ← 🟦 Padre 1
# Jueves      7h → CIE_2EGB     ← 🟦 Padre 1
# Jueves      8h → ING_2EGB     ← 🟦 Padre 1
# Jueves      9h → LEC_2EGB     ← 🟦 Padre 1
# Jueves     10h → MAT_2EGB     ← 🟦 Padre 1
# Jueves     13h → ING_2EGB     ← 🟦 Padre 1
# Jueves     14h → ROB_2EGB     ← 🟦 Padre 1
# Lunes       1h → PLA_2EGB     ← 🟦 Padre 1
# Lunes       2h → SPE_2EGB     ← 🟦 Padre 1
# Lunes       3h → INV_2EGB     ← 🟦 Padre 1
# Lunes       4h → CIE_2EGB     ← 🟦 Padre 1
# Lunes       6h → MAT_2EGB     ← 🟦 Padre 1
# Lunes       7h → NAT_2EGB     ← 🟦 Padre 1
# Lunes       8h → LEN_2EGB     ← 🟦 Padre 1
# Lunes       9h → MAT_2EGB     ← 🟦 Padre 1
# Lunes      10h → EDU_2EGB     ← 🟦 Padre 1
# Lunes      13h → LEC_2EGB     ← 🟦 Padre 1
# Lunes      14h → DAN_2EGB     ← 🟦 Padre 1
# Lunes      15h → MUS_2EGB     ← 🟦 Padre 1
# Lunes      16h → MAT_2EGB     ← 🟦 Padre 1
# Martes      1h → SOC_2EGB     ← 🟦 Padre 1
# Martes      2h → LEN_2EGB     ← 🟦 Padre 1
# Martes      3h → ROB_2EGB     ← 🟦 Padre 1
# Martes      4h → CIE_2EGB     ← 🟦 Padre 1
# Martes      6h → LEN_2EGB     ← 🟦 Padre 1
# Martes      7h → DES_2EGB     ← 🟦 Padre 1
# Martes      8h → LEN_2EGB     ← 🟦 Padre 1
# Martes      9h → NAT_2EGB     ← 🟦 Padre 1
# Martes     10h → MAT_2EGB     ← 🟦 Padre 1
# Martes     13h → ING_2EGB     ← 🟦 Padre 1
# Martes     14h → PRO_2EGB     ← 🟦 Padre 1
# Miércoles   3h → LEC_2EGB     ← 🟦 Padre 1
# Miércoles   4h → SOC_2EGB     ← 🟦 Padre 1
# Miércoles   6h → LEC_2EGB     ← 🟦 Padre 1
# Miércoles   7h → SAL_2EGB     ← 🟦 Padre 1
# Miércoles   8h → ECO_2EGB     ← 🟦 Padre 1
# Miércoles   9h → MAT_2EGB     ← 🟦 Padre 1
# Miércoles  10h → ING_2EGB     ← 🟦 Padre 1
# Miércoles  13h → MAT_2EGB     ← 🟦 Padre 1
# Miércoles  14h → MAT_2EGB     ← 🟦 Padre 1
# Miércoles  15h → EDU_2EGB     ← 🟦 Padre 1
# Miércoles  16h → CIE_2EGB     ← 🟦 Padre 1
# Viernes     1h → CAL_2EGB     ← 🟦 Padre 1
# Viernes     2h → EXP_2EGB     ← 🟦 Padre 1
# Viernes     3h → SOC_2EGB     ← 🟦 Padre 1
# Viernes     4h → LEN_2EGB     ← 🟦 Padre 1
# Viernes     6h → MAT_2EGB     ← 🟦 Padre 1
# Viernes     7h → ING_2EGB     ← 🟦 Padre 1
# Viernes     8h → ING_2EGB     ← 🟦 Padre 1
# Viernes     9h → MAT_2EGB     ← 🟦 Padre 1
# Viernes    10h → PRO_2EGB     ← 🟦 Padre 1
# Viernes    13h → DER_2EGB     ← 🟦 Padre 1
# Viernes    14h → COM_2EGB     ← 🟦 Padre 1
# Viernes    15h → LEN_2EGB     ← 🟦 Padre 1
# Viernes    16h → NAT_2EGB     ← 🟦 Padre 1
# ------------------------------------------------------------
#
# 📚 Nivel: 2EGB | Aula: Amistosos
# ------------------------------------------------------------
# Jueves      1h → LEN_2EGB     ← 🟦 Padre 1
# Jueves      2h → MAT_2EGB     ← 🟦 Padre 1
# Jueves      3h → CIE_2EGB     ← 🟦 Padre 1
# Jueves      4h → DES_2EGB     ← 🟦 Padre 1
# Jueves      6h → MUS_2EGB     ← 🟦 Padre 1
# Jueves      7h → DAN_2EGB     ← 🟦 Padre 1
# Jueves      8h → PLA_2EGB     ← 🟦 Padre 1
# Jueves      9h → PRO_2EGB     ← 🟦 Padre 1
# Jueves     10h → LEC_2EGB     ← 🟦 Padre 1
# Jueves     13h → LEN_2EGB     ← 🟦 Padre 1
# Jueves     14h → MAT_2EGB     ← 🟦 Padre 1
# Lunes       1h → ROB_2EGB     ← 🟦 Padre 1
# Lunes       2h → MAT_2EGB     ← 🟦 Padre 1
# Lunes       3h → MAT_2EGB     ← 🟦 Padre 1
# Lunes       4h → CIE_2EGB     ← 🟦 Padre 1
# Lunes       6h → ING_2EGB     ← 🟦 Padre 1
# Lunes       7h → DES_2EGB     ← 🟦 Padre 1
# Lunes       8h → PLA_2EGB     ← 🟦 Padre 1
# Lunes       9h → SOC_2EGB     ← 🟦 Padre 1
# Lunes      10h → SOC_2EGB     ← 🟦 Padre 1
# Lunes      13h → LEC_2EGB     ← 🟦 Padre 1
# Lunes      14h → ING_2EGB     ← 🟦 Padre 1
# Lunes      15h → MAT_2EGB     ← 🟦 Padre 1
# Lunes      16h → CIE_2EGB     ← 🟦 Padre 1
# Martes      1h → MAT_2EGB     ← 🟦 Padre 1
# Martes      2h → EXP_2EGB     ← 🟦 Padre 1
# Martes      3h → CAL_2EGB     ← 🟦 Padre 1
# Martes      4h → LEN_2EGB     ← 🟦 Padre 1
# Martes      6h → LEN_2EGB     ← 🟦 Padre 1
# Martes      7h → SPE_2EGB     ← 🟦 Padre 1
# Martes      8h → INV_2EGB     ← 🟦 Padre 1
# Martes      9h → ROB_2EGB     ← 🟦 Padre 1
# Martes     10h → EDU_2EGB     ← 🟦 Padre 1
# Martes     13h → EDU_2EGB     ← 🟦 Padre 1
# Martes     14h → ING_2EGB     ← 🟦 Padre 1
# Miércoles   3h → LEC_2EGB     ← 🟦 Padre 1
# Miércoles   4h → MAT_2EGB     ← 🟦 Padre 1
# Miércoles   6h → NAT_2EGB     ← 🟦 Padre 1
# Miércoles   7h → SOC_2EGB     ← 🟦 Padre 1
# Miércoles   8h → MAT_2EGB     ← 🟦 Padre 1
# Miércoles   9h → LEC_2EGB     ← 🟦 Padre 1
# Miércoles  10h → PRO_2EGB     ← 🟦 Padre 1
# Miércoles  13h → NAT_2EGB     ← 🟦 Padre 1
# Miércoles  14h → CIE_2EGB     ← 🟦 Padre 1
# Miércoles  15h → MAT_2EGB     ← 🟦 Padre 1
# Miércoles  16h → LEN_2EGB     ← 🟦 Padre 1
# Viernes     1h → ING_2EGB     ← 🟦 Padre 1
# Viernes     2h → NAT_2EGB     ← 🟦 Padre 1
# Viernes     3h → ING_2EGB     ← 🟦 Padre 1
# Viernes     4h → MAT_2EGB     ← 🟦 Padre 1
# Viernes     6h → SAL_2EGB     ← 🟦 Padre 1
# Viernes     7h → ECO_2EGB     ← 🟦 Padre 1
# Viernes     8h → DER_2EGB     ← 🟦 Padre 1
# Viernes     9h → COM_2EGB     ← 🟦 Padre 1
# Viernes    10h → MAT_2EGB     ← 🟦 Padre 1
# Viernes    13h → NAT_2EGB     ← 🟦 Padre 1
# Viernes    14h → ING_2EGB     ← 🟦 Padre 1
# Viernes    15h → LEN_2EGB     ← 🟦 Padre 1
# Viernes    16h → MAT_2EGB     ← 🟦 Padre 1
# ------------------------------------------------------------
#
# 📚 Nivel: 3BGU | Aula: Empáticos
# ------------------------------------------------------------
# Jueves      1h → LEN_3BGU     ← 🟦 Padre 1
# Jueves      2h → NAT_3BGU     ← 🟦 Padre 1
# Jueves      3h → ING_3BGU     ← 🟦 Padre 1
# Jueves      4h → ING_3BGU     ← 🟦 Padre 1
# Jueves      5h → MAT_3BGU     ← 🟦 Padre 1
# Jueves      7h → MAT_3BGU     ← 🟦 Padre 1
# Jueves      8h → PLA_3BGU     ← 🟦 Padre 1
# Jueves      9h → FIS_3BGU     ← 🟦 Padre 1
# Jueves     10h → QUI_3BGU     ← 🟦 Padre 1
# Jueves     11h → PEN_3BGU     ← 🟦 Padre 1
# Jueves     12h → LEC_3BGU     ← 🟦 Padre 1
# Jueves     15h → EMP_3BGU     ← 🟦 Padre 1
# Jueves     16h → GEO_3BGU     ← 🟦 Padre 1
# Lunes       1h → MAT_3BGU     ← 🟦 Padre 1
# Lunes       2h → LEN_3BGU     ← 🟦 Padre 1
# Lunes       3h → QUI_3BGU     ← 🟦 Padre 1
# Lunes       4h → SOC_3BGU     ← 🟦 Padre 1
# Lunes       5h → PEN_3BGU     ← 🟦 Padre 1
# Lunes       7h → INV_3BGU     ← 🟦 Padre 1
# Lunes       8h → SPE_3BGU     ← 🟦 Padre 1
# Lunes       9h → SOC_3BGU     ← 🟦 Padre 1
# Lunes      10h → FIS_3BGU     ← 🟦 Padre 1
# Lunes      11h → FIS_3BGU     ← 🟦 Padre 1
# Lunes      12h → FIS_3BGU     ← 🟦 Padre 1
# Lunes      15h → ROB_3BGU     ← 🟦 Padre 1
# Lunes      16h → MAT_3BGU     ← 🟦 Padre 1
# Martes      1h → SOC_3BGU     ← 🟦 Padre 1
# Martes      2h → EST_3BGU     ← 🟦 Padre 1
# Martes      3h → EST_3BGU     ← 🟦 Padre 1
# Martes      4h → NAT_3BGU     ← 🟦 Padre 1
# Martes      5h → MAT_3BGU     ← 🟦 Padre 1
# Martes      7h → NAT_3BGU     ← 🟦 Padre 1
# Martes      8h → EDU_3BGU     ← 🟦 Padre 1
# Martes      9h → DES_3BGU     ← 🟦 Padre 1
# Martes     10h → DES_3BGU     ← 🟦 Padre 1
# Martes     11h → LEC_3BGU     ← 🟦 Padre 1
# Martes     12h → PLA_3BGU     ← 🟦 Padre 1
# Martes     15h → LEC_3BGU     ← 🟦 Padre 1
# Martes     16h → PEN_3BGU     ← 🟦 Padre 1
# Miércoles   3h → LEN_3BGU     ← 🟦 Padre 1
# Miércoles   4h → QUI_3BGU     ← 🟦 Padre 1
# Miércoles   5h → PRO_3BGU     ← 🟦 Padre 1
# Miércoles   7h → ECO_3BGU     ← 🟦 Padre 1
# Miércoles   8h → SAL_3BGU     ← 🟦 Padre 1
# Miércoles   9h → ROB_3BGU     ← 🟦 Padre 1
# Miércoles  10h → ING_3BGU     ← 🟦 Padre 1
# Miércoles  11h → ING_3BGU     ← 🟦 Padre 1
# Miércoles  12h → EDU_3BGU     ← 🟦 Padre 1
# Viernes     1h → GEO_3BGU     ← 🟦 Padre 1
# Viernes     2h → MAT_3BGU     ← 🟦 Padre 1
# Viernes     3h → COM_3BGU     ← 🟦 Padre 1
# Viernes     4h → DER_3BGU     ← 🟦 Padre 1
# Viernes     5h → QUI_3BGU     ← 🟦 Padre 1
# Viernes     7h → EMP_3BGU     ← 🟦 Padre 1
# Viernes     8h → SOC_3BGU     ← 🟦 Padre 1
# Viernes     9h → GEO_3BGU     ← 🟦 Padre 1
# Viernes    10h → PRO_3BGU     ← 🟦 Padre 1
# Viernes    11h → ING_3BGU     ← 🟦 Padre 1
# Viernes    12h → ING_3BGU     ← 🟦 Padre 1
# ------------------------------------------------------------
#
# 📚 Nivel: 3BGU | Aula: Solidarios
# ------------------------------------------------------------
# Jueves      1h → MAT_3BGU     ← 🟦 Padre 1
# Jueves      2h → MAT_3BGU     ← 🟦 Padre 1
# Jueves      3h → ING_3BGU     ← 🟦 Padre 1
# Jueves      4h → ING_3BGU     ← 🟦 Padre 1
# Jueves      5h → PLA_3BGU     ← 🟦 Padre 1
# Jueves      7h → NAT_3BGU     ← 🟦 Padre 1
# Jueves      8h → LEC_3BGU     ← 🟦 Padre 1
# Jueves      9h → INV_3BGU     ← 🟦 Padre 1
# Jueves     10h → SPE_3BGU     ← 🟦 Padre 1
# Jueves     11h → GEO_3BGU     ← 🟦 Padre 1
# ...
# Viernes    12h → LEC_8EGB     ← 🟧 Reconstruido
# ------------------------------------------------------------
#
# 📚 Nivel: 8EGB | Aula: Dinámicos
# ------------------------------------------------------------
# Jueves      1h → LEC_8EGB     ← 🟦 Padre 1
# Jueves      2h → DER_8EGB     ← 🟦 Padre 1
# Jueves      3h → COM_8EGB     ← 🟦 Padre 1
# Jueves      4h → LEN_8EGB     ← 🟦 Padre 1
# Jueves      5h → EST_8EGB     ← 🟦 Padre 1
# Jueves      7h → SOC_8EGB     ← 🟦 Padre 1
# Jueves      8h → ING_8EGB     ← 🟦 Padre 1
# Jueves      9h → ING_8EGB     ← 🟦 Padre 1
# Jueves     10h → SOC_8EGB     ← 🟦 Padre 1
# Jueves     11h → MAT_8EGB     ← 🟦 Padre 1
# Jueves     12h → MAT_8EGB     ← 🟦 Padre 1
# Jueves     15h → EST_8EGB     ← 🟦 Padre 1
# Jueves     16h → ROB_8EGB     ← 🟦 Padre 1
# Lunes       1h → PEN_8EGB     ← 🟦 Padre 1
# Lunes       2h → ING_8EGB     ← 🟦 Padre 1
# Lunes       3h → ING_8EGB     ← 🟦 Padre 1
# Lunes       4h → NAT_8EGB     ← 🟦 Padre 1
# Lunes       5h → PLA_8EGB     ← 🟦 Padre 1
# Lunes       7h → EDU_8EGB     ← 🟦 Padre 1
# Lunes       8h → EMP_8EGB     ← 🟦 Padre 1
# Lunes       9h → ROB_8EGB     ← 🟦 Padre 1
# Lunes      10h → QUI_8EGB     ← 🟦 Padre 1
# Lunes      11h → QUI_8EGB     ← 🟦 Padre 1
# Lunes      12h → PRO_8EGB     ← 🟦 Padre 1
# Lunes      15h → NAT_8EGB     ← 🟦 Padre 1
# Lunes      16h → PLA_8EGB     ← 🟦 Padre 1
# Martes      1h → PEN_8EGB     ← 🟦 Padre 1
# Martes      2h → QUI_8EGB     ← 🟦 Padre 1
# Martes      3h → FIS_8EGB     ← 🟦 Padre 1
# Martes      4h → ING_8EGB     ← 🟦 Padre 1
# Martes      5h → ING_8EGB     ← 🟦 Padre 1
# Martes      7h → LEC_8EGB     ← 🟦 Padre 1
# Martes      8h → GEO_8EGB     ← 🟦 Padre 1
# Martes      9h → DAN_8EGB     ← 🟦 Padre 1
# Martes     10h → MUS_8EGB     ← 🟦 Padre 1
# Martes     11h → LEN_8EGB     ← 🟦 Padre 1
# Martes     12h → MAT_8EGB     ← 🟦 Padre 1
# Martes     15h → EDU_8EGB     ← 🟦 Padre 1
# Martes     16h → SOC_8EGB     ← 🟦 Padre 1
# Miércoles   3h → LEC_8EGB     ← 🟦 Padre 1
# Miércoles   4h → EMP_8EGB     ← 🟦 Padre 1
# Miércoles   5h → PRO_8EGB     ← 🟦 Padre 1
# Miércoles   7h → NAT_8EGB     ← 🟦 Padre 1
# Miércoles   8h → PEN_8EGB     ← 🟦 Padre 1
# Miércoles   9h → MAT_8EGB     ← 🟦 Padre 1
# Miércoles  10h → DES_8EGB     ← 🟦 Padre 1
# Miércoles  11h → DES_8EGB     ← 🟦 Padre 1
# Miércoles  12h → GEO_8EGB     ← 🟦 Padre 1
# Viernes     1h → SAL_8EGB     ← 🟦 Padre 1
# Viernes     2h → ECO_8EGB     ← 🟦 Padre 1
# Viernes     3h → MAT_8EGB     ← 🟦 Padre 1
# Viernes     4h → LEC_8EGB     ← 🟦 Padre 1
# Viernes     5h → MAT_8EGB     ← 🟦 Padre 1
# Viernes     7h → FIS_8EGB     ← 🟦 Padre 1
# Viernes     8h → SPE_8EGB     ← 🟦 Padre 1
# Viernes     9h → INV_8EGB     ← 🟦 Padre 1
# Viernes    10h → GEO_8EGB     ← 🟦 Padre 1
# Viernes    11h → GEO_8EGB     ← 🟦 Padre 1
# Viernes    12h → PEN_8EGB     ← 🟦 Padre 1
# ------------------------------------------------------------
#
# 📚 Nivel: 8EGB | Aula: Disciplinados
# ------------------------------------------------------------
# Jueves      1h → SOC_8EGB     ← 🟦 Padre 1
# Jueves      2h → EDU_8EGB     ← 🟦 Padre 1
# Jueves      3h → FIS_8EGB     ← 🟦 Padre 1
# Jueves      4h → NAT_8EGB     ← 🟦 Padre 1
# Jueves      5h → EMP_8EGB     ← 🟦 Padre 1
# Jueves      7h → GEO_8EGB     ← 🟦 Padre 1
# Jueves      8h → ING_8EGB     ← 🟦 Padre 1
# Jueves      9h → ING_8EGB     ← 🟦 Padre 1
# Jueves     10h → QUI_8EGB     ← 🟦 Padre 1
# Jueves     11h → ROB_8EGB     ← 🟦 Padre 1
# Jueves     12h → FIS_8EGB     ← 🟦 Padre 1
# Jueves     15h → MAT_8EGB     ← 🟦 Padre 1
# Jueves     16h → PEN_8EGB     ← 🟩 Padre 2
# Lunes       1h → DES_8EGB     ← 🟦 Padre 1
# Lunes       2h → ING_8EGB     ← 🟦 Padre 1
# Lunes       3h → ING_8EGB     ← 🟦 Padre 1
# Lunes       4h → QUI_8EGB     ← 🟦 Padre 1
# Lunes       5h → LEN_8EGB     ← 🟦 Padre 1
# Lunes       7h → MAT_8EGB     ← 🟦 Padre 1
# Lunes       8h → LEC_8EGB     ← 🟦 Padre 1
# Lunes       9h → INV_8EGB     ← 🟦 Padre 1
# Lunes      10h → SPE_8EGB     ← 🟦 Padre 1
# Lunes      11h → GEO_8EGB     ← 🟦 Padre 1
# Lunes      12h → PEN_8EGB     ← 🟦 Padre 1
# Lunes      15h → EST_8EGB     ← 🟦 Padre 1
# Lunes      16h → PEN_8EGB     ← 🟦 Padre 1
# Martes      1h → PEN_8EGB     ← 🟦 Padre 1
# Martes      2h → PLA_8EGB     ← 🟦 Padre 1
# Martes      3h → DAN_8EGB     ← 🟩 Padre 2
# Martes      4h → MUS_8EGB     ← 🟩 Padre 2
# Martes      5h → ING_8EGB     ← 🟦 Padre 1
# Martes      7h → PLA_8EGB     ← 🟦 Padre 1
# Martes      8h → QUI_8EGB     ← 🟦 Padre 1
# Martes      9h → LEN_8EGB     ← 🟦 Padre 1
# Martes     10h → PRO_8EGB     ← 🟦 Padre 1
# Martes     11h → PRO_8EGB     ← 🟧 Reconstruido
# Martes     12h → SOC_8EGB     ← 🟦 Padre 1
# Martes     15h → EMP_8EGB     ← 🟦 Padre 1
# Martes     16h → GEO_8EGB     ← 🟦 Padre 1
# Miércoles   3h → MAT_8EGB     ← 🟦 Padre 1
# Miércoles   4h → MAT_8EGB     ← 🟦 Padre 1
# Miércoles   5h → DES_8EGB     ← 🟦 Padre 1
# Miércoles   7h → EDU_8EGB     ← 🟦 Padre 1
# Miércoles   8h → ROB_8EGB     ← 🟧 Reconstruido
# Miércoles   9h → SAL_8EGB     ← 🟧 Reconstruido
# Miércoles  10h → ECO_8EGB     ← 🟦 Padre 1
# Miércoles  11h → MAT_8EGB     ← 🟦 Padre 1
# Miércoles  12h → LEC_8EGB     ← 🟦 Padre 1
# Viernes     1h → EST_8EGB     ← 🟦 Padre 1
# Viernes     2h → LEC_8EGB     ← 🟦 Padre 1
# Viernes     3h → NAT_8EGB     ← 🟦 Padre 1
# Viernes     4h → MAT_8EGB     ← 🟦 Padre 1
# Viernes     5h → SOC_8EGB     ← 🟦 Padre 1
# Viernes     7h → GEO_8EGB     ← 🟦 Padre 1
# Viernes     8h → DER_8EGB     ← 🟦 Padre 1
# Viernes     9h → COM_8EGB     ← 🟦 Padre 1
# Viernes    10h → LEC_8EGB     ← 🟦 Padre 1
# Viernes    11h → NAT_8EGB     ← 🟦 Padre 1
# Viernes    12h → ING_8EGB     ← 🟧 Reconstruido
# ------------------------------------------------------------
#
# 📚 Nivel: 9EGB | Aula: Altruistas
# ------------------------------------------------------------
# Jueves      1h → MAT_9EGB     ← 🟦 Padre 1
# Jueves      2h → ROB_9EGB     ← 🟦 Padre 1
# Jueves      3h → SPE_9EGB     ← 🟦 Padre 1
# Jueves      4h → INV_9EGB     ← 🟦 Padre 1
# Jueves      5h → DES_9EGB     ← 🟦 Padre 1
# Jueves      7h → LEC_9EGB     ← 🟦 Padre 1
# Jueves      8h → ECO_9EGB     ← 🟦 Padre 1
# Jueves      9h → SAL_9EGB     ← 🟦 Padre 1
# Jueves     10h → MAT_9EGB     ← 🟦 Padre 1
# Jueves     11h → SOC_9EGB     ← 🟦 Padre 1
# Jueves     12h → FIS_9EGB     ← 🟦 Padre 1
# Jueves     15h → GEO_9EGB     ← 🟦 Padre 1
# Jueves     16h → PLA_9EGB     ← 🟦 Padre 1
# Lunes       1h → LEN_9EGB     ← 🟦 Padre 1
# Lunes       2h → QUI_9EGB     ← 🟦 Padre 1
# Lunes       3h → DER_9EGB     ← 🟦 Padre 1
# Lunes       4h → COM_9EGB     ← 🟦 Padre 1
# Lunes       5h → EDU_9EGB     ← 🟦 Padre 1
# Lunes       7h → MAT_9EGB     ← 🟦 Padre 1
# Lunes       8h → LEC_9EGB     ← 🟦 Padre 1
# Lunes       9h → LEN_9EGB     ← 🟦 Padre 1
# Lunes      10h → ROB_9EGB     ← 🟦 Padre 1
# Lunes      11h → LEC_9EGB     ← 🟦 Padre 1
# Lunes      12h → EST_9EGB     ← 🟦 Padre 1
# Lunes      15h → GEO_9EGB     ← 🟦 Padre 1
# Lunes      16h → LEC_9EGB     ← 🟦 Padre 1
# Martes      1h → QUI_9EGB     ← 🟦 Padre 1
# Martes      2h → FIS_9EGB     ← 🟦 Padre 1
# Martes      3h → ING_9EGB     ← 🟦 Padre 1
# Martes      4h → ING_9EGB     ← 🟦 Padre 1
# Martes      5h → PEN_9EGB     ← 🟦 Padre 1
# Martes      7h → PRO_9EGB     ← 🟦 Padre 1
# Martes      8h → MAT_9EGB     ← 🟦 Padre 1
# Martes      9h → PRO_9EGB     ← 🟦 Padre 1
# Martes     10h → EMP_9EGB     ← 🟦 Padre 1
# Martes     11h → ING_9EGB     ← 🟦 Padre 1
# Martes     12h → ING_9EGB     ← 🟦 Padre 1
# Martes     15h → MAT_9EGB     ← 🟦 Padre 1
# Martes     16h → GEO_9EGB     ← 🟦 Padre 1
# Miércoles   3h → EMP_9EGB     ← 🟦 Padre 1
# Miércoles   4h → SOC_9EGB     ← 🟦 Padre 1
# Miércoles   5h → PEN_9EGB     ← 🟦 Padre 1
# Miércoles   7h → EST_9EGB     ← 🟦 Padre 1
# Miércoles   8h → QUI_9EGB     ← 🟦 Padre 1
# Miércoles   9h → PLA_9EGB     ← 🟦 Padre 1
# Miércoles  10h → MAT_9EGB     ← 🟦 Padre 1
# Miércoles  11h → PEN_9EGB     ← 🟦 Padre 1
# Miércoles  12h → PEN_9EGB     ← 🟦 Padre 1
# Viernes     1h → DAN_9EGB     ← 🟦 Padre 1
# Viernes     2h → MUS_9EGB     ← 🟦 Padre 1
# Viernes     3h → QUI_9EGB     ← 🟦 Padre 1
# Viernes     4h → GEO_9EGB     ← 🟦 Padre 1
# Viernes     5h → QUI_9EGB     ← 🟦 Padre 1
# Viernes     7h → QUI_9EGB     ← 🟦 Padre 1
# Viernes     8h → DES_9EGB     ← 🟦 Padre 1
# Viernes     9h → EDU_9EGB     ← 🟦 Padre 1
# Viernes    10h → ING_9EGB     ← 🟦 Padre 1
# Viernes    11h → ING_9EGB     ← 🟦 Padre 1
# Viernes    12h → SOC_9EGB     ← 🟦 Padre 1
# ------------------------------------------------------------
#
# 📚 Nivel: 9EGB | Aula: Asertivos
# ------------------------------------------------------------
# Jueves      1h → DER_9EGB     ← 🟦 Padre 1
# Jueves      2h → COM_9EGB     ← 🟦 Padre 1
# Jueves      3h → LEC_9EGB     ← 🟦 Padre 1
# Jueves      4h → EMP_9EGB     ← 🟦 Padre 1
# Jueves      5h → LEN_9EGB     ← 🟦 Padre 1
# Jueves      7h → EDU_9EGB     ← 🟦 Padre 1
# Jueves      8h → EMP_9EGB     ← 🟦 Padre 1
# Jueves      9h → SOC_9EGB     ← 🟦 Padre 1
# Jueves     10h → LEC_9EGB     ← 🟦 Padre 1
# Jueves     11h → QUI_9EGB     ← 🟦 Padre 1
# Jueves     12h → PEN_9EGB     ← 🟦 Padre 1
# Jueves     15h → GEO_9EGB     ← 🟦 Padre 1
# Jueves     16h → GEO_9EGB     ← 🟦 Padre 1
# Lunes       1h → PLA_9EGB     ← 🟦 Padre 1
# Lunes       2h → EDU_9EGB     ← 🟦 Padre 1
# Lunes       3h → DES_9EGB     ← 🟦 Padre 1
# Lunes       4h → MAT_9EGB     ← 🟦 Padre 1
# Lunes       5h → QUI_9EGB     ← 🟦 Padre 1
# Lunes       7h → EST_9EGB     ← 🟦 Padre 1
# Lunes       8h → SOC_9EGB     ← 🟦 Padre 1
# Lunes       9h → PRO_9EGB     ← 🟦 Padre 1
# Lunes      10h → SOC_9EGB     ← 🟦 Padre 1
# Lunes      11h → LEN_9EGB     ← 🟦 Padre 1
# Lunes      12h → QUI_9EGB     ← 🟦 Padre 1
# Lunes      15h → PRO_9EGB     ← 🟦 Padre 1
# Lunes      16h → PLA_9EGB     ← 🟦 Padre 1
# Martes      1h → FIS_9EGB     ← 🟦 Padre 1
# Martes      2h → FIS_9EGB     ← 🟦 Padre 1
# Martes      3h → ING_9EGB     ← 🟦 Padre 1
# Martes      4h → ING_9EGB     ← 🟦 Padre 1
# Martes      5h → LEC_9EGB     ← 🟦 Padre 1
# Martes      7h → DES_9EGB     ← 🟦 Padre 1
# Martes      8h → ECO_9EGB     ← 🟦 Padre 1
# Martes      9h → SAL_9EGB     ← 🟦 Padre 1
# Martes     10h → MAT_9EGB     ← 🟦 Padre 1
# Martes     11h → ING_9EGB     ← 🟦 Padre 1
# Martes     12h → ING_9EGB     ← 🟦 Padre 1
# Martes     15h → PEN_9EGB     ← 🟦 Padre 1
# Martes     16h → QUI_9EGB     ← 🟦 Padre 1
# Miércoles   3h → LEC_9EGB     ← 🟦 Padre 1
# Miércoles   4h → GEO_9EGB     ← 🟦 Padre 1
# Miércoles   5h → MAT_9EGB     ← 🟦 Padre 1
# Miércoles   7h → MAT_9EGB     ← 🟦 Padre 1
# Miércoles   8h → EST_9EGB     ← 🟦 Padre 1
# Miércoles   9h → QUI_9EGB     ← 🟦 Padre 1
# Miércoles  10h → QUI_9EGB     ← 🟦 Padre 1
# Miércoles  11h → ROB_9EGB     ← 🟦 Padre 1
# Miércoles  12h → MAT_9EGB     ← 🟦 Padre 1
# Viernes     1h → SPE_9EGB     ← 🟦 Padre 1
# Viernes     2h → INV_9EGB     ← 🟦 Padre 1
# Viernes     3h → PEN_9EGB     ← 🟦 Padre 1
# Viernes     4h → ROB_9EGB     ← 🟦 Padre 1
# Viernes     5h → GEO_9EGB     ← 🟦 Padre 1
# Viernes     7h → MUS_9EGB     ← 🟦 Padre 1
# Viernes     8h → DAN_9EGB     ← 🟦 Padre 1
# Viernes     9h → PEN_9EGB     ← 🟦 Padre 1
# Viernes    10h → ING_9EGB     ← 🟦 Padre 1
# Viernes    11h → ING_9EGB     ← 🟦 Padre 1
# Viernes    12h → MAT_9EGB     ← 🟦 Padre 1
# ------------------------------------------------------------
#
# 📚 Nivel: 9EGB | Aula: Audaces
# ------------------------------------------------------------
# Jueves      1h → PEN_9EGB     ← 🟦 Padre 1
# Jueves      2h → SOC_9EGB     ← 🟦 Padre 1
# Jueves      3h → COM_9EGB     ← 🟦 Padre 1
# Jueves      4h → DER_9EGB     ← 🟦 Padre 1
# Jueves      5h → PRO_9EGB     ← 🟦 Padre 1
# Jueves      7h → GEO_9EGB     ← 🟦 Padre 1
# Jueves      8h → MUS_9EGB     ← 🟦 Padre 1
# Jueves      9h → DAN_9EGB     ← 🟦 Padre 1
# Jueves     10h → SAL_9EGB     ← 🟦 Padre 1
# Jueves     11h → ECO_9EGB     ← 🟦 Padre 1
# Jueves     12h → PEN_9EGB     ← 🟦 Padre 1
# Jueves     15h → MAT_9EGB     ← 🟦 Padre 1
# Jueves     16h → SOC_9EGB     ← 🟦 Padre 1
# Lunes       1h → LEC_9EGB     ← 🟦 Padre 1
# Lunes       2h → PRO_9EGB     ← 🟦 Padre 1
# Lunes       3h → PEN_9EGB     ← 🟦 Padre 1
# Lunes       4h → MAT_9EGB     ← 🟦 Padre 1
# Lunes       5h → LEC_9EGB     ← 🟦 Padre 1
# Lunes       7h → QUI_9EGB     ← 🟦 Padre 1
# Lunes       8h → SOC_9EGB     ← 🟦 Padre 1
# Lunes       9h → LEN_9EGB     ← 🟦 Padre 1
# Lunes      10h → EST_9EGB     ← 🟦 Padre 1
# Lunes      11h → QUI_9EGB     ← 🟦 Padre 1
# Lunes      12h → QUI_9EGB     ← 🟦 Padre 1
# Lunes      15h → GEO_9EGB     ← 🟦 Padre 1
# Lunes      16h → MAT_9EGB     ← 🟦 Padre 1
# Martes      1h → MAT_9EGB     ← 🟦 Padre 1
# Martes      2h → FIS_9EGB     ← 🟦 Padre 1
# Martes      3h → ING_9EGB     ← 🟦 Padre 1
# Martes      4h → ING_9EGB     ← 🟦 Padre 1
# Martes      5h → EDU_9EGB     ← 🟦 Padre 1
# Martes      7h → LEC_9EGB     ← 🟦 Padre 1
# Martes      8h → QUI_9EGB     ← 🟦 Padre 1
# Martes      9h → ROB_9EGB     ← 🟦 Padre 1
# Martes     10h → PEN_9EGB     ← 🟦 Padre 1
# Martes     11h → ING_9EGB     ← 🟦 Padre 1
# Martes     12h → ING_9EGB     ← 🟦 Padre 1
# Martes     15h → PLA_9EGB     ← 🟦 Padre 1
# Martes     16h → LEN_9EGB     ← 🟦 Padre 1
# Miércoles   3h → DES_9EGB     ← 🟦 Padre 1
# Miércoles   4h → DES_9EGB     ← 🟦 Padre 1
# Miércoles   5h → QUI_9EGB     ← 🟦 Padre 1
# Miércoles   7h → MAT_9EGB     ← 🟦 Padre 1
# Miércoles   8h → FIS_9EGB     ← 🟦 Padre 1
# Miércoles   9h → SPE_9EGB     ← 🟦 Padre 1
# Miércoles  10h → INV_9EGB     ← 🟦 Padre 1
# Miércoles  11h → EMP_9EGB     ← 🟦 Padre 1
# Miércoles  12h → GEO_9EGB     ← 🟦 Padre 1
# Viernes     1h → EDU_9EGB     ← 🟦 Padre 1
# Viernes     2h → MAT_9EGB     ← 🟦 Padre 1
# Viernes     3h → LEC_9EGB     ← 🟦 Padre 1
# Viernes     4h → EMP_9EGB     ← 🟦 Padre 1
# Viernes     5h → PLA_9EGB     ← 🟦 Padre 1
# Viernes     7h → EST_9EGB     ← 🟦 Padre 1
# Viernes     8h → ROB_9EGB     ← 🟦 Padre 1
# Viernes     9h → QUI_9EGB     ← 🟦 Padre 1
# Viernes    10h → ING_9EGB     ← 🟦 Padre 1
# Viernes    11h → ING_9EGB     ← 🟦 Padre 1
# Viernes    12h → GEO_9EGB     ← 🟦 Padre 1
# ------------------------------------------------------------
#
# 📚 Nivel: 9EGB | Aula: Auténticos
# ------------------------------------------------------------
# Jueves      1h → PEN_9EGB     ← 🟦 Padre 1
# Jueves      2h → PLA_9EGB     ← 🟦 Padre 1
# Jueves      3h → LEC_9EGB     ← 🟦 Padre 1
# Jueves      4h → PEN_9EGB     ← 🟦 Padre 1
# Jueves      5h → SOC_9EGB     ← 🟦 Padre 1
# Jueves      7h → ROB_9EGB     ← 🟧 Reconstruido
# Jueves      8h → SAL_9EGB     ← 🟧 Reconstruido
# Jueves      9h → ECO_9EGB     ← 🟦 Padre 1
# Jueves     10h → QUI_9EGB     ← 🟦 Padre 1
# Jueves     11h → QUI_9EGB     ← 🟦 Padre 1
# Jueves     12h → EST_9EGB     ← 🟦 Padre 1
# Jueves     15h → ROB_9EGB     ← 🟦 Padre 1
# Jueves     16h → MAT_9EGB     ← 🟦 Padre 1
# Lunes       1h → SOC_9EGB     ← 🟦 Padre 1
# Lunes       2h → FIS_9EGB     ← 🟧 Reconstruido
# Lunes       3h → LEN_9EGB     ← 🟦 Padre 1
# Lunes       4h → PEN_9EGB     ← 🟦 Padre 1
# Lunes       5h → EMP_9EGB     ← 🟦 Padre 1
# Lunes       7h → QUI_9EGB     ← 🟦 Padre 1
# Lunes       8h → EMP_9EGB     ← 🟦 Padre 1
# Lunes       9h → MUS_9EGB     ← 🟩 Padre 2
# Lunes      10h → DAN_9EGB     ← 🟩 Padre 2
# Lunes      11h → LEC_9EGB     ← 🟦 Padre 1
# Lunes      12h → GEO_9EGB     ← 🟦 Padre 1
# Lunes      15h → EDU_9EGB     ← 🟦 Padre 1
# Lunes      16h → QUI_9EGB     ← 🟦 Padre 1
# Martes      1h → SOC_9EGB     ← 🟦 Padre 1
# Martes      2h → DES_9EGB     ← 🟦 Padre 1
# Martes      3h → ING_9EGB     ← 🟦 Padre 1
# Martes      4h → ING_9EGB     ← 🟦 Padre 1
# Martes      5h → PEN_9EGB     ← 🟦 Padre 1
# Martes      7h → DER_9EGB     ← 🟦 Padre 1
# Martes      8h → COM_9EGB     ← 🟧 Reconstruido
# Martes      9h → QUI_9EGB     ← 🟧 Reconstruido
# Martes     10h → MAT_9EGB     ← 🟦 Padre 1
# Martes     11h → ING_9EGB     ← 🟦 Padre 1
# Martes     12h → ING_9EGB     ← 🟦 Padre 1
# Martes     15h → LEC_9EGB     ← 🟦 Padre 1
# Martes     16h → PLA_9EGB     ← 🟦 Padre 1
# Miércoles   3h → PRO_9EGB     ← 🟦 Padre 1
# Miércoles   4h → GEO_9EGB     ← 🟦 Padre 1
# Miércoles   5h → PRO_9EGB     ← 🟦 Padre 1
# Miércoles   7h → MAT_9EGB     ← 🟦 Padre 1
# Miércoles   8h → EDU_9EGB     ← 🟦 Padre 1
# Miércoles   9h → SPE_9EGB     ← 🟩 Padre 2
# Miércoles  10h → INV_9EGB     ← 🟩 Padre 2
# Miércoles  11h → GEO_9EGB     ← 🟦 Padre 1
# Miércoles  12h → QUI_9EGB     ← 🟦 Padre 1
# Viernes     1h → MAT_9EGB     ← 🟦 Padre 1
# Viernes     2h → GEO_9EGB     ← 🟦 Padre 1
# Viernes     3h → FIS_9EGB     ← 🟦 Padre 1
# Viernes     4h → DES_9EGB     ← 🟦 Padre 1
# Viernes     5h → MAT_9EGB     ← 🟦 Padre 1
# Viernes     7h → EST_9EGB     ← 🟦 Padre 1
# Viernes     8h → LEC_9EGB     ← 🟦 Padre 1
# Viernes     9h → MAT_9EGB     ← 🟩 Padre 2
# Viernes    10h → ING_9EGB     ← 🟦 Padre 1
# Viernes    11h → ING_9EGB     ← 🟦 Padre 1
# Viernes    12h → LEN_9EGB     ← 🟧 Reconstruido
# ------------------------------------------------------------

# %% [markdown]
# ## 🔁 Operador de mutación: intercambio de materias dentro del mismo nivel
#
# Este operador de mutación introduce variación genética en el cromosoma (hijo) al intercambiar aleatoriamente dos asignaciones (genes) **dentro del mismo nivel educativo**, preservando así la coherencia estructural del horario.
#
# ### 🧬 ¿Cómo funciona?
#
# 1. Para cada nivel (e.g. 6EGB, 1BGU), se identifica la sublista de genes correspondientes.
# 2. Con una probabilidad `prob_mutacion`, se seleccionan dos posiciones aleatorias dentro de ese nivel.
# 3. Se intercambian las **materias** y los **docentes correspondientes** entre esas dos posiciones.
# 4. Las demás propiedades del gen (nivel, aula, día, hora) se conservan.
#
# ### Parámetro:
# - `prob_mutacion`: probabilidad con la que se aplica el intercambio en cada nivel (por defecto: 10%).
#
# ### Ventajas:
# - 🔄 Mantiene la asignación horaria constante (no cambia días ni horas).
# - 🎲 Introduce variabilidad sin romper la estructura del horario.
# - 📊 Ayuda a escapar de óptimos locales durante la evolución.
#
# > 💡 Este tipo de mutación es especialmente útil cuando el crossover ya genera soluciones válidas pero se desea **refinar o explorar nuevas combinaciones** sin perturbar demasiado la factibilidad.

# %%
import random
from copy import deepcopy
# Función de mutación: intercambio de materias en el mismo nivel
def mutacion_intercambio(hijo, prob_mutacion=0.1):
    hijo_mutado = deepcopy(hijo)

    niveles = set(gen[0] for gen in hijo_mutado)

    for nivel in niveles:
        # Obtener índices del nivel actual
        indices_nivel = [i for i, gen in enumerate(hijo_mutado) if gen[0] == nivel]

        if len(indices_nivel) >= 2:
            # Con probabilidad prob_mutacion, aplicar swap
            if random.random() < prob_mutacion:
                idx1, idx2 = random.sample(indices_nivel, 2)

                # Intercambiar materias
                materia1 = hijo_mutado[idx1][4]
                materia2 = hijo_mutado[idx2][4]

                # Reasignar materias y docentes intercambiados
                nivel1, aula1, dia1, hora1, _, _ = hijo_mutado[idx1]
                nivel2, aula2, dia2, hora2, _, _ = hijo_mutado[idx2]

                docente1 = obtener_docente_por_materia_codigo(materia1)
                docente2 = obtener_docente_por_materia_codigo(materia2)

                hijo_mutado[idx1] = (nivel1, aula1, dia1, hora1, materia2, docente2)
                hijo_mutado[idx2] = (nivel2, aula2, dia2, hora2, materia1, docente1)

    return hijo_mutado

# Ejemplo de uso:
hijo_mutado = mutacion_intercambio(hijo_ejemplo, prob_mutacion=0.1)

# Inspección visual
print("Primeros 10 genes del hijo después de la mutación:")
for gen in hijo_mutado[:10]:
    print(gen)
# Out:
# Primeros 10 genes del hijo después de la mutación:
# ('1EGB', 'Ejemplares', 'Lunes', 1, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Ejemplares', 'Lunes', 2, 'PEN_1EGB', 'FERNANDA CAÑIZARES')
# ('1EGB', 'Ejemplares', 'Lunes', 3, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Ejemplares', 'Lunes', 4, 'LEN_1EGB', 'MALENA OÑA')
# ('1EGB', 'Ejemplares', 'Lunes', 6, 'EXT_1EGB', 'MARIEL RODRIGUEZ')
# ('1EGB', 'Ejemplares', 'Lunes', 7, 'LEC_1EGB', 'ALISON PLAZA')
# ('1EGB', 'Ejemplares', 'Lunes', 8, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Ejemplares', 'Lunes', 9, 'ING_1EGB', 'MARCIA HERRERA VÁSQUEZ')
# ('1EGB', 'Ejemplares', 'Lunes', 10, 'MAT_1EGB', 'PAULINA ÑACATO')
# ('1EGB', 'Ejemplares', 'Lunes', 13, 'MAT_1EGB', 'PAULINA ÑACATO')

# %% [markdown]
# ## 🧬 Generación de nueva población a partir de padres seleccionados (elitismo + crossover + mutación)
#
# Esta función implementa el ciclo reproductivo del algoritmo genético: a partir de la élite seleccionada mediante fitness, se genera una nueva población mediante **cruce híbrido heurístico** y **mutación estructurada**.
#
# ### 🧱 ¿Cómo funciona?
#
# 1. Se toman pares aleatorios de la lista de `padres`.
# 2. Se aplica el operador `crossover_hibrido_heuristico_burke()` para producir un hijo.
# 3. Se aplica `mutacion_intercambio()` sobre el hijo resultante.
# 4. El nuevo cromosoma es agregado a la nueva población.
#
# ### Parámetro:
# - `prob_mutacion`: probabilidad de aplicar mutación a cada hijo generado.
#
# ### Resultado:
# Devuelve una lista con la **nueva generación** de cromosomas, del mismo tamaño que la cantidad de padres.
#
# ### Aplicaciones:
# - 🔄 Introduce recombinación genética para explorar el espacio de soluciones.
# - 🌱 Preserva parcialmente el conocimiento de los padres mientras se generan soluciones nuevas.
# - 📉 Junto con elitismo, permite conservar la calidad mientras se mantiene diversidad.
#
# > 🔍 El crossover implementado sigue un enfoque híbrido basado en Burke et al. (2004), que favorece la herencia de bloques sincronizados y pares pedagógicos clave.

# %%
# Función para generar una nueva población a partir de la élite
def generar_nueva_generacion(padres, prob_mutacion=0.1):
    nueva_generacion = []

    # Asumiendo que padres ya es una lista de individuos seleccionados
    cantidad_padres = len(padres)

    for _ in range(cantidad_padres):  # Generar tantos hijos como padres disponibles
        # Seleccionar dos padres aleatoriamente
        padre1, padre2 = random.sample(padres, 2)

        # Crossover
        hijo = crossover_hibrido_heuristico_burke(padre1, padre2)

        # Mutación
        hijo_mutado = mutacion_intercambio(hijo, prob_mutacion=prob_mutacion)

        # Agregar hijo mutado a la nueva generación
        nueva_generacion.append(hijo_mutado)

    return nueva_generacion


# Ejemplo de uso:
# padres = lista de cromosomas seleccionados con elitismo

nueva_generacion = generar_nueva_generacion(padres, prob_mutacion=0.1)

# Mostrar el tamaño de la nueva generación
print(f"Número de hijos generados: {len(nueva_generacion)}")
# Out:
# Número de hijos generados: 20

# %% [markdown]
# ## 🧬 Formación de nueva población combinando élite y descendencia (herencia controlada)
#
# Esta función consolida una nueva población genética seleccionando los mejores individuos entre los padres (élite) y los hijos generados, garantizando así la **herencia de calidad** y la **diversidad genética** en cada generación.
#
# ### 🧱 ¿Qué hace?
#
# 1. Evalúa el `fitness` de todos los cromosomas: padres + hijos.
# 2. Selecciona los `tamano_poblacion_final` mejores individuos (elitismo global).
# 3. Si faltan individuos, genera nuevos hijos usando crossover + mutación.
# 4. Asegura que la población resultante tenga el tamaño correcto.
#
# ### Parámetros:
# - `padres`: lista de cromosomas seleccionados por elitismo.
# - `hijos`: lista de nuevos cromosomas generados.
# - `tamano_poblacion_final`: tamaño deseado para la siguiente generación.
# - `prob_mutacion`: probabilidad de aplicar mutación a los hijos nuevos.
#
# ### Ventajas:
# - 🧠 Se preservan soluciones de alta calidad generadas previamente.
# - 🔄 Se promueve la exploración del espacio de búsqueda con nuevos cromosomas.
# - 📉 Reduce el riesgo de estancamiento evolutivo manteniendo diversidad genética.
#
# > ⚠️ Esta función **revalúa todo el conjunto** antes de decidir qué individuos conservar, lo que permite ajustes dinámicos por generación.

# %%
# Función para formar la nueva población respetando la herencia genética
def formar_nueva_poblacion_heredada(padres, hijos, tamano_poblacion_final=100, prob_mutacion=0.1):
    # Combinar padres élite y nuevos hijos
    poblacion_completa = padres + hijos

    # Evaluar fitness de la población completa
    fitness_completo = evaluar_fitness_poblacion(poblacion_completa)
    poblacion_fitness = list(zip(poblacion_completa, fitness_completo))

    # Ordenar por fitness de mayor a menor
    poblacion_fitness.sort(key=lambda x: x[1], reverse=True)

    # Seleccionar los mejores cromosomas disponibles
    nueva_poblacion = [individuo for individuo, _ in poblacion_fitness[:tamano_poblacion_final]]

    # Verificar si faltan individuos
    faltantes = tamano_poblacion_final - len(nueva_poblacion)

    # Completar los faltantes con hijos generados mediante crossover y mutación
    if faltantes > 0:
        print(f"🔄 Generando {faltantes} individuos adicionales con crossover entre padres para completar la población.")
        while len(nueva_poblacion) < tamano_poblacion_final:
            padre1, padre2 = random.sample(padres, 2)
            hijo = crossover_hibrido_heuristico_burke(padre1, padre2)
            hijo_mutado = mutacion_intercambio(hijo, prob_mutacion=prob_mutacion)
            nueva_poblacion.append(hijo_mutado)

    # Truncar si por alguna razón se excedió el tamaño
    return nueva_poblacion[:tamano_poblacion_final]

# Ejemplo de uso
nueva_poblacion = formar_nueva_poblacion_heredada(padres, nueva_generacion, tamano_poblacion_final=100, prob_mutacion=0.1)

# Mostrar el tamaño final
print(f"✅ Número total de individuos en la nueva población: {len(nueva_poblacion)}")
# Out:
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
# ✅ Número total de individuos en la nueva población: 100

# %% [markdown]
# ## 📊 Análisis de fitness promedio por nivel educativo (split)
#
# Esta función imprime el **fitness promedio por nivel** (e.g. 1EGB, 2EGB, ..., 3BGU) calculado sobre toda la población. Se utiliza la función `fitness_con_split()`, que descompone el fitness global en subcomponentes por nivel educativo.
#
# ### ¿Qué hace?
#
# 1. Recorre cada cromosoma en la población.
# 2. Calcula el `fitness` por nivel para ese individuo.
# 3. Acumula los scores por nivel y calcula su promedio final.
# 4. Imprime el resultado ordenado.
#
# ### Aplicaciones:
# - 🧠 Permite identificar **niveles problemáticos** que bajan el fitness global.
# - 📉 Apoya decisiones para **focalizar mejoras evolutivas**.
# - 📈 Útil para análisis exploratorio o como criterio para detención anticipada por subgrupo.
#
# > 💡 Complementa perfectamente las gráficas de evolución general, añadiendo un análisis interno por subconjuntos funcionales del problema.

# %%
def imprimir_fitness_por_split(poblacion, alpha=1.0, beta=0.2):
    from collections import defaultdict
    acumulado = defaultdict(float)
    for cromosoma in poblacion:
        _, split_scores = fitness_con_split(cromosoma, alpha, beta)
        for split, valor in split_scores.items():
            acumulado[split] += valor

    print("\n📊 Fitness promedio por nivel:")
    for split, total in acumulado.items():
        promedio = total / len(poblacion)
        print(f"  ➤ {split}: {promedio:.2f}")

# %% [markdown]
# ## 🔁 Ciclo principal de evolución genética multigeneracional
#
# Esta función orquesta el proceso completo de evolución genética para la optimización de horarios escolares, iterando sobre múltiples generaciones con evaluación, selección, cruce, mutación y reemplazo.
#
# ### 🧠 ¿Qué hace esta función?
#
# 1. Inicializa la población con cromosomas candidatos.
# 2. Itera hasta un máximo de `n_generaciones`:
#    - Evalúa fitness total y por nivel (split).
#    - Registra la historia del mejor y promedio fitness.
#    - Imprime e informa el progreso en consola y en archivos de log.
#    - Aplica selección por elitismo, crossover y mutación.
#    - Forma una nueva población respetando el tamaño requerido.
# 3. Devuelve la última población y todos los historiales útiles.
#
# ### Parámetros:
# - `poblacion_inicial`: lista de cromosomas iniciales.
# - `evaluar_fitness_poblacion`: función para calcular fitness general.
# - `evaluar_fitness_poblacion_con_split`: evaluación con desglose por nivel.
# - `seleccionar_padres_elitismo`: función de selección de élite.
# - `generar_nueva_generacion`: función de crossover + mutación.
# - `formar_nueva_poblacion_heredada`: combinación de élite e hijos.
# - `n_generaciones`: número máximo de generaciones (default: 1000).
# - `tamano_poblacion`: tamaño de cada generación.
# - `cantidad_padres`: número de padres para reproducción.
# - `prob_mutacion`: probabilidad de mutación aplicada a los hijos.
# - `ruta_log`, `nombre_log`: para guardar trazabilidad de la evolución.
#
# ### Devuelve:
# - `poblacion`: población final.
# - `historial_mejor_fitness`: evolución del mejor fitness.
# - `historial_fitness_promedio`: evolución del fitness promedio.
# - `fitness_poblacion`: valores de fitness de la última generación.
# - `historial_split_por_generacion`: historial de fitness por nivel educativo.
#
# ### Aplicaciones clave:
# - 📈 Seguimiento detallado del desempeño por generación.
# - 🧬 Evolución progresiva con conservación de soluciones de calidad.
# - 🧪 Control fino sobre cada etapa del proceso evolutivo.
#
# > Esta función constituye el **núcleo operativo** del algoritmo genético aplicado al Educational Timetabling Problem (ECTP).

# %%
from datetime import datetime
from collections import defaultdict
import os

def evolucionar_generaciones_multinivel(
    poblacion_inicial,
    evaluar_fitness_poblacion,
    evaluar_fitness_poblacion_con_split,
    seleccionar_padres_elitismo,
    generar_nueva_generacion,
    formar_nueva_poblacion_heredada,
    n_generaciones=1000,
    tamano_poblacion=1000,
    cantidad_padres=200,
    prob_mutacion=0.1,
    ruta_log=None,
    nombre_log=None
):
    poblacion = poblacion_inicial
    historial_mejor_fitness = []
    historial_fitness_promedio = []
    historial_split_por_generacion = []

    if ruta_log:
        with open(ruta_log, "w", encoding="utf-8") as f:
            f.write(f"📈 Evolución iniciada: {datetime.now()} {nombre_log or ''}\n\n")

    for generacion in range(n_generaciones):
        print(f"\n🚀 Generación {generacion + 1}/{n_generaciones}")

        fitness_poblacion = evaluar_fitness_poblacion(
            poblacion, alpha=1.0, beta=0.2, num_procesos=os.cpu_count()
        )

        # Evaluación por split cada 50 generaciones
        if generacion % 50 == 0:
            _, splits_poblacion = evaluar_fitness_poblacion_con_split(
                poblacion, alpha=1.0, beta=0.2, num_procesos=os.cpu_count()
            )
            acumulado = defaultdict(float)
            cuenta = defaultdict(int)
            for split_dict in splits_poblacion:
                for split, valor in split_dict.items():
                    acumulado[split] += valor
                    cuenta[split] += 1
            promedio_por_split = {
                split: acumulado[split] / cuenta[split]
                for split in acumulado
            }
            historial_split_por_generacion.append(promedio_por_split)

            print(f"\n📊 Resumen fitness por nivel:")
            for nivel, score in promedio_por_split.items():
                print(f"  ➤ {nivel}: {score:.4f}")

            if ruta_log:
                with open(ruta_log, "a", encoding="utf-8") as f:
                    f.write(f"\n📊 Nivel por split - Gen {generacion+1} {nombre_log or ''}:\n")
                    for nivel, score in promedio_por_split.items():
                        f.write(f"  ➤ {nivel}: {score:.4f}\n")

        # Estadísticas principales
        mejor_fitness = max(fitness_poblacion)
        fitness_promedio = sum(fitness_poblacion) / len(fitness_poblacion)
        historial_mejor_fitness.append(mejor_fitness)
        historial_fitness_promedio.append(fitness_promedio)

        print(f"⭐ Mejor fitness: {mejor_fitness:.6f}")
        print(f"📊 Fitness promedio: {fitness_promedio:.6f}")

        if ruta_log:
            with open(ruta_log, "a", encoding="utf-8") as f:
                f.write(f"Gen {generacion+1}: mejor = {mejor_fitness:.5f}, promedio = {fitness_promedio:.5f}\n")

        if ruta_log and (generacion + 1) % 50 == 0:
            top10 = sorted(zip(poblacion, fitness_poblacion), key=lambda x: x[1], reverse=True)[:10]
            with open(ruta_log, "a", encoding="utf-8") as f:
                f.write(f"\n🔟 Top 10 {nombre_log or ''} - Gen {generacion+1}:\n")
                for i, (cromo, fit) in enumerate(top10):
                    f.write(f"#{i+1}: fitness = {fit:.5f} - genes = {len(cromo)}\n")
                    for gen in cromo[:5]:
                        f.write(f"   {gen}\n")
                f.write("\n")

        padres = seleccionar_padres_elitismo(poblacion, fitness_poblacion, cantidad_padres=cantidad_padres)
        hijos = generar_nueva_generacion(padres, prob_mutacion=prob_mutacion)
        poblacion = formar_nueva_poblacion_heredada(
            padres, hijos, tamano_poblacion_final=tamano_poblacion, prob_mutacion=prob_mutacion
        )

    return poblacion, historial_mejor_fitness, historial_fitness_promedio, fitness_poblacion, historial_split_por_generacion

# %% [markdown]
# ## 🏆 Guardado de los 3 mejores cromosomas (Top 3 global)
#
# Esta función selecciona los tres mejores cromosomas de la población final con base en su fitness y los guarda en archivos `.txt` individuales.
#
# ### ¿Qué guarda?
# - La posición del cromosoma en el ranking (`#1`, `#2`, `#3`).
# - Su puntaje de fitness.
# - La secuencia completa de genes (asignaciones horarias).
#
# ### Parámetros:
# - `poblacion_final`: lista de cromosomas resultantes de la evolución.
# - `fitness_final`: lista de valores de fitness asociados.
# - `ruta_salida_base`: carpeta donde se guardarán los archivos.
#
# > 💾 Ideal para conservar las mejores soluciones y analizarlas posteriormente.

# %%
import os

def guardar_top3_cromosomas(poblacion_final, fitness_final, ruta_salida_base):
    top3 = sorted(zip(poblacion_final, fitness_final), key=lambda x: x[1], reverse=True)[:3]
    for i, (cromo, fit) in enumerate(top3, start=1):
        ruta_cromo = os.path.join(ruta_salida_base, f"mejor_GLOBAL_#{i}.txt")
        with open(ruta_cromo, "w", encoding="utf-8") as f:
            f.write(f"# Cromosoma top #{i} GLOBAL - fitness: {fit:.5f}\n")
            for gen in cromo:
                f.write(str(gen) + "\n")

# %% [markdown]
# ## 📈 Registro histórico de la evolución del fitness
#
# Esta función almacena en un archivo `.csv` el comportamiento del fitness a lo largo de las generaciones. Incluye:
# - `Fitness_Max`: mejor score de cada generación.
# - `Fitness_Prom`: score promedio de la población por generación.
# - `Fitness_Min`: el menor valor entre el mejor y promedio (proxy conservador).
#
# ### Parámetros:
# - `hist_mejor`: lista con el mejor fitness por generación.
# - `hist_prom`: lista con el fitness promedio por generación.
# - `ruta_csv`: ruta del archivo donde se guarda el historial.
#
# ### Aplicaciones:
# - 📊 Análisis de convergencia del algoritmo.
# - 🔬 Comparación entre configuraciones evolutivas.
# - 📉 Identificación de estancamiento o mejora progresiva.
#
# > 💡 Este archivo es esencial para construir gráficos de evolución y evaluar la efectividad del algoritmo.

# %%
import pandas as pd

def guardar_evolucion_fitness(hist_mejor, hist_prom, ruta_csv):
    hist_min = [min(m, p) for m, p in zip(hist_mejor, hist_prom)]
    df = pd.DataFrame({
        "Generacion": list(range(1, len(hist_mejor) + 1)),
        "Fitness_Max": hist_mejor,
        "Fitness_Prom": hist_prom,
        "Fitness_Min": hist_min
    })
    df.to_csv(ruta_csv, index=False, encoding="utf-8")
    return df

# %% [markdown]
# ## 🧪 Ejecución principal del algoritmo genético y guardado de resultados
#
# Este bloque ejecuta la función principal de evolución `evolucionar_generaciones_multinivel` y almacena los resultados obtenidos para su posterior análisis.
#
# ### ¿Qué hace?
#
# 1. **Inicializa los parámetros clave**:
#    - Ruta de log para seguimiento de la evolución.
#    - Nombre descriptivo del experimento (e.g., `EVOLUCIÓN COMPLETA MULTINIVEL`).
#
# 2. **Ejecuta la evolución** de la población por 1000 generaciones:
#    - Evalúa fitness general y por nivel.
#    - Aplica selección, crossover y mutación.
#    - Registra el historial de evolución.
#
# 3. **Guarda los resultados**:
#    - `Top 3` de los mejores cromosomas en archivos `.txt`.
#    - Evolución del fitness (`máximo`, `promedio`, `mínimo`) en un archivo `.csv`.
#
# ### Salidas esperadas:
# - `poblacion_final`: cromosomas resultantes tras la evolución.
# - `hist_mejor`: mejor fitness por generación.
# - `hist_prom`: fitness promedio por generación.
# - `fitness_final`: fitness actual de la última generación.
# - `split_hist`: evolución de fitness por nivel.
#
# > 📁 Los resultados son guardados automáticamente en la carpeta `/Tesis_MSDS/logs_evolucion` para su trazabilidad y análisis posterior.

# %%
# ✅ Definir ruta para guardar el log
ruta_log = "/content/drive/MyDrive/Tesis_MSDS/logs_evolucion/evolucion_COMPLETA.txt"
nombre_log = "[EVOLUCIÓN COMPLETA MULTINIVEL]"

# ✅ Llamar a la función
poblacion_final, hist_mejor, hist_prom, fitness_final, split_hist = evolucionar_generaciones_multinivel(
    poblacion_inicial=poblacion_inicial,
    evaluar_fitness_poblacion=evaluar_fitness_poblacion,
    evaluar_fitness_poblacion_con_split=evaluar_fitness_poblacion_con_split,
    seleccionar_padres_elitismo=seleccionar_padres_elitismo,
    generar_nueva_generacion=generar_nueva_generacion,
    formar_nueva_poblacion_heredada=formar_nueva_poblacion_heredada,
    n_generaciones=1000,
    tamano_poblacion=100,
    cantidad_padres=20,
    prob_mutacion=0.1,
    ruta_log=ruta_log,
    nombre_log=nombre_log
)
# ✅ Guardar resultados e histórico
guardar_top3_cromosomas(poblacion_final, fitness_final, "/content/drive/MyDrive/Tesis_MSDS/logs_evolucion")
ruta_csv_fitness = "/content/drive/MyDrive/Tesis_MSDS/logs_evolucion/evolucion_fitness.csv"
df_fitness = guardar_evolucion_fitness(hist_mejor, hist_prom, ruta_csv_fitness)
# Out:
# Streaming output truncated to the last 5000 lines.
#
# 🚀 Generación 55/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016662
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 56/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016486
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 57/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016471
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 58/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016407
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 59/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016492
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 60/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016182
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 61/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016200
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 62/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016591
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 63/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016450
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 64/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016506
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 65/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016464
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 66/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016700
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 67/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016528
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 68/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016464
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 69/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016444
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 70/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016278
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 71/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016420
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 72/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016553
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 73/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016691
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 74/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016444
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 75/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016688
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 76/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016445
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 77/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016615
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 78/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016638
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 79/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016185
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 80/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016464
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 81/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016594
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 82/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016371
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 83/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016176
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 84/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016342
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 85/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016290
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 86/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016338
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 87/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016445
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 88/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016664
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 89/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016401
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 90/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016589
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 91/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016458
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 92/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016140
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 93/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016668
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 94/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016624
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 95/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016499
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 96/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016435
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 97/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016289
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 98/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016481
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 99/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016264
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 100/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016457
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 101/1000
#
# 📊 Resumen fitness por nivel:
#   ➤ 1EGB: 0.8311
#   ➤ 2EGB: 0.8564
#   ➤ 3EGB: 0.9712
#   ➤ 4EGB: 0.9508
#   ➤ 5EGB: 0.9714
#   ➤ 6EGB: 0.9810
#   ➤ 7EGB: 0.9810
#   ➤ 8EGB: 0.9426
#   ➤ 9EGB: 0.9810
#   ➤ 10EGB: 0.9714
#   ➤ 1BGU: 0.9810
#   ➤ 2BGU: 1.0000
#   ➤ 3BGU: 0.9896
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016250
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 102/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016607
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 103/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016425
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 104/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016336
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 105/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016323
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 106/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016589
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 107/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016427
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 108/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016730
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 109/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016444
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 110/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016563
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 111/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016294
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 112/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016578
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 113/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016666
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 114/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016544
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 115/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016473
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 116/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016246
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 117/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016782
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 118/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016207
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 119/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016505
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 120/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016810
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 121/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016412
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 122/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016197
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 123/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016714
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 124/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016404
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 125/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016509
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 126/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016203
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 127/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016411
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 128/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016395
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 129/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016364
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 130/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016368
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 131/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016732
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 132/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016391
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 133/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016744
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 134/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016546
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 135/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016318
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 136/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016492
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 137/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016443
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 138/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016467
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 139/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016411
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 140/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016410
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 141/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016473
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 142/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016485
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 143/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016465
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 144/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016563
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 145/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016399
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 146/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016642
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 147/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016483
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 148/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016520
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 149/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016788
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 150/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016707
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 151/1000
#
# 📊 Resumen fitness por nivel:
#   ➤ 1EGB: 0.8832
#   ➤ 2EGB: 0.8832
#   ➤ 3EGB: 0.9714
#   ➤ 4EGB: 0.9810
#   ➤ 5EGB: 0.9800
#   ➤ 6EGB: 0.9905
#   ➤ 7EGB: 0.9714
#   ➤ 8EGB: 0.9229
#   ➤ 9EGB: 0.9905
#   ➤ 10EGB: 1.0000
#   ➤ 1BGU: 0.9810
#   ➤ 2BGU: 0.9712
#   ➤ 3BGU: 0.9521
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016566
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 152/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016458
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 153/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016436
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 154/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016675
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 155/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016448
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 156/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016512
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 157/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016515
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 158/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016431
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 159/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016261
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 160/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016655
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 161/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016503
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 162/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016632
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 163/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016224
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 164/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016203
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 165/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016263
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 166/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016602
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 167/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016396
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 168/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016563
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 169/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016518
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 170/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016752
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 171/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016532
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 172/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016381
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 173/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016612
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 174/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016333
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 175/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016361
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 176/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016201
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 177/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016742
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 178/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016568
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 179/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.016566
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 180/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017335
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 181/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017996
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 182/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017669
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 183/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017442
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 184/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017725
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 185/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017407
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 186/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017603
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 187/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017531
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 188/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017983
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 189/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017393
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 190/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.018201
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 191/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017788
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 192/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.018041
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 193/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017530
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 194/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017863
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 195/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017597
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 196/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017609
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 197/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017624
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 198/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017939
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 199/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017340
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 200/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017648
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 201/1000
#
# 📊 Resumen fitness por nivel:
#   ➤ 1EGB: 0.8485
#   ➤ 2EGB: 0.8581
#   ➤ 3EGB: 0.9810
#   ➤ 4EGB: 0.9714
#   ➤ 5EGB: 0.9712
#   ➤ 6EGB: 0.9714
#   ➤ 7EGB: 0.9810
#   ➤ 8EGB: 0.9521
#   ➤ 9EGB: 0.9800
#   ➤ 10EGB: 1.0000
#   ➤ 1BGU: 0.9807
#   ➤ 2BGU: 1.0000
#   ➤ 3BGU: 0.9810
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017542
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 202/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017783
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 203/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017624
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 204/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017598
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 205/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017898
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 206/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017598
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 207/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017759
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 208/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017710
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 209/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017380
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 210/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017928
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 211/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017644
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 212/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017703
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 213/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017619
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 214/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017859
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 215/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017572
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 216/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.018122
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 217/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017795
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 218/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017650
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 219/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017666
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 220/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017816
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 221/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017868
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 222/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017806
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 223/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017845
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 224/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017472
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 225/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017322
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 226/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017565
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 227/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017682
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 228/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017471
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 229/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017678
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 230/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017584
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 231/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017610
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 232/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017983
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 233/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.018481
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 234/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017724
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 235/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017716
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 236/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017860
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 237/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.018298
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 238/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017619
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 239/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017838
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 240/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017840
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 241/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017754
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 242/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017417
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 243/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017950
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 244/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017919
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 245/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017894
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 246/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017938
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 247/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017574
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 248/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017416
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 249/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.018075
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 250/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017873
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 251/1000
#
# 📊 Resumen fitness por nivel:
#   ➤ 1EGB: 0.8841
#   ➤ 2EGB: 0.8916
#   ➤ 3EGB: 0.9810
#   ➤ 4EGB: 0.9896
#   ➤ 5EGB: 0.9807
#   ➤ 6EGB: 0.9233
#   ➤ 7EGB: 0.9905
#   ➤ 8EGB: 0.9429
#   ➤ 9EGB: 0.9905
#   ➤ 10EGB: 0.9905
#   ➤ 1BGU: 0.9905
#   ➤ 2BGU: 0.9619
#   ➤ 3BGU: 1.0000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017699
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 252/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017528
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 253/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.018042
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 254/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017757
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 255/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017893
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 256/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017906
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 257/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017786
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 258/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017562
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 259/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017708
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 260/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017822
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 261/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017905
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 262/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017879
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 263/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017677
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 264/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017536
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 265/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017535
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 266/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017457
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 267/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017717
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 268/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017780
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 269/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017769
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 270/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017813
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 271/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017825
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 272/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017540
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 273/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017576
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 274/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017588
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 275/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017907
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 276/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017790
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 277/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017727
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 278/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.018278
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 279/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017634
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 280/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017970
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 281/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017941
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 282/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017295
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 283/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017427
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 284/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017512
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 285/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.018041
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 286/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.018137
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 287/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017739
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 288/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.018214
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 289/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.018137
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 290/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017680
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 291/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.018182
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 292/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017873
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 293/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017748
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 294/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017603
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 295/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017880
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 296/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.018167
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 297/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017460
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 298/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017742
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 299/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017971
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 300/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017938
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 301/1000
#
# 📊 Resumen fitness por nivel:
#   ➤ 1EGB: 0.8490
#   ➤ 2EGB: 0.8658
#   ➤ 3EGB: 0.9714
#   ➤ 4EGB: 0.9810
#   ➤ 5EGB: 0.9807
#   ➤ 6EGB: 0.9238
#   ➤ 7EGB: 0.9905
#   ➤ 8EGB: 0.9619
#   ➤ 9EGB: 0.9905
#   ➤ 10EGB: 0.9810
#   ➤ 1BGU: 0.9710
#   ➤ 2BGU: 0.9905
#   ➤ 3BGU: 0.9905
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017575
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 302/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017656
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 303/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017871
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 304/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017846
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 305/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017798
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 306/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017586
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 307/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017726
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 308/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017750
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 309/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017529
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 310/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017735
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 311/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017943
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 312/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017732
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 313/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017624
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 314/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017743
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 315/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017637
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 316/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.018000
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 317/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017563
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 318/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017337
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 319/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017668
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 320/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.018173
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 321/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.018112
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 322/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017947
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 323/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017589
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 324/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.018140
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 325/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017738
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 326/1000
# ⭐ Mejor fitness: 0.833333
# 📊 Fitness promedio: 0.017648
# ...
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 910/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.441276
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 911/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.414480
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 912/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.431983
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 913/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.344628
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 914/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.378384
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 915/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.370879
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 916/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.422905
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 917/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.441657
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 918/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.380273
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 919/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.384354
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 920/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.354131
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 921/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.351005
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 922/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.360518
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 923/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.407911
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 924/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.381684
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 925/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.380729
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 926/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.459943
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 927/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.405077
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 928/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.378386
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 929/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.432270
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 930/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.371233
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 931/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.379180
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 932/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.413301
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 933/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.389104
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 934/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.398059
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 935/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.407170
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 936/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.423838
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 937/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.387383
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 938/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.414249
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 939/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.451454
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 940/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.343227
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 941/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.390898
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 942/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.404759
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 943/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.432807
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 944/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.380886
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 945/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.372746
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 946/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.381199
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 947/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.379683
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 948/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.379596
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 949/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.451324
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 950/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.397760
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 951/1000
#
# 📊 Resumen fitness por nivel:
#   ➤ 1EGB: 0.9236
#   ➤ 2EGB: 0.8678
#   ➤ 3EGB: 0.9429
#   ➤ 4EGB: 0.9422
#   ➤ 5EGB: 0.9424
#   ➤ 6EGB: 0.9612
#   ➤ 7EGB: 0.9810
#   ➤ 8EGB: 0.9810
#   ➤ 9EGB: 0.9905
#   ➤ 10EGB: 0.9608
#   ➤ 1BGU: 0.9807
#   ➤ 2BGU: 1.0000
#   ➤ 3BGU: 0.9807
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.461788
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 952/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.433356
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 953/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.406983
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 954/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.449366
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 955/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.406488
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 956/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.316868
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 957/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.346522
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 958/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.378853
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 959/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.406952
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 960/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.407029
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 961/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.382905
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 962/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.356780
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 963/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.486164
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 964/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.365645
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 965/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.398383
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 966/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.388500
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 967/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.417541
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 968/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.391866
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 969/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.425811
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 970/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.371830
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 971/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.427444
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 972/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.380714
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 973/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.353504
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 974/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.453094
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 975/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.489663
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 976/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.399515
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 977/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.364366
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 978/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.417231
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 979/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.363910
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 980/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.294412
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 981/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.382342
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 982/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.355461
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 983/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.372792
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 984/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.416269
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 985/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.390137
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 986/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.452715
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 987/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.449214
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 988/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.364993
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 989/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.416181
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 990/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.310154
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 991/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.327832
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 992/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.397638
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 993/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.435541
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 994/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.450961
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 995/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.400505
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 996/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.356734
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 997/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.384244
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 998/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.424905
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 999/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.373773
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.
#
# 🚀 Generación 1000/1000
# ⭐ Mejor fitness: 1.000000
# 📊 Fitness promedio: 0.380790
# 🔄 Generando 60 individuos adicionales con crossover entre padres para completar la población.

# %% [markdown]
# # 🧬 Pipeline del Algoritmo Genético para Generación de Horarios Escolares
#
# Este pipeline resume la implementación completa del algoritmo genético personalizado para resolver el **Educational Course Timetabling Problem (ECTP)** en el contexto del Colegio Lev Vygotsky. Se detalla el flujo modular del código en etapas funcionales.
#
# ---
#
# ## 1. 🎯 Montaje de entorno y carga de datos
# - Montaje de Google Drive.
# - Lectura de archivos CSV: docentes, materias, paralelos, horarios.
#
# ## 2. 🧼 Preprocesamiento de datos
# - Unificación de docentes (e.g., inglés y educación física).
# - Normalización de códigos y separación por materia.
# - Generación del diccionario `dic_profesores`.
#
# ## 3. 🧠 Reglas de negocio y validación horaria
# - Definición de restricciones duras por recesos, almuerzos, clubs, evaluaciones.
# - Validación de horarios disponibles (`es_horario_valido`).
#
# ## 4. 🧱 Generación de cromosomas
# - Asignación de bloques sincronizados (e.g., INGLÉS, EST, DES).
# - Inserción de pares de materias preferidas (DER–COM, SPE–INV, etc.).
# - Relleno final con asignaciones aleatorias válidas.
#
# ## 5. 🧬 Evaluación de fitness
# - Penalizaciones por:
#   - Discontinuidad.
#   - Más de 3 horas seguidas.
#   - Cruces docentes.
#   - Restricciones blandas (medio tiempo, maternidad).
# - Fitness global y desagregado por nivel (`fitness_con_split`).
#
# ## 6. 🌱 Evolución poblacional
# - Generación de población inicial (opcionalmente desde cromosoma histórico).
# - Selección de élite.
# - Crossover híbrido heurístico.
# - Mutación por intercambio dentro de nivel.
# - Formación de nueva población respetando los mejores individuos.
#
# ## 7. 📊 Trazabilidad y visualización
# - Log de evolución generación por generación.
# - Registro del top 3 final.
# - Exportación del historial de fitness a CSV.
#
# ## 8. 🧾 Verificación final
# - Conteo de horas por materia y aula.
# - Reporte de materias faltantes.
# - Evaluación de pares contiguos válidos insertados.
#
# ---
#
# > 🧪 Este pipeline permite experimentar con distintas configuraciones del algoritmo y facilita la trazabilidad completa del proceso evolutivo.
